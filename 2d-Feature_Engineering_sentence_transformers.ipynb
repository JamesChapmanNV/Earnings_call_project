# %% [markdown]
# # Earnings Call Project: Sentence Transformers
# <br>
# CIS 831 Deep Learning – Term Project<br>
# Kansas State University
# <br><br>
# James Chapman<br>
# John Woods<br>
# Nathan Diehl<br>
# <br>

# %% [markdown]
# This notebook featurizes the text data from the earnings calls. [SentenceTransformer](https://www.sbert.net/) from hugging face is used with the following 3 models.
# - [finance-embeddings-investopedia](https://huggingface.co/FinLang/finance-embeddings-investopedia)
# - [bge-m3-financial-matryoshka](https://huggingface.co/haophancs/bge-m3-financial-matryoshka)
# - [bge-base-financial-matryoshka](https://huggingface.co/philschmid/bge-base-financial-matryoshka)
#
# The data from this notebook is stored in the "data/data_prep" directory as the following CSVs.
# - investopedia_features -768 features
# - bge_features -1024 features
# - bge_base_features -768 features

# %%
import pandas as pd
import os
from datetime import datetime
from tqdm import tqdm
from sentence_transformers import SentenceTransformer
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# c:\Users\James\anaconda3\envs\transformers\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
MAEC_dir = 'data/MAEC/MAEC_Dataset' # https://github.com/Earnings-Call-Dataset/MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction

############# too big for GitHub ########################
############# stored on local disk ######################
original_data_dir = r"D:\original_dataset" # https://github.com/GeminiLn/EarningsCall_Dataset 
MAEC_audio_dir = r"D:\MAEC_audio" 
# there is a link for the audio data in the MAEC GitHub, but it does not work
# I emailed the authors, and they send another link.
# There is like a half-million files, but only 19 GB
# https://drive.google.com/file/d/1m1GRCHgKn9Vz9IFMC_SpCog6uP3-gFgY/view?usp=drive_link

# %%
# Loop through the directory, each folder represents an earnings conference call; the folders are named as "CompanyName_Date".
filename_data = []
for filename in os.listdir(original_data_dir):
    company_name, date_str = filename.rsplit('_', 1)
    date_str = date_str.split('.')[0] 
    date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    filename_data.append([company_name, date])
filename_data = pd.DataFrame(filename_data, columns=["Company", "Date"])
company_ticker = pd.read_csv('data/data_prep/company_ticker.csv')
filename_data = filename_data.merge(company_ticker, on="Company", how="left")

# Loop through the directory, each folder represents an earnings conference call; the folders are named as "Date_CompanyName".
MAEC_filename_data = []
for filename in os.listdir(MAEC_dir):
    date_str, ticker = filename.rsplit('_', 1)
    date_str = date_str.split('.')[0] 
    date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    MAEC_filename_data.append([ticker, date])
MAEC_filename_data = pd.DataFrame(MAEC_filename_data, columns=["Ticker", "Date"])

# %%
# model = SentenceTransformer("haophancs/bge-m3-financial-matryoshka") # [, 1024]
# model = SentenceTransformer("philschmid/bge-base-financial-matryoshka") # [, 768]
model = SentenceTransformer("FinLang/finance-embeddings-investopedia") # [, 768]

investopedia_features = pd.DataFrame()
investopedia_error = []
first_iteration = True
for Company, Date in tqdm(filename_data[['Company', 'Date']].values):
    Date = Date.replace('-', '')
    text_path = f"D:/original_dataset/{Company}_{Date}/TextSequence.txt"
    try:
        with open(text_path, 'r', encoding='utf-8', errors='replace') as file:
            for i, line in enumerate(file, start=1):
                sentence_embedding = model.encode(line.strip())
                if first_iteration:
                    print(sentence_embedding.shape)
                    first_iteration = False
                # 768 features 
                features_df = pd.DataFrame([sentence_embedding.flatten()], columns=[f'investopedia_{j}' for j in range(768)])
                features_df['Company'] = Company
                features_df['Date'] = Date
                features_df['Sentence_num'] = i
                investopedia_features = pd.concat([investopedia_features, features_df], ignore_index=True)
    except KeyboardInterrupt: break
    except Exception as e:
        investopedia_error.append((Company, Date, str(e)))

print(len(investopedia_error))
print(investopedia_error)
# Out:
#   0%|          | 0/572 [00:00<?, ?it/s]
# (768,)
# 100%|██████████| 572/572 [1:13:20<00:00,  7.69s/it]
# 0
# []

# %%
investopedia_features.info(verbose=True)
###############################################
investopedia_features.to_csv('data/data_prep/investopedia_features.csv', index=False)
###############################################
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89722 entries, 0 to 89721
# Data columns (total 771 columns):
#  #    Column            Dtype
# ---   ------            -----
#  0    investopedia_0    float32
#  1    investopedia_1    float32
#  2    investopedia_2    float32
#  3    investopedia_3    float32
#  4    investopedia_4    float32
#  5    investopedia_5    float32
#  6    investopedia_6    float32
#  7    investopedia_7    float32
#  8    investopedia_8    float32
#  9    investopedia_9    float32
#  10   investopedia_10   float32
#  11   investopedia_11   float32
#  12   investopedia_12   float32
#  13   investopedia_13   float32
#  14   investopedia_14   float32
#  15   investopedia_15   float32
#  16   investopedia_16   float32
#  17   investopedia_17   float32
#  18   investopedia_18   float32
#  19   investopedia_19   float32
#  20   investopedia_20   float32
#  21   investopedia_21   float32
#  22   investopedia_22   float32
#  23   investopedia_23   float32
#  24   investopedia_24   float32
#  25   investopedia_25   float32
#  26   investopedia_26   float32
#  27   investopedia_27   float32
#  28   investopedia_28   float32
#  29   investopedia_29   float32
#  30   investopedia_30   float32
#  31   investopedia_31   float32
#  32   investopedia_32   float32
#  33   investopedia_33   float32
#  34   investopedia_34   float32
#  35   investopedia_35   float32
#  36   investopedia_36   float32
#  37   investopedia_37   float32
#  38   investopedia_38   float32
#  39   investopedia_39   float32
#  40   investopedia_40   float32
#  41   investopedia_41   float32
#  42   investopedia_42   float32
#  43   investopedia_43   float32
#  44   investopedia_44   float32
#  45   investopedia_45   float32
#  46   investopedia_46   float32
#  47   investopedia_47   float32
#  48   investopedia_48   float32
#  49   investopedia_49   float32
#  50   investopedia_50   float32
#  51   investopedia_51   float32
#  52   investopedia_52   float32
#  53   investopedia_53   float32
#  54   investopedia_54   float32
#  55   investopedia_55   float32
#  56   investopedia_56   float32
#  57   investopedia_57   float32
#  58   investopedia_58   float32
#  59   investopedia_59   float32
#  60   investopedia_60   float32
#  61   investopedia_61   float32
#  62   investopedia_62   float32
#  63   investopedia_63   float32
#  64   investopedia_64   float32
#  65   investopedia_65   float32
#  66   investopedia_66   float32
#  67   investopedia_67   float32
#  68   investopedia_68   float32
#  69   investopedia_69   float32
#  70   investopedia_70   float32
#  71   investopedia_71   float32
#  72   investopedia_72   float32
#  73   investopedia_73   float32
#  74   investopedia_74   float32
#  75   investopedia_75   float32
#  76   investopedia_76   float32
#  77   investopedia_77   float32
#  78   investopedia_78   float32
#  79   investopedia_79   float32
#  80   investopedia_80   float32
#  81   investopedia_81   float32
#  82   investopedia_82   float32
#  83   investopedia_83   float32
#  84   investopedia_84   float32
#  85   investopedia_85   float32
#  86   investopedia_86   float32
#  87   investopedia_87   float32
#  88   investopedia_88   float32
#  89   investopedia_89   float32
#  90   investopedia_90   float32
#  91   investopedia_91   float32
#  92   investopedia_92   float32
#  93   investopedia_93   float32
#  94   investopedia_94   float32
#  95   investopedia_95   float32
#  96   investopedia_96   float32
#  97   investopedia_97   float32
#  98   investopedia_98   float32
#  99   investopedia_99   float32
#  100  investopedia_100  float32
#  101  investopedia_101  float32
#  102  investopedia_102  float32
#  103  investopedia_103  float32
#  104  investopedia_104  float32
#  105  investopedia_105  float32
#  106  investopedia_106  float32
#  107  investopedia_107  float32
#  108  investopedia_108  float32
#  109  investopedia_109  float32
#  110  investopedia_110  float32
#  111  investopedia_111  float32
#  112  investopedia_112  float32
#  113  investopedia_113  float32
#  114  investopedia_114  float32
#  115  investopedia_115  float32
#  116  investopedia_116  float32
#  117  investopedia_117  float32
#  118  investopedia_118  float32
#  119  investopedia_119  float32
#  120  investopedia_120  float32
#  121  investopedia_121  float32
#  122  investopedia_122  float32
#  123  investopedia_123  float32
#  124  investopedia_124  float32
#  460  investopedia_460  float32
#  461  investopedia_461  float32
#  462  investopedia_462  float32
#  463  investopedia_463  float32
#  464  investopedia_464  float32
#  465  investopedia_465  float32
#  466  investopedia_466  float32
#  467  investopedia_467  float32
#  468  investopedia_468  float32
#  469  investopedia_469  float32
#  470  investopedia_470  float32
#  471  investopedia_471  float32
#  472  investopedia_472  float32
#  473  investopedia_473  float32
#  474  investopedia_474  float32
#  475  investopedia_475  float32
#  476  investopedia_476  float32
#  477  investopedia_477  float32
#  478  investopedia_478  float32
#  479  investopedia_479  float32
#  480  investopedia_480  float32
#  481  investopedia_481  float32
#  482  investopedia_482  float32
#  483  investopedia_483  float32
#  484  investopedia_484  float32
#  485  investopedia_485  float32
#  486  investopedia_486  float32
#  487  investopedia_487  float32
#  488  investopedia_488  float32
#  489  investopedia_489  float32
#  490  investopedia_490  float32
#  491  investopedia_491  float32
#  492  investopedia_492  float32
#  493  investopedia_493  float32
#  494  investopedia_494  float32
#  495  investopedia_495  float32
#  496  investopedia_496  float32
#  497  investopedia_497  float32
#  498  investopedia_498  float32
#  499  investopedia_499  float32
#  500  investopedia_500  float32
#  501  investopedia_501  float32
#  502  investopedia_502  float32
#  503  investopedia_503  float32
#  504  investopedia_504  float32
#  505  investopedia_505  float32
#  506  investopedia_506  float32
#  507  investopedia_507  float32
#  508  investopedia_508  float32
#  509  investopedia_509  float32
#  510  investopedia_510  float32
#  511  investopedia_511  float32
#  512  investopedia_512  float32
#  513  investopedia_513  float32
#  514  investopedia_514  float32
#  515  investopedia_515  float32
#  516  investopedia_516  float32
#  517  investopedia_517  float32
#  518  investopedia_518  float32
#  519  investopedia_519  float32
#  520  investopedia_520  float32
#  521  investopedia_521  float32
#  522  investopedia_522  float32
#  523  investopedia_523  float32
#  524  investopedia_524  float32
#  525  investopedia_525  float32
#  526  investopedia_526  float32
#  527  investopedia_527  float32
#  528  investopedia_528  float32
#  529  investopedia_529  float32
#  530  investopedia_530  float32
#  531  investopedia_531  float32
#  532  investopedia_532  float32
#  533  investopedia_533  float32
#  534  investopedia_534  float32
#  535  investopedia_535  float32
#  536  investopedia_536  float32
#  537  investopedia_537  float32
#  538  investopedia_538  float32
#  539  investopedia_539  float32
#  540  investopedia_540  float32
#  541  investopedia_541  float32
#  542  investopedia_542  float32
#  543  investopedia_543  float32
#  544  investopedia_544  float32
#  545  investopedia_545  float32
#  546  investopedia_546  float32
#  547  investopedia_547  float32
#  548  investopedia_548  float32
#  549  investopedia_549  float32
#  550  investopedia_550  float32
#  551  investopedia_551  float32
#  552  investopedia_552  float32
#  553  investopedia_553  float32
#  554  investopedia_554  float32
#  555  investopedia_555  float32
#  556  investopedia_556  float32
#  557  investopedia_557  float32
#  558  investopedia_558  float32
#  559  investopedia_559  float32
#  560  investopedia_560  float32
#  561  investopedia_561  float32
#  562  investopedia_562  float32
#  563  investopedia_563  float32
#  564  investopedia_564  float32
#  565  investopedia_565  float32
#  566  investopedia_566  float32
#  567  investopedia_567  float32
#  568  investopedia_568  float32
#  569  investopedia_569  float32
#  570  investopedia_570  float32
#  571  investopedia_571  float32
#  684  investopedia_684  float32
#  685  investopedia_685  float32
#  686  investopedia_686  float32
#  687  investopedia_687  float32
#  688  investopedia_688  float32
#  689  investopedia_689  float32
#  690  investopedia_690  float32
#  691  investopedia_691  float32
#  692  investopedia_692  float32
#  693  investopedia_693  float32
#  694  investopedia_694  float32
#  695  investopedia_695  float32
#  696  investopedia_696  float32
#  697  investopedia_697  float32
#  698  investopedia_698  float32
#  699  investopedia_699  float32
#  700  investopedia_700  float32
#  701  investopedia_701  float32
#  702  investopedia_702  float32
#  703  investopedia_703  float32
#  704  investopedia_704  float32
#  705  investopedia_705  float32
#  706  investopedia_706  float32
#  707  investopedia_707  float32
#  708  investopedia_708  float32
#  709  investopedia_709  float32
#  710  investopedia_710  float32
#  711  investopedia_711  float32
#  712  investopedia_712  float32
#  713  investopedia_713  float32
#  714  investopedia_714  float32
#  715  investopedia_715  float32
#  716  investopedia_716  float32
#  717  investopedia_717  float32
#  718  investopedia_718  float32
#  719  investopedia_719  float32
#  720  investopedia_720  float32
#  721  investopedia_721  float32
#  722  investopedia_722  float32
#  723  investopedia_723  float32
#  724  investopedia_724  float32
#  725  investopedia_725  float32
#  726  investopedia_726  float32
#  727  investopedia_727  float32
#  728  investopedia_728  float32
#  729  investopedia_729  float32
#  730  investopedia_730  float32
#  731  investopedia_731  float32
#  732  investopedia_732  float32
#  733  investopedia_733  float32
#  734  investopedia_734  float32
#  735  investopedia_735  float32
#  736  investopedia_736  float32
#  737  investopedia_737  float32
#  738  investopedia_738  float32
#  739  investopedia_739  float32
#  740  investopedia_740  float32
#  741  investopedia_741  float32
#  742  investopedia_742  float32
#  743  investopedia_743  float32
#  744  investopedia_744  float32
#  745  investopedia_745  float32
#  746  investopedia_746  float32
#  747  investopedia_747  float32
#  748  investopedia_748  float32
#  749  investopedia_749  float32
#  750  investopedia_750  float32
#  751  investopedia_751  float32
#  752  investopedia_752  float32
#  753  investopedia_753  float32
#  754  investopedia_754  float32
#  755  investopedia_755  float32
#  756  investopedia_756  float32
#  757  investopedia_757  float32
#  758  investopedia_758  float32
#  759  investopedia_759  float32
#  760  investopedia_760  float32
#  761  investopedia_761  float32
#  762  investopedia_762  float32
#  763  investopedia_763  float32
#  764  investopedia_764  float32
#  765  investopedia_765  float32
#  766  investopedia_766  float32
#  767  investopedia_767  float32
#  768  Company           object
#  769  Date              object
#  770  Sentence_num      int64
# dtypes: float32(768), int64(1), object(2)
# memory usage: 264.9+ MB

# %%
model = SentenceTransformer("haophancs/bge-m3-financial-matryoshka") # [, 1024]
# model = SentenceTransformer("philschmid/bge-base-financial-matryoshka") # [, 768]
# model = SentenceTransformer("FinLang/finance-embeddings-investopedia") # [, 768]

bge_features = pd.DataFrame()
bge_error = []
first_iteration = True
for Company, Date in tqdm(filename_data[['Company', 'Date']].values):
    Date = Date.replace('-', '')
    text_path = f"D:/original_dataset/{Company}_{Date}/TextSequence.txt"
    try:
        with open(text_path, 'r', encoding='utf-8', errors='replace') as file:
            for i, line in enumerate(file, start=1):
                sentence_embedding = model.encode(line.strip())
                if first_iteration:
                    print(sentence_embedding.shape)
                    first_iteration = False
                # 1024 features 
                features_df = pd.DataFrame([sentence_embedding.flatten()], columns=[f'bge_{j}' for j in range(1024)])
                features_df['Company'] = Company
                features_df['Date'] = Date
                features_df['Sentence_num'] = i
                bge_features = pd.concat([bge_features, features_df], ignore_index=True)
    except KeyboardInterrupt: break
    except Exception as e:
        bge_error.append((Company, Date, str(e)))

print(len(bge_error))
print(bge_error)
# Out:
#   0%|          | 0/572 [00:00<?, ?it/s]
# (1024,)
# 100%|██████████| 572/572 [1:37:40<00:00, 10.25s/it]
# 0
# []

# %%
bge_features.info(verbose=True)
###############################################
bge_features.to_csv('data/data_prep/bge_features.csv', index=False)
###############################################
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89722 entries, 0 to 89721
# Data columns (total 1027 columns):
#  #     Column        Dtype
# ---    ------        -----
#  0     bge_0         float32
#  1     bge_1         float32
#  2     bge_2         float32
#  3     bge_3         float32
#  4     bge_4         float32
#  5     bge_5         float32
#  6     bge_6         float32
#  7     bge_7         float32
#  8     bge_8         float32
#  9     bge_9         float32
#  10    bge_10        float32
#  11    bge_11        float32
#  12    bge_12        float32
#  13    bge_13        float32
#  14    bge_14        float32
#  15    bge_15        float32
#  16    bge_16        float32
#  17    bge_17        float32
#  18    bge_18        float32
#  19    bge_19        float32
#  20    bge_20        float32
#  21    bge_21        float32
#  22    bge_22        float32
#  23    bge_23        float32
#  24    bge_24        float32
#  25    bge_25        float32
#  26    bge_26        float32
#  27    bge_27        float32
#  28    bge_28        float32
#  29    bge_29        float32
#  30    bge_30        float32
#  31    bge_31        float32
#  32    bge_32        float32
#  33    bge_33        float32
#  34    bge_34        float32
#  35    bge_35        float32
#  36    bge_36        float32
#  37    bge_37        float32
#  38    bge_38        float32
#  39    bge_39        float32
#  40    bge_40        float32
#  41    bge_41        float32
#  42    bge_42        float32
#  43    bge_43        float32
#  44    bge_44        float32
#  45    bge_45        float32
#  46    bge_46        float32
#  47    bge_47        float32
#  48    bge_48        float32
#  49    bge_49        float32
#  50    bge_50        float32
#  51    bge_51        float32
#  52    bge_52        float32
#  53    bge_53        float32
#  54    bge_54        float32
#  55    bge_55        float32
#  56    bge_56        float32
#  57    bge_57        float32
#  58    bge_58        float32
#  59    bge_59        float32
#  60    bge_60        float32
#  61    bge_61        float32
#  62    bge_62        float32
#  63    bge_63        float32
#  64    bge_64        float32
#  65    bge_65        float32
#  66    bge_66        float32
#  67    bge_67        float32
#  68    bge_68        float32
#  69    bge_69        float32
#  70    bge_70        float32
#  71    bge_71        float32
#  72    bge_72        float32
#  73    bge_73        float32
#  74    bge_74        float32
#  75    bge_75        float32
#  76    bge_76        float32
#  77    bge_77        float32
#  78    bge_78        float32
#  79    bge_79        float32
#  80    bge_80        float32
#  81    bge_81        float32
#  82    bge_82        float32
#  83    bge_83        float32
#  84    bge_84        float32
#  85    bge_85        float32
#  86    bge_86        float32
#  87    bge_87        float32
#  88    bge_88        float32
#  89    bge_89        float32
#  90    bge_90        float32
#  91    bge_91        float32
#  92    bge_92        float32
#  93    bge_93        float32
#  94    bge_94        float32
#  95    bge_95        float32
#  96    bge_96        float32
#  97    bge_97        float32
#  98    bge_98        float32
#  99    bge_99        float32
#  100   bge_100       float32
#  101   bge_101       float32
#  102   bge_102       float32
#  103   bge_103       float32
#  104   bge_104       float32
#  105   bge_105       float32
#  106   bge_106       float32
#  107   bge_107       float32
#  108   bge_108       float32
#  109   bge_109       float32
#  110   bge_110       float32
#  111   bge_111       float32
#  112   bge_112       float32
#  113   bge_113       float32
#  114   bge_114       float32
#  115   bge_115       float32
#  116   bge_116       float32
#  117   bge_117       float32
#  118   bge_118       float32
#  119   bge_119       float32
#  120   bge_120       float32
#  121   bge_121       float32
#  122   bge_122       float32
#  123   bge_123       float32
#  124   bge_124       float32
#  125   bge_125       float32
#  126   bge_126       float32
#  127   bge_127       float32
#  128   bge_128       float32
#  129   bge_129       float32
#  130   bge_130       float32
#  131   bge_131       float32
#  132   bge_132       float32
#  133   bge_133       float32
#  134   bge_134       float32
#  135   bge_135       float32
#  136   bge_136       float32
#  137   bge_137       float32
#  138   bge_138       float32
#  139   bge_139       float32
#  140   bge_140       float32
#  141   bge_141       float32
#  142   bge_142       float32
#  143   bge_143       float32
#  144   bge_144       float32
#  145   bge_145       float32
#  146   bge_146       float32
#  147   bge_147       float32
#  148   bge_148       float32
#  149   bge_149       float32
#  150   bge_150       float32
#  151   bge_151       float32
#  152   bge_152       float32
#  153   bge_153       float32
#  154   bge_154       float32
#  155   bge_155       float32
#  156   bge_156       float32
#  157   bge_157       float32
#  158   bge_158       float32
#  159   bge_159       float32
#  160   bge_160       float32
#  161   bge_161       float32
#  162   bge_162       float32
#  163   bge_163       float32
#  164   bge_164       float32
#  165   bge_165       float32
#  166   bge_166       float32
#  167   bge_167       float32
#  168   bge_168       float32
#  169   bge_169       float32
#  170   bge_170       float32
#  171   bge_171       float32
#  172   bge_172       float32
#  173   bge_173       float32
#  174   bge_174       float32
#  175   bge_175       float32
#  176   bge_176       float32
#  177   bge_177       float32
#  178   bge_178       float32
#  179   bge_179       float32
#  180   bge_180       float32
#  181   bge_181       float32
#  182   bge_182       float32
#  183   bge_183       float32
#  184   bge_184       float32
#  185   bge_185       float32
#  186   bge_186       float32
#  187   bge_187       float32
#  188   bge_188       float32
#  189   bge_189       float32
#  190   bge_190       float32
#  191   bge_191       float32
#  192   bge_192       float32
#  193   bge_193       float32
#  194   bge_194       float32
#  195   bge_195       float32
#  196   bge_196       float32
#  197   bge_197       float32
#  198   bge_198       float32
#  199   bge_199       float32
#  200   bge_200       float32
#  201   bge_201       float32
#  202   bge_202       float32
#  203   bge_203       float32
#  204   bge_204       float32
#  205   bge_205       float32
#  206   bge_206       float32
#  207   bge_207       float32
#  208   bge_208       float32
#  209   bge_209       float32
#  210   bge_210       float32
#  211   bge_211       float32
#  212   bge_212       float32
#  213   bge_213       float32
#  214   bge_214       float32
#  215   bge_215       float32
#  216   bge_216       float32
#  217   bge_217       float32
#  218   bge_218       float32
#  219   bge_219       float32
#  220   bge_220       float32
#  221   bge_221       float32
#  222   bge_222       float32
#  223   bge_223       float32
#  224   bge_224       float32
#  225   bge_225       float32
#  226   bge_226       float32
#  227   bge_227       float32
#  228   bge_228       float32
#  229   bge_229       float32
#  230   bge_230       float32
#  231   bge_231       float32
#  232   bge_232       float32
#  233   bge_233       float32
#  234   bge_234       float32
#  235   bge_235       float32
#  236   bge_236       float32
#  237   bge_237       float32
#  238   bge_238       float32
#  239   bge_239       float32
#  240   bge_240       float32
#  241   bge_241       float32
#  242   bge_242       float32
#  243   bge_243       float32
#  244   bge_244       float32
#  245   bge_245       float32
#  246   bge_246       float32
#  247   bge_247       float32
#  248   bge_248       float32
#  249   bge_249       float32
#  250   bge_250       float32
#  251   bge_251       float32
#  252   bge_252       float32
#  253   bge_253       float32
#  254   bge_254       float32
#  255   bge_255       float32
#  256   bge_256       float32
#  257   bge_257       float32
#  258   bge_258       float32
#  259   bge_259       float32
#  260   bge_260       float32
#  261   bge_261       float32
#  262   bge_262       float32
#  263   bge_263       float32
#  264   bge_264       float32
#  265   bge_265       float32
#  266   bge_266       float32
#  267   bge_267       float32
#  268   bge_268       float32
#  269   bge_269       float32
#  270   bge_270       float32
#  271   bge_271       float32
#  272   bge_272       float32
#  273   bge_273       float32
#  274   bge_274       float32
#  275   bge_275       float32
#  276   bge_276       float32
#  277   bge_277       float32
#  278   bge_278       float32
#  279   bge_279       float32
#  280   bge_280       float32
#  281   bge_281       float32
#  282   bge_282       float32
#  283   bge_283       float32
#  284   bge_284       float32
#  285   bge_285       float32
#  286   bge_286       float32
#  287   bge_287       float32
#  288   bge_288       float32
#  289   bge_289       float32
#  290   bge_290       float32
#  291   bge_291       float32
#  292   bge_292       float32
#  293   bge_293       float32
#  294   bge_294       float32
#  295   bge_295       float32
#  296   bge_296       float32
#  297   bge_297       float32
#  298   bge_298       float32
#  299   bge_299       float32
#  300   bge_300       float32
#  301   bge_301       float32
#  302   bge_302       float32
#  303   bge_303       float32
#  304   bge_304       float32
#  305   bge_305       float32
#  306   bge_306       float32
#  307   bge_307       float32
#  308   bge_308       float32
#  309   bge_309       float32
#  310   bge_310       float32
#  311   bge_311       float32
#  312   bge_312       float32
#  313   bge_313       float32
#  314   bge_314       float32
#  315   bge_315       float32
#  316   bge_316       float32
#  317   bge_317       float32
#  318   bge_318       float32
#  319   bge_319       float32
#  320   bge_320       float32
#  321   bge_321       float32
#  322   bge_322       float32
#  323   bge_323       float32
#  324   bge_324       float32
#  325   bge_325       float32
#  326   bge_326       float32
#  327   bge_327       float32
#  328   bge_328       float32
#  329   bge_329       float32
#  330   bge_330       float32
#  331   bge_331       float32
#  332   bge_332       float32
#  333   bge_333       float32
#  334   bge_334       float32
#  335   bge_335       float32
#  336   bge_336       float32
#  337   bge_337       float32
#  338   bge_338       float32
#  339   bge_339       float32
#  340   bge_340       float32
#  341   bge_341       float32
#  342   bge_342       float32
#  343   bge_343       float32
#  344   bge_344       float32
#  345   bge_345       float32
#  346   bge_346       float32
#  347   bge_347       float32
#  348   bge_348       float32
#  349   bge_349       float32
#  350   bge_350       float32
#  351   bge_351       float32
#  352   bge_352       float32
#  353   bge_353       float32
#  354   bge_354       float32
#  355   bge_355       float32
#  356   bge_356       float32
#  357   bge_357       float32
#  358   bge_358       float32
#  359   bge_359       float32
#  360   bge_360       float32
#  361   bge_361       float32
#  362   bge_362       float32
#  363   bge_363       float32
#  364   bge_364       float32
#  365   bge_365       float32
#  366   bge_366       float32
#  367   bge_367       float32
#  368   bge_368       float32
#  369   bge_369       float32
#  370   bge_370       float32
#  371   bge_371       float32
#  372   bge_372       float32
#  373   bge_373       float32
#  374   bge_374       float32
#  375   bge_375       float32
#  376   bge_376       float32
#  377   bge_377       float32
#  378   bge_378       float32
#  379   bge_379       float32
#  380   bge_380       float32
#  381   bge_381       float32
#  382   bge_382       float32
#  383   bge_383       float32
#  384   bge_384       float32
#  385   bge_385       float32
#  386   bge_386       float32
#  387   bge_387       float32
#  388   bge_388       float32
#  389   bge_389       float32
#  390   bge_390       float32
#  391   bge_391       float32
#  392   bge_392       float32
#  393   bge_393       float32
#  394   bge_394       float32
#  395   bge_395       float32
#  396   bge_396       float32
#  397   bge_397       float32
#  398   bge_398       float32
#  399   bge_399       float32
#  400   bge_400       float32
#  401   bge_401       float32
#  402   bge_402       float32
#  403   bge_403       float32
#  404   bge_404       float32
#  405   bge_405       float32
#  406   bge_406       float32
#  407   bge_407       float32
#  408   bge_408       float32
#  409   bge_409       float32
#  410   bge_410       float32
#  411   bge_411       float32
#  412   bge_412       float32
#  413   bge_413       float32
#  414   bge_414       float32
#  415   bge_415       float32
#  416   bge_416       float32
#  417   bge_417       float32
#  418   bge_418       float32
#  419   bge_419       float32
#  420   bge_420       float32
#  421   bge_421       float32
#  422   bge_422       float32
#  423   bge_423       float32
#  424   bge_424       float32
#  425   bge_425       float32
#  426   bge_426       float32
#  427   bge_427       float32
#  428   bge_428       float32
#  429   bge_429       float32
#  430   bge_430       float32
#  431   bge_431       float32
#  432   bge_432       float32
#  433   bge_433       float32
#  434   bge_434       float32
#  435   bge_435       float32
#  436   bge_436       float32
#  437   bge_437       float32
#  438   bge_438       float32
#  439   bge_439       float32
#  440   bge_440       float32
#  441   bge_441       float32
#  442   bge_442       float32
#  443   bge_443       float32
#  444   bge_444       float32
#  445   bge_445       float32
#  446   bge_446       float32
#  447   bge_447       float32
#  448   bge_448       float32
#  449   bge_449       float32
#  450   bge_450       float32
#  451   bge_451       float32
#  452   bge_452       float32
#  453   bge_453       float32
#  454   bge_454       float32
#  455   bge_455       float32
#  456   bge_456       float32
#  457   bge_457       float32
#  458   bge_458       float32
#  459   bge_459       float32
#  460   bge_460       float32
#  461   bge_461       float32
#  462   bge_462       float32
#  463   bge_463       float32
#  464   bge_464       float32
#  465   bge_465       float32
#  466   bge_466       float32
#  467   bge_467       float32
#  468   bge_468       float32
#  469   bge_469       float32
#  470   bge_470       float32
#  471   bge_471       float32
#  472   bge_472       float32
#  473   bge_473       float32
#  474   bge_474       float32
#  475   bge_475       float32
#  476   bge_476       float32
#  477   bge_477       float32
#  478   bge_478       float32
#  479   bge_479       float32
#  480   bge_480       float32
#  481   bge_481       float32
#  482   bge_482       float32
#  483   bge_483       float32
#  484   bge_484       float32
#  485   bge_485       float32
#  486   bge_486       float32
#  487   bge_487       float32
#  488   bge_488       float32
#  489   bge_489       float32
#  490   bge_490       float32
#  491   bge_491       float32
#  492   bge_492       float32
#  493   bge_493       float32
#  494   bge_494       float32
#  495   bge_495       float32
#  496   bge_496       float32
#  497   bge_497       float32
#  498   bge_498       float32
#  499   bge_499       float32
#  500   bge_500       float32
#  501   bge_501       float32
#  502   bge_502       float32
#  503   bge_503       float32
#  504   bge_504       float32
#  505   bge_505       float32
#  506   bge_506       float32
#  507   bge_507       float32
#  508   bge_508       float32
#  509   bge_509       float32
#  510   bge_510       float32
#  511   bge_511       float32
#  512   bge_512       float32
#  513   bge_513       float32
#  514   bge_514       float32
#  515   bge_515       float32
#  516   bge_516       float32
#  517   bge_517       float32
#  518   bge_518       float32
#  519   bge_519       float32
#  520   bge_520       float32
#  521   bge_521       float32
#  522   bge_522       float32
#  523   bge_523       float32
#  524   bge_524       float32
#  525   bge_525       float32
#  526   bge_526       float32
#  527   bge_527       float32
#  528   bge_528       float32
#  529   bge_529       float32
#  530   bge_530       float32
#  531   bge_531       float32
#  532   bge_532       float32
#  533   bge_533       float32
#  534   bge_534       float32
#  535   bge_535       float32
#  536   bge_536       float32
#  537   bge_537       float32
#  538   bge_538       float32
#  539   bge_539       float32
#  540   bge_540       float32
#  541   bge_541       float32
#  542   bge_542       float32
#  543   bge_543       float32
#  544   bge_544       float32
#  545   bge_545       float32
#  546   bge_546       float32
#  547   bge_547       float32
#  548   bge_548       float32
#  549   bge_549       float32
#  550   bge_550       float32
#  551   bge_551       float32
#  552   bge_552       float32
#  553   bge_553       float32
#  554   bge_554       float32
#  555   bge_555       float32
#  556   bge_556       float32
#  557   bge_557       float32
#  558   bge_558       float32
#  559   bge_559       float32
#  560   bge_560       float32
#  561   bge_561       float32
#  562   bge_562       float32
#  563   bge_563       float32
#  564   bge_564       float32
#  565   bge_565       float32
#  566   bge_566       float32
#  567   bge_567       float32
#  568   bge_568       float32
#  569   bge_569       float32
#  570   bge_570       float32
#  571   bge_571       float32
#  572   bge_572       float32
#  573   bge_573       float32
#  574   bge_574       float32
#  575   bge_575       float32
#  576   bge_576       float32
#  577   bge_577       float32
#  578   bge_578       float32
#  579   bge_579       float32
#  580   bge_580       float32
#  581   bge_581       float32
#  582   bge_582       float32
#  583   bge_583       float32
#  584   bge_584       float32
#  585   bge_585       float32
#  586   bge_586       float32
#  587   bge_587       float32
#  588   bge_588       float32
#  589   bge_589       float32
#  590   bge_590       float32
#  591   bge_591       float32
#  592   bge_592       float32
#  593   bge_593       float32
#  594   bge_594       float32
#  595   bge_595       float32
#  596   bge_596       float32
#  597   bge_597       float32
#  598   bge_598       float32
#  599   bge_599       float32
#  600   bge_600       float32
#  601   bge_601       float32
#  602   bge_602       float32
#  603   bge_603       float32
#  604   bge_604       float32
#  605   bge_605       float32
#  606   bge_606       float32
#  607   bge_607       float32
#  608   bge_608       float32
#  609   bge_609       float32
#  610   bge_610       float32
#  611   bge_611       float32
#  612   bge_612       float32
#  613   bge_613       float32
#  614   bge_614       float32
#  615   bge_615       float32
#  616   bge_616       float32
#  617   bge_617       float32
#  618   bge_618       float32
#  619   bge_619       float32
#  620   bge_620       float32
#  621   bge_621       float32
#  622   bge_622       float32
#  623   bge_623       float32
#  624   bge_624       float32
#  625   bge_625       float32
#  626   bge_626       float32
#  627   bge_627       float32
#  628   bge_628       float32
#  629   bge_629       float32
#  630   bge_630       float32
#  631   bge_631       float32
#  632   bge_632       float32
#  633   bge_633       float32
#  634   bge_634       float32
#  635   bge_635       float32
#  636   bge_636       float32
#  637   bge_637       float32
#  638   bge_638       float32
#  639   bge_639       float32
#  640   bge_640       float32
#  641   bge_641       float32
#  642   bge_642       float32
#  643   bge_643       float32
#  644   bge_644       float32
#  645   bge_645       float32
#  646   bge_646       float32
#  647   bge_647       float32
#  648   bge_648       float32
#  649   bge_649       float32
#  650   bge_650       float32
#  651   bge_651       float32
#  652   bge_652       float32
#  653   bge_653       float32
#  654   bge_654       float32
#  655   bge_655       float32
#  656   bge_656       float32
#  657   bge_657       float32
#  658   bge_658       float32
#  659   bge_659       float32
#  660   bge_660       float32
#  661   bge_661       float32
#  662   bge_662       float32
#  663   bge_663       float32
#  664   bge_664       float32
#  665   bge_665       float32
#  666   bge_666       float32
#  667   bge_667       float32
#  668   bge_668       float32
#  669   bge_669       float32
#  670   bge_670       float32
#  671   bge_671       float32
#  672   bge_672       float32
#  673   bge_673       float32
#  674   bge_674       float32
#  675   bge_675       float32
#  676   bge_676       float32
#  677   bge_677       float32
#  678   bge_678       float32
#  679   bge_679       float32
#  680   bge_680       float32
#  681   bge_681       float32
#  682   bge_682       float32
#  683   bge_683       float32
#  684   bge_684       float32
#  685   bge_685       float32
#  686   bge_686       float32
#  687   bge_687       float32
#  688   bge_688       float32
#  689   bge_689       float32
#  690   bge_690       float32
#  691   bge_691       float32
#  692   bge_692       float32
#  693   bge_693       float32
#  694   bge_694       float32
#  695   bge_695       float32
#  696   bge_696       float32
#  697   bge_697       float32
#  698   bge_698       float32
#  699   bge_699       float32
#  700   bge_700       float32
#  701   bge_701       float32
#  702   bge_702       float32
#  703   bge_703       float32
#  704   bge_704       float32
#  705   bge_705       float32
#  706   bge_706       float32
#  707   bge_707       float32
#  708   bge_708       float32
#  709   bge_709       float32
#  710   bge_710       float32
#  711   bge_711       float32
#  712   bge_712       float32
#  713   bge_713       float32
#  714   bge_714       float32
#  715   bge_715       float32
#  716   bge_716       float32
#  717   bge_717       float32
#  718   bge_718       float32
#  719   bge_719       float32
#  720   bge_720       float32
#  721   bge_721       float32
#  722   bge_722       float32
#  723   bge_723       float32
#  724   bge_724       float32
#  725   bge_725       float32
#  726   bge_726       float32
#  727   bge_727       float32
#  728   bge_728       float32
#  729   bge_729       float32
#  730   bge_730       float32
#  731   bge_731       float32
#  732   bge_732       float32
#  733   bge_733       float32
#  734   bge_734       float32
#  735   bge_735       float32
#  736   bge_736       float32
#  737   bge_737       float32
#  738   bge_738       float32
#  739   bge_739       float32
#  740   bge_740       float32
#  741   bge_741       float32
#  742   bge_742       float32
#  743   bge_743       float32
#  744   bge_744       float32
#  745   bge_745       float32
#  746   bge_746       float32
#  747   bge_747       float32
#  748   bge_748       float32
#  749   bge_749       float32
#  750   bge_750       float32
#  751   bge_751       float32
#  752   bge_752       float32
#  753   bge_753       float32
#  754   bge_754       float32
#  755   bge_755       float32
#  756   bge_756       float32
#  757   bge_757       float32
#  758   bge_758       float32
#  759   bge_759       float32
#  760   bge_760       float32
#  761   bge_761       float32
#  762   bge_762       float32
#  763   bge_763       float32
#  764   bge_764       float32
#  765   bge_765       float32
#  766   bge_766       float32
#  767   bge_767       float32
#  768   bge_768       float32
#  769   bge_769       float32
#  770   bge_770       float32
#  771   bge_771       float32
#  772   bge_772       float32
#  773   bge_773       float32
#  774   bge_774       float32
#  775   bge_775       float32
#  776   bge_776       float32
#  777   bge_777       float32
#  778   bge_778       float32
#  779   bge_779       float32
#  780   bge_780       float32
#  781   bge_781       float32
#  782   bge_782       float32
#  783   bge_783       float32
#  784   bge_784       float32
#  785   bge_785       float32
#  786   bge_786       float32
#  787   bge_787       float32
#  788   bge_788       float32
#  789   bge_789       float32
#  790   bge_790       float32
#  791   bge_791       float32
#  792   bge_792       float32
#  793   bge_793       float32
#  794   bge_794       float32
#  795   bge_795       float32
#  796   bge_796       float32
#  797   bge_797       float32
#  798   bge_798       float32
#  799   bge_799       float32
#  800   bge_800       float32
#  801   bge_801       float32
#  802   bge_802       float32
#  803   bge_803       float32
#  804   bge_804       float32
#  805   bge_805       float32
#  806   bge_806       float32
#  807   bge_807       float32
#  808   bge_808       float32
#  809   bge_809       float32
#  810   bge_810       float32
#  811   bge_811       float32
#  812   bge_812       float32
#  813   bge_813       float32
#  814   bge_814       float32
#  815   bge_815       float32
#  816   bge_816       float32
#  817   bge_817       float32
#  818   bge_818       float32
#  819   bge_819       float32
#  820   bge_820       float32
#  821   bge_821       float32
#  822   bge_822       float32
#  823   bge_823       float32
#  824   bge_824       float32
#  825   bge_825       float32
#  826   bge_826       float32
#  827   bge_827       float32
#  828   bge_828       float32
#  829   bge_829       float32
#  830   bge_830       float32
#  831   bge_831       float32
#  832   bge_832       float32
#  833   bge_833       float32
#  834   bge_834       float32
#  835   bge_835       float32
#  836   bge_836       float32
#  837   bge_837       float32
#  838   bge_838       float32
#  839   bge_839       float32
#  840   bge_840       float32
#  841   bge_841       float32
#  842   bge_842       float32
#  843   bge_843       float32
#  844   bge_844       float32
#  845   bge_845       float32
#  846   bge_846       float32
#  847   bge_847       float32
#  848   bge_848       float32
#  849   bge_849       float32
#  850   bge_850       float32
#  851   bge_851       float32
#  852   bge_852       float32
#  853   bge_853       float32
#  854   bge_854       float32
#  855   bge_855       float32
#  856   bge_856       float32
#  857   bge_857       float32
#  858   bge_858       float32
#  859   bge_859       float32
#  860   bge_860       float32
#  861   bge_861       float32
#  862   bge_862       float32
#  863   bge_863       float32
#  864   bge_864       float32
#  865   bge_865       float32
#  866   bge_866       float32
#  867   bge_867       float32
#  868   bge_868       float32
#  869   bge_869       float32
#  870   bge_870       float32
#  871   bge_871       float32
#  872   bge_872       float32
#  873   bge_873       float32
#  874   bge_874       float32
#  875   bge_875       float32
#  876   bge_876       float32
#  877   bge_877       float32
#  878   bge_878       float32
#  879   bge_879       float32
#  880   bge_880       float32
#  881   bge_881       float32
#  882   bge_882       float32
#  883   bge_883       float32
#  884   bge_884       float32
#  885   bge_885       float32
#  886   bge_886       float32
#  887   bge_887       float32
#  888   bge_888       float32
#  889   bge_889       float32
#  890   bge_890       float32
#  891   bge_891       float32
#  892   bge_892       float32
#  893   bge_893       float32
#  894   bge_894       float32
#  895   bge_895       float32
#  896   bge_896       float32
#  897   bge_897       float32
#  898   bge_898       float32
#  899   bge_899       float32
#  900   bge_900       float32
#  901   bge_901       float32
#  902   bge_902       float32
#  903   bge_903       float32
#  904   bge_904       float32
#  905   bge_905       float32
#  906   bge_906       float32
#  907   bge_907       float32
#  908   bge_908       float32
#  909   bge_909       float32
#  910   bge_910       float32
#  911   bge_911       float32
#  912   bge_912       float32
#  913   bge_913       float32
#  914   bge_914       float32
#  915   bge_915       float32
#  916   bge_916       float32
#  917   bge_917       float32
#  918   bge_918       float32
#  919   bge_919       float32
#  920   bge_920       float32
#  921   bge_921       float32
#  922   bge_922       float32
#  923   bge_923       float32
#  924   bge_924       float32
#  925   bge_925       float32
#  926   bge_926       float32
#  927   bge_927       float32
#  928   bge_928       float32
#  929   bge_929       float32
#  930   bge_930       float32
#  931   bge_931       float32
#  932   bge_932       float32
#  933   bge_933       float32
#  934   bge_934       float32
#  935   bge_935       float32
#  936   bge_936       float32
#  937   bge_937       float32
#  938   bge_938       float32
#  939   bge_939       float32
#  940   bge_940       float32
#  941   bge_941       float32
#  942   bge_942       float32
#  943   bge_943       float32
#  944   bge_944       float32
#  945   bge_945       float32
#  946   bge_946       float32
#  947   bge_947       float32
#  948   bge_948       float32
#  949   bge_949       float32
#  950   bge_950       float32
#  951   bge_951       float32
#  952   bge_952       float32
#  953   bge_953       float32
#  954   bge_954       float32
#  955   bge_955       float32
#  956   bge_956       float32
#  957   bge_957       float32
#  958   bge_958       float32
#  959   bge_959       float32
#  960   bge_960       float32
#  961   bge_961       float32
#  962   bge_962       float32
#  963   bge_963       float32
#  964   bge_964       float32
#  965   bge_965       float32
#  966   bge_966       float32
#  967   bge_967       float32
#  968   bge_968       float32
#  969   bge_969       float32
#  970   bge_970       float32
#  971   bge_971       float32
#  972   bge_972       float32
#  973   bge_973       float32
#  974   bge_974       float32
#  975   bge_975       float32
#  976   bge_976       float32
#  977   bge_977       float32
#  978   bge_978       float32
#  979   bge_979       float32
#  980   bge_980       float32
#  981   bge_981       float32
#  982   bge_982       float32
#  983   bge_983       float32
#  984   bge_984       float32
#  985   bge_985       float32
#  986   bge_986       float32
#  987   bge_987       float32
#  988   bge_988       float32
#  989   bge_989       float32
#  990   bge_990       float32
#  991   bge_991       float32
#  992   bge_992       float32
#  993   bge_993       float32
#  994   bge_994       float32
#  995   bge_995       float32
#  996   bge_996       float32
#  997   bge_997       float32
#  998   bge_998       float32
#  999   bge_999       float32
#  1000  bge_1000      float32
#  1001  bge_1001      float32
#  1002  bge_1002      float32
#  1003  bge_1003      float32
#  1004  bge_1004      float32
#  1005  bge_1005      float32
#  1006  bge_1006      float32
#  1007  bge_1007      float32
#  1008  bge_1008      float32
#  1009  bge_1009      float32
#  1010  bge_1010      float32
#  1011  bge_1011      float32
#  1012  bge_1012      float32
#  1013  bge_1013      float32
#  1014  bge_1014      float32
#  1015  bge_1015      float32
#  1016  bge_1016      float32
#  1017  bge_1017      float32
#  1018  bge_1018      float32
#  1019  bge_1019      float32
#  1020  bge_1020      float32
#  1021  bge_1021      float32
#  1022  bge_1022      float32
#  1023  bge_1023      float32
#  1024  Company       object
#  1025  Date          object
#  1026  Sentence_num  int64
# dtypes: float32(1024), int64(1), object(2)
# memory usage: 352.5+ MB

# %%
# model = SentenceTransformer("haophancs/bge-m3-financial-matryoshka") # [, 1024]
model = SentenceTransformer("philschmid/bge-base-financial-matryoshka") # [, 768]
# model = SentenceTransformer("FinLang/finance-embeddings-investopedia") # [, 768]

bge_base_features = pd.DataFrame()
bge_base_error = []
first_iteration = True
for Company, Date in tqdm(filename_data[['Company', 'Date']].values):
    Date = Date.replace('-', '')
    text_path = f"D:/original_dataset/{Company}_{Date}/TextSequence.txt"
    try:
        with open(text_path, 'r', encoding='utf-8', errors='replace') as file:
            for i, line in enumerate(file, start=1):
                sentence_embedding = model.encode(line.strip())
                if first_iteration:
                    print(sentence_embedding.shape)
                    first_iteration = False
                # 768 features 
                features_df = pd.DataFrame([sentence_embedding.flatten()], columns=[f'bge_{j}' for j in range(768)])
                features_df['Company'] = Company
                features_df['Date'] = Date
                features_df['Sentence_num'] = i
                bge_base_features = pd.concat([bge_base_features, features_df], ignore_index=True)
    except KeyboardInterrupt: break
    except Exception as e:
        bge_base_error.append((Company, Date, str(e)))

print(len(bge_base_error))
print(bge_base_error)

# %%
bge_base_features.info(verbose=True)
###############################################
bge_base_features.to_csv('data/data_prep/bge_features.csv', index=False)
###############################################

# %% [markdown]
# # repeat with MAEC

# %%
MACE_RoBERTa_features = pd.DataFrame()
MACE_RoBERTa_error = []
for Ticker, Date in tqdm(MAEC_filename_data[['Ticker', 'Date']].values):
    Date = Date.replace('-', '')
    text_path = f"D:/MAEC_audio/{Date}_{Ticker}/text.txt"
    try:
        with open(text_path, 'r', encoding='utf-8', errors='replace') as file:
            for i, line in enumerate(file, start=1):
                sentence_embedding = get_RoBERTa(line.strip())
                # 1024 features 
                features_df = pd.DataFrame(sentence_embedding, columns=[f'RoBERTa_{j}' for j in range(1024)])
                features_df['Ticker'] = Ticker
                features_df['Date'] = Date
                features_df['Sentence_num'] = i
                MACE_RoBERTa_features = pd.concat([MACE_RoBERTa_features, features_df], ignore_index=True)
    except KeyboardInterrupt: break
    except Exception as e:
        MACE_RoBERTa_error.append((Company, Date, str(e)))

print(len(MACE_RoBERTa_error))
print(MACE_RoBERTa_error)

# %%
# model = SentenceTransformer("haophancs/bge-m3-financial-matryoshka") # [, 1024]
# model = SentenceTransformer("philschmid/bge-base-financial-matryoshka") # [, 768]
model = SentenceTransformer("FinLang/finance-embeddings-investopedia") # [, 768]

MAEC_investopedia_features = pd.DataFrame()
MAEC_investopedia_error = []
first_iteration = True
for Company, Date in tqdm(MAEC_filename_data[['Ticker', 'Date']].values):
    Date = Date.replace('-', '')
    text_path = f"D:/MAEC_audio/{Date}_{Ticker}/text.txt"
    try:
        with open(text_path, 'r', encoding='utf-8', errors='replace') as file:
            for i, line in enumerate(file, start=1):
                sentence_embedding = model.encode(line.strip())
                if first_iteration:
                    print(sentence_embedding.shape)
                    first_iteration = False
                # 768 features 
                features_df = pd.DataFrame([sentence_embedding.flatten()], columns=[f'investopedia_{j}' for j in range(768)])
                features_df['Company'] = Company
                features_df['Date'] = Date
                features_df['Sentence_num'] = i
                investopedia_features = pd.concat([investopedia_features, features_df], ignore_index=True)
    except KeyboardInterrupt: break
    except Exception as e:
        investopedia_error.append((Company, Date, str(e)))

print(len(investopedia_error))
print(investopedia_error)

# %%
investopedia_features.info(verbose=True)
###############################################
investopedia_features.to_csv('data/data_prep/investopedia_features.csv', index=False)
###############################################

# %%
model = SentenceTransformer("haophancs/bge-m3-financial-matryoshka") # [, 1024]
# model = SentenceTransformer("philschmid/bge-base-financial-matryoshka") # [, 768]
# model = SentenceTransformer("FinLang/finance-embeddings-investopedia") # [, 768]

bge_features = pd.DataFrame()
bge_error = []
first_iteration = True
for Company, Date in tqdm(filename_data[['Company', 'Date']].values):
    Date = Date.replace('-', '')
    text_path = f"D:/original_dataset/{Company}_{Date}/TextSequence.txt"
    try:
        with open(text_path, 'r', encoding='utf-8', errors='replace') as file:
            for i, line in enumerate(file, start=1):
                sentence_embedding = model.encode(line.strip())
                if first_iteration:
                    print(sentence_embedding.shape)
                    first_iteration = False
                # 1024 features 
                features_df = pd.DataFrame([sentence_embedding.flatten()], columns=[f'bge_{j}' for j in range(1024)])
                features_df['Company'] = Company
                features_df['Date'] = Date
                features_df['Sentence_num'] = i
                bge_features = pd.concat([bge_features, features_df], ignore_index=True)
    except KeyboardInterrupt: break
    except Exception as e:
        bge_error.append((Company, Date, str(e)))

print(len(bge_error))
print(bge_error)

# %%
bge_features.info(verbose=True)
###############################################
bge_features.to_csv('data/data_prep/bge_features.csv', index=False)
###############################################

# %%
# model = SentenceTransformer("haophancs/bge-m3-financial-matryoshka") # [, 1024]
model = SentenceTransformer("philschmid/bge-base-financial-matryoshka") # [, 768]
# model = SentenceTransformer("FinLang/finance-embeddings-investopedia") # [, 768]

bge_base_features = pd.DataFrame()
bge_base_error = []
first_iteration = True
for Company, Date in tqdm(filename_data[['Company', 'Date']].values):
    Date = Date.replace('-', '')
    text_path = f"D:/original_dataset/{Company}_{Date}/TextSequence.txt"
    try:
        with open(text_path, 'r', encoding='utf-8', errors='replace') as file:
            for i, line in enumerate(file, start=1):
                sentence_embedding = model.encode(line.strip())
                if first_iteration:
                    print(sentence_embedding.shape)
                    first_iteration = False
                # 768 features 
                features_df = pd.DataFrame([sentence_embedding.flatten()], columns=[f'bge_{j}' for j in range(768)])
                features_df['Company'] = Company
                features_df['Date'] = Date
                features_df['Sentence_num'] = i
                bge_base_features = pd.concat([bge_base_features, features_df], ignore_index=True)
    except KeyboardInterrupt: break
    except Exception as e:
        bge_base_error.append((Company, Date, str(e)))

print(len(bge_base_error))
print(bge_base_error)

# %%
bge_base_features.info(verbose=True)
###############################################
bge_base_features.to_csv('data/data_prep/bge_features.csv', index=False)
###############################################
