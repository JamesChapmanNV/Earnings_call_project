# %% [markdown]
# # Earnings Call Project: Data Cleaning
# <br>
# CIS 831 Deep Learning – Term Project<br>
# Kansas State University
# <br><br>
# James Chapman<br>
# John Woods<br>
# Nathan Diehl<br>
# <br>

# %% [markdown]
# This notebook creates data used for training/testing.
# - Calculates the targets for both datasets
# - Corrects Praat features for both datasets
# - Combines features (Glove & Praat) or (RoBERTa & Praat) and targets
# - save 9 numpy files specifically for HTML (RoBERTa & Praat)
#     - train (features, targets, secondary_targets)
#     - validation (features, targets, secondary_targets)
#     - test (features, targets, secondary_targets)
# - it is important to note 7 meetings were removed because we could not find stock data (Yahoo or alphadvantage)<br>
# - 218 meetings were removed from MAEC <br>
#
# The rest data from this notebook is stored in the "data" directory as the following CSVs
# - original_dataset
# - MAEC_dataset

# %%
import sys
IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    # !pip install yfinance
    from google.colab import drive
    drive.mount('/content/gdrive')
    # %cd gdrive/My Drive/831

# %%
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import re
import os
from datetime import datetime
from tqdm import tqdm

tqdm.pandas()

# %%
MAEC_dir = 'data/MAEC/MAEC_Dataset' # https://github.com/Earnings-Call-Dataset/MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction

############# too big for GitHub ########################
############# stored on local disk ######################
original_data_dir = r"D:\original_dataset" # https://github.com/GeminiLn/EarningsCall_Dataset 
MAEC_audio_dir = r"D:\MAEC_audio" 
# there is a link for the audio data in the MAEC GitHub, but it does not work
# I emailed the authors, and they send another link.
# There is like a half-million files, but only 19 GB
# https://drive.google.com/file/d/1m1GRCHgKn9Vz9IFMC_SpCog6uP3-gFgY/view?usp=drive_link 

# from Webscraping
alpha_dir = 'data/data_prep/alpha_data/{}.csv' #.format(ticker) # I saved the raw alphadvantage data, so I don't have to do it again
yahoo_data = pd.read_csv('data/data_prep/yahoo_data.csv', index_col=0)
alpha_data = pd.read_csv('data/data_prep/alpha_data.csv', index_col=0)
MAEC_yahoo_data = pd.read_csv('data/data_prep/MAEC_yahoo_data.csv', index_col=0)
MAEC_alpha_data = pd.read_csv('data/data_prep/MAEC_alpha_data.csv', index_col=0)

yahoo_data.index = pd.to_datetime(yahoo_data.index)
alpha_data.index = pd.to_datetime(alpha_data.index)
MAEC_yahoo_data.index = pd.to_datetime(MAEC_yahoo_data.index)
MAEC_alpha_data.index = pd.to_datetime(MAEC_alpha_data.index)

# from Feature Engineering
glove_features = pd.read_csv('data/data_prep/glove_features.csv')
praat_features = pd.read_csv('data/data_prep/praat_features.csv', low_memory=False)
MAEC_glove_features = pd.read_csv('data/data_prep/MAEC_glove_features.csv')
MAEC_praat_features = pd.read_csv('data/data_prep/MAEC_praat_features.csv', low_memory=False)

# from Feature Engineering RoBERTa
RoBERTa_features = pd.read_csv('data/data_prep/RoBERTa_features.csv', low_memory=False)
# MACE_RoBERTa_features = pd.read_csv('data/data_prep/MACE_RoBERTa_features.csv', low_memory=False)

# %%
# Loop through the directory, each folder represents an earnings conference call; the folders are named as "CompanyName_Date".
filename_data = []
for filename in os.listdir(original_data_dir):
    company_name, date_str = filename.rsplit('_', 1)
    date_str = date_str.split('.')[0] 
    date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    filename_data.append([company_name, date])
filename_data = pd.DataFrame(filename_data, columns=["Company", "Date"])
company_ticker = pd.read_csv('data/data_prep/company_ticker.csv')
filename_data = filename_data.merge(company_ticker, on="Company", how="left")

# Loop through the directory, each folder represents an earnings conference call; the folders are named as "Date_CompanyName".
MAEC_filename_data = []
for filename in os.listdir(MAEC_dir):
    date_str, ticker = filename.rsplit('_', 1)
    date_str = date_str.split('.')[0] 
    date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    MAEC_filename_data.append([ticker, date])
MAEC_filename_data = pd.DataFrame(MAEC_filename_data, columns=["Ticker", "Date"])

# %%
filename_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  572 non-null    object
#  1   Date     572 non-null    object
#  2   Ticker   572 non-null    object
# dtypes: object(3)
# memory usage: 13.5+ KB

# %% [markdown]
# # Add TARGET of the regression
#
# **n-day volatility predictions**: The predicted average volatility over the following n days.<br>
#
# $$
# v[0,n] = \ln \left( \sqrt{ \frac{1}{n} \sum_{i=1}^{n} (r_i - \bar{r})^2 } \right)
# $$
#
# Where:
# - \( r_i \) is the stock return on day \(i\),
# - \( \bar{r} \) is the average stock return over \(n\) days.
#
# The stock return \(r_i\) is defined as:
#
# $$
# r_i = \frac{P_i - P_{i-1}}{P_{i-1}}
# $$
#
# Where \(P_i\) is the adjusted closing price of the stock on day \(i\).
#
# For **single-day log volatility**, we estimate it using the **daily log absolute return**:
#
# $$
# v_n = \ln \left( \left| \frac{P_n - P_{n-1}}{P_{n-1}} \right| \right)
# $$
#
# Where:
# - \(P_n\) is the adjusted closing price of the stock on day \(n\),
# - \(P_{n-1}\) is the adjusted closing price on the previous day.
#
# Our multi-task learning objective is to **simultaneously predict** these two quantities:
# - \(v[0,n]\): The average volatility over \(n\) days (the main task).
# - \(v_n\): The single-day volatility (the auxiliary task).

# %%
targets = filename_data.copy()

# Yahoo (missing 9 companies)
def add_n_day(row, n_day):
    Ticker = row['Ticker']
    if Ticker in ['GGP', 'CA', 'STI', 'FLT', 'NLSN', 'WRK','RTN', 'UTX', 'DISH']:
        return float('inf'), float('inf')
    Date = pd.to_datetime(row['Date'])
    Date_index = yahoo_data.index.get_loc(Date)
    data = yahoo_data.iloc[Date_index:(Date_index + n_day)][f"{Ticker}_Adj Close"]  
    # # calendar days? 
    # start = Date # - pd.Timedelta(days=(1))
    # end = Date + pd.Timedelta(days=(n_day))
    # data = yahoo_data.loc[start:end, f"{Ticker}_Adj Close"]  
    stock_return = data.pct_change().dropna() # ri =(Pi − Pi−1)/Pi−1
    std_dev = stock_return.std()
    if pd.isna(std_dev) or std_dev == 0:
        return 0, 0
    else:
        return np.log(std_dev), np.log(abs(stock_return.iloc[-1]) + 1e-10) #log 0 is undefined

targets['3_day'], targets['3_day_single'] = zip(*targets.apply(lambda row: add_n_day(row, 3), axis=1))
targets['7_day'], targets['7_day_single'] = zip(*targets.apply(lambda row: add_n_day(row, 7), axis=1))
targets['15_day'], targets['15_day_single'] = zip(*targets.apply(lambda row: add_n_day(row, 15), axis=1))
targets['30_day'], targets['30_day_single'] = zip(*targets.apply(lambda row: add_n_day(row, 30), axis=1))
targets.info(verbose=True)
targets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        572 non-null    object
#  1   Date           572 non-null    object
#  2   Ticker         572 non-null    object
#  3   3_day          572 non-null    float64
#  4   3_day_single   572 non-null    float64
#  5   7_day          572 non-null    float64
#  6   7_day_single   572 non-null    float64
#  7   15_day         572 non-null    float64
#  8   15_day_single  572 non-null    float64
#  9   30_day         572 non-null    float64
#  10  30_day_single  572 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 49.3+ KB
#                  Company        Date Ticker     3_day  3_day_single     7_day  \
# 0             3M Company  2017-04-25    MMM -5.404551     -5.168630 -5.227834
# 1             3M Company  2017-07-25    MMM -5.318414     -5.273632 -5.186644
# 2        A.O. Smith Corp  2017-07-26    AOS -4.988524     -4.954916 -4.684553
# 3    Abbott Laboratories  2017-10-18    ABT -6.790460     -5.164792 -5.008287
# 4            AbbVie Inc.  2017-04-27   ABBV -4.936198     -4.804931 -5.347910
# ..                   ...         ...    ...       ...           ...       ...
# 567                Xerox  2017-08-01    XRX -4.445102     -4.281294 -4.816060
# 568               Xilinx  2017-04-26    AMD -3.586806     -3.750975 -2.295418
# 569             XL Group  2017-10-24    AXS -4.062756     -3.593155 -4.458956
# 570      Yum! Brands Inc  2017-02-09    YUM -5.248287     -6.426674 -5.382302
# 571      Yum! Brands Inc  2017-08-03    YUM -6.223240     -7.536442 -4.930233
#
#      7_day_single    15_day  15_day_single    30_day  30_day_single
# 0       -5.185492 -5.259718      -5.222715 -5.102879      -5.539662
# 1       -4.512109 -5.216313      -4.998475 -5.094012      -4.368167
# 2       -5.768826 -4.814348      -5.552145 -4.790013      -8.623037
# 3       -8.621272 -4.663901      -5.904620 -4.776023      -4.846676
# 4       -5.635156 -4.685676      -3.810418 -4.899575      -8.837683
# ..            ...       ...            ...       ...            ...
# 567     -8.079787 -4.456054      -4.962510 -4.514521      -3.768720
# 568     -3.578718 -2.547102      -2.150187 -2.800488      -3.537225
# 569     -7.907852 -4.724728      -4.653762 -4.581437      -4.306009
# 570     -7.444556 -4.815293      -5.204771 -5.058510      -6.114364
# 571     -5.931825 -4.995031      -6.304044 -5.041857      -7.851151
#
# [572 rows x 11 columns]

# %%
# using alphadvantage 
def add_n_day(row, n_day):
    Ticker = row['Ticker']
    Date = pd.to_datetime(row['Date'])
    Date_index = alpha_data.index.get_loc(Date)
    data = alpha_data.iloc[Date_index:(Date_index + n_day)][Ticker]  
    # # calendar days
    # start = Date #- pd.Timedelta(days=1)
    # end = Date + pd.Timedelta(days=n_day)
    # data = alpha_data.loc[start:end, Ticker]
    stock_return = data.pct_change().dropna() # ri =(Pi − Pi−1)/Pi−1
    std_dev = stock_return.std()
    if pd.isna(std_dev) or std_dev == 0:
        return 0, 0
    else:
        return np.log(std_dev), np.log(abs(stock_return.iloc[-1]) + 1e-10)

targets['3_day_alpha'], targets['3_day_single_alpha'] = zip(*targets.apply(lambda row: add_n_day(row, 3), axis=1))
targets['7_day_alpha'], targets['7_day_single_alpha'] = zip(*targets.apply(lambda row: add_n_day(row, 7), axis=1))
targets['15_day_alpha'], targets['15_day_single_alpha'] = zip(*targets.apply(lambda row: add_n_day(row, 15), axis=1))
targets['30_day_alpha'], targets['30_day_single_alpha'] = zip(*targets.apply(lambda row: add_n_day(row, 30), axis=1))

# %% [markdown]
# Here I am comparing the Yahoo data to alphadvantage. Why is there a difference? How does each calculate dividend adjustment?

# %%
targets['3_day_diff'] = targets['3_day_alpha'] - targets['3_day']
targets['7_day_diff'] = targets['7_day_alpha'] - targets['7_day']
targets['15_day_diff'] = targets['15_day_alpha'] - targets['15_day']
targets['30_day_diff'] = targets['30_day_alpha'] - targets['30_day']

targets['3_day_pct_change'] = abs(((targets['3_day_alpha'] - targets['3_day']) / targets['3_day_alpha']) * 100)
targets['7_day_pct_change'] = abs(((targets['7_day_alpha'] - targets['7_day']) / targets['7_day_alpha']) * 100)
targets['15_day_pct_change'] = abs(((targets['15_day_alpha'] - targets['15_day']) / targets['15_day_alpha']) * 100)
targets['30_day_pct_change'] = abs(((targets['30_day_alpha'] - targets['30_day']) / targets['30_day_alpha']) * 100)
 
targets['3_day_single_diff'] = targets['3_day_single_alpha'] - targets['3_day_single']
targets['7_day_single_diff'] = targets['7_day_single_alpha'] - targets['7_day_single']
targets['15_day_single_diff'] = targets['15_day_single_alpha'] - targets['15_day_single']
targets['30_day_single_diff'] = targets['30_day_single_alpha'] - targets['30_day_single']

targets['3_day_single_pct_change'] = abs(((targets['3_day_single_alpha'] - targets['3_day_single']) / targets['3_day_single_alpha']) * 100)
targets['7_day_single_pct_change'] = abs(((targets['7_day_single_alpha'] - targets['7_day_single']) / targets['7_day_single_alpha']) * 100)
targets['15_day_single_pct_change'] = abs(((targets['15_day_single_alpha'] - targets['15_day_single']) / targets['15_day_single_alpha']) * 100)
targets['30_day_single_pct_change'] = abs(((targets['30_day_single_alpha'] - targets['30_day_single']) / targets['30_day_single_alpha']) * 100)

# investigate discrepancies
targets = targets.sort_values(by='30_day_pct_change', ascending=False)
targets = targets.sort_values(by='30_day_single_pct_change', ascending=False)
targets.to_csv('data/data_prep/temp.csv', index=False)

# %%
# Change Yahoo errors to the values found with alphadvantage 
targets['3_day_single'] = np.where(targets['3_day'] == float('inf'), targets['3_day_single_alpha'], targets['3_day_single'])
targets['7_day_single'] = np.where(targets['7_day'] == float('inf'), targets['7_day_single_alpha'], targets['7_day_single'])
targets['15_day_single'] = np.where(targets['15_day'] == float('inf'), targets['15_day_single_alpha'], targets['15_day_single'])
targets['30_day_single'] = np.where(targets['30_day'] == float('inf'), targets['30_day_single_alpha'], targets['30_day_single'])
targets['3_day'] = np.where(targets['3_day'] == float('inf'), targets['3_day_alpha'], targets['3_day'])
targets['7_day'] = np.where(targets['7_day'] == float('inf'), targets['7_day_alpha'], targets['7_day'])
targets['15_day'] = np.where(targets['15_day'] == float('inf'), targets['15_day_alpha'], targets['15_day'])
targets['30_day'] = np.where(targets['30_day'] == float('inf'), targets['30_day_alpha'], targets['30_day'])

targets['3_day_single'] = np.where(targets['3_day'] == 0, targets['3_day_single_alpha'], targets['3_day_single'])
targets['7_day_single'] = np.where(targets['7_day'] == 0, targets['7_day_single_alpha'], targets['7_day_single'])
targets['15_day_single'] = np.where(targets['15_day'] == 0, targets['15_day_single_alpha'], targets['15_day_single'])
targets['30_day_single'] = np.where(targets['30_day'] == 0, targets['30_day_single_alpha'], targets['30_day_single'])
targets['3_day'] = np.where(targets['3_day'] == 0, targets['3_day_alpha'], targets['3_day'])
targets['7_day'] = np.where(targets['7_day'] == 0, targets['7_day_alpha'], targets['7_day'])
targets['15_day'] = np.where(targets['15_day'] == 0, targets['15_day_alpha'], targets['15_day'])
targets['30_day'] = np.where(targets['30_day'] == 0, targets['30_day_alpha'], targets['30_day'])

print('Number of rows without data-', len(targets[((targets['3_day'] == 0) & 
                                                    (targets['7_day'] == 0) & 
                                                    (targets['15_day'] == 0) & 
                                                    (targets['30_day'] == 0))]))
print('----------------------------------------------------------------------')

# delete?
# targets = targets[~((targets['3_day'] == 0) & 
#                 (targets['7_day'] == 0) & 
#                 (targets['15_day'] == 0) & 
#                 (targets['30_day'] == 0))]
# Out:
# Number of rows without data- 7
# ----------------------------------------------------------------------

# %%
targets = targets.drop(['3_day_alpha', '3_day_single_alpha', '7_day_alpha', '7_day_single_alpha', '15_day_alpha', 
                        '15_day_single_alpha', '30_day_alpha', '30_day_single_alpha', '3_day_diff', '7_day_diff', 
                        '15_day_diff', '30_day_diff', '3_day_pct_change', '7_day_pct_change', '15_day_pct_change', 
                        '30_day_pct_change', '3_day_single_diff', '7_day_single_diff', '15_day_single_diff', 
                        '30_day_single_diff', '3_day_single_pct_change', '7_day_single_pct_change', 
                        '15_day_single_pct_change', '30_day_single_pct_change'], axis=1)
targets = targets.sort_values(by='3_day', ascending=True)
targets.info(verbose=True)
### save ############################################
targets.to_csv('data/data_prep/targets.csv', index=False)
#####################################################
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 572 entries, 37 to 273
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        572 non-null    object
#  1   Date           572 non-null    object
#  2   Ticker         572 non-null    object
#  3   3_day          572 non-null    float64
#  4   3_day_single   572 non-null    float64
#  5   7_day          572 non-null    float64
#  6   7_day_single   572 non-null    float64
#  7   15_day         572 non-null    float64
#  8   15_day_single  572 non-null    float64
#  9   30_day         572 non-null    float64
#  10  30_day_single  572 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 53.6+ KB

# %% [markdown]
# # MAEC dataset TARGETS
#
# [paper](https://dl.acm.org/doi/10.1145/3340531.3412879)
# [GitHub](https://github.com/Earnings-Call-Dataset/MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction/tree/master)

# %%
MAEC_targets = MAEC_filename_data.copy()

# Yahoo (missing 9 companies)
def add_n_day(row, n_day):
    Ticker = row['Ticker']
    Date = pd.to_datetime(row['Date'])
    Date_index = MAEC_yahoo_data.index.get_loc(Date)
    data = MAEC_yahoo_data.iloc[Date_index:(Date_index + n_day)][f"{Ticker}_Adj Close"]  
    # # calendar days? 
    # start = Date # - pd.Timedelta(days=(1))
    # end = Date + pd.Timedelta(days=(n_day))
    # data = MAEC_yahoo_data.loc[start:end, f"{Ticker}_Adj Close"]  
    stock_return = data.pct_change().dropna() # ri =(Pi − Pi−1)/Pi−1
    std_dev = stock_return.std()
    if pd.isna(std_dev) or std_dev == 0:
        return 0, 0
    else:
        return np.log(std_dev), np.log(abs(stock_return.iloc[-1]) + 1e-10)

MAEC_targets['3_day'], MAEC_targets['3_day_single'] = zip(*MAEC_targets.apply(lambda row: add_n_day(row, 3), axis=1))
MAEC_targets['7_day'], MAEC_targets['7_day_single'] = zip(*MAEC_targets.apply(lambda row: add_n_day(row, 7), axis=1))
MAEC_targets['15_day'], MAEC_targets['15_day_single'] = zip(*MAEC_targets.apply(lambda row: add_n_day(row, 15), axis=1))
MAEC_targets['30_day'], MAEC_targets['30_day_single'] = zip(*MAEC_targets.apply(lambda row: add_n_day(row, 30), axis=1))
MAEC_targets.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3443 entries, 0 to 3442
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ticker         3443 non-null   object
#  1   Date           3443 non-null   object
#  2   3_day          3443 non-null   float64
#  3   3_day_single   3443 non-null   float64
#  4   7_day          3443 non-null   float64
#  5   7_day_single   3443 non-null   float64
#  6   15_day         3443 non-null   float64
#  7   15_day_single  3443 non-null   float64
#  8   30_day         3443 non-null   float64
#  9   30_day_single  3443 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 269.1+ KB

# %%
# 58 tickers that did not return data from alphadvantage
bad_tickers = ['GPS', 'JCP', 'TUP', 'BBT', 'MDP', 'LL', 'ABC', 'PKI', 'HFC', 'HSC', 'CBB', 'ILG', 'JCOM', 'EBIX', 'ENDP', 
               'BIG', 'ASNA', 'IVC', 'BCOR', 'INT', 'FRED', 'CAMP', 'ELY', 'COG', 'CLD', 'CRY', 'PLT', 'FRAN', 'ADS', 'CPSI', 
               'FBHS', 'CHFC', 'UIHC', 'OFC', 'TMST', 'FTD', 'SWM', 'WPG', 'WLTW', 'AKRX', 'BLL', 'DF', 'TLRD', 'SPN', 'CLI', 
               'ESV', 'RCII', 'ANTM', 'RE', 'NCR', 'NEWM', 'PEI', 'LCI', 'ERA', 'ACOR', 'FB', 'AAXN', 'NLS']
def add_n_day(row, n_day):
    Ticker = row['Ticker']
    if Ticker in bad_tickers:
        return float('inf'), float('inf')
    Date = pd.to_datetime(row['Date'])
    Date_index = MAEC_alpha_data.index.get_loc(Date)
    data = MAEC_alpha_data.iloc[Date_index:(Date_index + n_day)][Ticker]  
    # # calendar days
    # start = Date #- pd.Timedelta(days=1)
    # end = Date + pd.Timedelta(days=n_day)
    # data = alpha_data.loc[start:end, Ticker]
    stock_return = data.pct_change().dropna() # ri =(Pi − Pi−1)/Pi−1
    std_dev = stock_return.std()
    if pd.isna(std_dev) or std_dev == 0:
        return 0, 0
    else:
        return np.log(std_dev), np.log(abs(stock_return.iloc[-1]) + 1e-10)

MAEC_targets['3_day_alpha'], MAEC_targets['3_day_single_alpha'] = zip(*MAEC_targets.apply(lambda row: add_n_day(row, 3), axis=1))
MAEC_targets['7_day_alpha'], MAEC_targets['7_day_single_alpha'] = zip(*MAEC_targets.apply(lambda row: add_n_day(row, 7), axis=1))
MAEC_targets['15_day_alpha'], MAEC_targets['15_day_single_alpha'] = zip(*MAEC_targets.apply(lambda row: add_n_day(row, 15), axis=1))
MAEC_targets['30_day_alpha'], MAEC_targets['30_day_single_alpha'] = zip(*MAEC_targets.apply(lambda row: add_n_day(row, 30), axis=1))

# %%
MAEC_targets['3_day_diff'] = MAEC_targets['3_day_alpha'] - MAEC_targets['3_day']
MAEC_targets['7_day_diff'] = MAEC_targets['7_day_alpha'] - MAEC_targets['7_day']
MAEC_targets['15_day_diff'] = MAEC_targets['15_day_alpha'] - MAEC_targets['15_day']
MAEC_targets['30_day_diff'] = MAEC_targets['30_day_alpha'] - MAEC_targets['30_day']

MAEC_targets['3_day_pct_change'] = abs(((MAEC_targets['3_day_alpha'] - MAEC_targets['3_day']) / MAEC_targets['3_day_alpha']) * 100)
MAEC_targets['7_day_pct_change'] = abs(((MAEC_targets['7_day_alpha'] - MAEC_targets['7_day']) / MAEC_targets['7_day_alpha']) * 100)
MAEC_targets['15_day_pct_change'] = abs(((MAEC_targets['15_day_alpha'] - MAEC_targets['15_day']) / MAEC_targets['15_day_alpha']) * 100)
MAEC_targets['30_day_pct_change'] = abs(((MAEC_targets['30_day_alpha'] - MAEC_targets['30_day']) / MAEC_targets['30_day_alpha']) * 100)
 
MAEC_targets['3_day_single_diff'] = MAEC_targets['3_day_single_alpha'] - MAEC_targets['3_day_single']
MAEC_targets['7_day_single_diff'] = MAEC_targets['7_day_single_alpha'] - MAEC_targets['7_day_single']
MAEC_targets['15_day_single_diff'] = MAEC_targets['15_day_single_alpha'] - MAEC_targets['15_day_single']
MAEC_targets['30_day_single_diff'] = MAEC_targets['30_day_single_alpha'] - MAEC_targets['30_day_single']

MAEC_targets['3_day_single_pct_change'] = abs(((MAEC_targets['3_day_single_alpha'] - MAEC_targets['3_day_single']) / MAEC_targets['3_day_single_alpha']) * 100)
MAEC_targets['7_day_single_pct_change'] = abs(((MAEC_targets['7_day_single_alpha'] - MAEC_targets['7_day_single']) / MAEC_targets['7_day_single_alpha']) * 100)
MAEC_targets['15_day_single_pct_change'] = abs(((MAEC_targets['15_day_single_alpha'] - MAEC_targets['15_day_single']) / MAEC_targets['15_day_single_alpha']) * 100)
MAEC_targets['30_day_single_pct_change'] = abs(((MAEC_targets['30_day_single_alpha'] - MAEC_targets['30_day_single']) / MAEC_targets['30_day_single_alpha']) * 100)
# investigate discrepancies
MAEC_targets = MAEC_targets.sort_values(by='30_day_pct_change', ascending=False)
MAEC_targets.to_csv('data/data_prep/MAEC_temp.csv', index=False)

# %%
# Change Yahoo errors to the values found with alphadvantage 
MAEC_targets['3_day_single'] = np.where(MAEC_targets['3_day'] == float('inf'), MAEC_targets['3_day_single_alpha'], MAEC_targets['3_day_single'])
MAEC_targets['7_day_single'] = np.where(MAEC_targets['7_day'] == float('inf'), MAEC_targets['7_day_single_alpha'], MAEC_targets['7_day_single'])
MAEC_targets['15_day_single'] = np.where(MAEC_targets['15_day'] == float('inf'), MAEC_targets['15_day_single_alpha'], MAEC_targets['15_day_single'])
MAEC_targets['30_day_single'] = np.where(MAEC_targets['30_day'] == float('inf'), MAEC_targets['30_day_single_alpha'], MAEC_targets['30_day_single'])
MAEC_targets['3_day'] = np.where(MAEC_targets['3_day'] == float('inf'), MAEC_targets['3_day_alpha'], MAEC_targets['3_day'])
MAEC_targets['7_day'] = np.where(MAEC_targets['7_day'] == float('inf'), MAEC_targets['7_day_alpha'], MAEC_targets['7_day'])
MAEC_targets['15_day'] = np.where(MAEC_targets['15_day'] == float('inf'), MAEC_targets['15_day_alpha'], MAEC_targets['15_day'])
MAEC_targets['30_day'] = np.where(MAEC_targets['30_day'] == float('inf'), MAEC_targets['30_day_alpha'], MAEC_targets['30_day'])

MAEC_targets['3_day_single'] = np.where(MAEC_targets['3_day'] == 0, MAEC_targets['3_day_single_alpha'], MAEC_targets['3_day_single'])
MAEC_targets['7_day_single'] = np.where(MAEC_targets['7_day'] == 0, MAEC_targets['7_day_single_alpha'], MAEC_targets['7_day_single'])
MAEC_targets['15_day_single'] = np.where(MAEC_targets['15_day'] == 0, MAEC_targets['15_day_single_alpha'], MAEC_targets['15_day_single'])
MAEC_targets['30_day_single'] = np.where(MAEC_targets['30_day'] == 0, MAEC_targets['30_day_single_alpha'], MAEC_targets['30_day_single'])
MAEC_targets['3_day'] = np.where(MAEC_targets['3_day'] == 0, MAEC_targets['3_day_alpha'], MAEC_targets['3_day'])
MAEC_targets['7_day'] = np.where(MAEC_targets['7_day'] == 0, MAEC_targets['7_day_alpha'], MAEC_targets['7_day'])
MAEC_targets['15_day'] = np.where(MAEC_targets['15_day'] == 0, MAEC_targets['15_day_alpha'], MAEC_targets['15_day'])
MAEC_targets['30_day'] = np.where(MAEC_targets['30_day'] == 0, MAEC_targets['30_day_alpha'], MAEC_targets['30_day'])

MAEC_targets.replace([float('inf'), -float('inf')], 0, inplace=True)
print('Number of rows without data-', len(MAEC_targets[((MAEC_targets['3_day'] == 0) & 
                                                        (MAEC_targets['7_day'] == 0) & 
                                                        (MAEC_targets['15_day'] == 0)& 
                                                        (MAEC_targets['30_day'] == 0))]))
print('----------------------------------------------------------------------')

# delete?
# MAEC_targets = MAEC_targets[~((MAEC_targets['3_day'] == 0) & 
#                 (MAEC_targets['7_day'] == 0) & 
#                 (MAEC_targets['15_day'] == 0) & 
#                 (MAEC_targets['30_day'] == 0))]
# Out:
# Number of rows without data- 218
# ----------------------------------------------------------------------

# %%
MAEC_targets = MAEC_targets.drop(['3_day_alpha', '3_day_single_alpha', '7_day_alpha', '7_day_single_alpha', '15_day_alpha', 
                        '15_day_single_alpha', '30_day_alpha', '30_day_single_alpha', '3_day_diff', '7_day_diff', 
                        '15_day_diff', '30_day_diff', '3_day_pct_change', '7_day_pct_change', '15_day_pct_change', 
                        '30_day_pct_change', '3_day_single_diff', '7_day_single_diff', '15_day_single_diff', 
                        '30_day_single_diff', '3_day_single_pct_change', '7_day_single_pct_change', 
                        '15_day_single_pct_change', '30_day_single_pct_change'], axis=1)
MAEC_targets = MAEC_targets.sort_values(by='7_day', ascending=True)
MAEC_targets.info(verbose=True)
### save ############################################
MAEC_targets.to_csv('data/data_prep/MAEC_targets.csv', index=False)
#####################################################
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3443 entries, 1635 to 3441
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ticker         3443 non-null   object
#  1   Date           3443 non-null   object
#  2   3_day          3443 non-null   float64
#  3   3_day_single   3443 non-null   float64
#  4   7_day          3443 non-null   float64
#  5   7_day_single   3443 non-null   float64
#  6   15_day         3443 non-null   float64
#  7   15_day_single  3443 non-null   float64
#  8   30_day         3443 non-null   float64
#  9   30_day_single  3443 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 295.9+ KB

# %% [markdown]
# # Clean Praat features
#
# - Replace '--undefined--' data
# - Convert to numeric float64
# - Compare our Praat data (MAEC), which was calculated from MP3 files.
#     - To the provided Praat data (MAEC) [GitHub](https://github.com/Earnings-Call-Dataset/MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction/tree/master)

# %%
praat_features = praat_features.replace(['--undefined--', '--undefined-', '--undefined-- ',  '--'], np.nan)

# Convert all columns into float64 except 
cols_to_convert = praat_features.columns.difference(['Company', 'Date', 'audio_file'])
praat_features[cols_to_convert] = praat_features[cols_to_convert].apply(pd.to_numeric)
# impute median on all NULL (--undefined--)
praat_features[cols_to_convert] = praat_features[cols_to_convert].apply(
    lambda col: col.fillna(col.median()) if pd.api.types.is_numeric_dtype(col) else col
)
praat_features.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89722 entries, 0 to 89721
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Mean pitch                    89722 non-null  float64
#  1   Standard deviation            89722 non-null  float64
#  2   Minimum pitch                 89722 non-null  float64
#  3   Maximum pitch                 89722 non-null  float64
#  4   Number of pulses              89722 non-null  float64
#  5   Number of periods             89722 non-null  float64
#  6   Mean period                   89722 non-null  float64
#  7   Mean intensity                89722 non-null  float64
#  8   Minimum intensity             89722 non-null  float64
#  9   Maximum intensity             89722 non-null  float64
#  10  Standard deviation of period  89722 non-null  float64
#  11  Fraction of unvoiced          89722 non-null  float64
#  12  Number of voice breaks        89722 non-null  float64
#  13  Degree of voice breaks        89722 non-null  float64
#  14  Jitter local                  89722 non-null  float64
#  15  Jitter local absolute         89722 non-null  float64
#  16  Jitter rap                    89722 non-null  float64
#  17  Jitter ppq5                   89722 non-null  float64
#  18  Jitter ddp                    89722 non-null  float64
#  19  Shimmer local                 89722 non-null  float64
#  20  Shimmer local dB              89722 non-null  float64
#  21  Shimmer apq3                  89722 non-null  float64
#  22  Shimmer apq5                  89722 non-null  float64
#  23  Shimmer apq11                 89722 non-null  float64
#  24  Shimmer dda                   89722 non-null  float64
#  25  Mean autocorrelation          89722 non-null  float64
#  26  Mean NHR                      89722 non-null  float64
#  27  Mean HNR                      89722 non-null  float64
#  28  Audio Length                  89722 non-null  float64
#  29  Company                       89722 non-null  object
#  30  Date                          89722 non-null  int64
#  31  Sentence_num                  89722 non-null  int64
#  32  audio_file                    89722 non-null  object
# dtypes: float64(29), int64(2), object(2)
# memory usage: 22.6+ MB

# %%
MAEC_praat_features = MAEC_praat_features.replace(['--undefined--', '--undefined-', '--undefined-- ',  '--'], np.nan)

# Convert all columns into float64 except 
cols_to_convert = MAEC_praat_features.columns.difference(['Ticker', 'Date', 'audio_file'])
MAEC_praat_features[cols_to_convert] = MAEC_praat_features[cols_to_convert].apply(pd.to_numeric)
# impute median on all NULL (--undefined--)
MAEC_praat_features[cols_to_convert] = MAEC_praat_features[cols_to_convert].apply(
    lambda col: col.fillna(col.median()) if pd.api.types.is_numeric_dtype(col) else col
)
MAEC_praat_features.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394277 entries, 0 to 394276
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Mean pitch                    394277 non-null  float64
#  1   Standard deviation            394277 non-null  float64
#  2   Minimum pitch                 394277 non-null  float64
#  3   Maximum pitch                 394277 non-null  float64
#  4   Number of pulses              394277 non-null  int64
#  5   Number of periods             394277 non-null  int64
#  6   Mean period                   394277 non-null  float64
#  7   Mean intensity                394277 non-null  float64
#  8   Minimum intensity             394277 non-null  float64
#  9   Maximum intensity             394277 non-null  float64
#  10  Standard deviation of period  394277 non-null  float64
#  11  Fraction of unvoiced          394277 non-null  float64
#  12  Number of voice breaks        394277 non-null  int64
#  13  Degree of voice breaks        394277 non-null  float64
#  14  Jitter local                  394277 non-null  float64
#  15  Jitter local absolute         394277 non-null  float64
#  16  Jitter rap                    394277 non-null  float64
#  17  Jitter ppq5                   394277 non-null  float64
#  18  Jitter ddp                    394277 non-null  float64
#  19  Shimmer local                 394277 non-null  float64
#  20  Shimmer local dB              394277 non-null  float64
#  21  Shimmer apq3                  394277 non-null  float64
#  22  Shimmer apq5                  394277 non-null  float64
#  23  Shimmer apq11                 394277 non-null  float64
#  24  Shimmer dda                   394277 non-null  float64
#  25  Mean autocorrelation          394277 non-null  float64
#  26  Mean NHR                      394277 non-null  float64
#  27  Mean HNR                      394277 non-null  float64
#  28  Audio Length                  394277 non-null  float64
#  29  Ticker                        394277 non-null  object
#  30  Date                          394277 non-null  int64
#  31  Sentence_num                  394277 non-null  int64
#  32  audio_file                    394277 non-null  object
# dtypes: float64(26), int64(5), object(2)
# memory usage: 99.3+ MB

# %% [markdown]
# Compare

# %%
MAEC_GitHub_features = pd.DataFrame()
def each_row(row):
    Ticker = row['Ticker']
    Date = row['Date'].replace('-', '') 

    features_df = pd.read_csv(f"data/MAEC/MAEC_Dataset/{Date}_{Ticker}/features.csv")
    features_df['Ticker'] = Ticker
    features_df['Date'] = Date
    features_df['Sentence_num'] = range(1, len(features_df) + 1)

    global MAEC_GitHub_features
    MAEC_GitHub_features = pd.concat([MAEC_GitHub_features, features_df], ignore_index=True)

MAEC_filename_data.progress_apply(each_row, axis=1)

MAEC_GitHub_features = MAEC_GitHub_features.replace(['--undefined--', '--undefined-', '--undefined-- ',  '--'], np.nan)
# Convert all columns into float64 except 'Ticker', 'Date', 'audio_file' 
cols_to_convert = MAEC_GitHub_features.columns.difference(['Ticker', 'Date', 'audio_file'])
MAEC_GitHub_features[cols_to_convert] = MAEC_GitHub_features[cols_to_convert].apply(pd.to_numeric)
# impute median on all NULL (--undefined--)
MAEC_GitHub_features[cols_to_convert] = MAEC_GitHub_features[cols_to_convert].apply(
    lambda col: col.fillna(col.median()) if pd.api.types.is_numeric_dtype(col) else col
)
MAEC_GitHub_features.to_csv('data/MAEC_GitHub_features.csv', index=False)
MAEC_GitHub_features.info(verbose=True)
# Out:
# 100%|██████████| 3443/3443 [02:26<00:00, 23.43it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394277 entries, 0 to 394276
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Mean pitch                    394277 non-null  float64
#  1   Standard deviation            394277 non-null  float64
#  2   Minimum pitch                 394277 non-null  float64
#  3   Maximum pitch                 394277 non-null  float64
#  4   Mean intensity                394277 non-null  float64
#  5   Minimum intensity             394277 non-null  float64
#  6   Maximum intensity             394277 non-null  float64
#  7   Number of pulses              394277 non-null  float64
#  8   Number of periods             394277 non-null  float64
#  9   Mean period                   394277 non-null  float64
#  10  Standard deviation of period  394277 non-null  float64
#  11  Fraction of unvoiced          394277 non-null  float64
#  12  Number of voice breaks        394277 non-null  float64
#  13  Degree of voice breaks        394277 non-null  float64
#  14  Jitter local                  394277 non-null  float64
#  15  Jitter local absolute         394277 non-null  float64
#  16  Jitter rap                    394277 non-null  float64
#  17  Jitter ppq5                   394277 non-null  float64
#  18  Jitter ddp                    394277 non-null  float64
#  19  Shimmer local                 394277 non-null  float64
#  20  Shimmer local dB              394277 non-null  float64
#  21  Shimmer apq3                  394277 non-null  float64
#  22  Shimmer apq5                  394277 non-null  float64
#  23  Shimmer apq11                 394277 non-null  float64
#  24  Shimmer dda                   394277 non-null  float64
#  25  Mean autocorrelation          394277 non-null  float64
#  26  Mean NHR                      394277 non-null  float64
#  27  Mean HNR                      394277 non-null  float64
#  28  Audio Length                  394277 non-null  float64
#  29  Ticker                        394277 non-null  object
#  30  Date                          394277 non-null  object
#  31  Sentence_num                  394277 non-null  int64
# dtypes: float64(29), int64(1), object(2)
# memory usage: 96.3+ MB

# %% [markdown]
# # Compare
# These are very close. That's good. This gives assurance that the original dataset Pratt features are okay.

# %%
MAEC_praat_features
# Out:
#         Mean pitch  Standard deviation  Minimum pitch  Maximum pitch  \
# 0          122.509               4.582        119.282        132.486
# 1          137.390              76.065         91.597        572.261
# 2          117.168              11.177         91.897        150.239
# 3          117.238              11.779         97.850        145.271
# 4          136.303              70.402         98.310        577.893
# ...            ...                 ...            ...            ...
# 394272     133.531              14.505        105.107        157.856
# 394273     128.154              49.849         95.974        567.649
# 394274     130.803              12.533        102.188        160.576
# 394275     116.219              11.366         87.046        137.937
# 394276     114.745              14.108         89.099        144.958
#
#         Number of pulses  Number of periods  Mean period  Mean intensity  \
# 0                     15                 14     0.008145       48.617273
# 1                    103                 96     0.007461       42.840412
# 2                    283                266     0.008527       43.585335
# 3                    170                162     0.008542       42.735277
# 4                    342                319     0.007383       44.440119
# ...                  ...                ...          ...             ...
# 394272                42                 40     0.007475       59.591205
# 394273               396                377     0.007820       67.647350
# 394274               315                304     0.007669       62.469106
# 394275               157                148     0.008614       61.795049
# 394276               106                103     0.008770       53.664604
#
#         Minimum intensity  Maximum intensity  ...  Shimmer apq11  Shimmer dda  \
# 0               33.245858          59.811569  ...         30.665       18.235
# 1               17.956942          61.970121  ...         17.935       29.632
# 2               14.603231          68.719015  ...         12.035       23.836
# 3               15.718385          63.319417  ...         17.816       23.452
# 4               22.618467          62.993807  ...         14.846       20.482
# ...                   ...                ...  ...            ...          ...
# 394272         -15.285724          80.196919  ...          6.825       10.370
# 394273          45.119193          80.862428  ...         13.618       15.330
# 394274          38.641636          80.928417  ...         11.752       14.277
# 394275          36.740310          80.262575  ...         13.835       13.291
# 394276          -2.796562          77.555516  ...         11.363       17.409
#
#         Mean autocorrelation  Mean NHR  Mean HNR  Audio Length  Ticker  \
# 0                   0.675386  0.524708     3.356      0.370979    LMAT
# 1                   0.712884  0.482183     4.893      2.506979    LMAT
# 2                   0.717230  0.468501     4.744      5.170979    LMAT
# 3                   0.741878  0.407407     5.231      3.250979    LMAT
# 4                   0.752116  0.394099     5.627      5.338979    LMAT
# ...                      ...       ...       ...           ...     ...
# 394272              0.800006  0.290069     6.972      0.743379     BKS
# 394273              0.823743  0.265119     8.079      4.452766     BKS
# 394274              0.824435  0.265622     8.167      4.452766     BKS
# 394275              0.814544  0.285962     8.096      2.075624     BKS
# 394276              0.753636  0.375386     5.439      2.153991     BKS
#
#             Date  Sentence_num                    audio_file
# 0       20150225             2  LMAT_20150225_f000002100.mp3
# 1       20150225             3  LMAT_20150225_f000002101.mp3
# 2       20150225             4  LMAT_20150225_f000002102.mp3
# 3       20150225             5  LMAT_20150225_f000002103.mp3
# 4       20150225             6  LMAT_20150225_f000002104.mp3
# ...          ...           ...                           ...
# 394272  20180621            24   BKS_20180621_f000039100.mp3
# 394273  20180621            25   BKS_20180621_f000039101.mp3
# 394274  20180621            26   BKS_20180621_f000039102.mp3
# 394275  20180621            27   BKS_20180621_f000039103.mp3
# 394276  20180621            28   BKS_20180621_f000039104.mp3
#
# [394277 rows x 33 columns]

# %%
MAEC_GitHub_features
# Out:
#         Mean pitch  Standard deviation  Minimum pitch  Maximum pitch  \
# 0          122.509               4.582        119.282        132.486
# 1          137.390              76.065         91.597        572.261
# 2          117.168              11.177         91.897        150.239
# 3          117.238              11.779         97.850        145.271
# 4          136.303              70.402         98.310        577.893
# ...            ...                 ...            ...            ...
# 394272     133.531              14.505        105.107        157.856
# 394273     128.154              49.849         95.974        567.649
# 394274     130.803              12.533        102.188        160.576
# 394275     116.219              11.366         87.046        137.937
# 394276     114.745              14.108         89.099        144.958
#
#         Mean intensity  Minimum intensity  Maximum intensity  \
# 0            48.617273          59.811569          33.245858
# 1            42.840412          61.970121          17.956942
# 2            43.585335          68.719015          14.603231
# 3            42.735277          63.319417          15.718385
# 4            44.440119          62.993807          22.618467
# ...                ...                ...                ...
# 394272       59.591205          80.196919         -15.285724
# 394273       67.647350          80.862428          45.119193
# 394274       62.469106          80.928417          38.641636
# 394275       61.795049          80.262575          36.740310
# 394276       53.664604          77.555516          -2.796562
#
#         Number of pulses  Number of periods  Mean period  ...  Shimmer apq5  \
# 0                   15.0               14.0     0.008145  ...        11.513
# 1                  103.0               96.0     0.007461  ...        12.248
# 2                  283.0              266.0     0.008527  ...        10.633
# 3                  170.0              162.0     0.008542  ...         9.040
# 4                  342.0              319.0     0.007383  ...         8.630
# ...                  ...                ...          ...  ...           ...
# 394272              42.0               40.0     0.007475  ...         4.486
# 394273             396.0              377.0     0.007820  ...         7.697
# 394274             315.0              304.0     0.007669  ...         5.904
# 394275             157.0              148.0     0.008614  ...         7.349
# 394276             106.0              103.0     0.008770  ...         7.395
#
#         Shimmer apq11  Shimmer dda  Mean autocorrelation  Mean NHR  Mean HNR  \
# 0              30.665       18.235              0.675386  0.524708     3.356
# 1              17.935       29.632              0.712884  0.482183     4.893
# 2              12.035       23.836              0.717230  0.468501     4.744
# 3              17.816       23.452              0.741878  0.407407     5.231
# 4              14.846       20.482              0.752116  0.394099     5.627
# ...               ...          ...                   ...       ...       ...
# 394272          6.825       10.370              0.800006  0.290069     6.972
# 394273         13.618       15.330              0.823743  0.265119     8.079
# 394274         11.752       14.277              0.824435  0.265622     8.167
# 394275         13.835       13.291              0.814544  0.285962     8.096
# 394276         11.363       17.409              0.753636  0.375386     5.439
#
#         Audio Length  Ticker      Date  Sentence_num
# 0           0.370979    LMAT  20150225             1
# 1           2.506979    LMAT  20150225             2
# 2           5.170979    LMAT  20150225             3
# 3           3.250979    LMAT  20150225             4
# 4           5.338979    LMAT  20150225             5
# ...              ...     ...       ...           ...
# 394272      0.743379     BKS  20180621            24
# 394273      4.452766     BKS  20180621            25
# 394274      4.452766     BKS  20180621            26
# 394275      2.075624     BKS  20180621            27
# 394276      2.153991     BKS  20180621            28
#
# [394277 rows x 32 columns]

# %% [markdown]
# # Final dataset

# %%
praat_features['Date'] = praat_features['Date'].astype('Int64')

##################################################################
# if you want to merge Glove features 
# Merge glove and Pratt features (each sentence is 327 features)
# features = pd.merge(praat_features, glove_features, how="left",on = ['Company','Date','Sentence_num'])
##################################################################
# Merge RoBERTa and Pratt features (each sentence is 1051 features)
features = pd.merge(praat_features, RoBERTa_features, how="left",on = ['Company','Date','Sentence_num'])
features = features.drop(['Shimmer apq11','Audio Length','audio_file'], axis=1)

# The maximum sentences per meeting is 523 
# Ensure each meeting has 523 sentences, add zeros to the end
def add_zero_padding(group):
    complete_index = pd.Index(np.arange(1, 524), name='Sentence_num')
    group = group.set_index('Sentence_num').reindex(complete_index).reset_index()
    
    group['Company'] = group['Company'].fillna(method='ffill').fillna(method='bfill')
    group['Date'] = group['Date'].fillna(method='ffill').fillna(method='bfill')
    
    group.fillna(0.0, inplace=True)
    return group

features = features.groupby(['Company', 'Date']).apply(add_zero_padding).reset_index(drop=True)
features.fillna(0, inplace=True)

# %%
# Merge the targets 
# (will be duplicated 523 times, for each meeting, but that's okay for now)
# we need the date and company columns to sort
targets['Date'] = targets['Date'].astype(str).str.replace('-', '').astype('Int64')
original_dataset = pd.merge(features, targets, how="left",on = ['Company','Date'])

# Fill in null
rows_with_nulls = original_dataset[original_dataset.isnull().any(axis=1)]
# print(rows_with_nulls)
original_dataset.fillna(0, inplace=True)

# dump rows without targets
original_dataset = original_dataset.drop(['Ticker'], axis=1)
original_dataset = original_dataset[~((original_dataset['3_day'] == 0) & 
                                    (original_dataset['7_day'] == 0) & 
                                    (original_dataset['15_day'] == 0) & 
                                    (original_dataset['30_day'] == 0))]

original_dataset = original_dataset.sort_values(by=['Date', 'Company', 'Sentence_num'], ascending=[True, True, True])

# original_dataset = original_dataset.groupby(['Company', 'Date'])
original_dataset.info(verbose=True)
###### save ############################################
original_dataset.to_csv('data/original_dataset.csv', index=False)
########################################################
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295495 entries, 73743 to 75311
# Data columns (total 1062 columns):
#  #     Column                        Dtype
# ---    ------                        -----
#  0     Sentence_num                  int32
#  1     Mean pitch                    float64
#  2     Standard deviation            float64
#  3     Minimum pitch                 float64
#  4     Maximum pitch                 float64
#  5     Number of pulses              float64
#  6     Number of periods             float64
#  7     Mean period                   float64
#  8     Mean intensity                float64
#  9     Minimum intensity             float64
#  10    Maximum intensity             float64
#  11    Standard deviation of period  float64
#  12    Fraction of unvoiced          float64
#  13    Number of voice breaks        float64
#  14    Degree of voice breaks        float64
#  15    Jitter local                  float64
#  16    Jitter local absolute         float64
#  17    Jitter rap                    float64
#  18    Jitter ppq5                   float64
#  19    Jitter ddp                    float64
#  20    Shimmer local                 float64
#  21    Shimmer local dB              float64
#  22    Shimmer apq3                  float64
#  23    Shimmer apq5                  float64
#  24    Shimmer dda                   float64
#  25    Mean autocorrelation          float64
#  26    Mean NHR                      float64
#  27    Mean HNR                      float64
#  28    Company                       object
#  29    Date                          Int64
#  30    RoBERTa_0                     float64
#  31    RoBERTa_1                     float64
#  32    RoBERTa_2                     float64
#  33    RoBERTa_3                     float64
#  34    RoBERTa_4                     float64
#  35    RoBERTa_5                     float64
#  36    RoBERTa_6                     float64
#  37    RoBERTa_7                     float64
#  38    RoBERTa_8                     float64
#  39    RoBERTa_9                     float64
#  40    RoBERTa_10                    float64
#  41    RoBERTa_11                    float64
#  42    RoBERTa_12                    float64
#  43    RoBERTa_13                    float64
#  44    RoBERTa_14                    float64
#  45    RoBERTa_15                    float64
#  46    RoBERTa_16                    float64
#  47    RoBERTa_17                    float64
#  48    RoBERTa_18                    float64
#  49    RoBERTa_19                    float64
#  50    RoBERTa_20                    float64
#  51    RoBERTa_21                    float64
#  52    RoBERTa_22                    float64
#  53    RoBERTa_23                    float64
#  54    RoBERTa_24                    float64
#  55    RoBERTa_25                    float64
#  56    RoBERTa_26                    float64
#  57    RoBERTa_27                    float64
#  58    RoBERTa_28                    float64
#  59    RoBERTa_29                    float64
#  60    RoBERTa_30                    float64
#  61    RoBERTa_31                    float64
#  62    RoBERTa_32                    float64
#  63    RoBERTa_33                    float64
#  64    RoBERTa_34                    float64
#  65    RoBERTa_35                    float64
#  66    RoBERTa_36                    float64
#  67    RoBERTa_37                    float64
#  68    RoBERTa_38                    float64
#  69    RoBERTa_39                    float64
#  70    RoBERTa_40                    float64
#  71    RoBERTa_41                    float64
#  72    RoBERTa_42                    float64
#  73    RoBERTa_43                    float64
#  74    RoBERTa_44                    float64
#  75    RoBERTa_45                    float64
#  76    RoBERTa_46                    float64
#  77    RoBERTa_47                    float64
#  78    RoBERTa_48                    float64
#  79    RoBERTa_49                    float64
#  80    RoBERTa_50                    float64
#  81    RoBERTa_51                    float64
#  82    RoBERTa_52                    float64
#  83    RoBERTa_53                    float64
#  84    RoBERTa_54                    float64
#  85    RoBERTa_55                    float64
#  86    RoBERTa_56                    float64
#  87    RoBERTa_57                    float64
#  88    RoBERTa_58                    float64
#  89    RoBERTa_59                    float64
#  90    RoBERTa_60                    float64
#  91    RoBERTa_61                    float64
#  92    RoBERTa_62                    float64
#  93    RoBERTa_63                    float64
#  94    RoBERTa_64                    float64
#  95    RoBERTa_65                    float64
#  96    RoBERTa_66                    float64
#  97    RoBERTa_67                    float64
#  98    RoBERTa_68                    float64
#  99    RoBERTa_69                    float64
#  100   RoBERTa_70                    float64
#  101   RoBERTa_71                    float64
#  102   RoBERTa_72                    float64
#  103   RoBERTa_73                    float64
#  104   RoBERTa_74                    float64
#  105   RoBERTa_75                    float64
#  106   RoBERTa_76                    float64
#  107   RoBERTa_77                    float64
#  108   RoBERTa_78                    float64
#  109   RoBERTa_79                    float64
#  110   RoBERTa_80                    float64
#  111   RoBERTa_81                    float64
#  112   RoBERTa_82                    float64
#  113   RoBERTa_83                    float64
#  114   RoBERTa_84                    float64
#  115   RoBERTa_85                    float64
#  116   RoBERTa_86                    float64
#  117   RoBERTa_87                    float64
#  118   RoBERTa_88                    float64
#  119   RoBERTa_89                    float64
#  120   RoBERTa_90                    float64
#  121   RoBERTa_91                    float64
#  122   RoBERTa_92                    float64
#  123   RoBERTa_93                    float64
#  124   RoBERTa_94                    float64
#  125   RoBERTa_95                    float64
#  126   RoBERTa_96                    float64
#  127   RoBERTa_97                    float64
#  128   RoBERTa_98                    float64
#  129   RoBERTa_99                    float64
#  130   RoBERTa_100                   float64
#  131   RoBERTa_101                   float64
#  132   RoBERTa_102                   float64
#  133   RoBERTa_103                   float64
#  134   RoBERTa_104                   float64
#  135   RoBERTa_105                   float64
#  136   RoBERTa_106                   float64
#  137   RoBERTa_107                   float64
#  138   RoBERTa_108                   float64
#  139   RoBERTa_109                   float64
#  140   RoBERTa_110                   float64
#  141   RoBERTa_111                   float64
#  142   RoBERTa_112                   float64
#  143   RoBERTa_113                   float64
#  144   RoBERTa_114                   float64
#  145   RoBERTa_115                   float64
#  146   RoBERTa_116                   float64
#  147   RoBERTa_117                   float64
#  148   RoBERTa_118                   float64
#  149   RoBERTa_119                   float64
#  150   RoBERTa_120                   float64
#  151   RoBERTa_121                   float64
#  152   RoBERTa_122                   float64
#  153   RoBERTa_123                   float64
#  154   RoBERTa_124                   float64
#  155   RoBERTa_125                   float64
#  156   RoBERTa_126                   float64
#  157   RoBERTa_127                   float64
#  158   RoBERTa_128                   float64
#  159   RoBERTa_129                   float64
#  160   RoBERTa_130                   float64
#  161   RoBERTa_131                   float64
#  162   RoBERTa_132                   float64
#  163   RoBERTa_133                   float64
#  164   RoBERTa_134                   float64
#  165   RoBERTa_135                   float64
#  166   RoBERTa_136                   float64
#  167   RoBERTa_137                   float64
#  168   RoBERTa_138                   float64
#  169   RoBERTa_139                   float64
#  170   RoBERTa_140                   float64
#  171   RoBERTa_141                   float64
#  172   RoBERTa_142                   float64
#  173   RoBERTa_143                   float64
#  174   RoBERTa_144                   float64
#  175   RoBERTa_145                   float64
#  176   RoBERTa_146                   float64
#  177   RoBERTa_147                   float64
#  178   RoBERTa_148                   float64
#  179   RoBERTa_149                   float64
#  180   RoBERTa_150                   float64
#  181   RoBERTa_151                   float64
#  182   RoBERTa_152                   float64
#  183   RoBERTa_153                   float64
#  184   RoBERTa_154                   float64
#  185   RoBERTa_155                   float64
#  186   RoBERTa_156                   float64
#  187   RoBERTa_157                   float64
#  188   RoBERTa_158                   float64
#  189   RoBERTa_159                   float64
#  190   RoBERTa_160                   float64
#  191   RoBERTa_161                   float64
#  192   RoBERTa_162                   float64
#  193   RoBERTa_163                   float64
#  194   RoBERTa_164                   float64
#  195   RoBERTa_165                   float64
#  196   RoBERTa_166                   float64
#  197   RoBERTa_167                   float64
#  198   RoBERTa_168                   float64
#  199   RoBERTa_169                   float64
#  200   RoBERTa_170                   float64
#  201   RoBERTa_171                   float64
#  202   RoBERTa_172                   float64
#  203   RoBERTa_173                   float64
#  204   RoBERTa_174                   float64
#  205   RoBERTa_175                   float64
#  206   RoBERTa_176                   float64
#  207   RoBERTa_177                   float64
#  208   RoBERTa_178                   float64
#  209   RoBERTa_179                   float64
#  210   RoBERTa_180                   float64
#  211   RoBERTa_181                   float64
#  212   RoBERTa_182                   float64
#  213   RoBERTa_183                   float64
#  214   RoBERTa_184                   float64
#  215   RoBERTa_185                   float64
#  216   RoBERTa_186                   float64
#  217   RoBERTa_187                   float64
#  218   RoBERTa_188                   float64
#  219   RoBERTa_189                   float64
#  220   RoBERTa_190                   float64
#  221   RoBERTa_191                   float64
#  222   RoBERTa_192                   float64
#  223   RoBERTa_193                   float64
#  224   RoBERTa_194                   float64
#  225   RoBERTa_195                   float64
#  226   RoBERTa_196                   float64
#  227   RoBERTa_197                   float64
#  228   RoBERTa_198                   float64
#  229   RoBERTa_199                   float64
#  230   RoBERTa_200                   float64
#  231   RoBERTa_201                   float64
#  232   RoBERTa_202                   float64
#  233   RoBERTa_203                   float64
#  234   RoBERTa_204                   float64
#  235   RoBERTa_205                   float64
#  236   RoBERTa_206                   float64
#  237   RoBERTa_207                   float64
#  238   RoBERTa_208                   float64
#  239   RoBERTa_209                   float64
#  240   RoBERTa_210                   float64
#  241   RoBERTa_211                   float64
#  242   RoBERTa_212                   float64
#  243   RoBERTa_213                   float64
#  244   RoBERTa_214                   float64
#  245   RoBERTa_215                   float64
#  246   RoBERTa_216                   float64
#  247   RoBERTa_217                   float64
#  248   RoBERTa_218                   float64
#  249   RoBERTa_219                   float64
#  250   RoBERTa_220                   float64
#  251   RoBERTa_221                   float64
#  252   RoBERTa_222                   float64
#  253   RoBERTa_223                   float64
#  254   RoBERTa_224                   float64
#  255   RoBERTa_225                   float64
#  256   RoBERTa_226                   float64
#  257   RoBERTa_227                   float64
#  258   RoBERTa_228                   float64
#  259   RoBERTa_229                   float64
#  260   RoBERTa_230                   float64
#  261   RoBERTa_231                   float64
#  262   RoBERTa_232                   float64
#  263   RoBERTa_233                   float64
#  264   RoBERTa_234                   float64
#  265   RoBERTa_235                   float64
#  266   RoBERTa_236                   float64
#  267   RoBERTa_237                   float64
#  268   RoBERTa_238                   float64
#  269   RoBERTa_239                   float64
#  270   RoBERTa_240                   float64
#  271   RoBERTa_241                   float64
#  272   RoBERTa_242                   float64
#  273   RoBERTa_243                   float64
#  274   RoBERTa_244                   float64
#  275   RoBERTa_245                   float64
#  276   RoBERTa_246                   float64
#  277   RoBERTa_247                   float64
#  278   RoBERTa_248                   float64
#  279   RoBERTa_249                   float64
#  280   RoBERTa_250                   float64
#  281   RoBERTa_251                   float64
#  282   RoBERTa_252                   float64
#  283   RoBERTa_253                   float64
#  284   RoBERTa_254                   float64
#  285   RoBERTa_255                   float64
#  286   RoBERTa_256                   float64
#  287   RoBERTa_257                   float64
#  288   RoBERTa_258                   float64
#  289   RoBERTa_259                   float64
#  290   RoBERTa_260                   float64
#  291   RoBERTa_261                   float64
#  292   RoBERTa_262                   float64
#  293   RoBERTa_263                   float64
#  294   RoBERTa_264                   float64
#  295   RoBERTa_265                   float64
#  296   RoBERTa_266                   float64
#  297   RoBERTa_267                   float64
#  298   RoBERTa_268                   float64
#  299   RoBERTa_269                   float64
#  300   RoBERTa_270                   float64
#  301   RoBERTa_271                   float64
#  302   RoBERTa_272                   float64
#  303   RoBERTa_273                   float64
#  304   RoBERTa_274                   float64
#  305   RoBERTa_275                   float64
#  306   RoBERTa_276                   float64
#  307   RoBERTa_277                   float64
#  308   RoBERTa_278                   float64
#  309   RoBERTa_279                   float64
#  310   RoBERTa_280                   float64
#  311   RoBERTa_281                   float64
#  312   RoBERTa_282                   float64
#  313   RoBERTa_283                   float64
#  314   RoBERTa_284                   float64
#  315   RoBERTa_285                   float64
#  316   RoBERTa_286                   float64
#  317   RoBERTa_287                   float64
#  318   RoBERTa_288                   float64
#  319   RoBERTa_289                   float64
#  320   RoBERTa_290                   float64
#  321   RoBERTa_291                   float64
#  322   RoBERTa_292                   float64
#  323   RoBERTa_293                   float64
#  324   RoBERTa_294                   float64
#  325   RoBERTa_295                   float64
#  326   RoBERTa_296                   float64
#  327   RoBERTa_297                   float64
#  328   RoBERTa_298                   float64
#  329   RoBERTa_299                   float64
#  330   RoBERTa_300                   float64
#  331   RoBERTa_301                   float64
#  332   RoBERTa_302                   float64
#  333   RoBERTa_303                   float64
#  334   RoBERTa_304                   float64
#  335   RoBERTa_305                   float64
#  336   RoBERTa_306                   float64
#  337   RoBERTa_307                   float64
#  338   RoBERTa_308                   float64
#  339   RoBERTa_309                   float64
#  340   RoBERTa_310                   float64
#  341   RoBERTa_311                   float64
#  342   RoBERTa_312                   float64
#  343   RoBERTa_313                   float64
#  344   RoBERTa_314                   float64
#  345   RoBERTa_315                   float64
#  346   RoBERTa_316                   float64
#  347   RoBERTa_317                   float64
#  348   RoBERTa_318                   float64
#  349   RoBERTa_319                   float64
#  350   RoBERTa_320                   float64
#  351   RoBERTa_321                   float64
#  352   RoBERTa_322                   float64
#  353   RoBERTa_323                   float64
#  354   RoBERTa_324                   float64
#  355   RoBERTa_325                   float64
#  356   RoBERTa_326                   float64
#  357   RoBERTa_327                   float64
#  358   RoBERTa_328                   float64
#  359   RoBERTa_329                   float64
#  360   RoBERTa_330                   float64
#  361   RoBERTa_331                   float64
#  362   RoBERTa_332                   float64
#  363   RoBERTa_333                   float64
#  364   RoBERTa_334                   float64
#  365   RoBERTa_335                   float64
#  366   RoBERTa_336                   float64
#  367   RoBERTa_337                   float64
#  368   RoBERTa_338                   float64
#  369   RoBERTa_339                   float64
#  370   RoBERTa_340                   float64
#  371   RoBERTa_341                   float64
#  372   RoBERTa_342                   float64
#  373   RoBERTa_343                   float64
#  374   RoBERTa_344                   float64
#  375   RoBERTa_345                   float64
#  376   RoBERTa_346                   float64
#  377   RoBERTa_347                   float64
#  378   RoBERTa_348                   float64
#  379   RoBERTa_349                   float64
#  380   RoBERTa_350                   float64
#  381   RoBERTa_351                   float64
#  382   RoBERTa_352                   float64
#  383   RoBERTa_353                   float64
#  384   RoBERTa_354                   float64
#  385   RoBERTa_355                   float64
#  386   RoBERTa_356                   float64
#  387   RoBERTa_357                   float64
#  388   RoBERTa_358                   float64
#  389   RoBERTa_359                   float64
#  390   RoBERTa_360                   float64
#  391   RoBERTa_361                   float64
#  392   RoBERTa_362                   float64
#  393   RoBERTa_363                   float64
#  394   RoBERTa_364                   float64
#  395   RoBERTa_365                   float64
#  396   RoBERTa_366                   float64
#  397   RoBERTa_367                   float64
#  398   RoBERTa_368                   float64
#  399   RoBERTa_369                   float64
#  400   RoBERTa_370                   float64
#  401   RoBERTa_371                   float64
#  402   RoBERTa_372                   float64
#  403   RoBERTa_373                   float64
#  404   RoBERTa_374                   float64
#  405   RoBERTa_375                   float64
#  406   RoBERTa_376                   float64
#  407   RoBERTa_377                   float64
#  408   RoBERTa_378                   float64
#  409   RoBERTa_379                   float64
#  410   RoBERTa_380                   float64
#  411   RoBERTa_381                   float64
#  412   RoBERTa_382                   float64
#  413   RoBERTa_383                   float64
#  414   RoBERTa_384                   float64
#  415   RoBERTa_385                   float64
#  416   RoBERTa_386                   float64
#  417   RoBERTa_387                   float64
#  418   RoBERTa_388                   float64
#  419   RoBERTa_389                   float64
#  420   RoBERTa_390                   float64
#  421   RoBERTa_391                   float64
#  422   RoBERTa_392                   float64
#  423   RoBERTa_393                   float64
#  424   RoBERTa_394                   float64
#  425   RoBERTa_395                   float64
#  426   RoBERTa_396                   float64
#  427   RoBERTa_397                   float64
#  428   RoBERTa_398                   float64
#  429   RoBERTa_399                   float64
#  430   RoBERTa_400                   float64
#  431   RoBERTa_401                   float64
#  432   RoBERTa_402                   float64
#  433   RoBERTa_403                   float64
#  434   RoBERTa_404                   float64
#  435   RoBERTa_405                   float64
#  436   RoBERTa_406                   float64
#  437   RoBERTa_407                   float64
#  438   RoBERTa_408                   float64
#  439   RoBERTa_409                   float64
#  440   RoBERTa_410                   float64
#  441   RoBERTa_411                   float64
#  442   RoBERTa_412                   float64
#  443   RoBERTa_413                   float64
#  444   RoBERTa_414                   float64
#  445   RoBERTa_415                   float64
#  446   RoBERTa_416                   float64
#  447   RoBERTa_417                   float64
#  448   RoBERTa_418                   float64
#  449   RoBERTa_419                   float64
#  450   RoBERTa_420                   float64
#  451   RoBERTa_421                   float64
#  452   RoBERTa_422                   float64
#  453   RoBERTa_423                   float64
#  454   RoBERTa_424                   float64
#  455   RoBERTa_425                   float64
#  456   RoBERTa_426                   float64
#  457   RoBERTa_427                   float64
#  458   RoBERTa_428                   float64
#  459   RoBERTa_429                   float64
#  460   RoBERTa_430                   float64
#  461   RoBERTa_431                   float64
#  462   RoBERTa_432                   float64
#  463   RoBERTa_433                   float64
#  464   RoBERTa_434                   float64
#  465   RoBERTa_435                   float64
#  466   RoBERTa_436                   float64
#  467   RoBERTa_437                   float64
#  468   RoBERTa_438                   float64
#  469   RoBERTa_439                   float64
#  470   RoBERTa_440                   float64
#  471   RoBERTa_441                   float64
#  472   RoBERTa_442                   float64
#  473   RoBERTa_443                   float64
#  474   RoBERTa_444                   float64
#  475   RoBERTa_445                   float64
#  476   RoBERTa_446                   float64
#  477   RoBERTa_447                   float64
#  478   RoBERTa_448                   float64
#  479   RoBERTa_449                   float64
#  480   RoBERTa_450                   float64
#  481   RoBERTa_451                   float64
#  482   RoBERTa_452                   float64
#  483   RoBERTa_453                   float64
#  484   RoBERTa_454                   float64
#  485   RoBERTa_455                   float64
#  486   RoBERTa_456                   float64
#  487   RoBERTa_457                   float64
#  488   RoBERTa_458                   float64
#  489   RoBERTa_459                   float64
#  490   RoBERTa_460                   float64
#  491   RoBERTa_461                   float64
#  492   RoBERTa_462                   float64
#  493   RoBERTa_463                   float64
#  494   RoBERTa_464                   float64
#  495   RoBERTa_465                   float64
#  496   RoBERTa_466                   float64
#  497   RoBERTa_467                   float64
#  498   RoBERTa_468                   float64
#  499   RoBERTa_469                   float64
#  500   RoBERTa_470                   float64
#  501   RoBERTa_471                   float64
#  502   RoBERTa_472                   float64
#  503   RoBERTa_473                   float64
#  504   RoBERTa_474                   float64
#  505   RoBERTa_475                   float64
#  506   RoBERTa_476                   float64
#  507   RoBERTa_477                   float64
#  508   RoBERTa_478                   float64
#  509   RoBERTa_479                   float64
#  510   RoBERTa_480                   float64
#  511   RoBERTa_481                   float64
#  512   RoBERTa_482                   float64
#  513   RoBERTa_483                   float64
#  514   RoBERTa_484                   float64
#  515   RoBERTa_485                   float64
#  516   RoBERTa_486                   float64
#  517   RoBERTa_487                   float64
#  518   RoBERTa_488                   float64
#  519   RoBERTa_489                   float64
#  520   RoBERTa_490                   float64
#  521   RoBERTa_491                   float64
#  522   RoBERTa_492                   float64
#  523   RoBERTa_493                   float64
#  524   RoBERTa_494                   float64
#  525   RoBERTa_495                   float64
#  526   RoBERTa_496                   float64
#  527   RoBERTa_497                   float64
#  528   RoBERTa_498                   float64
#  529   RoBERTa_499                   float64
#  530   RoBERTa_500                   float64
#  531   RoBERTa_501                   float64
#  532   RoBERTa_502                   float64
#  533   RoBERTa_503                   float64
#  534   RoBERTa_504                   float64
#  535   RoBERTa_505                   float64
#  536   RoBERTa_506                   float64
#  537   RoBERTa_507                   float64
#  538   RoBERTa_508                   float64
#  539   RoBERTa_509                   float64
#  540   RoBERTa_510                   float64
#  541   RoBERTa_511                   float64
#  542   RoBERTa_512                   float64
#  543   RoBERTa_513                   float64
#  544   RoBERTa_514                   float64
#  545   RoBERTa_515                   float64
#  546   RoBERTa_516                   float64
#  547   RoBERTa_517                   float64
#  548   RoBERTa_518                   float64
#  549   RoBERTa_519                   float64
#  550   RoBERTa_520                   float64
#  551   RoBERTa_521                   float64
#  552   RoBERTa_522                   float64
#  553   RoBERTa_523                   float64
#  554   RoBERTa_524                   float64
#  555   RoBERTa_525                   float64
#  556   RoBERTa_526                   float64
#  557   RoBERTa_527                   float64
#  558   RoBERTa_528                   float64
#  559   RoBERTa_529                   float64
#  560   RoBERTa_530                   float64
#  561   RoBERTa_531                   float64
#  562   RoBERTa_532                   float64
#  563   RoBERTa_533                   float64
#  564   RoBERTa_534                   float64
#  565   RoBERTa_535                   float64
#  566   RoBERTa_536                   float64
#  567   RoBERTa_537                   float64
#  568   RoBERTa_538                   float64
#  569   RoBERTa_539                   float64
#  570   RoBERTa_540                   float64
#  571   RoBERTa_541                   float64
#  572   RoBERTa_542                   float64
#  573   RoBERTa_543                   float64
#  574   RoBERTa_544                   float64
#  575   RoBERTa_545                   float64
#  576   RoBERTa_546                   float64
#  577   RoBERTa_547                   float64
#  578   RoBERTa_548                   float64
#  579   RoBERTa_549                   float64
#  580   RoBERTa_550                   float64
#  581   RoBERTa_551                   float64
#  582   RoBERTa_552                   float64
#  583   RoBERTa_553                   float64
#  584   RoBERTa_554                   float64
#  585   RoBERTa_555                   float64
#  586   RoBERTa_556                   float64
#  587   RoBERTa_557                   float64
#  588   RoBERTa_558                   float64
#  589   RoBERTa_559                   float64
#  590   RoBERTa_560                   float64
#  591   RoBERTa_561                   float64
#  592   RoBERTa_562                   float64
#  593   RoBERTa_563                   float64
#  594   RoBERTa_564                   float64
#  595   RoBERTa_565                   float64
#  596   RoBERTa_566                   float64
#  597   RoBERTa_567                   float64
#  598   RoBERTa_568                   float64
#  599   RoBERTa_569                   float64
#  600   RoBERTa_570                   float64
#  601   RoBERTa_571                   float64
#  602   RoBERTa_572                   float64
#  603   RoBERTa_573                   float64
#  604   RoBERTa_574                   float64
#  605   RoBERTa_575                   float64
#  606   RoBERTa_576                   float64
#  607   RoBERTa_577                   float64
#  608   RoBERTa_578                   float64
#  609   RoBERTa_579                   float64
#  610   RoBERTa_580                   float64
#  611   RoBERTa_581                   float64
#  612   RoBERTa_582                   float64
#  613   RoBERTa_583                   float64
#  614   RoBERTa_584                   float64
#  615   RoBERTa_585                   float64
#  616   RoBERTa_586                   float64
#  617   RoBERTa_587                   float64
#  618   RoBERTa_588                   float64
#  619   RoBERTa_589                   float64
#  620   RoBERTa_590                   float64
#  621   RoBERTa_591                   float64
#  622   RoBERTa_592                   float64
#  623   RoBERTa_593                   float64
#  624   RoBERTa_594                   float64
#  625   RoBERTa_595                   float64
#  626   RoBERTa_596                   float64
#  627   RoBERTa_597                   float64
#  628   RoBERTa_598                   float64
#  629   RoBERTa_599                   float64
#  630   RoBERTa_600                   float64
#  631   RoBERTa_601                   float64
#  632   RoBERTa_602                   float64
#  633   RoBERTa_603                   float64
#  634   RoBERTa_604                   float64
#  635   RoBERTa_605                   float64
#  636   RoBERTa_606                   float64
#  637   RoBERTa_607                   float64
#  638   RoBERTa_608                   float64
#  639   RoBERTa_609                   float64
#  640   RoBERTa_610                   float64
#  641   RoBERTa_611                   float64
#  642   RoBERTa_612                   float64
#  643   RoBERTa_613                   float64
#  644   RoBERTa_614                   float64
#  645   RoBERTa_615                   float64
#  646   RoBERTa_616                   float64
#  647   RoBERTa_617                   float64
#  648   RoBERTa_618                   float64
#  649   RoBERTa_619                   float64
#  650   RoBERTa_620                   float64
#  651   RoBERTa_621                   float64
#  652   RoBERTa_622                   float64
#  653   RoBERTa_623                   float64
#  654   RoBERTa_624                   float64
#  655   RoBERTa_625                   float64
#  656   RoBERTa_626                   float64
#  657   RoBERTa_627                   float64
#  658   RoBERTa_628                   float64
#  659   RoBERTa_629                   float64
#  660   RoBERTa_630                   float64
#  661   RoBERTa_631                   float64
#  662   RoBERTa_632                   float64
#  663   RoBERTa_633                   float64
#  664   RoBERTa_634                   float64
#  665   RoBERTa_635                   float64
#  666   RoBERTa_636                   float64
#  667   RoBERTa_637                   float64
#  668   RoBERTa_638                   float64
#  669   RoBERTa_639                   float64
#  670   RoBERTa_640                   float64
#  671   RoBERTa_641                   float64
#  672   RoBERTa_642                   float64
#  673   RoBERTa_643                   float64
#  674   RoBERTa_644                   float64
#  675   RoBERTa_645                   float64
#  676   RoBERTa_646                   float64
#  677   RoBERTa_647                   float64
#  678   RoBERTa_648                   float64
#  679   RoBERTa_649                   float64
#  680   RoBERTa_650                   float64
#  681   RoBERTa_651                   float64
#  682   RoBERTa_652                   float64
#  683   RoBERTa_653                   float64
#  684   RoBERTa_654                   float64
#  685   RoBERTa_655                   float64
#  686   RoBERTa_656                   float64
#  687   RoBERTa_657                   float64
#  688   RoBERTa_658                   float64
#  689   RoBERTa_659                   float64
#  690   RoBERTa_660                   float64
#  691   RoBERTa_661                   float64
#  692   RoBERTa_662                   float64
#  693   RoBERTa_663                   float64
#  694   RoBERTa_664                   float64
#  695   RoBERTa_665                   float64
#  696   RoBERTa_666                   float64
#  697   RoBERTa_667                   float64
#  698   RoBERTa_668                   float64
#  699   RoBERTa_669                   float64
#  700   RoBERTa_670                   float64
#  701   RoBERTa_671                   float64
#  702   RoBERTa_672                   float64
#  703   RoBERTa_673                   float64
#  704   RoBERTa_674                   float64
#  705   RoBERTa_675                   float64
#  706   RoBERTa_676                   float64
#  707   RoBERTa_677                   float64
#  708   RoBERTa_678                   float64
#  709   RoBERTa_679                   float64
#  710   RoBERTa_680                   float64
#  711   RoBERTa_681                   float64
#  712   RoBERTa_682                   float64
#  713   RoBERTa_683                   float64
#  714   RoBERTa_684                   float64
#  715   RoBERTa_685                   float64
#  716   RoBERTa_686                   float64
#  717   RoBERTa_687                   float64
#  718   RoBERTa_688                   float64
#  719   RoBERTa_689                   float64
#  720   RoBERTa_690                   float64
#  721   RoBERTa_691                   float64
#  722   RoBERTa_692                   float64
#  723   RoBERTa_693                   float64
#  724   RoBERTa_694                   float64
#  725   RoBERTa_695                   float64
#  726   RoBERTa_696                   float64
#  727   RoBERTa_697                   float64
#  728   RoBERTa_698                   float64
#  729   RoBERTa_699                   float64
#  730   RoBERTa_700                   float64
#  731   RoBERTa_701                   float64
#  732   RoBERTa_702                   float64
#  733   RoBERTa_703                   float64
#  734   RoBERTa_704                   float64
#  735   RoBERTa_705                   float64
#  736   RoBERTa_706                   float64
#  737   RoBERTa_707                   float64
#  738   RoBERTa_708                   float64
#  739   RoBERTa_709                   float64
#  740   RoBERTa_710                   float64
#  741   RoBERTa_711                   float64
#  742   RoBERTa_712                   float64
#  743   RoBERTa_713                   float64
#  744   RoBERTa_714                   float64
#  745   RoBERTa_715                   float64
#  746   RoBERTa_716                   float64
#  747   RoBERTa_717                   float64
#  748   RoBERTa_718                   float64
#  749   RoBERTa_719                   float64
#  750   RoBERTa_720                   float64
#  751   RoBERTa_721                   float64
#  752   RoBERTa_722                   float64
#  753   RoBERTa_723                   float64
#  754   RoBERTa_724                   float64
#  755   RoBERTa_725                   float64
#  756   RoBERTa_726                   float64
#  757   RoBERTa_727                   float64
#  758   RoBERTa_728                   float64
#  759   RoBERTa_729                   float64
#  760   RoBERTa_730                   float64
#  761   RoBERTa_731                   float64
#  762   RoBERTa_732                   float64
#  763   RoBERTa_733                   float64
#  764   RoBERTa_734                   float64
#  765   RoBERTa_735                   float64
#  766   RoBERTa_736                   float64
#  767   RoBERTa_737                   float64
#  768   RoBERTa_738                   float64
#  769   RoBERTa_739                   float64
#  770   RoBERTa_740                   float64
#  771   RoBERTa_741                   float64
#  772   RoBERTa_742                   float64
#  773   RoBERTa_743                   float64
#  774   RoBERTa_744                   float64
#  775   RoBERTa_745                   float64
#  776   RoBERTa_746                   float64
#  777   RoBERTa_747                   float64
#  778   RoBERTa_748                   float64
#  779   RoBERTa_749                   float64
#  780   RoBERTa_750                   float64
#  781   RoBERTa_751                   float64
#  782   RoBERTa_752                   float64
#  783   RoBERTa_753                   float64
#  784   RoBERTa_754                   float64
#  785   RoBERTa_755                   float64
#  786   RoBERTa_756                   float64
#  787   RoBERTa_757                   float64
#  788   RoBERTa_758                   float64
#  789   RoBERTa_759                   float64
#  790   RoBERTa_760                   float64
#  791   RoBERTa_761                   float64
#  792   RoBERTa_762                   float64
#  793   RoBERTa_763                   float64
#  794   RoBERTa_764                   float64
#  795   RoBERTa_765                   float64
#  796   RoBERTa_766                   float64
#  797   RoBERTa_767                   float64
#  798   RoBERTa_768                   float64
#  799   RoBERTa_769                   float64
#  800   RoBERTa_770                   float64
#  801   RoBERTa_771                   float64
#  802   RoBERTa_772                   float64
#  803   RoBERTa_773                   float64
#  804   RoBERTa_774                   float64
#  805   RoBERTa_775                   float64
#  806   RoBERTa_776                   float64
#  807   RoBERTa_777                   float64
#  808   RoBERTa_778                   float64
#  809   RoBERTa_779                   float64
#  810   RoBERTa_780                   float64
#  811   RoBERTa_781                   float64
#  812   RoBERTa_782                   float64
#  813   RoBERTa_783                   float64
#  814   RoBERTa_784                   float64
#  815   RoBERTa_785                   float64
#  816   RoBERTa_786                   float64
#  817   RoBERTa_787                   float64
#  818   RoBERTa_788                   float64
#  819   RoBERTa_789                   float64
#  820   RoBERTa_790                   float64
#  821   RoBERTa_791                   float64
#  822   RoBERTa_792                   float64
#  823   RoBERTa_793                   float64
#  824   RoBERTa_794                   float64
#  825   RoBERTa_795                   float64
#  826   RoBERTa_796                   float64
#  827   RoBERTa_797                   float64
#  828   RoBERTa_798                   float64
#  829   RoBERTa_799                   float64
#  830   RoBERTa_800                   float64
#  831   RoBERTa_801                   float64
#  832   RoBERTa_802                   float64
#  833   RoBERTa_803                   float64
#  834   RoBERTa_804                   float64
#  835   RoBERTa_805                   float64
#  836   RoBERTa_806                   float64
#  837   RoBERTa_807                   float64
#  838   RoBERTa_808                   float64
#  839   RoBERTa_809                   float64
#  840   RoBERTa_810                   float64
#  841   RoBERTa_811                   float64
#  842   RoBERTa_812                   float64
#  843   RoBERTa_813                   float64
#  844   RoBERTa_814                   float64
#  845   RoBERTa_815                   float64
#  846   RoBERTa_816                   float64
#  847   RoBERTa_817                   float64
#  848   RoBERTa_818                   float64
#  849   RoBERTa_819                   float64
#  850   RoBERTa_820                   float64
#  851   RoBERTa_821                   float64
#  852   RoBERTa_822                   float64
#  853   RoBERTa_823                   float64
#  854   RoBERTa_824                   float64
#  855   RoBERTa_825                   float64
#  856   RoBERTa_826                   float64
#  857   RoBERTa_827                   float64
#  858   RoBERTa_828                   float64
#  859   RoBERTa_829                   float64
#  860   RoBERTa_830                   float64
#  861   RoBERTa_831                   float64
#  862   RoBERTa_832                   float64
#  863   RoBERTa_833                   float64
#  864   RoBERTa_834                   float64
#  865   RoBERTa_835                   float64
#  866   RoBERTa_836                   float64
#  867   RoBERTa_837                   float64
#  868   RoBERTa_838                   float64
#  869   RoBERTa_839                   float64
#  870   RoBERTa_840                   float64
#  871   RoBERTa_841                   float64
#  872   RoBERTa_842                   float64
#  873   RoBERTa_843                   float64
#  874   RoBERTa_844                   float64
#  875   RoBERTa_845                   float64
#  876   RoBERTa_846                   float64
#  877   RoBERTa_847                   float64
#  878   RoBERTa_848                   float64
#  879   RoBERTa_849                   float64
#  880   RoBERTa_850                   float64
#  881   RoBERTa_851                   float64
#  882   RoBERTa_852                   float64
#  883   RoBERTa_853                   float64
#  884   RoBERTa_854                   float64
#  885   RoBERTa_855                   float64
#  886   RoBERTa_856                   float64
#  887   RoBERTa_857                   float64
#  888   RoBERTa_858                   float64
#  889   RoBERTa_859                   float64
#  890   RoBERTa_860                   float64
#  891   RoBERTa_861                   float64
#  892   RoBERTa_862                   float64
#  893   RoBERTa_863                   float64
#  894   RoBERTa_864                   float64
#  895   RoBERTa_865                   float64
#  896   RoBERTa_866                   float64
#  897   RoBERTa_867                   float64
#  898   RoBERTa_868                   float64
#  899   RoBERTa_869                   float64
#  900   RoBERTa_870                   float64
#  901   RoBERTa_871                   float64
#  902   RoBERTa_872                   float64
#  903   RoBERTa_873                   float64
#  904   RoBERTa_874                   float64
#  905   RoBERTa_875                   float64
#  906   RoBERTa_876                   float64
#  907   RoBERTa_877                   float64
#  908   RoBERTa_878                   float64
#  909   RoBERTa_879                   float64
#  910   RoBERTa_880                   float64
#  911   RoBERTa_881                   float64
#  912   RoBERTa_882                   float64
#  913   RoBERTa_883                   float64
#  914   RoBERTa_884                   float64
#  915   RoBERTa_885                   float64
#  916   RoBERTa_886                   float64
#  917   RoBERTa_887                   float64
#  918   RoBERTa_888                   float64
#  919   RoBERTa_889                   float64
#  920   RoBERTa_890                   float64
#  921   RoBERTa_891                   float64
#  922   RoBERTa_892                   float64
#  923   RoBERTa_893                   float64
#  924   RoBERTa_894                   float64
#  925   RoBERTa_895                   float64
#  926   RoBERTa_896                   float64
#  927   RoBERTa_897                   float64
#  928   RoBERTa_898                   float64
#  929   RoBERTa_899                   float64
#  930   RoBERTa_900                   float64
#  931   RoBERTa_901                   float64
#  932   RoBERTa_902                   float64
#  933   RoBERTa_903                   float64
#  934   RoBERTa_904                   float64
#  935   RoBERTa_905                   float64
#  936   RoBERTa_906                   float64
#  937   RoBERTa_907                   float64
#  938   RoBERTa_908                   float64
#  939   RoBERTa_909                   float64
#  940   RoBERTa_910                   float64
#  941   RoBERTa_911                   float64
#  942   RoBERTa_912                   float64
#  943   RoBERTa_913                   float64
#  944   RoBERTa_914                   float64
#  945   RoBERTa_915                   float64
#  946   RoBERTa_916                   float64
#  947   RoBERTa_917                   float64
#  948   RoBERTa_918                   float64
#  949   RoBERTa_919                   float64
#  950   RoBERTa_920                   float64
#  951   RoBERTa_921                   float64
#  952   RoBERTa_922                   float64
#  953   RoBERTa_923                   float64
#  954   RoBERTa_924                   float64
#  955   RoBERTa_925                   float64
#  956   RoBERTa_926                   float64
#  957   RoBERTa_927                   float64
#  958   RoBERTa_928                   float64
#  959   RoBERTa_929                   float64
#  960   RoBERTa_930                   float64
#  961   RoBERTa_931                   float64
#  962   RoBERTa_932                   float64
#  963   RoBERTa_933                   float64
#  964   RoBERTa_934                   float64
#  965   RoBERTa_935                   float64
#  966   RoBERTa_936                   float64
#  967   RoBERTa_937                   float64
#  968   RoBERTa_938                   float64
#  969   RoBERTa_939                   float64
#  970   RoBERTa_940                   float64
#  971   RoBERTa_941                   float64
#  972   RoBERTa_942                   float64
#  973   RoBERTa_943                   float64
#  974   RoBERTa_944                   float64
#  975   RoBERTa_945                   float64
#  976   RoBERTa_946                   float64
#  977   RoBERTa_947                   float64
#  978   RoBERTa_948                   float64
#  979   RoBERTa_949                   float64
#  980   RoBERTa_950                   float64
#  981   RoBERTa_951                   float64
#  982   RoBERTa_952                   float64
#  983   RoBERTa_953                   float64
#  984   RoBERTa_954                   float64
#  985   RoBERTa_955                   float64
#  986   RoBERTa_956                   float64
#  987   RoBERTa_957                   float64
#  988   RoBERTa_958                   float64
#  989   RoBERTa_959                   float64
#  990   RoBERTa_960                   float64
#  991   RoBERTa_961                   float64
#  992   RoBERTa_962                   float64
#  993   RoBERTa_963                   float64
#  994   RoBERTa_964                   float64
#  995   RoBERTa_965                   float64
#  996   RoBERTa_966                   float64
#  997   RoBERTa_967                   float64
#  998   RoBERTa_968                   float64
#  999   RoBERTa_969                   float64
#  1000  RoBERTa_970                   float64
#  1001  RoBERTa_971                   float64
#  1002  RoBERTa_972                   float64
#  1003  RoBERTa_973                   float64
#  1004  RoBERTa_974                   float64
#  1005  RoBERTa_975                   float64
#  1006  RoBERTa_976                   float64
#  1007  RoBERTa_977                   float64
#  1008  RoBERTa_978                   float64
#  1009  RoBERTa_979                   float64
#  1010  RoBERTa_980                   float64
#  1011  RoBERTa_981                   float64
#  1012  RoBERTa_982                   float64
#  1013  RoBERTa_983                   float64
#  1014  RoBERTa_984                   float64
#  1015  RoBERTa_985                   float64
#  1016  RoBERTa_986                   float64
#  1017  RoBERTa_987                   float64
#  1018  RoBERTa_988                   float64
#  1019  RoBERTa_989                   float64
#  1020  RoBERTa_990                   float64
#  1021  RoBERTa_991                   float64
#  1022  RoBERTa_992                   float64
#  1023  RoBERTa_993                   float64
#  1024  RoBERTa_994                   float64
#  1025  RoBERTa_995                   float64
#  1026  RoBERTa_996                   float64
#  1027  RoBERTa_997                   float64
#  1028  RoBERTa_998                   float64
#  1029  RoBERTa_999                   float64
#  1030  RoBERTa_1000                  float64
#  1031  RoBERTa_1001                  float64
#  1032  RoBERTa_1002                  float64
#  1033  RoBERTa_1003                  float64
#  1034  RoBERTa_1004                  float64
#  1035  RoBERTa_1005                  float64
#  1036  RoBERTa_1006                  float64
#  1037  RoBERTa_1007                  float64
#  1038  RoBERTa_1008                  float64
#  1039  RoBERTa_1009                  float64
#  1040  RoBERTa_1010                  float64
#  1041  RoBERTa_1011                  float64
#  1042  RoBERTa_1012                  float64
#  1043  RoBERTa_1013                  float64
#  1044  RoBERTa_1014                  float64
#  1045  RoBERTa_1015                  float64
#  1046  RoBERTa_1016                  float64
#  1047  RoBERTa_1017                  float64
#  1048  RoBERTa_1018                  float64
#  1049  RoBERTa_1019                  float64
#  1050  RoBERTa_1020                  float64
#  1051  RoBERTa_1021                  float64
#  1052  RoBERTa_1022                  float64
#  1053  RoBERTa_1023                  float64
#  1054  3_day                         float64
#  1055  3_day_single                  float64
#  1056  7_day                         float64
#  1057  7_day_single                  float64
#  1058  15_day                        float64
#  1059  15_day_single                 float64
#  1060  30_day                        float64
#  1061  30_day_single                 float64
# dtypes: Int64(1), float64(1059), int32(1), object(1)
# memory usage: 2.3+ GB

# %%
original_dataset['Date'] = pd.to_datetime(original_dataset['Date'].astype(str), format='%Y%m%d')
train_features = original_dataset[original_dataset['Date'] <= '2017-08-02']
val_features = original_dataset[(original_dataset['Date'] >= '2017-08-03') & (original_dataset['Date'] < '2017-10-24')]
test_features = original_dataset[original_dataset['Date'] >= '2017-10-24']

print(len(train_features))
print(len(val_features))
print(len(test_features))

train_features = train_features.drop(['Company','Date','Sentence_num','3_day','3_day_single','7_day','7_day_single', '15_day','15_day_single','30_day','30_day_single'], axis=1).to_numpy()
val_features = val_features.drop(['Company','Date','Sentence_num','3_day','3_day_single','7_day','7_day_single', '15_day','15_day_single','30_day','30_day_single'], axis=1).to_numpy()
test_features = test_features.drop(['Company','Date','Sentence_num','3_day','3_day_single','7_day','7_day_single', '15_day','15_day_single','30_day','30_day_single'], axis=1).to_numpy()

print(train_features.shape)
print(val_features.shape)
print(test_features.shape)

# # for HTML
# # FEATURES- Reshape the NumPy array to have dimensions (  meetings, 523 sentences (with padding), 327 features)
np.save('data/train_features.npy', train_features.reshape(392, 523, 1051))
np.save('data/val_features.npy', val_features.reshape(56, 523, 1051))
np.save('data/test_features.npy', test_features.reshape(117, 523, 1051))

# # targets to numpy & dump rows without targets
targets = targets[~((targets['3_day'] == 0) & 
                    (targets['7_day'] == 0) & 
                    (targets['15_day'] == 0) & 
                    (targets['30_day'] == 0))]


targets = targets.copy().sort_values(by=['Date', 'Company'], ascending=[True, True])
targets['Date'] = pd.to_datetime(targets['Date'].astype(str), format='%Y%m%d')

train_targets = targets[targets['Date'] <= '2017-08-02']
val_targets = targets[(targets['Date'] >= '2017-08-03') & (targets['Date'] < '2017-10-24')]
test_targets = targets[targets['Date'] >= '2017-10-24']

print(train_targets.shape)
print(val_targets.shape)
print(test_targets.shape)

np.save('data/train_targets.npy', train_targets['3_day'].to_numpy())
np.save('data/val_targets.npy', val_targets['3_day'].to_numpy())
np.save('data/test_targets.npy', test_targets['3_day'].to_numpy())

np.save('data/train_secondary_targets.npy', train_targets['3_day_single'].to_numpy())
np.save('data/val_secondary_targets.npy', val_targets['3_day_single'].to_numpy())
np.save('data/test_secondary_targets.npy', test_targets['3_day_single'].to_numpy())
# Out:
# 205016
# 29288
# 61191
# (205016, 1051)
# (29288, 1051)
# (61191, 1051)
# (392, 11)
# (56, 11)
# (117, 11)

# %% [markdown]
# # Final MAEC dataset

# %%
MAEC_praat_features['Date'] = MAEC_praat_features['Date'].astype('Int64')

##################################################################
# if you want to merge Glove features 
# Merge glove and Pratt features (each sentence is 327 features)
# MAEC_features = pd.merge(MAEC_praat_features, MAEC_glove_features, how="left",on = ['Ticker','Date','Sentence_num'])
##################################################################
# Merge RoBERTa and Pratt features (each sentence is 1051 features)
MAEC_features = pd.merge(MAEC_praat_features, MAEC_RoBERTa_features, how="left",on = ['Ticker','Date','Sentence_num'])
MAEC_features = MAEC_features.drop(['Shimmer apq11','Audio Length','audio_file'], axis=1)

# The maximum sentences per meeting is 497
# Ensure each meeting has 497 sentences, add zeros to the end
def add_zero_padding(group):
    complete_index = pd.Index(np.arange(1, 498), name='Sentence_num')
    group = group.set_index('Sentence_num').reindex(complete_index).reset_index()
    
    group['Company'] = group['Company'].fillna(method='ffill').fillna(method='bfill')
    group['Date'] = group['Date'].fillna(method='ffill').fillna(method='bfill')
    
    group.fillna(0.0, inplace=True)
    return group

MAEC_features = MAEC_features.groupby(['Company', 'Date']).apply(add_zero_padding).reset_index(drop=True)
MAEC_features.fillna(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 9
#       1 MAEC_praat_features['Date'] = MAEC_praat_features['Date'].astype('Int64')
#       3 ##################################################################
#       4 # if you want to merge Glove features
#       5 # Merge glove and Pratt features (each sentence is 327 features)
#       6 # MAEC_features = pd.merge(MAEC_praat_features, MAEC_glove_features, how="left",on = ['Ticker','Date','Sentence_num'])
#       7 ##################################################################
#       8 # Merge RoBERTa and Pratt features (each sentence is 1051 features)
# ----> 9 MAEC_features = pd.merge(MAEC_praat_features, MAEC_RoBERTa_features, how="left",on = ['Ticker','Date','Sentence_num'])
#      10 MAEC_features = MAEC_features.drop(['Shimmer apq11','Audio Length','audio_file'], axis=1)
#      12 # The maximum sentences per meeting is 497
#      13 # Ensure each meeting has 497 sentences, add zeros to the end
#
# NameError: name 'MAEC_RoBERTa_features' is not defined
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Merge the targets 
# (will be duplicated 497 times, for each meeting, but that's okay for now)
# we need the date and Ticker columns to sort
MAEC_targets['Date'] = MAEC_targets['Date'].astype(str).str.replace('-', '').astype('Int64')
MAEC_dataset = pd.merge(MAEC_features, MAEC_targets, how="left",on = ['Ticker','Date'])

# Fill in null
rows_with_nulls = MAEC_dataset[MAEC_dataset.isnull().any(axis=1)]
# print(rows_with_nulls)
MAEC_dataset.fillna(0, inplace=True)

# dump rows without targets
MAEC_dataset = MAEC_dataset.drop(['Ticker'], axis=1)
MAEC_dataset = MAEC_dataset[~((MAEC_dataset['3_day'] == 0) & 
                                    (MAEC_dataset['7_day'] == 0) & 
                                    (MAEC_dataset['15_day'] == 0) & 
                                    (MAEC_dataset['30_day'] == 0))]

MAEC_dataset = MAEC_dataset.sort_values(by=['Date', 'Ticker', 'Sentence_num'], ascending=[True, True, True])
TEXT_emb = MAEC_dataset.drop(['Ticker','Date','Sentence_num','3_day','3_day_single','7_day','7_day_single',
                                 '15_day','15_day_single','30_day','30_day_single'], axis=1).to_numpy()
# for HTML
# FEATURES- Reshape the NumPy array to have dimensions (565 meetings, 497 sentences (with padding), 1051 features)
# TEXT_emb = TEXT_emb.reshape(565, 497, 1051)
TEXT_emb = TEXT_emb.reshape(565, 497, 1051)

# targets to numpy & dump rows without targets
MAEC_targets = MAEC_targets[~((MAEC_targets['3_day'] == 0) & 
                            (MAEC_targets['7_day'] == 0) & 
                            (MAEC_targets['15_day'] == 0) & 
                            (MAEC_targets['30_day'] == 0))]

MAEC_targets = MAEC_targets.copy().sort_values(by=['Date', 'Ticker'], ascending=[True, True])
LABEL_emb_b = MAEC_targets['3_day_single'].to_numpy() # (1051,)
LABEL_emb = MAEC_targets['3_day'].to_numpy() # (1051,)

np.save('data/MAEC_TEXT_emb.npy',MAEC_ TEXT_emb)
np.save('data/MAEC_LABEL_emb.npy', MAEC_LABEL_emb)
np.save('data/MAEC_LABEL_emb_b.npy', MAEC_LABEL_emb_b)

# MAEC_dataset = MAEC_dataset.groupby(['Company', 'Date'])
MAEC_dataset.info(verbose=True)
###### save ############################################
MAEC_dataset.to_csv('data/MAEC_dataset.csv', index=False)
########################################################
