# %%
import yfinance as yf
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import re
import os
from datetime import datetime
from tqdm import tqdm
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
ACL19_dir = r"D:\ACL19_Release" # too big for GitHub https://github.com/GeminiLn/EarningsCall_Dataset 
MAEC_dir = 'data/MAEC' # https://github.com/Earnings-Call-Dataset/MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction
sp1500_dir = r"D:\sp1500" 
# there is a link for the audio data in the MAEC GitHub, but it does not work
# I emailed the authors, and they send another link.
# There is like a half-million files, but only 19 GB
# https://drive.google.com/file/d/1m1GRCHgKn9Vz9IFMC_SpCog6uP3-gFgY/view?usp=drive_link

# %% [markdown]
# # Original dataset
# [paper](https://aclanthology.org/P19-1038.pdf)
# [GitHub](https://github.com/GeminiLn/EarningsCall_Dataset)

# %%
# Loop through the directory, each folder represents an earnings conference call; the folders are named as "CompanyName_Date".
filename_data = []
for filename in os.listdir(ACL19_dir):
    company_name, date_str = filename.rsplit('_', 1)
    date_str = date_str.split('.')[0] 
    date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    filename_data.append([company_name, date])
filename_data = pd.DataFrame(filename_data, columns=["Company", "Date"])
filename_data.drop_duplicates(inplace=True)

# Special file I made to match the company name to the ticker
company_ticker = pd.read_csv('data/company_ticker.csv')# special file
filename_data = filename_data.merge(company_ticker, on="Company", how="left")
filename_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  572 non-null    object
#  1   Date     572 non-null    object
#  2   Ticker   572 non-null    object
# dtypes: object(3)
# memory usage: 13.5+ KB

# %% [markdown]
# # Yahoo
#
# In order to compare apples to apples, we need stock data for the year 2017, for each ticker. In the original paper, the loss function is MSE of standard deviation of n_day after the call (3, 7, 15, 30 days).

# %%
tickers = filename_data.Ticker.unique().tolist()
# 9 tickers do not have data on Yahoo! (No longer trading)
tickers_to_remove = ['GGP', 'CA', 'STI', 'FLT', 'NLSN', 'WRK','RTN', 'UTX', 'DISH']
tickers = [ticker for ticker in tickers if ticker not in tickers_to_remove]
yahoo_data = yf.download(tickers, start="2017-01-01", end="2017-12-31", group_by="ticker")
yahoo_data.index = yahoo_data.index.tz_localize(None)
yahoo_data.to_csv('data/yahoo_data.csv')
yahoo_data.info(verbose=True)
# Out:
# [*********************100%***********************]  265 of 265 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2017-01-03 to 2017-12-29
# Data columns (total 1590 columns):
#  #     Column              Dtype
# ---    ------              -----
#  0     (REGN, Open)        float64
#  1     (REGN, High)        float64
#  2     (REGN, Low)         float64
#  3     (REGN, Close)       float64
#  4     (REGN, Adj Close)   float64
#  5     (REGN, Volume)      int64
#  6     (NEM, Open)         float64
#  7     (NEM, High)         float64
#  8     (NEM, Low)          float64
#  9     (NEM, Close)        float64
#  10    (NEM, Adj Close)    float64
#  11    (NEM, Volume)       int64
#  12    (LRCX, Open)        float64
#  13    (LRCX, High)        float64
#  14    (LRCX, Low)         float64
#  15    (LRCX, Close)       float64
#  16    (LRCX, Adj Close)   float64
#  17    (LRCX, Volume)      int64
#  18    (IPGP, Open)        float64
#  19    (IPGP, High)        float64
#  20    (IPGP, Low)         float64
#  21    (IPGP, Close)       float64
#  22    (IPGP, Adj Close)   float64
#  23    (IPGP, Volume)      int64
#  24    (ULTA, Open)        float64
#  25    (ULTA, High)        float64
#  26    (ULTA, Low)         float64
#  27    (ULTA, Close)       float64
#  28    (ULTA, Adj Close)   float64
#  29    (ULTA, Volume)      int64
#  30    (TDY, Open)         float64
#  31    (TDY, High)         float64
#  32    (TDY, Low)          float64
#  33    (TDY, Close)        float64
#  34    (TDY, Adj Close)    float64
#  35    (TDY, Volume)       int64
#  36    (DG, Open)          float64
#  37    (DG, High)          float64
#  38    (DG, Low)           float64
#  39    (DG, Close)         float64
#  40    (DG, Adj Close)     float64
#  41    (DG, Volume)        int64
#  42    (PCAR, Open)        float64
#  43    (PCAR, High)        float64
#  44    (PCAR, Low)         float64
#  45    (PCAR, Close)       float64
#  46    (PCAR, Adj Close)   float64
#  47    (PCAR, Volume)      int64
#  48    (AXS, Open)         float64
#  49    (AXS, High)         float64
#  50    (AXS, Low)          float64
#  51    (AXS, Close)        float64
#  52    (AXS, Adj Close)    float64
#  53    (AXS, Volume)       int64
#  54    (LUMN, Open)        float64
#  55    (LUMN, High)        float64
#  56    (LUMN, Low)         float64
#  57    (LUMN, Close)       float64
#  58    (LUMN, Adj Close)   float64
#  59    (LUMN, Volume)      int64
#  60    (DGX, Open)         float64
#  61    (DGX, High)         float64
#  62    (DGX, Low)          float64
#  63    (DGX, Close)        float64
#  64    (DGX, Adj Close)    float64
#  65    (DGX, Volume)       int64
#  66    (CBOE, Open)        float64
#  67    (CBOE, High)        float64
#  68    (CBOE, Low)         float64
#  69    (CBOE, Close)       float64
#  70    (CBOE, Adj Close)   float64
#  71    (CBOE, Volume)      int64
#  72    (TSCO, Open)        float64
#  73    (TSCO, High)        float64
#  74    (TSCO, Low)         float64
#  75    (TSCO, Close)       float64
#  76    (TSCO, Adj Close)   float64
#  77    (TSCO, Volume)      int64
#  78    (HAL, Open)         float64
#  79    (HAL, High)         float64
#  80    (HAL, Low)          float64
#  81    (HAL, Close)        float64
#  82    (HAL, Adj Close)    float64
#  83    (HAL, Volume)       int64
#  84    (GS, Open)          float64
#  85    (GS, High)          float64
#  86    (GS, Low)           float64
#  87    (GS, Close)         float64
#  88    (GS, Adj Close)     float64
#  89    (GS, Volume)        int64
#  90    (RF, Open)          float64
#  91    (RF, High)          float64
#  92    (RF, Low)           float64
#  93    (RF, Close)         float64
#  94    (RF, Adj Close)     float64
#  95    (RF, Volume)        int64
#  96    (KO, Open)          float64
#  97    (KO, High)          float64
#  98    (KO, Low)           float64
#  99    (KO, Close)         float64
#  100   (KO, Adj Close)     float64
#  101   (KO, Volume)        int64
#  102   (BDX, Open)         float64
#  103   (BDX, High)         float64
#  104   (BDX, Low)          float64
#  105   (BDX, Close)        float64
#  106   (BDX, Adj Close)    float64
#  107   (BDX, Volume)       int64
#  108   (HES, Open)         float64
#  109   (HES, High)         float64
#  110   (HES, Low)          float64
#  111   (HES, Close)        float64
#  112   (HES, Adj Close)    float64
#  113   (HES, Volume)       int64
#  114   (VTRS, Open)        float64
#  115   (VTRS, High)        float64
#  116   (VTRS, Low)         float64
#  117   (VTRS, Close)       float64
#  118   (VTRS, Adj Close)   float64
#  119   (VTRS, Volume)      int64
#  120   (EMR, Open)         float64
#  121   (EMR, High)         float64
#  122   (EMR, Low)          float64
#  123   (EMR, Close)        float64
#  124   (EMR, Adj Close)    float64
#  125   (EMR, Volume)       int64
#  126   (ABT, Open)         float64
#  127   (ABT, High)         float64
#  128   (ABT, Low)          float64
#  129   (ABT, Close)        float64
#  130   (ABT, Adj Close)    float64
#  131   (ABT, Volume)       int64
#  132   (IBM, Open)         float64
#  133   (IBM, High)         float64
#  134   (IBM, Low)          float64
#  135   (IBM, Close)        float64
#  136   (IBM, Adj Close)    float64
#  137   (IBM, Volume)       int64
#  138   (DHR, Open)         float64
#  139   (DHR, High)         float64
#  140   (DHR, Low)          float64
#  141   (DHR, Close)        float64
#  142   (DHR, Adj Close)    float64
#  143   (DHR, Volume)       int64
#  144   (HBI, Open)         float64
#  145   (HBI, High)         float64
#  146   (HBI, Low)          float64
#  147   (HBI, Close)        float64
#  148   (HBI, Adj Close)    float64
#  149   (HBI, Volume)       int64
#  150   (HOLX, Open)        float64
#  151   (HOLX, High)        float64
#  152   (HOLX, Low)         float64
#  153   (HOLX, Close)       float64
#  154   (HOLX, Adj Close)   float64
#  155   (HOLX, Volume)      int64
#  156   (CVX, Open)         float64
#  157   (CVX, High)         float64
#  158   (CVX, Low)          float64
#  159   (CVX, Close)        float64
#  160   (CVX, Adj Close)    float64
#  161   (CVX, Volume)       int64
#  162   (COO, Open)         float64
#  163   (COO, High)         float64
#  164   (COO, Low)          float64
#  165   (COO, Close)        float64
#  166   (COO, Adj Close)    float64
#  167   (COO, Volume)       int64
#  168   (KMB, Open)         float64
#  169   (KMB, High)         float64
#  170   (KMB, Low)          float64
#  171   (KMB, Close)        float64
#  172   (KMB, Adj Close)    float64
#  173   (KMB, Volume)       int64
#  174   (AES, Open)         float64
#  175   (AES, High)         float64
#  176   (AES, Low)          float64
#  177   (AES, Close)        float64
#  178   (AES, Adj Close)    float64
#  179   (AES, Volume)       int64
#  180   (BIIB, Open)        float64
#  181   (BIIB, High)        float64
#  182   (BIIB, Low)         float64
#  183   (BIIB, Close)       float64
#  184   (BIIB, Adj Close)   float64
#  185   (BIIB, Volume)      int64
#  186   (LKQ, Open)         float64
#  187   (LKQ, High)         float64
#  188   (LKQ, Low)          float64
#  189   (LKQ, Close)        float64
#  190   (LKQ, Adj Close)    float64
#  191   (LKQ, Volume)       int64
#  192   (ADP, Open)         float64
#  193   (ADP, High)         float64
#  194   (ADP, Low)          float64
#  195   (ADP, Close)        float64
#  196   (ADP, Adj Close)    float64
#  197   (ADP, Volume)       int64
#  198   (CMA, Open)         float64
#  199   (CMA, High)         float64
#  200   (CMA, Low)          float64
#  201   (CMA, Close)        float64
#  202   (CMA, Adj Close)    float64
#  203   (CMA, Volume)       int64
#  204   (FFIV, Open)        float64
#  205   (FFIV, High)        float64
#  206   (FFIV, Low)         float64
#  207   (FFIV, Close)       float64
#  208   (FFIV, Adj Close)   float64
#  209   (FFIV, Volume)      int64
#  210   (BA, Open)          float64
#  211   (BA, High)          float64
#  212   (BA, Low)           float64
#  213   (BA, Close)         float64
#  214   (BA, Adj Close)     float64
#  215   (BA, Volume)        int64
#  216   (INTC, Open)        float64
#  217   (INTC, High)        float64
#  218   (INTC, Low)         float64
#  219   (INTC, Close)       float64
#  220   (INTC, Adj Close)   float64
#  221   (INTC, Volume)      int64
#  222   (DOV, Open)         float64
#  223   (DOV, High)         float64
#  224   (DOV, Low)          float64
#  225   (DOV, Close)        float64
#  226   (DOV, Adj Close)    float64
#  227   (DOV, Volume)       int64
#  228   (SBUX, Open)        float64
#  229   (SBUX, High)        float64
#  230   (SBUX, Low)         float64
#  231   (SBUX, Close)       float64
#  232   (SBUX, Adj Close)   float64
#  233   (SBUX, Volume)      int64
#  234   (DTE, Open)         float64
#  235   (DTE, High)         float64
#  236   (DTE, Low)          float64
#  237   (DTE, Close)        float64
#  238   (DTE, Adj Close)    float64
#  239   (DTE, Volume)       int64
#  240   (AMT, Open)         float64
#  241   (AMT, High)         float64
#  242   (AMT, Low)          float64
#  243   (AMT, Close)        float64
#  244   (AMT, Adj Close)    float64
#  245   (AMT, Volume)       int64
#  246   (AZN, Open)         float64
#  247   (AZN, High)         float64
#  248   (AZN, Low)          float64
#  249   (AZN, Close)        float64
#  250   (AZN, Adj Close)    float64
#  251   (AZN, Volume)       int64
#  252   (TEL, Open)         float64
#  253   (TEL, High)         float64
#  254   (TEL, Low)          float64
#  255   (TEL, Close)        float64
#  256   (TEL, Adj Close)    float64
#  257   (TEL, Volume)       int64
#  258   (D, Open)           float64
#  259   (D, High)           float64
#  260   (D, Low)            float64
#  261   (D, Close)          float64
#  262   (D, Adj Close)      float64
#  263   (D, Volume)         int64
#  264   (FITB, Open)        float64
#  265   (FITB, High)        float64
#  266   (FITB, Low)         float64
#  267   (FITB, Close)       float64
#  268   (FITB, Adj Close)   float64
#  269   (FITB, Volume)      int64
#  270   (PRGO, Open)        float64
#  271   (PRGO, High)        float64
#  272   (PRGO, Low)         float64
#  273   (PRGO, Close)       float64
#  274   (PRGO, Adj Close)   float64
#  275   (PRGO, Volume)      int64
#  276   (VTR, Open)         float64
#  277   (VTR, High)         float64
#  278   (VTR, Low)          float64
#  279   (VTR, Close)        float64
#  280   (VTR, Adj Close)    float64
#  281   (VTR, Volume)       int64
#  282   (WM, Open)          float64
#  283   (WM, High)          float64
#  284   (WM, Low)           float64
#  285   (WM, Close)         float64
#  286   (WM, Adj Close)     float64
#  287   (WM, Volume)        int64
#  288   (A, Open)           float64
#  289   (A, High)           float64
#  290   (A, Low)            float64
#  291   (A, Close)          float64
#  292   (A, Adj Close)      float64
#  293   (A, Volume)         int64
#  294   (WMT, Open)         float64
#  295   (WMT, High)         float64
#  296   (WMT, Low)          float64
#  297   (WMT, Close)        float64
#  298   (WMT, Adj Close)    float64
#  299   (WMT, Volume)       int64
#  300   (GLW, Open)         float64
#  301   (GLW, High)         float64
#  302   (GLW, Low)          float64
#  303   (GLW, Close)        float64
#  304   (GLW, Adj Close)    float64
#  305   (GLW, Volume)       int64
#  306   (X, Open)           float64
#  307   (X, High)           float64
#  308   (X, Low)            float64
#  309   (X, Close)          float64
#  310   (X, Adj Close)      float64
#  311   (X, Volume)         int64
#  312   (NUE, Open)         float64
#  313   (NUE, High)         float64
#  314   (NUE, Low)          float64
#  315   (NUE, Close)        float64
#  316   (NUE, Adj Close)    float64
#  317   (NUE, Volume)       int64
#  318   (LHX, Open)         float64
#  319   (LHX, High)         float64
#  320   (LHX, Low)          float64
#  321   (LHX, Close)        float64
#  322   (LHX, Adj Close)    float64
#  323   (LHX, Volume)       int64
#  324   (RL, Open)          float64
#  325   (RL, High)          float64
#  326   (RL, Low)           float64
#  327   (RL, Close)         float64
#  328   (RL, Adj Close)     float64
#  329   (RL, Volume)        int64
#  330   (HUM, Open)         float64
#  331   (HUM, High)         float64
#  332   (HUM, Low)          float64
#  333   (HUM, Close)        float64
#  334   (HUM, Adj Close)    float64
#  335   (HUM, Volume)       int64
#  336   (MMM, Open)         float64
#  337   (MMM, High)         float64
#  338   (MMM, Low)          float64
#  339   (MMM, Close)        float64
#  340   (MMM, Adj Close)    float64
#  341   (MMM, Volume)       int64
#  342   (PARA, Open)        float64
#  343   (PARA, High)        float64
#  344   (PARA, Low)         float64
#  345   (PARA, Close)       float64
#  346   (PARA, Adj Close)   float64
#  347   (PARA, Volume)      int64
#  348   (COR, Open)         float64
#  349   (COR, High)         float64
#  350   (COR, Low)          float64
#  351   (COR, Close)        float64
#  352   (COR, Adj Close)    float64
#  353   (COR, Volume)       int64
#  354   (LLY, Open)         float64
#  355   (LLY, High)         float64
#  356   (LLY, Low)          float64
#  357   (LLY, Close)        float64
#  358   (LLY, Adj Close)    float64
#  359   (LLY, Volume)       int64
#  360   (SCG, Open)         float64
#  361   (SCG, High)         float64
#  362   (SCG, Low)          float64
#  363   (SCG, Close)        float64
#  364   (SCG, Adj Close)    float64
#  365   (SCG, Volume)       int64
#  366   (TXN, Open)         float64
#  367   (TXN, High)         float64
#  368   (TXN, Low)          float64
#  369   (TXN, Close)        float64
#  370   (TXN, Adj Close)    float64
#  371   (TXN, Volume)       int64
#  372   (DUK, Open)         float64
#  373   (DUK, High)         float64
#  374   (DUK, Low)          float64
#  375   (DUK, Close)        float64
#  376   (DUK, Adj Close)    float64
#  377   (DUK, Volume)       int64
#  378   (RSG, Open)         float64
#  379   (RSG, High)         float64
#  380   (RSG, Low)          float64
#  381   (RSG, Close)        float64
#  382   (RSG, Adj Close)    float64
#  383   (RSG, Volume)       int64
#  384   (SYK, Open)         float64
#  385   (SYK, High)         float64
#  386   (SYK, Low)          float64
#  387   (SYK, Close)        float64
#  388   (SYK, Adj Close)    float64
#  389   (SYK, Volume)       int64
#  390   (GIS, Open)         float64
#  391   (GIS, High)         float64
#  392   (GIS, Low)          float64
#  393   (GIS, Close)        float64
#  394   (GIS, Adj Close)    float64
#  395   (GIS, Volume)       int64
#  396   (YUM, Open)         float64
#  397   (YUM, High)         float64
#  398   (YUM, Low)          float64
#  399   (YUM, Close)        float64
#  400   (YUM, Adj Close)    float64
#  401   (YUM, Volume)       int64
#  402   (CME, Open)         float64
#  403   (CME, High)         float64
#  404   (CME, Low)          float64
#  405   (CME, Close)        float64
#  406   (CME, Adj Close)    float64
#  407   (CME, Volume)       int64
#  408   (JCI, Open)         float64
#  409   (JCI, High)         float64
#  410   (JCI, Low)          float64
#  411   (JCI, Close)        float64
#  412   (JCI, Adj Close)    float64
#  413   (JCI, Volume)       int64
#  414   (GD, Open)          float64
#  415   (GD, High)          float64
#  416   (GD, Low)           float64
#  417   (GD, Close)         float64
#  418   (GD, Adj Close)     float64
#  419   (GD, Volume)        int64
#  420   (CAG, Open)         float64
#  421   (CAG, High)         float64
#  422   (CAG, Low)          float64
#  423   (CAG, Close)        float64
#  424   (CAG, Adj Close)    float64
#  425   (CAG, Volume)       int64
#  426   (NKE, Open)         float64
#  427   (NKE, High)         float64
#  428   (NKE, Low)          float64
#  429   (NKE, Close)        float64
#  430   (NKE, Adj Close)    float64
#  431   (NKE, Volume)       int64
#  432   (LMT, Open)         float64
#  433   (LMT, High)         float64
#  434   (LMT, Low)          float64
#  435   (LMT, Close)        float64
#  436   (LMT, Adj Close)    float64
#  437   (LMT, Volume)       int64
#  438   (SHW, Open)         float64
#  439   (SHW, High)         float64
#  440   (SHW, Low)          float64
#  441   (SHW, Close)        float64
#  442   (SHW, Adj Close)    float64
#  443   (SHW, Volume)       int64
#  444   (AKAM, Open)        float64
#  445   (AKAM, High)        float64
#  446   (AKAM, Low)         float64
#  447   (AKAM, Close)       float64
#  448   (AKAM, Adj Close)   float64
#  449   (AKAM, Volume)      int64
#  450   (ITW, Open)         float64
#  451   (ITW, High)         float64
#  452   (ITW, Low)          float64
#  453   (ITW, Close)        float64
#  454   (ITW, Adj Close)    float64
#  455   (ITW, Volume)       int64
#  456   (AET, Open)         float64
#  457   (AET, High)         float64
#  458   (AET, Low)          float64
#  459   (AET, Close)        float64
#  460   (AET, Adj Close)    float64
#  461   (AET, Volume)       int64
#  462   (CPB, Open)         float64
#  463   (CPB, High)         float64
#  464   (CPB, Low)          float64
#  465   (CPB, Close)        float64
#  466   (CPB, Adj Close)    float64
#  467   (CPB, Volume)       int64
#  468   (IR, Open)          float64
#  469   (IR, High)          float64
#  470   (IR, Low)           float64
#  471   (IR, Close)         float64
#  472   (IR, Adj Close)     float64
#  473   (IR, Volume)        float64
#  474   (AAP, Open)         float64
#  475   (AAP, High)         float64
#  476   (AAP, Low)          float64
#  477   (AAP, Close)        float64
#  478   (AAP, Adj Close)    float64
#  479   (AAP, Volume)       int64
#  480   (ROK, Open)         float64
#  481   (ROK, High)         float64
#  482   (ROK, Low)          float64
#  483   (ROK, Close)        float64
#  484   (ROK, Adj Close)    float64
#  485   (ROK, Volume)       int64
#  486   (BR, Open)          float64
#  487   (BR, High)          float64
#  488   (BR, Low)           float64
#  489   (BR, Close)         float64
#  490   (BR, Adj Close)     float64
#  491   (BR, Volume)        int64
#  492   (NKTR, Open)        float64
#  493   (NKTR, High)        float64
#  494   (NKTR, Low)         float64
#  495   (NKTR, Close)       float64
#  496   (NKTR, Adj Close)   float64
#  497   (NKTR, Volume)      int64
#  498   (CHD, Open)         float64
#  499   (CHD, High)         float64
#  500   (CHD, Low)          float64
#  501   (CHD, Close)        float64
#  502   (CHD, Adj Close)    float64
#  503   (CHD, Volume)       int64
#  504   (FL, Open)          float64
#  505   (FL, High)          float64
#  506   (FL, Low)           float64
#  507   (FL, Close)         float64
#  508   (FL, Adj Close)     float64
#  509   (FL, Volume)        int64
#  510   (IT, Open)          float64
#  511   (IT, High)          float64
#  512   (IT, Low)           float64
#  513   (IT, Close)         float64
#  514   (IT, Adj Close)     float64
#  515   (IT, Volume)        int64
#  516   (NDAQ, Open)        float64
#  517   (NDAQ, High)        float64
#  518   (NDAQ, Low)         float64
#  519   (NDAQ, Close)       float64
#  520   (NDAQ, Adj Close)   float64
#  521   (NDAQ, Volume)      int64
#  522   (FTV, Open)         float64
#  523   (FTV, High)         float64
#  524   (FTV, Low)          float64
#  525   (FTV, Close)        float64
#  526   (FTV, Adj Close)    float64
#  527   (FTV, Volume)       int64
#  528   (AON, Open)         float64
#  529   (AON, High)         float64
#  530   (AON, Low)          float64
#  531   (AON, Close)        float64
#  532   (AON, Adj Close)    float64
#  533   (AON, Volume)       int64
#  534   (GPC, Open)         float64
#  535   (GPC, High)         float64
#  536   (GPC, Low)          float64
#  537   (GPC, Close)        float64
#  538   (GPC, Adj Close)    float64
#  539   (GPC, Volume)       int64
#  540   (KLAC, Open)        float64
#  541   (KLAC, High)        float64
#  542   (KLAC, Low)         float64
#  543   (KLAC, Close)       float64
#  544   (KLAC, Adj Close)   float64
#  545   (KLAC, Volume)      int64
#  546   (PNW, Open)         float64
#  547   (PNW, High)         float64
#  548   (PNW, Low)          float64
#  549   (PNW, Close)        float64
#  550   (PNW, Adj Close)    float64
#  551   (PNW, Volume)       int64
#  552   (EIX, Open)         float64
#  553   (EIX, High)         float64
#  554   (EIX, Low)          float64
#  555   (EIX, Close)        float64
#  556   (EIX, Adj Close)    float64
#  557   (EIX, Volume)       int64
#  558   (DLR, Open)         float64
#  559   (DLR, High)         float64
#  560   (DLR, Low)          float64
#  561   (DLR, Close)        float64
#  562   (DLR, Adj Close)    float64
#  563   (DLR, Volume)       int64
#  564   (VRSN, Open)        float64
#  565   (VRSN, High)        float64
#  566   (VRSN, Low)         float64
#  567   (VRSN, Close)       float64
#  568   (VRSN, Adj Close)   float64
#  569   (VRSN, Volume)      int64
#  570   (LVMUY, Open)       float64
#  571   (LVMUY, High)       float64
#  572   (LVMUY, Low)        float64
#  573   (LVMUY, Close)      float64
#  574   (LVMUY, Adj Close)  float64
#  575   (LVMUY, Volume)     int64
#  576   (ICE, Open)         float64
#  577   (ICE, High)         float64
#  578   (ICE, Low)          float64
#  579   (ICE, Close)        float64
#  580   (ICE, Adj Close)    float64
#  581   (ICE, Volume)       int64
#  582   (AMZN, Open)        float64
#  583   (AMZN, High)        float64
#  584   (AMZN, Low)         float64
#  585   (AMZN, Close)       float64
#  586   (AMZN, Adj Close)   float64
#  587   (AMZN, Volume)      int64
#  588   (XRX, Open)         float64
#  589   (XRX, High)         float64
#  590   (XRX, Low)          float64
#  591   (XRX, Close)        float64
#  592   (XRX, Adj Close)    float64
#  593   (XRX, Volume)       int64
#  594   (SWKS, Open)        float64
#  595   (SWKS, High)        float64
#  596   (SWKS, Low)         float64
#  597   (SWKS, Close)       float64
#  598   (SWKS, Adj Close)   float64
#  599   (SWKS, Volume)      int64
#  600   (SRCL, Open)        float64
#  601   (SRCL, High)        float64
#  602   (SRCL, Low)         float64
#  603   (SRCL, Close)       float64
#  604   (SRCL, Adj Close)   float64
#  605   (SRCL, Volume)      int64
#  606   (NTAP, Open)        float64
#  607   (NTAP, High)        float64
#  608   (NTAP, Low)         float64
#  609   (NTAP, Close)       float64
#  610   (NTAP, Adj Close)   float64
#  611   (NTAP, Volume)      int64
#  612   (AXP, Open)         float64
#  613   (AXP, High)         float64
#  614   (AXP, Low)          float64
#  615   (AXP, Close)        float64
#  616   (AXP, Adj Close)    float64
#  617   (AXP, Volume)       int64
#  618   (ADSK, Open)        float64
#  619   (ADSK, High)        float64
#  620   (ADSK, Low)         float64
#  621   (ADSK, Close)       float64
#  622   (ADSK, Adj Close)   float64
#  623   (ADSK, Volume)      int64
#  624   (MCD, Open)         float64
#  625   (MCD, High)         float64
#  626   (MCD, Low)          float64
#  627   (MCD, Close)        float64
#  628   (MCD, Adj Close)    float64
#  629   (MCD, Volume)       int64
#  630   (HSY, Open)         float64
#  631   (HSY, High)         float64
#  632   (HSY, Low)          float64
#  633   (HSY, Close)        float64
#  634   (HSY, Adj Close)    float64
#  635   (HSY, Volume)       int64
#  636   (WDC, Open)         float64
#  637   (WDC, High)         float64
#  638   (WDC, Low)          float64
#  639   (WDC, Close)        float64
#  640   (WDC, Adj Close)    float64
#  641   (WDC, Volume)       int64
#  642   (HAS, Open)         float64
#  643   (HAS, High)         float64
#  644   (HAS, Low)          float64
#  645   (HAS, Close)        float64
#  646   (HAS, Adj Close)    float64
#  647   (HAS, Volume)       int64
#  648   (NSC, Open)         float64
#  649   (NSC, High)         float64
#  650   (NSC, Low)          float64
#  651   (NSC, Close)        float64
#  652   (NSC, Adj Close)    float64
#  653   (NSC, Volume)       int64
#  654   (RCL, Open)         float64
#  655   (RCL, High)         float64
#  656   (RCL, Low)          float64
#  657   (RCL, Close)        float64
#  658   (RCL, Adj Close)    float64
#  659   (RCL, Volume)       int64
#  660   (SLB, Open)         float64
#  661   (SLB, High)         float64
#  662   (SLB, Low)          float64
#  663   (SLB, Close)        float64
#  664   (SLB, Adj Close)    float64
#  665   (SLB, Volume)       int64
#  666   (RVTY, Open)        float64
#  667   (RVTY, High)        float64
#  668   (RVTY, Low)         float64
#  669   (RVTY, Close)       float64
#  670   (RVTY, Adj Close)   float64
#  671   (RVTY, Volume)      int64
#  672   (WELL, Open)        float64
#  673   (WELL, High)        float64
#  674   (WELL, Low)         float64
#  675   (WELL, Close)       float64
#  676   (WELL, Adj Close)   float64
#  677   (WELL, Volume)      int64
#  678   (CAH, Open)         float64
#  679   (CAH, High)         float64
#  680   (CAH, Low)          float64
#  681   (CAH, Close)        float64
#  682   (CAH, Adj Close)    float64
#  683   (CAH, Volume)       int64
#  684   (XEL, Open)         float64
#  685   (XEL, High)         float64
#  686   (XEL, Low)          float64
#  687   (XEL, Close)        float64
#  688   (XEL, Adj Close)    float64
#  689   (XEL, Volume)       int64
#  690   (MGM, Open)         float64
#  691   (MGM, High)         float64
#  692   (MGM, Low)          float64
#  693   (MGM, Close)        float64
#  694   (MGM, Adj Close)    float64
#  695   (MGM, Volume)       int64
#  696   (WY, Open)          float64
#  697   (WY, High)          float64
#  698   (WY, Low)           float64
#  699   (WY, Close)         float64
#  700   (WY, Adj Close)     float64
#  701   (WY, Volume)        int64
#  702   (BFH, Open)         float64
#  703   (BFH, High)         float64
#  704   (BFH, Low)          float64
#  705   (BFH, Close)        float64
#  706   (BFH, Adj Close)    float64
#  707   (BFH, Volume)       int64
#  708   (ABBV, Open)        float64
#  709   (ABBV, High)        float64
#  710   (ABBV, Low)         float64
#  711   (ABBV, Close)       float64
#  712   (ABBV, Adj Close)   float64
#  713   (ABBV, Volume)      int64
#  714   (EQT, Open)         float64
#  715   (EQT, High)         float64
#  716   (EQT, Low)          float64
#  717   (EQT, Close)        float64
#  718   (EQT, Adj Close)    float64
#  719   (EQT, Volume)       int64
#  720   (ALK, Open)         float64
#  721   (ALK, High)         float64
#  722   (ALK, Low)          float64
#  723   (ALK, Close)        float64
#  724   (ALK, Adj Close)    float64
#  725   (ALK, Volume)       int64
#  726   (BAX, Open)         float64
#  727   (BAX, High)         float64
#  728   (BAX, Low)          float64
#  729   (BAX, Close)        float64
#  730   (BAX, Adj Close)    float64
#  731   (BAX, Volume)       int64
#  732   (CTRA, Open)        float64
#  733   (CTRA, High)        float64
#  734   (CTRA, Low)         float64
#  735   (CTRA, Close)       float64
#  736   (CTRA, Adj Close)   float64
#  737   (CTRA, Volume)      int64
#  738   (COTY, Open)        float64
#  739   (COTY, High)        float64
#  740   (COTY, Low)         float64
#  741   (COTY, Close)       float64
#  742   (COTY, Adj Close)   float64
#  743   (COTY, Volume)      int64
#  744   (VLO, Open)         float64
#  745   (VLO, High)         float64
#  746   (VLO, Low)          float64
#  747   (VLO, Close)        float64
#  748   (VLO, Adj Close)    float64
#  749   (VLO, Volume)       int64
#  750   (PEP, Open)         float64
#  751   (PEP, High)         float64
#  752   (PEP, Low)          float64
#  753   (PEP, Close)        float64
#  754   (PEP, Adj Close)    float64
#  755   (PEP, Volume)       int64
#  756   (MOS, Open)         float64
#  757   (MOS, High)         float64
#  758   (MOS, Low)          float64
#  759   (MOS, Close)        float64
#  760   (MOS, Adj Close)    float64
#  761   (MOS, Volume)       int64
#  762   (MA, Open)          float64
#  763   (MA, High)          float64
#  764   (MA, Low)           float64
#  765   (MA, Close)         float64
#  766   (MA, Adj Close)     float64
#  767   (MA, Volume)        int64
#  768   (ECL, Open)         float64
#  769   (ECL, High)         float64
#  770   (ECL, Low)          float64
#  771   (ECL, Close)        float64
#  772   (ECL, Adj Close)    float64
#  773   (ECL, Volume)       int64
#  774   (IP, Open)          float64
#  775   (IP, High)          float64
#  776   (IP, Low)           float64
#  777   (IP, Close)         float64
#  778   (IP, Adj Close)     float64
#  779   (IP, Volume)        int64
#  780   (XOM, Open)         float64
#  781   (XOM, High)         float64
#  782   (XOM, Low)          float64
#  783   (XOM, Close)        float64
#  784   (XOM, Adj Close)    float64
#  785   (XOM, Volume)       int64
#  786   (MAS, Open)         float64
#  787   (MAS, High)         float64
#  788   (MAS, Low)          float64
#  789   (MAS, Close)        float64
#  790   (MAS, Adj Close)    float64
#  791   (MAS, Volume)       int64
#  792   (ELV, Open)         float64
#  793   (ELV, High)         float64
#  794   (ELV, Low)          float64
#  795   (ELV, Close)        float64
#  796   (ELV, Adj Close)    float64
#  797   (ELV, Volume)       int64
#  798   (TDG, Open)         float64
#  799   (TDG, High)         float64
#  800   (TDG, Low)          float64
#  801   (TDG, Close)        float64
#  802   (TDG, Adj Close)    float64
#  803   (TDG, Volume)       int64
#  804   (LEN, Open)         float64
#  805   (LEN, High)         float64
#  806   (LEN, Low)          float64
#  807   (LEN, Close)        float64
#  808   (LEN, Adj Close)    float64
#  809   (LEN, Volume)       int64
#  810   (TMO, Open)         float64
#  811   (TMO, High)         float64
#  812   (TMO, Low)          float64
#  813   (TMO, Close)        float64
#  814   (TMO, Adj Close)    float64
#  815   (TMO, Volume)       int64
#  816   (HPE, Open)         float64
#  817   (HPE, High)         float64
#  818   (HPE, Low)          float64
#  819   (HPE, Close)        float64
#  820   (HPE, Adj Close)    float64
#  821   (HPE, Volume)       int64
#  822   (MDLZ, Open)        float64
#  823   (MDLZ, High)        float64
#  824   (MDLZ, Low)         float64
#  825   (MDLZ, Close)       float64
#  826   (MDLZ, Adj Close)   float64
#  827   (MDLZ, Volume)      int64
#  828   (MAT, Open)         float64
#  829   (MAT, High)         float64
#  830   (MAT, Low)          float64
#  831   (MAT, Close)        float64
#  832   (MAT, Adj Close)    float64
#  833   (MAT, Volume)       int64
#  834   (ILMN, Open)        float64
#  835   (ILMN, High)        float64
#  836   (ILMN, Low)         float64
#  837   (ILMN, Close)       float64
#  838   (ILMN, Adj Close)   float64
#  839   (ILMN, Volume)      int64
#  840   (PPG, Open)         float64
#  841   (PPG, High)         float64
#  842   (PPG, Low)          float64
#  843   (PPG, Close)        float64
#  844   (PPG, Adj Close)    float64
#  845   (PPG, Volume)       int64
#  846   (CSCO, Open)        float64
#  847   (CSCO, High)        float64
#  848   (CSCO, Low)         float64
#  849   (CSCO, Close)       float64
#  850   (CSCO, Adj Close)   float64
#  851   (CSCO, Volume)      int64
#  852   (AEE, Open)         float64
#  853   (AEE, High)         float64
#  854   (AEE, Low)          float64
#  855   (AEE, Close)        float64
#  856   (AEE, Adj Close)    float64
#  857   (AEE, Volume)       int64
#  858   (VMC, Open)         float64
#  859   (VMC, High)         float64
#  860   (VMC, Low)          float64
#  861   (VMC, Close)        float64
#  862   (VMC, Adj Close)    float64
#  863   (VMC, Volume)       int64
#  864   (AMGN, Open)        float64
#  865   (AMGN, High)        float64
#  866   (AMGN, Low)         float64
#  867   (AMGN, Close)       float64
#  868   (AMGN, Adj Close)   float64
#  869   (AMGN, Volume)      int64
#  870   (PH, Open)          float64
#  871   (PH, High)          float64
#  872   (PH, Low)           float64
#  873   (PH, Close)         float64
#  874   (PH, Adj Close)     float64
#  875   (PH, Volume)        int64
#  876   (TGT, Open)         float64
#  877   (TGT, High)         float64
#  878   (TGT, Low)          float64
#  879   (TGT, Close)        float64
#  880   (TGT, Adj Close)    float64
#  881   (TGT, Volume)       int64
#  882   (HRL, Open)         float64
#  883   (HRL, High)         float64
#  884   (HRL, Low)          float64
#  885   (HRL, Close)        float64
#  886   (HRL, Adj Close)    float64
#  887   (HRL, Volume)       int64
#  888   (MU, Open)          float64
#  889   (MU, High)          float64
#  890   (MU, Low)           float64
#  891   (MU, Close)         float64
#  892   (MU, Adj Close)     float64
#  893   (MU, Volume)        int64
#  894   (PLD, Open)         float64
#  895   (PLD, High)         float64
#  896   (PLD, Low)          float64
#  897   (PLD, Close)        float64
#  898   (PLD, Adj Close)    float64
#  899   (PLD, Volume)       int64
#  900   (BEN, Open)         float64
#  901   (BEN, High)         float64
#  902   (BEN, Low)          float64
#  903   (BEN, Close)        float64
#  904   (BEN, Adj Close)    float64
#  905   (BEN, Volume)       int64
#  906   (AOS, Open)         float64
#  907   (AOS, High)         float64
#  908   (AOS, Low)          float64
#  909   (AOS, Close)        float64
#  910   (AOS, Adj Close)    float64
#  911   (AOS, Volume)       int64
#  912   (AMD, Open)         float64
#  913   (AMD, High)         float64
#  914   (AMD, Low)          float64
#  915   (AMD, Close)        float64
#  916   (AMD, Adj Close)    float64
#  917   (AMD, Volume)       int64
#  918   (CAT, Open)         float64
#  919   (CAT, High)         float64
#  920   (CAT, Low)          float64
#  921   (CAT, Close)        float64
#  922   (CAT, Adj Close)    float64
#  923   (CAT, Volume)       int64
#  924   (VZ, Open)          float64
#  925   (VZ, High)          float64
#  926   (VZ, Low)           float64
#  927   (VZ, Close)         float64
#  928   (VZ, Adj Close)     float64
#  929   (VZ, Volume)        int64
#  930   (SRE, Open)         float64
#  931   (SRE, High)         float64
#  932   (SRE, Low)          float64
#  933   (SRE, Close)        float64
#  934   (SRE, Adj Close)    float64
#  935   (SRE, Volume)       int64
#  936   (CI, Open)          float64
#  937   (CI, High)          float64
#  938   (CI, Low)           float64
#  939   (CI, Close)         float64
#  940   (CI, Adj Close)     float64
#  941   (CI, Volume)        int64
#  942   (DHI, Open)         float64
#  943   (DHI, High)         float64
#  944   (DHI, Low)          float64
#  945   (DHI, Close)        float64
#  946   (DHI, Adj Close)    float64
#  947   (DHI, Volume)       int64
#  948   (SEE, Open)         float64
#  949   (SEE, High)         float64
#  950   (SEE, Low)          float64
#  951   (SEE, Close)        float64
#  952   (SEE, Adj Close)    float64
#  953   (SEE, Volume)       int64
#  954   (CVS, Open)         float64
#  955   (CVS, High)         float64
#  956   (CVS, Low)          float64
#  957   (CVS, Close)        float64
#  958   (CVS, Adj Close)    float64
#  959   (CVS, Volume)       int64
#  960   (FIS, Open)         float64
#  961   (FIS, High)         float64
#  962   (FIS, Low)          float64
#  963   (FIS, Close)        float64
#  964   (FIS, Adj Close)    float64
#  965   (FIS, Volume)       int64
#  966   (JNPR, Open)        float64
#  967   (JNPR, High)        float64
#  968   (JNPR, Low)         float64
#  969   (JNPR, Close)       float64
#  970   (JNPR, Adj Close)   float64
#  971   (JNPR, Volume)      int64
#  972   (GT, Open)          float64
#  973   (GT, High)          float64
#  974   (GT, Low)           float64
#  975   (GT, Close)         float64
#  976   (GT, Adj Close)     float64
#  977   (GT, Volume)        int64
#  978   (ALLE, Open)        float64
#  979   (ALLE, High)        float64
#  980   (ALLE, Low)         float64
#  981   (ALLE, Close)       float64
#  982   (ALLE, Adj Close)   float64
#  983   (ALLE, Volume)      int64
#  984   (GILD, Open)        float64
#  985   (GILD, High)        float64
#  986   (GILD, Low)         float64
#  987   (GILD, Close)       float64
#  988   (GILD, Adj Close)   float64
#  989   (GILD, Volume)      int64
#  990   (HSIC, Open)        float64
#  991   (HSIC, High)        float64
#  992   (HSIC, Low)         float64
#  993   (HSIC, Close)       float64
#  994   (HSIC, Adj Close)   float64
#  995   (HSIC, Volume)      int64
#  996   (EW, Open)          float64
#  997   (EW, High)          float64
#  998   (EW, Low)           float64
#  999   (EW, Close)         float64
#  1000  (EW, Adj Close)     float64
#  1001  (EW, Volume)        int64
#  1002  (TPR, Open)         float64
#  1003  (TPR, High)         float64
#  1004  (TPR, Low)          float64
#  1005  (TPR, Close)        float64
#  1006  (TPR, Adj Close)    float64
#  1007  (TPR, Volume)       int64
#  1008  (KMI, Open)         float64
#  1009  (KMI, High)         float64
#  1010  (KMI, Low)          float64
#  1011  (KMI, Close)        float64
#  1012  (KMI, Adj Close)    float64
#  1013  (KMI, Volume)       int64
#  1014  (PYPL, Open)        float64
#  1015  (PYPL, High)        float64
#  1016  (PYPL, Low)         float64
#  1017  (PYPL, Close)       float64
#  1018  (PYPL, Adj Close)   float64
#  1019  (PYPL, Volume)      int64
#  1020  (NCLH, Open)        float64
#  1021  (NCLH, High)        float64
#  1022  (NCLH, Low)         float64
#  1023  (NCLH, Close)       float64
#  1024  (NCLH, Adj Close)   float64
#  1025  (NCLH, Volume)      int64
#  1026  (HCA, Open)         float64
#  1027  (HCA, High)         float64
#  1028  (HCA, Low)          float64
#  1029  (HCA, Close)        float64
#  1030  (HCA, Adj Close)    float64
#  1031  (HCA, Volume)       int64
#  1032  (IRM, Open)         float64
#  1033  (IRM, High)         float64
#  1034  (IRM, Low)          float64
#  1035  (IRM, Close)        float64
#  1036  (IRM, Adj Close)    float64
#  1037  (IRM, Volume)       int64
#  1038  (BALL, Open)        float64
#  1039  (BALL, High)        float64
#  1040  (BALL, Low)         float64
#  1041  (BALL, Close)       float64
#  1042  (BALL, Adj Close)   float64
#  1043  (BALL, Volume)      int64
#  1044  (TAP, Open)         float64
#  1045  (TAP, High)         float64
#  1046  (TAP, Low)          float64
#  1047  (TAP, Close)        float64
#  1048  (TAP, Adj Close)    float64
#  1049  (TAP, Volume)       int64
#  1050  (MMC, Open)         float64
#  1051  (MMC, High)         float64
#  1052  (MMC, Low)          float64
#  1053  (MMC, Close)        float64
#  1054  (MMC, Adj Close)    float64
#  1055  (MMC, Volume)       int64
#  1056  (GWW, Open)         float64
#  1057  (GWW, High)         float64
#  1058  (GWW, Low)          float64
#  1059  (GWW, Close)        float64
#  1060  (GWW, Adj Close)    float64
#  1061  (GWW, Volume)       int64
#  1062  (INTU, Open)        float64
#  1063  (INTU, High)        float64
#  1064  (INTU, Low)         float64
#  1065  (INTU, Close)       float64
#  1066  (INTU, Adj Close)   float64
#  1067  (INTU, Volume)      int64
#  1068  (EA, Open)          float64
#  1069  (EA, High)          float64
#  1070  (EA, Low)           float64
#  1071  (EA, Close)         float64
#  1072  (EA, Adj Close)     float64
#  1073  (EA, Volume)        int64
#  1074  (AVY, Open)         float64
#  1075  (AVY, High)         float64
#  1076  (AVY, Low)          float64
#  1077  (AVY, Close)        float64
#  1078  (AVY, Adj Close)    float64
#  1079  (AVY, Volume)       int64
#  1080  (DRI, Open)         float64
#  1081  (DRI, High)         float64
#  1082  (DRI, Low)          float64
#  1083  (DRI, Close)        float64
#  1084  (DRI, Adj Close)    float64
#  1085  (DRI, Volume)       int64
#  1086  (CRM, Open)         float64
#  1087  (CRM, High)         float64
#  1088  (CRM, Low)          float64
#  1089  (CRM, Close)        float64
#  1090  (CRM, Adj Close)    float64
#  1091  (CRM, Volume)       int64
#  1092  (NRG, Open)         float64
#  1093  (NRG, High)         float64
#  1094  (NRG, Low)          float64
#  1095  (NRG, Close)        float64
#  1096  (NRG, Adj Close)    float64
#  1097  (NRG, Volume)       int64
#  1098  (USB, Open)         float64
#  1099  (USB, High)         float64
#  1100  (USB, Low)          float64
#  1101  (USB, Close)        float64
#  1102  (USB, Adj Close)    float64
#  1103  (USB, Volume)       int64
#  1104  (EQIX, Open)        float64
#  1105  (EQIX, High)        float64
#  1106  (EQIX, Low)         float64
#  1107  (EQIX, Close)       float64
#  1108  (EQIX, Adj Close)   float64
#  1109  (EQIX, Volume)      int64
#  1110  (EBAY, Open)        float64
#  1111  (EBAY, High)        float64
#  1112  (EBAY, Low)         float64
#  1113  (EBAY, Close)       float64
#  1114  (EBAY, Adj Close)   float64
#  1115  (EBAY, Volume)      int64
#  1116  (AVGO, Open)        float64
#  1117  (AVGO, High)        float64
#  1118  (AVGO, Low)         float64
#  1119  (AVGO, Close)       float64
#  1120  (AVGO, Adj Close)   float64
#  1121  (AVGO, Volume)      int64
#  1122  (ADBE, Open)        float64
#  1123  (ADBE, High)        float64
#  1124  (ADBE, Low)         float64
#  1125  (ADBE, Close)       float64
#  1126  (ADBE, Adj Close)   float64
#  1127  (ADBE, Volume)      int64
#  1128  (IVZ, Open)         float64
#  1129  (IVZ, High)         float64
#  1130  (IVZ, Low)          float64
#  1131  (IVZ, Close)        float64
#  1132  (IVZ, Adj Close)    float64
#  1133  (IVZ, Volume)       int64
#  1134  (KMX, Open)         float64
#  1135  (KMX, High)         float64
#  1136  (KMX, Low)          float64
#  1137  (KMX, Close)        float64
#  1138  (KMX, Adj Close)    float64
#  1139  (KMX, Volume)       int64
#  1140  (ROP, Open)         float64
#  1141  (ROP, High)         float64
#  1142  (ROP, Low)          float64
#  1143  (ROP, Close)        float64
#  1144  (ROP, Adj Close)    float64
#  1145  (ROP, Volume)       int64
#  1146  (CLX, Open)         float64
#  1147  (CLX, High)         float64
#  1148  (CLX, Low)          float64
#  1149  (CLX, Close)        float64
#  1150  (CLX, Adj Close)    float64
#  1151  (CLX, Volume)       int64
#  1152  (PCG, Open)         float64
#  1153  (PCG, High)         float64
#  1154  (PCG, Low)          float64
#  1155  (PCG, Close)        float64
#  1156  (PCG, Adj Close)    float64
#  1157  (PCG, Volume)       int64
#  1158  (FCX, Open)         float64
#  1159  (FCX, High)         float64
#  1160  (FCX, Low)          float64
#  1161  (FCX, Close)        float64
#  1162  (FCX, Adj Close)    float64
#  1163  (FCX, Volume)       int64
#  1164  (TSN, Open)         float64
#  1165  (TSN, High)         float64
#  1166  (TSN, Low)          float64
#  1167  (TSN, Close)        float64
#  1168  (TSN, Adj Close)    float64
#  1169  (TSN, Volume)       int64
#  1170  (KSS, Open)         float64
#  1171  (KSS, High)         float64
#  1172  (KSS, Low)          float64
#  1173  (KSS, Close)        float64
#  1174  (KSS, Adj Close)    float64
#  1175  (KSS, Volume)       int64
#  1176  (LYB, Open)         float64
#  1177  (LYB, High)         float64
#  1178  (LYB, Low)          float64
#  1179  (LYB, Close)        float64
#  1180  (LYB, Adj Close)    float64
#  1181  (LYB, Volume)       int64
#  1182  (NVDA, Open)        float64
#  1183  (NVDA, High)        float64
#  1184  (NVDA, Low)         float64
#  1185  (NVDA, Close)       float64
#  1186  (NVDA, Adj Close)   float64
#  1187  (NVDA, Volume)      int64
#  1188  (FBIN, Open)        float64
#  1189  (FBIN, High)        float64
#  1190  (FBIN, Low)         float64
#  1191  (FBIN, Close)       float64
#  1192  (FBIN, Adj Close)   float64
#  1193  (FBIN, Volume)      int64
#  1194  (AME, Open)         float64
#  1195  (AME, High)         float64
#  1196  (AME, Low)          float64
#  1197  (AME, Close)        float64
#  1198  (AME, Adj Close)    float64
#  1199  (AME, Volume)       int64
#  1200  (GAP, Open)         float64
#  1201  (GAP, High)         float64
#  1202  (GAP, Low)          float64
#  1203  (GAP, Close)        float64
#  1204  (GAP, Adj Close)    float64
#  1205  (GAP, Volume)       int64
#  1206  (HD, Open)          float64
#  1207  (HD, High)          float64
#  1208  (HD, Low)           float64
#  1209  (HD, Close)         float64
#  1210  (HD, Adj Close)     float64
#  1211  (HD, Volume)        int64
#  1212  (INCY, Open)        float64
#  1213  (INCY, High)        float64
#  1214  (INCY, Low)         float64
#  1215  (INCY, Close)       float64
#  1216  (INCY, Adj Close)   float64
#  1217  (INCY, Volume)      int64
#  1218  (ALGN, Open)        float64
#  1219  (ALGN, High)        float64
#  1220  (ALGN, Low)         float64
#  1221  (ALGN, Close)       float64
#  1222  (ALGN, Adj Close)   float64
#  1223  (ALGN, Volume)      int64
#  1224  (MSCI, Open)        float64
#  1225  (MSCI, High)        float64
#  1226  (MSCI, Low)         float64
#  1227  (MSCI, Close)       float64
#  1228  (MSCI, Adj Close)   float64
#  1229  (MSCI, Volume)      int64
#  1230  (MRK, Open)         float64
#  1231  (MRK, High)         float64
#  1232  (MRK, Low)          float64
#  1233  (MRK, Close)        float64
#  1234  (MRK, Adj Close)    float64
#  1235  (MRK, Volume)       int64
#  1236  (PWR, Open)         float64
#  1237  (PWR, High)         float64
#  1238  (PWR, Low)          float64
#  1239  (PWR, Close)        float64
#  1240  (PWR, Adj Close)    float64
#  1241  (PWR, Volume)       int64
#  1242  (CPAY, Open)        float64
#  1243  (CPAY, High)        float64
#  1244  (CPAY, Low)         float64
#  1245  (CPAY, Close)       float64
#  1246  (CPAY, Adj Close)   float64
#  1247  (CPAY, Volume)      int64
#  1248  (BKNG, Open)        float64
#  1249  (BKNG, High)        float64
#  1250  (BKNG, Low)         float64
#  1251  (BKNG, Close)       float64
#  1252  (BKNG, Adj Close)   float64
#  1253  (BKNG, Volume)      int64
#  1254  (CCI, Open)         float64
#  1255  (CCI, High)         float64
#  1256  (CCI, Low)          float64
#  1257  (CCI, Close)        float64
#  1258  (CCI, Adj Close)    float64
#  1259  (CCI, Volume)       int64
#  1260  (SIVBQ, Open)       float64
#  1261  (SIVBQ, High)       float64
#  1262  (SIVBQ, Low)        float64
#  1263  (SIVBQ, Close)      float64
#  1264  (SIVBQ, Adj Close)  float64
#  1265  (SIVBQ, Volume)     int64
#  1266  (CBRE, Open)        float64
#  1267  (CBRE, High)        float64
#  1268  (CBRE, Low)         float64
#  1269  (CBRE, Close)       float64
#  1270  (CBRE, Adj Close)   float64
#  1271  (CBRE, Volume)      int64
#  1272  (META, Open)        float64
#  1273  (META, High)        float64
#  1274  (META, Low)         float64
#  1275  (META, Close)       float64
#  1276  (META, Adj Close)   float64
#  1277  (META, Volume)      int64
#  1278  (NWL, Open)         float64
#  1279  (NWL, High)         float64
#  1280  (NWL, Low)          float64
#  1281  (NWL, Close)        float64
#  1282  (NWL, Adj Close)    float64
#  1283  (NWL, Volume)       int64
#  1284  (C, Open)           float64
#  1285  (C, High)           float64
#  1286  (C, Low)            float64
#  1287  (C, Close)          float64
#  1288  (C, Adj Close)      float64
#  1289  (C, Volume)         int64
#  1290  (GRMN, Open)        float64
#  1291  (GRMN, High)        float64
#  1292  (GRMN, Low)         float64
#  1293  (GRMN, Close)       float64
#  1294  (GRMN, Adj Close)   float64
#  1295  (GRMN, Volume)      int64
#  1296  (PNR, Open)         float64
#  1297  (PNR, High)         float64
#  1298  (PNR, Low)          float64
#  1299  (PNR, Close)        float64
#  1300  (PNR, Adj Close)    float64
#  1301  (PNR, Volume)       int64
#  1302  (IPG, Open)         float64
#  1303  (IPG, High)         float64
#  1304  (IPG, Low)          float64
#  1305  (IPG, Close)        float64
#  1306  (IPG, Adj Close)    float64
#  1307  (IPG, Volume)       int64
#  1308  (SNPS, Open)        float64
#  1309  (SNPS, High)        float64
#  1310  (SNPS, Low)         float64
#  1311  (SNPS, Close)       float64
#  1312  (SNPS, Adj Close)   float64
#  1313  (SNPS, Volume)      int64
#  1314  (T, Open)           float64
#  1315  (T, High)           float64
#  1316  (T, Low)            float64
#  1317  (T, Close)          float64
#  1318  (T, Adj Close)      float64
#  1319  (T, Volume)         int64
#  1320  (DVA, Open)         float64
#  1321  (DVA, High)         float64
#  1322  (DVA, Low)          float64
#  1323  (DVA, Close)        float64
#  1324  (DVA, Adj Close)    float64
#  1325  (DVA, Volume)       int64
#  1326  (F, Open)           float64
#  1327  (F, High)           float64
#  1328  (F, Low)            float64
#  1329  (F, Close)          float64
#  1330  (F, Adj Close)      float64
#  1331  (F, Volume)         int64
#  1332  (HLT, Open)         float64
#  1333  (HLT, High)         float64
#  1334  (HLT, Low)          float64
#  1335  (HLT, Close)        float64
#  1336  (HLT, Adj Close)    float64
#  1337  (HLT, Volume)       int64
#  1338  (NWSA, Open)        float64
#  1339  (NWSA, High)        float64
#  1340  (NWSA, Low)         float64
#  1341  (NWSA, Close)       float64
#  1342  (NWSA, Adj Close)   float64
#  1343  (NWSA, Volume)      int64
#  1344  (BMY, Open)         float64
#  1345  (BMY, High)         float64
#  1346  (BMY, Low)          float64
#  1347  (BMY, Close)        float64
#  1348  (BMY, Adj Close)    float64
#  1349  (BMY, Volume)       int64
#  1350  (WEC, Open)         float64
#  1351  (WEC, High)         float64
#  1352  (WEC, Low)          float64
#  1353  (WEC, Close)        float64
#  1354  (WEC, Adj Close)    float64
#  1355  (WEC, Volume)       int64
#  1356  (APA, Open)         float64
#  1357  (APA, High)         float64
#  1358  (APA, Low)          float64
#  1359  (APA, Close)        float64
#  1360  (APA, Adj Close)    float64
#  1361  (APA, Volume)       int64
#  1362  (WU, Open)          float64
#  1363  (WU, High)          float64
#  1364  (WU, Low)           float64
#  1365  (WU, Close)         float64
#  1366  (WU, Adj Close)     float64
#  1367  (WU, Volume)        int64
#  1368  (CTSH, Open)        float64
#  1369  (CTSH, High)        float64
#  1370  (CTSH, Low)         float64
#  1371  (CTSH, Close)       float64
#  1372  (CTSH, Adj Close)   float64
#  1373  (CTSH, Volume)      int64
#  1374  (UNH, Open)         float64
#  1375  (UNH, High)         float64
#  1376  (UNH, Low)          float64
#  1377  (UNH, Close)        float64
#  1378  (UNH, Adj Close)    float64
#  1379  (UNH, Volume)       int64
#  1380  (RMD, Open)         float64
#  1381  (RMD, High)         float64
#  1382  (RMD, Low)          float64
#  1383  (RMD, Close)        float64
#  1384  (RMD, Adj Close)    float64
#  1385  (RMD, Volume)       int64
#  1386  (DIS, Open)         float64
#  1387  (DIS, High)         float64
#  1388  (DIS, Low)          float64
#  1389  (DIS, Close)        float64
#  1390  (DIS, Adj Close)    float64
#  1391  (DIS, Volume)       int64
#  1392  (CP, Open)          float64
#  1393  (CP, High)          float64
#  1394  (CP, Low)           float64
#  1395  (CP, Close)         float64
#  1396  (CP, Adj Close)     float64
#  1397  (CP, Volume)        int64
#  1398  (PPL, Open)         float64
#  1399  (PPL, High)         float64
#  1400  (PPL, Low)          float64
#  1401  (PPL, Close)        float64
#  1402  (PPL, Adj Close)    float64
#  1403  (PPL, Volume)       int64
#  1404  (SYY, Open)         float64
#  1405  (SYY, High)         float64
#  1406  (SYY, Low)          float64
#  1407  (SYY, Close)        float64
#  1408  (SYY, Adj Close)    float64
#  1409  (SYY, Volume)       int64
#  1410  (BK, Open)          float64
#  1411  (BK, High)          float64
#  1412  (BK, Low)           float64
#  1413  (BK, Close)         float64
#  1414  (BK, Adj Close)     float64
#  1415  (BK, Volume)        int64
#  1416  (ROST, Open)        float64
#  1417  (ROST, High)        float64
#  1418  (ROST, Low)         float64
#  1419  (ROST, Close)       float64
#  1420  (ROST, Adj Close)   float64
#  1421  (ROST, Volume)      int64
#  1422  (ORCL, Open)        float64
#  1423  (ORCL, High)        float64
#  1424  (ORCL, Low)         float64
#  1425  (ORCL, Close)       float64
#  1426  (ORCL, Adj Close)   float64
#  1427  (ORCL, Volume)      int64
#  1428  (MSFT, Open)        float64
#  1429  (MSFT, High)        float64
#  1430  (MSFT, Low)         float64
#  1431  (MSFT, Close)       float64
#  1432  (MSFT, Adj Close)   float64
#  1433  (MSFT, Volume)      int64
#  1434  (MSI, Open)         float64
#  1435  (MSI, High)         float64
#  1436  (MSI, Low)          float64
#  1437  (MSI, Close)        float64
#  1438  (MSI, Adj Close)    float64
#  1439  (MSI, Volume)       int64
#  1440  (ADM, Open)         float64
#  1441  (ADM, High)         float64
#  1442  (ADM, Low)          float64
#  1443  (ADM, Close)        float64
#  1444  (ADM, Adj Close)    float64
#  1445  (ADM, Volume)       int64
#  1446  (SNA, Open)         float64
#  1447  (SNA, High)         float64
#  1448  (SNA, Low)          float64
#  1449  (SNA, Close)        float64
#  1450  (SNA, Adj Close)    float64
#  1451  (SNA, Volume)       int64
#  1452  (NI, Open)          float64
#  1453  (NI, High)          float64
#  1454  (NI, Low)           float64
#  1455  (NI, Close)         float64
#  1456  (NI, Adj Close)     float64
#  1457  (NI, Volume)        int64
#  1458  (CPRI, Open)        float64
#  1459  (CPRI, High)        float64
#  1460  (CPRI, Low)         float64
#  1461  (CPRI, Close)       float64
#  1462  (CPRI, Adj Close)   float64
#  1463  (CPRI, Volume)      int64
#  1464  (JPM, Open)         float64
#  1465  (JPM, High)         float64
#  1466  (JPM, Low)          float64
#  1467  (JPM, Close)        float64
#  1468  (JPM, Adj Close)    float64
#  1469  (JPM, Volume)       int64
#  1470  (STX, Open)         float64
#  1471  (STX, High)         float64
#  1472  (STX, Low)          float64
#  1473  (STX, Close)        float64
#  1474  (STX, Adj Close)    float64
#  1475  (STX, Volume)       int64
#  1476  (GM, Open)          float64
#  1477  (GM, High)          float64
#  1478  (GM, Low)           float64
#  1479  (GM, Close)         float64
#  1480  (GM, Adj Close)     float64
#  1481  (GM, Volume)        int64
#  1482  (MO, Open)          float64
#  1483  (MO, High)          float64
#  1484  (MO, Low)           float64
#  1485  (MO, Close)         float64
#  1486  (MO, Adj Close)     float64
#  1487  (MO, Volume)        int64
#  1488  (GEN, Open)         float64
#  1489  (GEN, High)         float64
#  1490  (GEN, Low)          float64
#  1491  (GEN, Close)        float64
#  1492  (GEN, Adj Close)    float64
#  1493  (GEN, Volume)       int64
#  1494  (CMI, Open)         float64
#  1495  (CMI, High)         float64
#  1496  (CMI, Low)          float64
#  1497  (CMI, Close)        float64
#  1498  (CMI, Adj Close)    float64
#  1499  (CMI, Volume)       int64
#  1500  (K, Open)           float64
#  1501  (K, High)           float64
#  1502  (K, Low)            float64
#  1503  (K, Close)          float64
#  1504  (K, Adj Close)      float64
#  1505  (K, Volume)         int64
#  1506  (CDNS, Open)        float64
#  1507  (CDNS, High)        float64
#  1508  (CDNS, Low)         float64
#  1509  (CDNS, Close)       float64
#  1510  (CDNS, Adj Close)   float64
#  1511  (CDNS, Volume)      int64
#  1512  (EL, Open)          float64
#  1513  (EL, High)          float64
#  1514  (EL, Low)           float64
#  1515  (EL, Close)         float64
#  1516  (EL, Adj Close)     float64
#  1517  (EL, Volume)        int64
#  1518  (MLM, Open)         float64
#  1519  (MLM, High)         float64
#  1520  (MLM, Low)          float64
#  1521  (MLM, Close)        float64
#  1522  (MLM, Adj Close)    float64
#  1523  (MLM, Volume)       int64
#  1524  (PEG, Open)         float64
#  1525  (PEG, High)         float64
#  1526  (PEG, Low)          float64
#  1527  (PEG, Close)        float64
#  1528  (PEG, Adj Close)    float64
#  1529  (PEG, Volume)       int64
#  1530  (CMS, Open)         float64
#  1531  (CMS, High)         float64
#  1532  (CMS, Low)          float64
#  1533  (CMS, Close)        float64
#  1534  (CMS, Adj Close)    float64
#  1535  (CMS, Volume)       int64
#  1536  (UPS, Open)         float64
#  1537  (UPS, High)         float64
#  1538  (UPS, Low)          float64
#  1539  (UPS, Close)        float64
#  1540  (UPS, Adj Close)    float64
#  1541  (UPS, Volume)       int64
#  1542  (BWA, Open)         float64
#  1543  (BWA, High)         float64
#  1544  (BWA, Low)          float64
#  1545  (BWA, Close)        float64
#  1546  (BWA, Adj Close)    float64
#  1547  (BWA, Volume)       int64
#  1548  (WBA, Open)         float64
#  1549  (WBA, High)         float64
#  1550  (WBA, Low)          float64
#  1551  (WBA, Close)        float64
#  1552  (WBA, Adj Close)    float64
#  1553  (WBA, Volume)       int64
#  1554  (CMCSA, Open)       float64
#  1555  (CMCSA, High)       float64
#  1556  (CMCSA, Low)        float64
#  1557  (CMCSA, Close)      float64
#  1558  (CMCSA, Adj Close)  float64
#  1559  (CMCSA, Volume)     int64
#  1560  (HPQ, Open)         float64
#  1561  (HPQ, High)         float64
#  1562  (HPQ, Low)          float64
#  1563  (HPQ, Close)        float64
#  1564  (HPQ, Adj Close)    float64
#  1565  (HPQ, Volume)       int64
#  1566  (JWN, Open)         float64
#  1567  (JWN, High)         float64
#  1568  (JWN, Low)          float64
#  1569  (JWN, Close)        float64
#  1570  (JWN, Adj Close)    float64
#  1571  (JWN, Volume)       int64
#  1572  (LOW, Open)         float64
#  1573  (LOW, High)         float64
#  1574  (LOW, Low)          float64
#  1575  (LOW, Close)        float64
#  1576  (LOW, Adj Close)    float64
#  1577  (LOW, Volume)       int64
#  1578  (KR, Open)          float64
#  1579  (KR, High)          float64
#  1580  (KR, Low)           float64
#  1581  (KR, Close)         float64
#  1582  (KR, Adj Close)     float64
#  1583  (KR, Volume)        int64
#  1584  (KHC, Open)         float64
#  1585  (KHC, High)         float64
#  1586  (KHC, Low)          float64
#  1587  (KHC, Close)        float64
#  1588  (KHC, Adj Close)    float64
#  1589  (KHC, Volume)       int64
# dtypes: float64(1326), int64(264)
# memory usage: 3.0 MB

# %% [markdown]
# # Alphadvantage
#
# I broke down and went with Alphadvantage API. It requires an API key.

# %%
API_KEY = os.getenv('API_KEY') # used with www.alphavantage.co
alpha_url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={}&apikey={}&outputsize=full&datatype=json' #.format(ticker,API_KEY)
alpha_dir = 'data/alpha_data/{}.csv' #.format(ticker) # I saved the raw alphadvantage data, so I don't have to do it again
alpha_columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Dividend Amount', 'Split Coefficient'] # same as Yahoo

alpha_data = pd.DataFrame()
tickers = filename_data.Ticker.unique().tolist()
for ticker in tqdm(tickers):
    try:
        response = requests.get(alpha_url.format(ticker,API_KEY)).json()
        ticker_df = pd.DataFrame(response['Time Series (Daily)']).T
        ticker_df.columns = [f"{ticker}_{col}" for col in alpha_columns]
        ticker_df.index = pd.to_datetime(ticker_df.index)
        ticker_df = ticker_df.apply(pd.to_numeric, errors='coerce')
        ticker_df.to_csv(alpha_dir.format(ticker))
        ticker_df_2017 = ticker_df[ticker_df.index.year == 2017]
        ticker_df_2017 = ticker_df_2017.rename(columns={f"{ticker}_Adj Close": ticker})
        ticker_df_2017 = ticker_df_2017[[ticker]].copy()
        if alpha_data.empty:
            alpha_data = ticker_df_2017
        else:
            alpha_data = pd.concat([alpha_data, ticker_df_2017], axis=1)
        # this API has a limit per minute
        time.sleep(0.8)
    except KeyboardInterrupt: break
    except Exception as e: 
        print(ticker, e)

alpha_data.to_csv('data/alpha_data.csv')
alpha_data.info(verbose=True)
# Out:
# 100%|██████████| 273/273 [06:38<00:00,  1.46s/it]
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2017-01-03 to 2017-12-29
# Data columns (total 273 columns):
#  #    Column  Dtype
# ---   ------  -----
#  0    MMM     float64
#  1    AOS     float64
#  2    ABT     float64
#  3    ABBV    float64
#  4    MSFT    float64
#  5    ADBE    float64
#  6    AAP     float64
#  7    AMD     float64
#  8    AES     float64
#  9    AET     float64
#  10   A       float64
#  11   AKAM    float64
#  12   ALK     float64
#  13   AZN     float64
#  14   ALGN    float64
#  15   ALLE    float64
#  16   BFH     float64
#  17   MO      float64
#  18   AMZN    float64
#  19   AEE     float64
#  20   AXP     float64
#  21   AMT     float64
#  22   COR     float64
#  23   AME     float64
#  24   AMGN    float64
#  25   ELV     float64
#  26   AON     float64
#  27   APA     float64
#  28   ADM     float64
#  29   T       float64
#  30   ADSK    float64
#  31   ADP     float64
#  32   AVY     float64
#  33   BALL    float64
#  34   BAX     float64
#  35   BDX     float64
#  36   BIIB    float64
#  37   BA      float64
#  38   BKNG    float64
#  39   BWA     float64
#  40   BMY     float64
#  41   BR      float64
#  42   CA      float64
#  43   CDNS    float64
#  44   CPB     float64
#  45   CAH     float64
#  46   KMX     float64
#  47   CAT     float64
#  48   CBOE    float64
#  49   CBRE    float64
#  50   PARA    float64
#  51   LUMN    float64
#  52   CVX     float64
#  53   CHD     float64
#  54   CI      float64
#  55   CTRA    float64
#  56   CSCO    float64
#  57   C       float64
#  58   AVGO    float64
#  59   CME     float64
#  60   CMS     float64
#  61   KO      float64
#  62   CTSH    float64
#  63   CMCSA   float64
#  64   CMA     float64
#  65   CAG     float64
#  66   GLW     float64
#  67   COTY    float64
#  68   CCI     float64
#  69   CMI     float64
#  70   CVS     float64
#  71   DHI     float64
#  72   DRI     float64
#  73   DVA     float64
#  74   DLR     float64
#  75   DISH    float64
#  76   DG      float64
#  77   D       float64
#  78   DOV     float64
#  79   DTE     float64
#  80   DUK     float64
#  81   EBAY    float64
#  82   ECL     float64
#  83   EIX     float64
#  84   EW      float64
#  85   EA      float64
#  86   EMR     float64
#  87   EQT     float64
#  88   EQIX    float64
#  89   EL      float64
#  90   XOM     float64
#  91   FFIV    float64
#  92   META    float64
#  93   FIS     float64
#  94   FITB    float64
#  95   CPAY    float64
#  96   TDY     float64
#  97   FL      float64
#  98   F       float64
#  99   FTV     float64
#  100  FBIN    float64
#  101  BEN     float64
#  102  FCX     float64
#  103  GAP     float64
#  104  GRMN    float64
#  105  IT      float64
#  106  GD      float64
#  107  GGP     float64
#  108  GIS     float64
#  109  GM      float64
#  110  GPC     float64
#  111  GILD    float64
#  112  GS      float64
#  113  GT      float64
#  114  GWW     float64
#  115  HAL     float64
#  116  HBI     float64
#  117  LHX     float64
#  118  HAS     float64
#  119  HCA     float64
#  120  HSIC    float64
#  121  HES     float64
#  122  HPE     float64
#  123  HLT     float64
#  124  HOLX    float64
#  125  HD      float64
#  126  HRL     float64
#  127  HPQ     float64
#  128  HUM     float64
#  129  ITW     float64
#  130  ILMN    float64
#  131  INCY    float64
#  132  IR      float64
#  133  INTC    float64
#  134  ICE     float64
#  135  IP      float64
#  136  IPG     float64
#  137  INTU    float64
#  138  IVZ     float64
#  139  IPGP    float64
#  140  IRM     float64
#  141  JCI     float64
#  142  JPM     float64
#  143  JNPR    float64
#  144  CP      float64
#  145  K       float64
#  146  KMB     float64
#  147  KMI     float64
#  148  KLAC    float64
#  149  KSS     float64
#  150  KHC     float64
#  151  KR      float64
#  152  LRCX    float64
#  153  LEN     float64
#  154  LLY     float64
#  155  LKQ     float64
#  156  LMT     float64
#  157  LOW     float64
#  158  LYB     float64
#  159  MMC     float64
#  160  MLM     float64
#  161  MAS     float64
#  162  MA      float64
#  163  MAT     float64
#  164  MCD     float64
#  165  MRK     float64
#  166  MGM     float64
#  167  CPRI    float64
#  168  MU      float64
#  169  TAP     float64
#  170  MDLZ    float64
#  171  MSI     float64
#  172  MSCI    float64
#  173  VTRS    float64
#  174  NDAQ    float64
#  175  NKTR    float64
#  176  NTAP    float64
#  177  NWL     float64
#  178  NEM     float64
#  179  NWSA    float64
#  180  NLSN    float64
#  181  NKE     float64
#  182  NI      float64
#  183  JWN     float64
#  184  NSC     float64
#  185  NCLH    float64
#  186  NRG     float64
#  187  NUE     float64
#  188  NVDA    float64
#  189  ORCL    float64
#  190  PCAR    float64
#  191  PH      float64
#  192  PYPL    float64
#  193  PNR     float64
#  194  PEP     float64
#  195  RVTY    float64
#  196  PRGO    float64
#  197  PCG     float64
#  198  PNW     float64
#  199  RL      float64
#  200  PPG     float64
#  201  PPL     float64
#  202  PLD     float64
#  203  PEG     float64
#  204  PWR     float64
#  205  DGX     float64
#  206  RTN     float64
#  207  IBM     float64
#  208  REGN    float64
#  209  RF      float64
#  210  RSG     float64
#  211  RMD     float64
#  212  ROK     float64
#  213  ROP     float64
#  214  ROST    float64
#  215  RCL     float64
#  216  CRM     float64
#  217  SCG     float64
#  218  SLB     float64
#  219  STX     float64
#  220  SEE     float64
#  221  SRE     float64
#  222  SHW     float64
#  223  SWKS    float64
#  224  SNA     float64
#  225  SBUX    float64
#  226  SRCL    float64
#  227  SYK     float64
#  228  STI     float64
#  229  SIVBQ   float64
#  230  GEN     float64
#  231  SNPS    float64
#  232  SYY     float64
#  233  TPR     float64
#  234  TGT     float64
#  235  TEL     float64
#  236  TXN     float64
#  237  BK      float64
#  238  CLX     float64
#  239  COO     float64
#  240  HSY     float64
#  241  MOS     float64
#  242  DIS     float64
#  243  TMO     float64
#  244  LVMUY   float64
#  245  TSCO    float64
#  246  TDG     float64
#  247  X       float64
#  248  TSN     float64
#  249  USB     float64
#  250  ULTA    float64
#  251  UNH     float64
#  252  UPS     float64
#  253  UTX     float64
#  254  VLO     float64
#  255  DHR     float64
#  256  VTR     float64
#  257  VRSN    float64
#  258  VZ      float64
#  259  VMC     float64
#  260  WBA     float64
#  261  WMT     float64
#  262  WM      float64
#  263  WEC     float64
#  264  WELL    float64
#  265  WDC     float64
#  266  WU      float64
#  267  WRK     float64
#  268  WY      float64
#  269  XEL     float64
#  270  XRX     float64
#  271  AXS     float64
#  272  YUM     float64
# dtypes: float64(273)
# memory usage: 537.3 KB

# %% [markdown]
# # Add standard deviation (TARGET of the regression)

# %%
def add_n_day(row, n_day):
    Ticker = row['Ticker']
    Date = pd.to_datetime(row['Date'])
    end = Date + pd.Timedelta(days=n_day)
    data = alpha_data.loc[Date:end, Ticker]
    std_dev = data.std()
    if pd.isna(std_dev):
        return 0  
    else:
        return std_dev

filename_data['3_day'] = filename_data.apply(lambda row: add_n_day(row, 3), axis=1)
filename_data['7_day'] = filename_data.apply(lambda row: add_n_day(row, 7), axis=1)
filename_data['15_day'] = filename_data.apply(lambda row: add_n_day(row, 15), axis=1)
filename_data['30_day'] = filename_data.apply(lambda row: add_n_day(row, 30), axis=1)
filename_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  572 non-null    object
#  1   Date     572 non-null    object
#  2   Ticker   572 non-null    object
#  3   3_day    572 non-null    float64
#  4   7_day    572 non-null    float64
#  5   15_day   572 non-null    float64
#  6   30_day   572 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 31.4+ KB

# %%
def add_n_day(row, n_day):
    Ticker = row['Ticker']
    if Ticker in ['GGP', 'CA', 'STI', 'FLT', 'NLSN', 'WRK','RTN', 'UTX', 'DISH']:
        return float('inf')
        
    Date = pd.to_datetime(row['Date'])
    end = Date + pd.Timedelta(days=n_day)
    data = yahoo_data.loc[Date:end, (Ticker, 'Adj Close')] 
    std_dev = data.std()
    if pd.isna(std_dev):
        return 0  
    else:
        return std_dev


filename_data['3_day_Yahoo'] = filename_data.apply(lambda row: add_n_day(row, 3), axis=1)
filename_data['7_day_Yahoo'] = filename_data.apply(lambda row: add_n_day(row, 7), axis=1)
filename_data['15_day_Yahoo'] = filename_data.apply(lambda row: add_n_day(row, 15), axis=1)
filename_data['30_day_Yahoo'] = filename_data.apply(lambda row: add_n_day(row, 30), axis=1)
filename_data.info(verbose=True)
filename_data.to_csv('data/targets.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       572 non-null    object
#  1   Date          572 non-null    object
#  2   Ticker        572 non-null    object
#  3   3_day         572 non-null    float64
#  4   7_day         572 non-null    float64
#  5   15_day        572 non-null    float64
#  6   30_day        572 non-null    float64
#  7   3_day_Yahoo   572 non-null    float64
#  8   7_day_Yahoo   572 non-null    float64
#  9   15_day_Yahoo  572 non-null    float64
#  10  30_day_Yahoo  572 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 49.3+ KB

# %% [markdown]
# Here I am comparing the Yahoo data to the alphabet advantage. Why is there a difference? This is where I was when the meeting started

# %%
filename_data['3_day_diff'] = filename_data['3_day'] - filename_data['3_day_Yahoo']
filename_data['7_day_diff'] = filename_data['7_day'] - filename_data['7_day_Yahoo']
filename_data['15_day_diff'] = filename_data['15_day'] - filename_data['15_day_Yahoo']
filename_data['30_day_diff'] = filename_data['30_day'] - filename_data['30_day_Yahoo']

filename_data['3_day_pct_change'] = ((filename_data['3_day_Yahoo'] - filename_data['3_day']) / filename_data['3_day']) * 100
filename_data['7_day_pct_change'] = ((filename_data['7_day_Yahoo'] - filename_data['7_day']) / filename_data['7_day']) * 100
filename_data['15_day_pct_change'] = ((filename_data['15_day_Yahoo'] - filename_data['15_day']) / filename_data['15_day']) * 100
filename_data['30_day_pct_change'] = ((filename_data['30_day_Yahoo'] - filename_data['30_day']) / filename_data['30_day']) * 100

sorted_data = filename_data.sort_values(by='30_day_pct_change', ascending=False)

# Step 6: Save to CSV
sorted_data.to_csv('data/temp.csv', index=False)

# %%
Stop (scratch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 Stop (scratch)
#
# NameError: name 'Stop' is not defined
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename_data

# %%
tickers = filename_data.Ticker.unique().tolist()
alpha_advantage = pd.DataFrame(columns = alpha_columns)
for ticker in tqdm(tickers):
    try:
        response = requests.get(alpha_url.format(ticker,API_KEY)).json()
        ticker_df = pd.DataFrame(response['Time Series (Daily)']).T
        ticker_df.columns = alpha_columns
        ticker_df.index = pd.to_datetime(ticker_df.index)
        ticker_df = ticker_df.apply(pd.to_numeric, errors='coerce')
        ticker_df.to_csv(alpha_dir.format(ticker))
        ticker_df_2017 = ticker_df[ticker_df.index.year == 2017]
        ticker_df_2017.columns = [f"{ticker}_{col}" for col in ticker_df_2017.columns]
        if alpha_advantage.empty:
            alpha_advantage = ticker_df_2017
        else:
            alpha_advantage = pd.concat([alpha_advantage, ticker_df_2017], axis=1)
        time.sleep(0.8)
    except KeyboardInterrupt: break
    except Exception as e: 
        print(ticker, e)

alpha_advantage.info(verbose=True)
alpha_advantage.to_csv('data/alpha_advantage.csv', index=False)

# %%
filename_data[filename_data['Ticker']=='FLT']CPAY
filename_data[filename_data['Ticker']=='GPS']GAP
Alpha had different takers
	Company	Date	Ticker	otherTicker
197	FleetCor Technologies Inc	2017-08-03	CPAY	FLT
208	Gap Inc.	2017-02-23	GAP	GPS
209	Gap Inc.	2017-05-18	GAP	GPS

UTX
RTN
Raytheon Co.
United Technologies
RTX

# %%
print(filename_data[filename_data['Ticker']=='GGP'] )
print(filename_data[filename_data['Ticker']=='CA'] )
print(filename_data[filename_data['Ticker']=='STI'] )
print(filename_data[filename_data['Ticker']=='FLT'] )
print(filename_data[filename_data['Ticker']=='NLSN'] )
print(filename_data[filename_data['Ticker']=='WRK'] )
