# %% [markdown]
# # Earnings Call Project: WebScraping
# <br>
# CIS 831 Deep Learning – Term Project<br>
# Kansas State University
# <br><br>
# James Chapman<br>
# John Woods<br>
# Nathan Diehl<br>
# <br>

# %% [markdown]
# This notebook collects various types of stock price data from 2 different APIs (Yahoo & Alphavantage).
# - [yfinance](https://pypi.org/project/yfinance/)
# - [Alphavantage Documentation](https://www.alphavantage.co/documentation/)
#
# In the original papers, the target metric is volatility. This is defined as the standard deviation of the dividend-adjusted closing price, measured n_days after the earnings call (3, 7, 15, 30 days). The loss function is the MSE of the volatility. See Data_Cleaning notebook for more.
#
# The data from this notebook is stored in the "data/data_prep" directory as the following CSVs, as well as the raw data from Alphavantage in the "alpha_data" directory.
# - yahoo_data
# - alpha_data
# - MAEC_yahoo_data
# - MAEC_alpha_data

# %%
import sys
IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    # !pip install yfinance
    # !pip install load_dotenv
    from google.colab import drive
    drive.mount('/content/gdrive')
    # %cd gdrive/My Drive/831

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import requests
import time
import os
from datetime import datetime
from tqdm import tqdm
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
MAEC_dir = 'data/MAEC/MAEC_Dataset' # https://github.com/Earnings-Call-Dataset/MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction

############# too big for GitHub ########################
############# stored on local disk ######################
original_data_dir = r"D:\original_dataset" # https://github.com/GeminiLn/EarningsCall_Dataset 
MAEC_audio_dir = r"D:\MAEC_audio" 
# there is a link for the audio data in the MAEC GitHub, but it does not work
# I emailed the authors, and they send another link.
# There is like a half-million files, but only 19 GB
# https://drive.google.com/file/d/1m1GRCHgKn9Vz9IFMC_SpCog6uP3-gFgY/view?usp=drive_link

# %% [markdown]
# # Original dataset
# [paper](https://aclanthology.org/P19-1038.pdf)
# [GitHub](https://github.com/GeminiLn/EarningsCall_Dataset)

# %%
# Loop through the directory, each folder represents an earnings conference call; the folders are named as "CompanyName_Date".
filename_data = []
for filename in os.listdir(original_data_dir):
    company_name, date_str = filename.rsplit('_', 1)
    date_str = date_str.split('.')[0] 
    date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    filename_data.append([company_name, date])
filename_data = pd.DataFrame(filename_data, columns=["Company", "Date"])
filename_data.drop_duplicates(inplace=True)

# Special file I made to match the company name to the ticker
company_ticker = pd.read_csv('data/data_prep/company_ticker.csv')
filename_data = filename_data.merge(company_ticker, on="Company", how="left")
filename_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  572 non-null    object
#  1   Date     572 non-null    object
#  2   Ticker   572 non-null    object
# dtypes: object(3)
# memory usage: 13.5+ KB

# %% [markdown]
# # Yahoo

# %%
tickers = filename_data.Ticker.unique().tolist()
# 26 tickers do not have data on Yahoo! (No longer trading etc.)
tickers_to_remove = ['GGP', 'CA', 'STI', 'FLT', 'NLSN', 'WRK','RTN', 'UTX', 'DISH', 'VIACOM', 
                     'TIF', 'CELG', 'RHT', 'FLIR', 'AGN', 'KSU', 'NBL', 'ALXN', 'ABMD ', 'CTXS', 
                     'CBS', 'XL', 'VAR', 'ATVI', 'XLNX', 'SIVB']
tickers = [ticker for ticker in tickers if ticker not in tickers_to_remove]
yahoo_data = yf.download(tickers, start="2017-01-01", end="2017-12-31", group_by="ticker")
yahoo_data.index = yahoo_data.index.tz_localize(None)
yahoo_data.columns = ['_'.join(col) if isinstance(col, tuple) else col for col in yahoo_data.columns]
yahoo_data = yahoo_data.sort_index(axis=1)
### save ############################################
yahoo_data.to_csv('data/data_prep/yahoo_data.csv', index=True)
#####################################################
yahoo_data.info(verbose=True)
# Out:
# [*********************100%***********************]  254 of 254 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2017-01-03 to 2017-12-29
# Data columns (total 1524 columns):
#  #     Column           Dtype
# ---    ------           -----
#  0     AAP_Adj Close    float64
#  1     AAP_Close        float64
#  2     AAP_High         float64
#  3     AAP_Low          float64
#  4     AAP_Open         float64
#  5     AAP_Volume       int64
#  6     ABBV_Adj Close   float64
#  7     ABBV_Close       float64
#  8     ABBV_High        float64
#  9     ABBV_Low         float64
#  10    ABBV_Open        float64
#  11    ABBV_Volume      int64
#  12    ABT_Adj Close    float64
#  13    ABT_Close        float64
#  14    ABT_High         float64
#  15    ABT_Low          float64
#  16    ABT_Open         float64
#  17    ABT_Volume       int64
#  18    ADBE_Adj Close   float64
#  19    ADBE_Close       float64
#  20    ADBE_High        float64
#  21    ADBE_Low         float64
#  22    ADBE_Open        float64
#  23    ADBE_Volume      int64
#  24    ADM_Adj Close    float64
#  25    ADM_Close        float64
#  26    ADM_High         float64
#  27    ADM_Low          float64
#  28    ADM_Open         float64
#  29    ADM_Volume       int64
#  30    ADP_Adj Close    float64
#  31    ADP_Close        float64
#  32    ADP_High         float64
#  33    ADP_Low          float64
#  34    ADP_Open         float64
#  35    ADP_Volume       int64
#  36    ADSK_Adj Close   float64
#  37    ADSK_Close       float64
#  38    ADSK_High        float64
#  39    ADSK_Low         float64
#  40    ADSK_Open        float64
#  41    ADSK_Volume      int64
#  42    AEE_Adj Close    float64
#  43    AEE_Close        float64
#  44    AEE_High         float64
#  45    AEE_Low          float64
#  46    AEE_Open         float64
#  47    AEE_Volume       int64
#  48    AES_Adj Close    float64
#  49    AES_Close        float64
#  50    AES_High         float64
#  51    AES_Low          float64
#  52    AES_Open         float64
#  53    AES_Volume       int64
#  54    AET_Adj Close    float64
#  55    AET_Close        float64
#  56    AET_High         float64
#  57    AET_Low          float64
#  58    AET_Open         float64
#  59    AET_Volume       int64
#  60    AKAM_Adj Close   float64
#  61    AKAM_Close       float64
#  62    AKAM_High        float64
#  63    AKAM_Low         float64
#  64    AKAM_Open        float64
#  65    AKAM_Volume      int64
#  66    ALGN_Adj Close   float64
#  67    ALGN_Close       float64
#  68    ALGN_High        float64
#  69    ALGN_Low         float64
#  70    ALGN_Open        float64
#  71    ALGN_Volume      int64
#  72    ALK_Adj Close    float64
#  73    ALK_Close        float64
#  74    ALK_High         float64
#  75    ALK_Low          float64
#  76    ALK_Open         float64
#  77    ALK_Volume       int64
#  78    ALLE_Adj Close   float64
#  79    ALLE_Close       float64
#  80    ALLE_High        float64
#  81    ALLE_Low         float64
#  82    ALLE_Open        float64
#  83    ALLE_Volume      int64
#  84    AMD_Adj Close    float64
#  85    AMD_Close        float64
#  86    AMD_High         float64
#  87    AMD_Low          float64
#  88    AMD_Open         float64
#  89    AMD_Volume       int64
#  90    AME_Adj Close    float64
#  91    AME_Close        float64
#  92    AME_High         float64
#  93    AME_Low          float64
#  94    AME_Open         float64
#  95    AME_Volume       int64
#  96    AMGN_Adj Close   float64
#  97    AMGN_Close       float64
#  98    AMGN_High        float64
#  99    AMGN_Low         float64
#  100   AMGN_Open        float64
#  101   AMGN_Volume      int64
#  102   AMT_Adj Close    float64
#  103   AMT_Close        float64
#  104   AMT_High         float64
#  105   AMT_Low          float64
#  106   AMT_Open         float64
#  107   AMT_Volume       int64
#  108   AMZN_Adj Close   float64
#  109   AMZN_Close       float64
#  110   AMZN_High        float64
#  111   AMZN_Low         float64
#  112   AMZN_Open        float64
#  113   AMZN_Volume      int64
#  114   AON_Adj Close    float64
#  115   AON_Close        float64
#  116   AON_High         float64
#  117   AON_Low          float64
#  118   AON_Open         float64
#  119   AON_Volume       int64
#  120   AOS_Adj Close    float64
#  121   AOS_Close        float64
#  122   AOS_High         float64
#  123   AOS_Low          float64
#  124   AOS_Open         float64
#  125   AOS_Volume       int64
#  126   APA_Adj Close    float64
#  127   APA_Close        float64
#  128   APA_High         float64
#  129   APA_Low          float64
#  130   APA_Open         float64
#  131   APA_Volume       int64
#  132   AVY_Adj Close    float64
#  133   AVY_Close        float64
#  134   AVY_High         float64
#  135   AVY_Low          float64
#  136   AVY_Open         float64
#  137   AVY_Volume       int64
#  138   AXP_Adj Close    float64
#  139   AXP_Close        float64
#  140   AXP_High         float64
#  141   AXP_Low          float64
#  142   AXP_Open         float64
#  143   AXP_Volume       int64
#  144   A_Adj Close      float64
#  145   A_Close          float64
#  146   A_High           float64
#  147   A_Low            float64
#  148   A_Open           float64
#  149   A_Volume         int64
#  150   BALL_Adj Close   float64
#  151   BALL_Close       float64
#  152   BALL_High        float64
#  153   BALL_Low         float64
#  154   BALL_Open        float64
#  155   BALL_Volume      int64
#  156   BAX_Adj Close    float64
#  157   BAX_Close        float64
#  158   BAX_High         float64
#  159   BAX_Low          float64
#  160   BAX_Open         float64
#  161   BAX_Volume       int64
#  162   BA_Adj Close     float64
#  163   BA_Close         float64
#  164   BA_High          float64
#  165   BA_Low           float64
#  166   BA_Open          float64
#  167   BA_Volume        int64
#  168   BDX_Adj Close    float64
#  169   BDX_Close        float64
#  170   BDX_High         float64
#  171   BDX_Low          float64
#  172   BDX_Open         float64
#  173   BDX_Volume       int64
#  174   BEN_Adj Close    float64
#  175   BEN_Close        float64
#  176   BEN_High         float64
#  177   BEN_Low          float64
#  178   BEN_Open         float64
#  179   BEN_Volume       int64
#  180   BFH_Adj Close    float64
#  181   BFH_Close        float64
#  182   BFH_High         float64
#  183   BFH_Low          float64
#  184   BFH_Open         float64
#  185   BFH_Volume       int64
#  186   BIIB_Adj Close   float64
#  187   BIIB_Close       float64
#  188   BIIB_High        float64
#  189   BIIB_Low         float64
#  190   BIIB_Open        float64
#  191   BIIB_Volume      int64
#  192   BKNG_Adj Close   float64
#  193   BKNG_Close       float64
#  194   BKNG_High        float64
#  195   BKNG_Low         float64
#  196   BKNG_Open        float64
#  197   BKNG_Volume      int64
#  198   BK_Adj Close     float64
#  199   BK_Close         float64
#  200   BK_High          float64
#  201   BK_Low           float64
#  202   BK_Open          float64
#  203   BK_Volume        int64
#  204   BMY_Adj Close    float64
#  205   BMY_Close        float64
#  206   BMY_High         float64
#  207   BMY_Low          float64
#  208   BMY_Open         float64
#  209   BMY_Volume       int64
#  210   BR_Adj Close     float64
#  211   BR_Close         float64
#  212   BR_High          float64
#  213   BR_Low           float64
#  214   BR_Open          float64
#  215   BR_Volume        int64
#  216   BWA_Adj Close    float64
#  217   BWA_Close        float64
#  218   BWA_High         float64
#  219   BWA_Low          float64
#  220   BWA_Open         float64
#  221   BWA_Volume       int64
#  222   CAG_Adj Close    float64
#  223   CAG_Close        float64
#  224   CAG_High         float64
#  225   CAG_Low          float64
#  226   CAG_Open         float64
#  227   CAG_Volume       int64
#  228   CAH_Adj Close    float64
#  229   CAH_Close        float64
#  230   CAH_High         float64
#  231   CAH_Low          float64
#  232   CAH_Open         float64
#  233   CAH_Volume       int64
#  234   CAT_Adj Close    float64
#  235   CAT_Close        float64
#  236   CAT_High         float64
#  237   CAT_Low          float64
#  238   CAT_Open         float64
#  239   CAT_Volume       int64
#  240   CBOE_Adj Close   float64
#  241   CBOE_Close       float64
#  242   CBOE_High        float64
#  243   CBOE_Low         float64
#  244   CBOE_Open        float64
#  245   CBOE_Volume      int64
#  246   CBRE_Adj Close   float64
#  247   CBRE_Close       float64
#  248   CBRE_High        float64
#  249   CBRE_Low         float64
#  250   CBRE_Open        float64
#  251   CBRE_Volume      int64
#  252   CCI_Adj Close    float64
#  253   CCI_Close        float64
#  254   CCI_High         float64
#  255   CCI_Low          float64
#  256   CCI_Open         float64
#  257   CCI_Volume       int64
#  258   CDNS_Adj Close   float64
#  259   CDNS_Close       float64
#  260   CDNS_High        float64
#  261   CDNS_Low         float64
#  262   CDNS_Open        float64
#  263   CDNS_Volume      int64
#  264   CHD_Adj Close    float64
#  265   CHD_Close        float64
#  266   CHD_High         float64
#  267   CHD_Low          float64
#  268   CHD_Open         float64
#  269   CHD_Volume       int64
#  270   CI_Adj Close     float64
#  271   CI_Close         float64
#  272   CI_High          float64
#  273   CI_Low           float64
#  274   CI_Open          float64
#  275   CI_Volume        int64
#  276   CLX_Adj Close    float64
#  277   CLX_Close        float64
#  278   CLX_High         float64
#  279   CLX_Low          float64
#  280   CLX_Open         float64
#  281   CLX_Volume       int64
#  282   CMA_Adj Close    float64
#  283   CMA_Close        float64
#  284   CMA_High         float64
#  285   CMA_Low          float64
#  286   CMA_Open         float64
#  287   CMA_Volume       int64
#  288   CMCSA_Adj Close  float64
#  289   CMCSA_Close      float64
#  290   CMCSA_High       float64
#  291   CMCSA_Low        float64
#  292   CMCSA_Open       float64
#  293   CMCSA_Volume     int64
#  294   CME_Adj Close    float64
#  295   CME_Close        float64
#  296   CME_High         float64
#  297   CME_Low          float64
#  298   CME_Open         float64
#  299   CME_Volume       int64
#  300   CMI_Adj Close    float64
#  301   CMI_Close        float64
#  302   CMI_High         float64
#  303   CMI_Low          float64
#  304   CMI_Open         float64
#  305   CMI_Volume       int64
#  306   CMS_Adj Close    float64
#  307   CMS_Close        float64
#  308   CMS_High         float64
#  309   CMS_Low          float64
#  310   CMS_Open         float64
#  311   CMS_Volume       int64
#  312   COO_Adj Close    float64
#  313   COO_Close        float64
#  314   COO_High         float64
#  315   COO_Low          float64
#  316   COO_Open         float64
#  317   COO_Volume       int64
#  318   COR_Adj Close    float64
#  319   COR_Close        float64
#  320   COR_High         float64
#  321   COR_Low          float64
#  322   COR_Open         float64
#  323   COR_Volume       int64
#  324   COTY_Adj Close   float64
#  325   COTY_Close       float64
#  326   COTY_High        float64
#  327   COTY_Low         float64
#  328   COTY_Open        float64
#  329   COTY_Volume      int64
#  330   CPB_Adj Close    float64
#  331   CPB_Close        float64
#  332   CPB_High         float64
#  333   CPB_Low          float64
#  334   CPB_Open         float64
#  335   CPB_Volume       int64
#  336   CPRI_Adj Close   float64
#  337   CPRI_Close       float64
#  338   CPRI_High        float64
#  339   CPRI_Low         float64
#  340   CPRI_Open        float64
#  341   CPRI_Volume      int64
#  342   CRM_Adj Close    float64
#  343   CRM_Close        float64
#  344   CRM_High         float64
#  345   CRM_Low          float64
#  346   CRM_Open         float64
#  347   CRM_Volume       int64
#  348   CSCO_Adj Close   float64
#  349   CSCO_Close       float64
#  350   CSCO_High        float64
#  351   CSCO_Low         float64
#  352   CSCO_Open        float64
#  353   CSCO_Volume      int64
#  354   CTRA_Adj Close   float64
#  355   CTRA_Close       float64
#  356   CTRA_High        float64
#  357   CTRA_Low         float64
#  358   CTRA_Open        float64
#  359   CTRA_Volume      int64
#  360   CTSH_Adj Close   float64
#  361   CTSH_Close       float64
#  362   CTSH_High        float64
#  363   CTSH_Low         float64
#  364   CTSH_Open        float64
#  365   CTSH_Volume      int64
#  366   CVS_Adj Close    float64
#  367   CVS_Close        float64
#  368   CVS_High         float64
#  369   CVS_Low          float64
#  370   CVS_Open         float64
#  371   CVS_Volume       int64
#  372   CVX_Adj Close    float64
#  373   CVX_Close        float64
#  374   CVX_High         float64
#  375   CVX_Low          float64
#  376   CVX_Open         float64
#  377   CVX_Volume       int64
#  378   C_Adj Close      float64
#  379   C_Close          float64
#  380   C_High           float64
#  381   C_Low            float64
#  382   C_Open           float64
#  383   C_Volume         int64
#  384   DGX_Adj Close    float64
#  385   DGX_Close        float64
#  386   DGX_High         float64
#  387   DGX_Low          float64
#  388   DGX_Open         float64
#  389   DGX_Volume       int64
#  390   DG_Adj Close     float64
#  391   DG_Close         float64
#  392   DG_High          float64
#  393   DG_Low           float64
#  394   DG_Open          float64
#  395   DG_Volume        int64
#  396   DHI_Adj Close    float64
#  397   DHI_Close        float64
#  398   DHI_High         float64
#  399   DHI_Low          float64
#  400   DHI_Open         float64
#  401   DHI_Volume       int64
#  402   DIS_Adj Close    float64
#  403   DIS_Close        float64
#  404   DIS_High         float64
#  405   DIS_Low          float64
#  406   DIS_Open         float64
#  407   DIS_Volume       int64
#  408   DLR_Adj Close    float64
#  409   DLR_Close        float64
#  410   DLR_High         float64
#  411   DLR_Low          float64
#  412   DLR_Open         float64
#  413   DLR_Volume       int64
#  414   DOV_Adj Close    float64
#  415   DOV_Close        float64
#  416   DOV_High         float64
#  417   DOV_Low          float64
#  418   DOV_Open         float64
#  419   DOV_Volume       int64
#  420   DRI_Adj Close    float64
#  421   DRI_Close        float64
#  422   DRI_High         float64
#  423   DRI_Low          float64
#  424   DRI_Open         float64
#  425   DRI_Volume       int64
#  426   DTE_Adj Close    float64
#  427   DTE_Close        float64
#  428   DTE_High         float64
#  429   DTE_Low          float64
#  430   DTE_Open         float64
#  431   DTE_Volume       int64
#  432   DUK_Adj Close    float64
#  433   DUK_Close        float64
#  434   DUK_High         float64
#  435   DUK_Low          float64
#  436   DUK_Open         float64
#  437   DUK_Volume       int64
#  438   DVA_Adj Close    float64
#  439   DVA_Close        float64
#  440   DVA_High         float64
#  441   DVA_Low          float64
#  442   DVA_Open         float64
#  443   DVA_Volume       int64
#  444   D_Adj Close      float64
#  445   D_Close          float64
#  446   D_High           float64
#  447   D_Low            float64
#  448   D_Open           float64
#  449   D_Volume         int64
#  450   EA_Adj Close     float64
#  451   EA_Close         float64
#  452   EA_High          float64
#  453   EA_Low           float64
#  454   EA_Open          float64
#  455   EA_Volume        int64
#  456   EBAY_Adj Close   float64
#  457   EBAY_Close       float64
#  458   EBAY_High        float64
#  459   EBAY_Low         float64
#  460   EBAY_Open        float64
#  461   EBAY_Volume      int64
#  462   ECL_Adj Close    float64
#  463   ECL_Close        float64
#  464   ECL_High         float64
#  465   ECL_Low          float64
#  466   ECL_Open         float64
#  467   ECL_Volume       int64
#  468   EIX_Adj Close    float64
#  469   EIX_Close        float64
#  470   EIX_High         float64
#  471   EIX_Low          float64
#  472   EIX_Open         float64
#  473   EIX_Volume       int64
#  474   ELV_Adj Close    float64
#  475   ELV_Close        float64
#  476   ELV_High         float64
#  477   ELV_Low          float64
#  478   ELV_Open         float64
#  479   ELV_Volume       int64
#  480   EL_Adj Close     float64
#  481   EL_Close         float64
#  482   EL_High          float64
#  483   EL_Low           float64
#  484   EL_Open          float64
#  485   EL_Volume        int64
#  486   EMR_Adj Close    float64
#  487   EMR_Close        float64
#  488   EMR_High         float64
#  489   EMR_Low          float64
#  490   EMR_Open         float64
#  491   EMR_Volume       int64
#  492   EQIX_Adj Close   float64
#  493   EQIX_Close       float64
#  494   EQIX_High        float64
#  495   EQIX_Low         float64
#  496   EQIX_Open        float64
#  497   EQIX_Volume      int64
#  498   EQT_Adj Close    float64
#  499   EQT_Close        float64
#  500   EQT_High         float64
#  501   EQT_Low          float64
#  502   EQT_Open         float64
#  503   EQT_Volume       int64
#  504   EW_Adj Close     float64
#  505   EW_Close         float64
#  506   EW_High          float64
#  507   EW_Low           float64
#  508   EW_Open          float64
#  509   EW_Volume        int64
#  510   FBIN_Adj Close   float64
#  511   FBIN_Close       float64
#  512   FBIN_High        float64
#  513   FBIN_Low         float64
#  514   FBIN_Open        float64
#  515   FBIN_Volume      int64
#  516   FCX_Adj Close    float64
#  517   FCX_Close        float64
#  518   FCX_High         float64
#  519   FCX_Low          float64
#  520   FCX_Open         float64
#  521   FCX_Volume       int64
#  522   FFIV_Adj Close   float64
#  523   FFIV_Close       float64
#  524   FFIV_High        float64
#  525   FFIV_Low         float64
#  526   FFIV_Open        float64
#  527   FFIV_Volume      int64
#  528   FIS_Adj Close    float64
#  529   FIS_Close        float64
#  530   FIS_High         float64
#  531   FIS_Low          float64
#  532   FIS_Open         float64
#  533   FIS_Volume       int64
#  534   FITB_Adj Close   float64
#  535   FITB_Close       float64
#  536   FITB_High        float64
#  537   FITB_Low         float64
#  538   FITB_Open        float64
#  539   FITB_Volume      int64
#  540   FL_Adj Close     float64
#  541   FL_Close         float64
#  542   FL_High          float64
#  543   FL_Low           float64
#  544   FL_Open          float64
#  545   FL_Volume        int64
#  546   FTV_Adj Close    float64
#  547   FTV_Close        float64
#  548   FTV_High         float64
#  549   FTV_Low          float64
#  550   FTV_Open         float64
#  551   FTV_Volume       int64
#  552   F_Adj Close      float64
#  553   F_Close          float64
#  554   F_High           float64
#  555   F_Low            float64
#  556   F_Open           float64
#  557   F_Volume         int64
#  558   GAP_Adj Close    float64
#  559   GAP_Close        float64
#  560   GAP_High         float64
#  561   GAP_Low          float64
#  562   GAP_Open         float64
#  563   GAP_Volume       int64
#  564   GD_Adj Close     float64
#  565   GD_Close         float64
#  566   GD_High          float64
#  567   GD_Low           float64
#  568   GD_Open          float64
#  569   GD_Volume        int64
#  570   GEN_Adj Close    float64
#  571   GEN_Close        float64
#  572   GEN_High         float64
#  573   GEN_Low          float64
#  574   GEN_Open         float64
#  575   GEN_Volume       int64
#  576   GILD_Adj Close   float64
#  577   GILD_Close       float64
#  578   GILD_High        float64
#  579   GILD_Low         float64
#  580   GILD_Open        float64
#  581   GILD_Volume      int64
#  582   GIS_Adj Close    float64
#  583   GIS_Close        float64
#  584   GIS_High         float64
#  585   GIS_Low          float64
#  586   GIS_Open         float64
#  587   GIS_Volume       int64
#  588   GLW_Adj Close    float64
#  589   GLW_Close        float64
#  590   GLW_High         float64
#  591   GLW_Low          float64
#  592   GLW_Open         float64
#  593   GLW_Volume       int64
#  594   GM_Adj Close     float64
#  595   GM_Close         float64
#  596   GM_High          float64
#  597   GM_Low           float64
#  598   GM_Open          float64
#  599   GM_Volume        int64
#  600   GPC_Adj Close    float64
#  601   GPC_Close        float64
#  602   GPC_High         float64
#  603   GPC_Low          float64
#  604   GPC_Open         float64
#  605   GPC_Volume       int64
#  606   GRMN_Adj Close   float64
#  607   GRMN_Close       float64
#  608   GRMN_High        float64
#  609   GRMN_Low         float64
#  610   GRMN_Open        float64
#  611   GRMN_Volume      int64
#  612   GS_Adj Close     float64
#  613   GS_Close         float64
#  614   GS_High          float64
#  615   GS_Low           float64
#  616   GS_Open          float64
#  617   GS_Volume        int64
#  618   GT_Adj Close     float64
#  619   GT_Close         float64
#  620   GT_High          float64
#  621   GT_Low           float64
#  622   GT_Open          float64
#  623   GT_Volume        int64
#  624   GWW_Adj Close    float64
#  625   GWW_Close        float64
#  626   GWW_High         float64
#  627   GWW_Low          float64
#  628   GWW_Open         float64
#  629   GWW_Volume       int64
#  630   HAL_Adj Close    float64
#  631   HAL_Close        float64
#  632   HAL_High         float64
#  633   HAL_Low          float64
#  634   HAL_Open         float64
#  635   HAL_Volume       int64
#  636   HAS_Adj Close    float64
#  637   HAS_Close        float64
#  638   HAS_High         float64
#  639   HAS_Low          float64
#  640   HAS_Open         float64
#  641   HAS_Volume       int64
#  642   HBI_Adj Close    float64
#  643   HBI_Close        float64
#  644   HBI_High         float64
#  645   HBI_Low          float64
#  646   HBI_Open         float64
#  647   HBI_Volume       int64
#  648   HCA_Adj Close    float64
#  649   HCA_Close        float64
#  650   HCA_High         float64
#  651   HCA_Low          float64
#  652   HCA_Open         float64
#  653   HCA_Volume       int64
#  654   HD_Adj Close     float64
#  655   HD_Close         float64
#  656   HD_High          float64
#  657   HD_Low           float64
#  658   HD_Open          float64
#  659   HD_Volume        int64
#  660   HES_Adj Close    float64
#  661   HES_Close        float64
#  662   HES_High         float64
#  663   HES_Low          float64
#  664   HES_Open         float64
#  665   HES_Volume       int64
#  666   HLT_Adj Close    float64
#  667   HLT_Close        float64
#  668   HLT_High         float64
#  669   HLT_Low          float64
#  670   HLT_Open         float64
#  671   HLT_Volume       int64
#  672   HOLX_Adj Close   float64
#  673   HOLX_Close       float64
#  674   HOLX_High        float64
#  675   HOLX_Low         float64
#  676   HOLX_Open        float64
#  677   HOLX_Volume      int64
#  678   HPE_Adj Close    float64
#  679   HPE_Close        float64
#  680   HPE_High         float64
#  681   HPE_Low          float64
#  682   HPE_Open         float64
#  683   HPE_Volume       int64
#  684   HPQ_Adj Close    float64
#  685   HPQ_Close        float64
#  686   HPQ_High         float64
#  687   HPQ_Low          float64
#  688   HPQ_Open         float64
#  689   HPQ_Volume       int64
#  690   HRL_Adj Close    float64
#  691   HRL_Close        float64
#  692   HRL_High         float64
#  693   HRL_Low          float64
#  694   HRL_Open         float64
#  695   HRL_Volume       int64
#  696   HSIC_Adj Close   float64
#  697   HSIC_Close       float64
#  698   HSIC_High        float64
#  699   HSIC_Low         float64
#  700   HSIC_Open        float64
#  701   HSIC_Volume      int64
#  702   HSY_Adj Close    float64
#  703   HSY_Close        float64
#  704   HSY_High         float64
#  705   HSY_Low          float64
#  706   HSY_Open         float64
#  707   HSY_Volume       int64
#  708   HUM_Adj Close    float64
#  709   HUM_Close        float64
#  710   HUM_High         float64
#  711   HUM_Low          float64
#  712   HUM_Open         float64
#  713   HUM_Volume       int64
#  714   ICE_Adj Close    float64
#  715   ICE_Close        float64
#  716   ICE_High         float64
#  717   ICE_Low          float64
#  718   ICE_Open         float64
#  719   ICE_Volume       int64
#  720   ILMN_Adj Close   float64
#  721   ILMN_Close       float64
#  722   ILMN_High        float64
#  723   ILMN_Low         float64
#  724   ILMN_Open        float64
#  725   ILMN_Volume      int64
#  726   INCY_Adj Close   float64
#  727   INCY_Close       float64
#  728   INCY_High        float64
#  729   INCY_Low         float64
#  730   INCY_Open        float64
#  731   INCY_Volume      int64
#  732   INTC_Adj Close   float64
#  733   INTC_Close       float64
#  734   INTC_High        float64
#  735   INTC_Low         float64
#  736   INTC_Open        float64
#  737   INTC_Volume      int64
#  738   INTU_Adj Close   float64
#  739   INTU_Close       float64
#  740   INTU_High        float64
#  741   INTU_Low         float64
#  742   INTU_Open        float64
#  743   INTU_Volume      int64
#  744   IPGP_Adj Close   float64
#  745   IPGP_Close       float64
#  746   IPGP_High        float64
#  747   IPGP_Low         float64
#  748   IPGP_Open        float64
#  749   IPGP_Volume      int64
#  750   IPG_Adj Close    float64
#  751   IPG_Close        float64
#  752   IPG_High         float64
#  753   IPG_Low          float64
#  754   IPG_Open         float64
#  755   IPG_Volume       int64
#  756   IP_Adj Close     float64
#  757   IP_Close         float64
#  758   IP_High          float64
#  759   IP_Low           float64
#  760   IP_Open          float64
#  761   IP_Volume        int64
#  762   IRM_Adj Close    float64
#  763   IRM_Close        float64
#  764   IRM_High         float64
#  765   IRM_Low          float64
#  766   IRM_Open         float64
#  767   IRM_Volume       int64
#  768   IR_Adj Close     float64
#  769   IR_Close         float64
#  770   IR_High          float64
#  771   IR_Low           float64
#  772   IR_Open          float64
#  773   IR_Volume        float64
#  774   ITW_Adj Close    float64
#  775   ITW_Close        float64
#  776   ITW_High         float64
#  777   ITW_Low          float64
#  778   ITW_Open         float64
#  779   ITW_Volume       int64
#  780   IT_Adj Close     float64
#  781   IT_Close         float64
#  782   IT_High          float64
#  783   IT_Low           float64
#  784   IT_Open          float64
#  785   IT_Volume        int64
#  786   IVZ_Adj Close    float64
#  787   IVZ_Close        float64
#  788   IVZ_High         float64
#  789   IVZ_Low          float64
#  790   IVZ_Open         float64
#  791   IVZ_Volume       int64
#  792   JCI_Adj Close    float64
#  793   JCI_Close        float64
#  794   JCI_High         float64
#  795   JCI_Low          float64
#  796   JCI_Open         float64
#  797   JCI_Volume       int64
#  798   JNPR_Adj Close   float64
#  799   JNPR_Close       float64
#  800   JNPR_High        float64
#  801   JNPR_Low         float64
#  802   JNPR_Open        float64
#  803   JNPR_Volume      int64
#  804   JPM_Adj Close    float64
#  805   JPM_Close        float64
#  806   JPM_High         float64
#  807   JPM_Low          float64
#  808   JPM_Open         float64
#  809   JPM_Volume       int64
#  810   JWN_Adj Close    float64
#  811   JWN_Close        float64
#  812   JWN_High         float64
#  813   JWN_Low          float64
#  814   JWN_Open         float64
#  815   JWN_Volume       int64
#  816   KHC_Adj Close    float64
#  817   KHC_Close        float64
#  818   KHC_High         float64
#  819   KHC_Low          float64
#  820   KHC_Open         float64
#  821   KHC_Volume       int64
#  822   KLAC_Adj Close   float64
#  823   KLAC_Close       float64
#  824   KLAC_High        float64
#  825   KLAC_Low         float64
#  826   KLAC_Open        float64
#  827   KLAC_Volume      int64
#  828   KMB_Adj Close    float64
#  829   KMB_Close        float64
#  830   KMB_High         float64
#  831   KMB_Low          float64
#  832   KMB_Open         float64
#  833   KMB_Volume       int64
#  834   KMI_Adj Close    float64
#  835   KMI_Close        float64
#  836   KMI_High         float64
#  837   KMI_Low          float64
#  838   KMI_Open         float64
#  839   KMI_Volume       int64
#  840   KMX_Adj Close    float64
#  841   KMX_Close        float64
#  842   KMX_High         float64
#  843   KMX_Low          float64
#  844   KMX_Open         float64
#  845   KMX_Volume       int64
#  846   KO_Adj Close     float64
#  847   KO_Close         float64
#  848   KO_High          float64
#  849   KO_Low           float64
#  850   KO_Open          float64
#  851   KO_Volume        int64
#  852   KR_Adj Close     float64
#  853   KR_Close         float64
#  854   KR_High          float64
#  855   KR_Low           float64
#  856   KR_Open          float64
#  857   KR_Volume        int64
#  858   KSS_Adj Close    float64
#  859   KSS_Close        float64
#  860   KSS_High         float64
#  861   KSS_Low          float64
#  862   KSS_Open         float64
#  863   KSS_Volume       int64
#  864   K_Adj Close      float64
#  865   K_Close          float64
#  866   K_High           float64
#  867   K_Low            float64
#  868   K_Open           float64
#  869   K_Volume         int64
#  870   LEN_Adj Close    float64
#  871   LEN_Close        float64
#  872   LEN_High         float64
#  873   LEN_Low          float64
#  874   LEN_Open         float64
#  875   LEN_Volume       int64
#  876   LHX_Adj Close    float64
#  877   LHX_Close        float64
#  878   LHX_High         float64
#  879   LHX_Low          float64
#  880   LHX_Open         float64
#  881   LHX_Volume       int64
#  882   LKQ_Adj Close    float64
#  883   LKQ_Close        float64
#  884   LKQ_High         float64
#  885   LKQ_Low          float64
#  886   LKQ_Open         float64
#  887   LKQ_Volume       int64
#  888   LLY_Adj Close    float64
#  889   LLY_Close        float64
#  890   LLY_High         float64
#  891   LLY_Low          float64
#  892   LLY_Open         float64
#  893   LLY_Volume       int64
#  894   LMT_Adj Close    float64
#  895   LMT_Close        float64
#  896   LMT_High         float64
#  897   LMT_Low          float64
#  898   LMT_Open         float64
#  899   LMT_Volume       int64
#  900   LOW_Adj Close    float64
#  901   LOW_Close        float64
#  902   LOW_High         float64
#  903   LOW_Low          float64
#  904   LOW_Open         float64
#  905   LOW_Volume       int64
#  906   LRCX_Adj Close   float64
#  907   LRCX_Close       float64
#  908   LRCX_High        float64
#  909   LRCX_Low         float64
#  910   LRCX_Open        float64
#  911   LRCX_Volume      int64
#  912   LUMN_Adj Close   float64
#  913   LUMN_Close       float64
#  914   LUMN_High        float64
#  915   LUMN_Low         float64
#  916   LUMN_Open        float64
#  917   LUMN_Volume      int64
#  918   LYB_Adj Close    float64
#  919   LYB_Close        float64
#  920   LYB_High         float64
#  921   LYB_Low          float64
#  922   LYB_Open         float64
#  923   LYB_Volume       int64
#  924   MAS_Adj Close    float64
#  925   MAS_Close        float64
#  926   MAS_High         float64
#  927   MAS_Low          float64
#  928   MAS_Open         float64
#  929   MAS_Volume       int64
#  930   MAT_Adj Close    float64
#  931   MAT_Close        float64
#  932   MAT_High         float64
#  933   MAT_Low          float64
#  934   MAT_Open         float64
#  935   MAT_Volume       int64
#  936   MA_Adj Close     float64
#  937   MA_Close         float64
#  938   MA_High          float64
#  939   MA_Low           float64
#  940   MA_Open          float64
#  941   MA_Volume        int64
#  942   MCD_Adj Close    float64
#  943   MCD_Close        float64
#  944   MCD_High         float64
#  945   MCD_Low          float64
#  946   MCD_Open         float64
#  947   MCD_Volume       int64
#  948   MDLZ_Adj Close   float64
#  949   MDLZ_Close       float64
#  950   MDLZ_High        float64
#  951   MDLZ_Low         float64
#  952   MDLZ_Open        float64
#  953   MDLZ_Volume      int64
#  954   META_Adj Close   float64
#  955   META_Close       float64
#  956   META_High        float64
#  957   META_Low         float64
#  958   META_Open        float64
#  959   META_Volume      int64
#  960   MGM_Adj Close    float64
#  961   MGM_Close        float64
#  962   MGM_High         float64
#  963   MGM_Low          float64
#  964   MGM_Open         float64
#  965   MGM_Volume       int64
#  966   MLM_Adj Close    float64
#  967   MLM_Close        float64
#  968   MLM_High         float64
#  969   MLM_Low          float64
#  970   MLM_Open         float64
#  971   MLM_Volume       int64
#  972   MMC_Adj Close    float64
#  973   MMC_Close        float64
#  974   MMC_High         float64
#  975   MMC_Low          float64
#  976   MMC_Open         float64
#  977   MMC_Volume       int64
#  978   MMM_Adj Close    float64
#  979   MMM_Close        float64
#  980   MMM_High         float64
#  981   MMM_Low          float64
#  982   MMM_Open         float64
#  983   MMM_Volume       int64
#  984   MOS_Adj Close    float64
#  985   MOS_Close        float64
#  986   MOS_High         float64
#  987   MOS_Low          float64
#  988   MOS_Open         float64
#  989   MOS_Volume       int64
#  990   MO_Adj Close     float64
#  991   MO_Close         float64
#  992   MO_High          float64
#  993   MO_Low           float64
#  994   MO_Open          float64
#  995   MO_Volume        int64
#  996   MRK_Adj Close    float64
#  997   MRK_Close        float64
#  998   MRK_High         float64
#  999   MRK_Low          float64
#  1000  MRK_Open         float64
#  1001  MRK_Volume       int64
#  1002  MSCI_Adj Close   float64
#  1003  MSCI_Close       float64
#  1004  MSCI_High        float64
#  1005  MSCI_Low         float64
#  1006  MSCI_Open        float64
#  1007  MSCI_Volume      int64
#  1008  MSFT_Adj Close   float64
#  1009  MSFT_Close       float64
#  1010  MSFT_High        float64
#  1011  MSFT_Low         float64
#  1012  MSFT_Open        float64
#  1013  MSFT_Volume      int64
#  1014  MSI_Adj Close    float64
#  1015  MSI_Close        float64
#  1016  MSI_High         float64
#  1017  MSI_Low          float64
#  1018  MSI_Open         float64
#  1019  MSI_Volume       int64
#  1020  MU_Adj Close     float64
#  1021  MU_Close         float64
#  1022  MU_High          float64
#  1023  MU_Low           float64
#  1024  MU_Open          float64
#  1025  MU_Volume        int64
#  1026  NCLH_Adj Close   float64
#  1027  NCLH_Close       float64
#  1028  NCLH_High        float64
#  1029  NCLH_Low         float64
#  1030  NCLH_Open        float64
#  1031  NCLH_Volume      int64
#  1032  NDAQ_Adj Close   float64
#  1033  NDAQ_Close       float64
#  1034  NDAQ_High        float64
#  1035  NDAQ_Low         float64
#  1036  NDAQ_Open        float64
#  1037  NDAQ_Volume      int64
#  1038  NEM_Adj Close    float64
#  1039  NEM_Close        float64
#  1040  NEM_High         float64
#  1041  NEM_Low          float64
#  1042  NEM_Open         float64
#  1043  NEM_Volume       int64
#  1044  NI_Adj Close     float64
#  1045  NI_Close         float64
#  1046  NI_High          float64
#  1047  NI_Low           float64
#  1048  NI_Open          float64
#  1049  NI_Volume        int64
#  1050  NKE_Adj Close    float64
#  1051  NKE_Close        float64
#  1052  NKE_High         float64
#  1053  NKE_Low          float64
#  1054  NKE_Open         float64
#  1055  NKE_Volume       int64
#  1056  NKTR_Adj Close   float64
#  1057  NKTR_Close       float64
#  1058  NKTR_High        float64
#  1059  NKTR_Low         float64
#  1060  NKTR_Open        float64
#  1061  NKTR_Volume      int64
#  1062  NRG_Adj Close    float64
#  1063  NRG_Close        float64
#  1064  NRG_High         float64
#  1065  NRG_Low          float64
#  1066  NRG_Open         float64
#  1067  NRG_Volume       int64
#  1068  NSC_Adj Close    float64
#  1069  NSC_Close        float64
#  1070  NSC_High         float64
#  1071  NSC_Low          float64
#  1072  NSC_Open         float64
#  1073  NSC_Volume       int64
#  1074  NTAP_Adj Close   float64
#  1075  NTAP_Close       float64
#  1076  NTAP_High        float64
#  1077  NTAP_Low         float64
#  1078  NTAP_Open        float64
#  1079  NTAP_Volume      int64
#  1080  NUE_Adj Close    float64
#  1081  NUE_Close        float64
#  1082  NUE_High         float64
#  1083  NUE_Low          float64
#  1084  NUE_Open         float64
#  1085  NUE_Volume       int64
#  1086  NVDA_Adj Close   float64
#  1087  NVDA_Close       float64
#  1088  NVDA_High        float64
#  1089  NVDA_Low         float64
#  1090  NVDA_Open        float64
#  1091  NVDA_Volume      int64
#  1092  NWL_Adj Close    float64
#  1093  NWL_Close        float64
#  1094  NWL_High         float64
#  1095  NWL_Low          float64
#  1096  NWL_Open         float64
#  1097  NWL_Volume       int64
#  1098  NWSA_Adj Close   float64
#  1099  NWSA_Close       float64
#  1100  NWSA_High        float64
#  1101  NWSA_Low         float64
#  1102  NWSA_Open        float64
#  1103  NWSA_Volume      int64
#  1104  ORCL_Adj Close   float64
#  1105  ORCL_Close       float64
#  1106  ORCL_High        float64
#  1107  ORCL_Low         float64
#  1108  ORCL_Open        float64
#  1109  ORCL_Volume      int64
#  1110  PCAR_Adj Close   float64
#  1111  PCAR_Close       float64
#  1112  PCAR_High        float64
#  1113  PCAR_Low         float64
#  1114  PCAR_Open        float64
#  1115  PCAR_Volume      int64
#  1116  PCG_Adj Close    float64
#  1117  PCG_Close        float64
#  1118  PCG_High         float64
#  1119  PCG_Low          float64
#  1120  PCG_Open         float64
#  1121  PCG_Volume       int64
#  1122  PEG_Adj Close    float64
#  1123  PEG_Close        float64
#  1124  PEG_High         float64
#  1125  PEG_Low          float64
#  1126  PEG_Open         float64
#  1127  PEG_Volume       int64
#  1128  PEP_Adj Close    float64
#  1129  PEP_Close        float64
#  1130  PEP_High         float64
#  1131  PEP_Low          float64
#  1132  PEP_Open         float64
#  1133  PEP_Volume       int64
#  1134  PH_Adj Close     float64
#  1135  PH_Close         float64
#  1136  PH_High          float64
#  1137  PH_Low           float64
#  1138  PH_Open          float64
#  1139  PH_Volume        int64
#  1140  PLD_Adj Close    float64
#  1141  PLD_Close        float64
#  1142  PLD_High         float64
#  1143  PLD_Low          float64
#  1144  PLD_Open         float64
#  1145  PLD_Volume       int64
#  1146  PNR_Adj Close    float64
#  1147  PNR_Close        float64
#  1148  PNR_High         float64
#  1149  PNR_Low          float64
#  1150  PNR_Open         float64
#  1151  PNR_Volume       int64
#  1152  PNW_Adj Close    float64
#  1153  PNW_Close        float64
#  1154  PNW_High         float64
#  1155  PNW_Low          float64
#  1156  PNW_Open         float64
#  1157  PNW_Volume       int64
#  1158  PPG_Adj Close    float64
#  1159  PPG_Close        float64
#  1160  PPG_High         float64
#  1161  PPG_Low          float64
#  1162  PPG_Open         float64
#  1163  PPG_Volume       int64
#  1164  PPL_Adj Close    float64
#  1165  PPL_Close        float64
#  1166  PPL_High         float64
#  1167  PPL_Low          float64
#  1168  PPL_Open         float64
#  1169  PPL_Volume       int64
#  1170  PRGO_Adj Close   float64
#  1171  PRGO_Close       float64
#  1172  PRGO_High        float64
#  1173  PRGO_Low         float64
#  1174  PRGO_Open        float64
#  1175  PRGO_Volume      int64
#  1176  PWR_Adj Close    float64
#  1177  PWR_Close        float64
#  1178  PWR_High         float64
#  1179  PWR_Low          float64
#  1180  PWR_Open         float64
#  1181  PWR_Volume       int64
#  1182  PYPL_Adj Close   float64
#  1183  PYPL_Close       float64
#  1184  PYPL_High        float64
#  1185  PYPL_Low         float64
#  1186  PYPL_Open        float64
#  1187  PYPL_Volume      int64
#  1188  RCL_Adj Close    float64
#  1189  RCL_Close        float64
#  1190  RCL_High         float64
#  1191  RCL_Low          float64
#  1192  RCL_Open         float64
#  1193  RCL_Volume       int64
#  1194  REGN_Adj Close   float64
#  1195  REGN_Close       float64
#  1196  REGN_High        float64
#  1197  REGN_Low         float64
#  1198  REGN_Open        float64
#  1199  REGN_Volume      int64
#  1200  RF_Adj Close     float64
#  1201  RF_Close         float64
#  1202  RF_High          float64
#  1203  RF_Low           float64
#  1204  RF_Open          float64
#  1205  RF_Volume        int64
#  1206  RL_Adj Close     float64
#  1207  RL_Close         float64
#  1208  RL_High          float64
#  1209  RL_Low           float64
#  1210  RL_Open          float64
#  1211  RL_Volume        int64
#  1212  RMD_Adj Close    float64
#  1213  RMD_Close        float64
#  1214  RMD_High         float64
#  1215  RMD_Low          float64
#  1216  RMD_Open         float64
#  1217  RMD_Volume       int64
#  1218  ROK_Adj Close    float64
#  1219  ROK_Close        float64
#  1220  ROK_High         float64
#  1221  ROK_Low          float64
#  1222  ROK_Open         float64
#  1223  ROK_Volume       int64
#  1224  ROP_Adj Close    float64
#  1225  ROP_Close        float64
#  1226  ROP_High         float64
#  1227  ROP_Low          float64
#  1228  ROP_Open         float64
#  1229  ROP_Volume       int64
#  1230  ROST_Adj Close   float64
#  1231  ROST_Close       float64
#  1232  ROST_High        float64
#  1233  ROST_Low         float64
#  1234  ROST_Open        float64
#  1235  ROST_Volume      int64
#  1236  RSG_Adj Close    float64
#  1237  RSG_Close        float64
#  1238  RSG_High         float64
#  1239  RSG_Low          float64
#  1240  RSG_Open         float64
#  1241  RSG_Volume       int64
#  1242  RVTY_Adj Close   float64
#  1243  RVTY_Close       float64
#  1244  RVTY_High        float64
#  1245  RVTY_Low         float64
#  1246  RVTY_Open        float64
#  1247  RVTY_Volume      int64
#  1248  SBUX_Adj Close   float64
#  1249  SBUX_Close       float64
#  1250  SBUX_High        float64
#  1251  SBUX_Low         float64
#  1252  SBUX_Open        float64
#  1253  SBUX_Volume      int64
#  1254  SCG_Adj Close    float64
#  1255  SCG_Close        float64
#  1256  SCG_High         float64
#  1257  SCG_Low          float64
#  1258  SCG_Open         float64
#  1259  SCG_Volume       int64
#  1260  SEE_Adj Close    float64
#  1261  SEE_Close        float64
#  1262  SEE_High         float64
#  1263  SEE_Low          float64
#  1264  SEE_Open         float64
#  1265  SEE_Volume       int64
#  1266  SHW_Adj Close    float64
#  1267  SHW_Close        float64
#  1268  SHW_High         float64
#  1269  SHW_Low          float64
#  1270  SHW_Open         float64
#  1271  SHW_Volume       int64
#  1272  SLB_Adj Close    float64
#  1273  SLB_Close        float64
#  1274  SLB_High         float64
#  1275  SLB_Low          float64
#  1276  SLB_Open         float64
#  1277  SLB_Volume       int64
#  1278  SNA_Adj Close    float64
#  1279  SNA_Close        float64
#  1280  SNA_High         float64
#  1281  SNA_Low          float64
#  1282  SNA_Open         float64
#  1283  SNA_Volume       int64
#  1284  SNPS_Adj Close   float64
#  1285  SNPS_Close       float64
#  1286  SNPS_High        float64
#  1287  SNPS_Low         float64
#  1288  SNPS_Open        float64
#  1289  SNPS_Volume      int64
#  1290  SRCL_Adj Close   float64
#  1291  SRCL_Close       float64
#  1292  SRCL_High        float64
#  1293  SRCL_Low         float64
#  1294  SRCL_Open        float64
#  1295  SRCL_Volume      int64
#  1296  SRE_Adj Close    float64
#  1297  SRE_Close        float64
#  1298  SRE_High         float64
#  1299  SRE_Low          float64
#  1300  SRE_Open         float64
#  1301  SRE_Volume       int64
#  1302  STX_Adj Close    float64
#  1303  STX_Close        float64
#  1304  STX_High         float64
#  1305  STX_Low          float64
#  1306  STX_Open         float64
#  1307  STX_Volume       int64
#  1308  SWKS_Adj Close   float64
#  1309  SWKS_Close       float64
#  1310  SWKS_High        float64
#  1311  SWKS_Low         float64
#  1312  SWKS_Open        float64
#  1313  SWKS_Volume      int64
#  1314  SYK_Adj Close    float64
#  1315  SYK_Close        float64
#  1316  SYK_High         float64
#  1317  SYK_Low          float64
#  1318  SYK_Open         float64
#  1319  SYK_Volume       int64
#  1320  SYY_Adj Close    float64
#  1321  SYY_Close        float64
#  1322  SYY_High         float64
#  1323  SYY_Low          float64
#  1324  SYY_Open         float64
#  1325  SYY_Volume       int64
#  1326  TAP_Adj Close    float64
#  1327  TAP_Close        float64
#  1328  TAP_High         float64
#  1329  TAP_Low          float64
#  1330  TAP_Open         float64
#  1331  TAP_Volume       int64
#  1332  TDG_Adj Close    float64
#  1333  TDG_Close        float64
#  1334  TDG_High         float64
#  1335  TDG_Low          float64
#  1336  TDG_Open         float64
#  1337  TDG_Volume       int64
#  1338  TEL_Adj Close    float64
#  1339  TEL_Close        float64
#  1340  TEL_High         float64
#  1341  TEL_Low          float64
#  1342  TEL_Open         float64
#  1343  TEL_Volume       int64
#  1344  TGT_Adj Close    float64
#  1345  TGT_Close        float64
#  1346  TGT_High         float64
#  1347  TGT_Low          float64
#  1348  TGT_Open         float64
#  1349  TGT_Volume       int64
#  1350  TMO_Adj Close    float64
#  1351  TMO_Close        float64
#  1352  TMO_High         float64
#  1353  TMO_Low          float64
#  1354  TMO_Open         float64
#  1355  TMO_Volume       int64
#  1356  TPR_Adj Close    float64
#  1357  TPR_Close        float64
#  1358  TPR_High         float64
#  1359  TPR_Low          float64
#  1360  TPR_Open         float64
#  1361  TPR_Volume       int64
#  1362  TSCO_Adj Close   float64
#  1363  TSCO_Close       float64
#  1364  TSCO_High        float64
#  1365  TSCO_Low         float64
#  1366  TSCO_Open        float64
#  1367  TSCO_Volume      int64
#  1368  TSN_Adj Close    float64
#  1369  TSN_Close        float64
#  1370  TSN_High         float64
#  1371  TSN_Low          float64
#  1372  TSN_Open         float64
#  1373  TSN_Volume       int64
#  1374  TXN_Adj Close    float64
#  1375  TXN_Close        float64
#  1376  TXN_High         float64
#  1377  TXN_Low          float64
#  1378  TXN_Open         float64
#  1379  TXN_Volume       int64
#  1380  T_Adj Close      float64
#  1381  T_Close          float64
#  1382  T_High           float64
#  1383  T_Low            float64
#  1384  T_Open           float64
#  1385  T_Volume         int64
#  1386  ULTA_Adj Close   float64
#  1387  ULTA_Close       float64
#  1388  ULTA_High        float64
#  1389  ULTA_Low         float64
#  1390  ULTA_Open        float64
#  1391  ULTA_Volume      int64
#  1392  UNH_Adj Close    float64
#  1393  UNH_Close        float64
#  1394  UNH_High         float64
#  1395  UNH_Low          float64
#  1396  UNH_Open         float64
#  1397  UNH_Volume       int64
#  1398  UPS_Adj Close    float64
#  1399  UPS_Close        float64
#  1400  UPS_High         float64
#  1401  UPS_Low          float64
#  1402  UPS_Open         float64
#  1403  UPS_Volume       int64
#  1404  USB_Adj Close    float64
#  1405  USB_Close        float64
#  1406  USB_High         float64
#  1407  USB_Low          float64
#  1408  USB_Open         float64
#  1409  USB_Volume       int64
#  1410  VLO_Adj Close    float64
#  1411  VLO_Close        float64
#  1412  VLO_High         float64
#  1413  VLO_Low          float64
#  1414  VLO_Open         float64
#  1415  VLO_Volume       int64
#  1416  VMC_Adj Close    float64
#  1417  VMC_Close        float64
#  1418  VMC_High         float64
#  1419  VMC_Low          float64
#  1420  VMC_Open         float64
#  1421  VMC_Volume       int64
#  1422  VRSN_Adj Close   float64
#  1423  VRSN_Close       float64
#  1424  VRSN_High        float64
#  1425  VRSN_Low         float64
#  1426  VRSN_Open        float64
#  1427  VRSN_Volume      int64
#  1428  VTRS_Adj Close   float64
#  1429  VTRS_Close       float64
#  1430  VTRS_High        float64
#  1431  VTRS_Low         float64
#  1432  VTRS_Open        float64
#  1433  VTRS_Volume      int64
#  1434  VTR_Adj Close    float64
#  1435  VTR_Close        float64
#  1436  VTR_High         float64
#  1437  VTR_Low          float64
#  1438  VTR_Open         float64
#  1439  VTR_Volume       int64
#  1440  VZ_Adj Close     float64
#  1441  VZ_Close         float64
#  1442  VZ_High          float64
#  1443  VZ_Low           float64
#  1444  VZ_Open          float64
#  1445  VZ_Volume        int64
#  1446  WBA_Adj Close    float64
#  1447  WBA_Close        float64
#  1448  WBA_High         float64
#  1449  WBA_Low          float64
#  1450  WBA_Open         float64
#  1451  WBA_Volume       int64
#  1452  WDC_Adj Close    float64
#  1453  WDC_Close        float64
#  1454  WDC_High         float64
#  1455  WDC_Low          float64
#  1456  WDC_Open         float64
#  1457  WDC_Volume       int64
#  1458  WEC_Adj Close    float64
#  1459  WEC_Close        float64
#  1460  WEC_High         float64
#  1461  WEC_Low          float64
#  1462  WEC_Open         float64
#  1463  WEC_Volume       int64
#  1464  WELL_Adj Close   float64
#  1465  WELL_Close       float64
#  1466  WELL_High        float64
#  1467  WELL_Low         float64
#  1468  WELL_Open        float64
#  1469  WELL_Volume      int64
#  1470  WMT_Adj Close    float64
#  1471  WMT_Close        float64
#  1472  WMT_High         float64
#  1473  WMT_Low          float64
#  1474  WMT_Open         float64
#  1475  WMT_Volume       int64
#  1476  WM_Adj Close     float64
#  1477  WM_Close         float64
#  1478  WM_High          float64
#  1479  WM_Low           float64
#  1480  WM_Open          float64
#  1481  WM_Volume        int64
#  1482  WU_Adj Close     float64
#  1483  WU_Close         float64
#  1484  WU_High          float64
#  1485  WU_Low           float64
#  1486  WU_Open          float64
#  1487  WU_Volume        int64
#  1488  WY_Adj Close     float64
#  1489  WY_Close         float64
#  1490  WY_High          float64
#  1491  WY_Low           float64
#  1492  WY_Open          float64
#  1493  WY_Volume        int64
#  1494  XEL_Adj Close    float64
#  1495  XEL_Close        float64
#  1496  XEL_High         float64
#  1497  XEL_Low          float64
#  1498  XEL_Open         float64
#  1499  XEL_Volume       int64
#  1500  XOM_Adj Close    float64
#  1501  XOM_Close        float64
#  1502  XOM_High         float64
#  1503  XOM_Low          float64
#  1504  XOM_Open         float64
#  1505  XOM_Volume       int64
#  1506  XRX_Adj Close    float64
#  1507  XRX_Close        float64
#  1508  XRX_High         float64
#  1509  XRX_Low          float64
#  1510  XRX_Open         float64
#  1511  XRX_Volume       int64
#  1512  X_Adj Close      float64
#  1513  X_Close          float64
#  1514  X_High           float64
#  1515  X_Low            float64
#  1516  X_Open           float64
#  1517  X_Volume         int64
#  1518  YUM_Adj Close    float64
#  1519  YUM_Close        float64
#  1520  YUM_High         float64
#  1521  YUM_Low          float64
#  1522  YUM_Open         float64
#  1523  YUM_Volume       int64
# dtypes: float64(1271), int64(253)
# memory usage: 2.9 MB

# %% [markdown]
# # Alphadvantage

# %%
API_KEY = os.getenv('API_KEY') # used with www.alphavantage.co
alpha_url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={}&apikey={}&outputsize=full&datatype=json' #.format(ticker,API_KEY)
alpha_dir = 'data/alpha_data/{}.csv' #.format(ticker) # I saved the raw alphadvantage data, so I don't have to do it again
alpha_columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Dividend Amount', 'Split Coefficient'] # same as Yahoo

alpha_data = pd.DataFrame()
tickers = filename_data.Ticker.unique().tolist()
for ticker in tqdm(tickers):
    try:
        response = requests.get(alpha_url.format(ticker,API_KEY)).json()
        ticker_df = pd.DataFrame(response['Time Series (Daily)']).T
        ticker_df.columns = [f"{ticker}_{col}" for col in alpha_columns] # same as Yahoo
        ticker_df.index = pd.to_datetime(ticker_df.index)
        ticker_df = ticker_df.apply(pd.to_numeric, errors='coerce')
        ### save ############################################
        ticker_df.to_csv(alpha_dir.format(ticker), index=True) # dates are index
        #####################################################
        ticker_df_2017 = ticker_df[ticker_df.index.year == 2017]
        ticker_df_2017 = ticker_df_2017.rename(columns={f"{ticker}_Adj Close": ticker})
        ticker_df_2017 = ticker_df_2017[[ticker]].copy()
        if alpha_data.empty:
            alpha_data = ticker_df_2017
        else:
            alpha_data = pd.concat([alpha_data, ticker_df_2017], axis=1)
        # this API has a limit per minute
        time.sleep(0.8)
    except KeyboardInterrupt: break
    except Exception as e: 
        print(ticker, e)
### save ############################################
alpha_data.to_csv('data/data_prep/alpha_data.csv', index=True)
#####################################################
alpha_data.info(verbose=True)
# Out:
#   2%|▏         | 5/280 [00:05<03:57,  1.16it/s]
# ABMD  'Time Series (Daily)'
#  14%|█▎        | 38/280 [00:49<04:00,  1.01it/s]
# BDX 'Time Series (Daily)'
#  14%|█▍        | 39/280 [00:49<03:09,  1.27it/s]
# BIIB 'Time Series (Daily)'
#  14%|█▍        | 40/280 [00:50<02:43,  1.47it/s]
# BA 'Time Series (Daily)'
#  19%|█▉        | 53/280 [01:08<03:50,  1.02s/it]
# CBS 'Time Series (Daily)'
#  35%|███▌      | 99/280 [02:13<03:00,  1.00it/s]
# FLT 'Time Series (Daily)'
#  95%|█████████▍| 265/280 [06:04<00:17,  1.16s/it]
# VIACOM 'Time Series (Daily)'
# 100%|██████████| 280/280 [06:25<00:00,  1.38s/it]
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2017-01-03 to 2017-12-29
# Data columns (total 273 columns):
#  #    Column  Dtype
# ---   ------  -----
#  0    MMM     float64
#  1    AOS     float64
#  2    ABT     float64
#  3    ABBV    float64
#  4    ATVI    float64
#  5    ADBE    float64
#  6    AAP     float64
#  7    AMD     float64
#  8    AES     float64
#  9    AET     float64
#  10   A       float64
#  11   AKAM    float64
#  12   ALK     float64
#  13   ALXN    float64
#  14   ALGN    float64
#  15   ALLE    float64
#  16   AGN     float64
#  17   BFH     float64
#  18   MO      float64
#  19   AMZN    float64
#  20   AEE     float64
#  21   AXP     float64
#  22   AMT     float64
#  23   COR     float64
#  24   AME     float64
#  25   AMGN    float64
#  26   ELV     float64
#  27   AON     float64
#  28   APA     float64
#  29   ADM     float64
#  30   T       float64
#  31   ADSK    float64
#  32   ADP     float64
#  33   AVY     float64
#  34   BALL    float64
#  35   BAX     float64
#  36   BKNG    float64
#  37   BWA     float64
#  38   BMY     float64
#  39   BR      float64
#  40   CA      float64
#  41   CDNS    float64
#  42   CPB     float64
#  43   CAH     float64
#  44   KMX     float64
#  45   CAT     float64
#  46   CBOE    float64
#  47   CBRE    float64
#  48   CELG    float64
#  49   LUMN    float64
#  50   CVX     float64
#  51   CHD     float64
#  52   CI      float64
#  53   CTRA    float64
#  54   CSCO    float64
#  55   C       float64
#  56   CTXS    float64
#  57   CME     float64
#  58   CMS     float64
#  59   KO      float64
#  60   CTSH    float64
#  61   CMCSA   float64
#  62   CMA     float64
#  63   CAG     float64
#  64   GLW     float64
#  65   COTY    float64
#  66   CCI     float64
#  67   CMI     float64
#  68   CVS     float64
#  69   DHI     float64
#  70   DRI     float64
#  71   DVA     float64
#  72   DLR     float64
#  73   DISH    float64
#  74   DG      float64
#  75   D       float64
#  76   DOV     float64
#  77   DTE     float64
#  78   DUK     float64
#  79   EBAY    float64
#  80   ECL     float64
#  81   EIX     float64
#  82   EW      float64
#  83   EA      float64
#  84   EMR     float64
#  85   EQT     float64
#  86   EQIX    float64
#  87   EL      float64
#  88   XOM     float64
#  89   FFIV    float64
#  90   META    float64
#  91   FIS     float64
#  92   FITB    float64
#  93   FLIR    float64
#  94   FL      float64
#  95   F       float64
#  96   FTV     float64
#  97   FBIN    float64
#  98   BEN     float64
#  99   FCX     float64
#  100  GAP     float64
#  101  GRMN    float64
#  102  IT      float64
#  103  GD      float64
#  104  GGP     float64
#  105  GIS     float64
#  106  GM      float64
#  107  GPC     float64
#  108  GILD    float64
#  109  GS      float64
#  110  GT      float64
#  111  GWW     float64
#  112  HAL     float64
#  113  HBI     float64
#  114  LHX     float64
#  115  HAS     float64
#  116  HCA     float64
#  117  HSIC    float64
#  118  HES     float64
#  119  HPE     float64
#  120  HLT     float64
#  121  HOLX    float64
#  122  HD      float64
#  123  HRL     float64
#  124  HPQ     float64
#  125  HUM     float64
#  126  ITW     float64
#  127  ILMN    float64
#  128  INCY    float64
#  129  IR      float64
#  130  INTC    float64
#  131  ICE     float64
#  132  IP      float64
#  133  IPG     float64
#  134  INTU    float64
#  135  IVZ     float64
#  136  IPGP    float64
#  137  IRM     float64
#  138  JCI     float64
#  139  JPM     float64
#  140  JNPR    float64
#  141  KSU     float64
#  142  K       float64
#  143  KMB     float64
#  144  KMI     float64
#  145  KLAC    float64
#  146  KSS     float64
#  147  KHC     float64
#  148  KR      float64
#  149  LRCX    float64
#  150  LEN     float64
#  151  LLY     float64
#  152  LKQ     float64
#  153  LMT     float64
#  154  LOW     float64
#  155  LYB     float64
#  156  MMC     float64
#  157  MLM     float64
#  158  MAS     float64
#  159  MA      float64
#  160  MAT     float64
#  161  MCD     float64
#  162  MRK     float64
#  163  MGM     float64
#  164  CPRI    float64
#  165  MU      float64
#  166  MSFT    float64
#  167  TAP     float64
#  168  MDLZ    float64
#  169  MSI     float64
#  170  MSCI    float64
#  171  VTRS    float64
#  172  NDAQ    float64
#  173  NKTR    float64
#  174  NTAP    float64
#  175  NWL     float64
#  176  NEM     float64
#  177  NWSA    float64
#  178  NLSN    float64
#  179  NKE     float64
#  180  NI      float64
#  181  NBL     float64
#  182  JWN     float64
#  183  NSC     float64
#  184  NCLH    float64
#  185  NRG     float64
#  186  NUE     float64
#  187  NVDA    float64
#  188  ORCL    float64
#  189  PCAR    float64
#  190  PH      float64
#  191  PYPL    float64
#  192  PNR     float64
#  193  PEP     float64
#  194  RVTY    float64
#  195  PRGO    float64
#  196  PCG     float64
#  197  PNW     float64
#  198  RL      float64
#  199  PPG     float64
#  200  PPL     float64
#  201  PLD     float64
#  202  PEG     float64
#  203  PWR     float64
#  204  DGX     float64
#  205  RTN     float64
#  206  RHT     float64
#  207  REGN    float64
#  208  RF      float64
#  209  RSG     float64
#  210  RMD     float64
#  211  ROK     float64
#  212  ROP     float64
#  213  ROST    float64
#  214  RCL     float64
#  215  CRM     float64
#  216  SCG     float64
#  217  SLB     float64
#  218  STX     float64
#  219  SEE     float64
#  220  SRE     float64
#  221  SHW     float64
#  222  SWKS    float64
#  223  SNA     float64
#  224  SBUX    float64
#  225  SRCL    float64
#  226  SYK     float64
#  227  STI     float64
#  228  SIVB    float64
#  229  GEN     float64
#  230  SNPS    float64
#  231  SYY     float64
#  232  TPR     float64
#  233  TGT     float64
#  234  TEL     float64
#  235  TXN     float64
#  236  BK      float64
#  237  CLX     float64
#  238  COO     float64
#  239  HSY     float64
#  240  MOS     float64
#  241  DIS     float64
#  242  TMO     float64
#  243  TIF     float64
#  244  TSCO    float64
#  245  TDG     float64
#  246  X       float64
#  247  TSN     float64
#  248  USB     float64
#  249  ULTA    float64
#  250  UNH     float64
#  251  UPS     float64
#  252  UTX     float64
#  253  VLO     float64
#  254  VAR     float64
#  255  VTR     float64
#  256  VRSN    float64
#  257  VZ      float64
#  258  VMC     float64
#  259  WBA     float64
#  260  WMT     float64
#  261  WM      float64
#  262  WEC     float64
#  263  WELL    float64
#  264  WDC     float64
#  265  WU      float64
#  266  WRK     float64
#  267  WY      float64
#  268  XEL     float64
#  269  XRX     float64
#  270  XLNX    float64
#  271  XL      float64
#  272  YUM     float64
# dtypes: float64(273)
# memory usage: 537.3 KB

# %% [markdown]
# # MAEC dataset
#
#
# [paper](https://dl.acm.org/doi/10.1145/3340531.3412879)
# [GitHub](https://github.com/Earnings-Call-Dataset/MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction/tree/master)

# %%
# Loop through the directory, each folder represents an earnings conference call; the folders are named as "Date_CompanyName".
MAEC_filename_data = []
for filename in os.listdir(MAEC_dir):
    date_str, ticker = filename.rsplit('_', 1)
    date_str = date_str.split('.')[0] 
    date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    MAEC_filename_data.append([ticker, date])
MAEC_filename_data = pd.DataFrame(MAEC_filename_data, columns=["Ticker", "Date"])
MAEC_filename_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3443 entries, 0 to 3442
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ticker  3443 non-null   object
#  1   Date    3443 non-null   object
# dtypes: object(2)
# memory usage: 53.9+ KB

# %%
MAEC_tickers = MAEC_filename_data.Ticker.unique().tolist()
MAEC_yahoo_data = yf.download(MAEC_tickers, start="2015-01-01", end="2018-12-31", group_by="ticker")
MAEC_yahoo_data.index = MAEC_yahoo_data.index.tz_localize(None)
successful_tickers = [col[0] if isinstance(col, tuple) else col for col in MAEC_yahoo_data.columns]
MAEC_yahoo_data.columns = ['_'.join(col) if isinstance(col, tuple) else col for col in MAEC_yahoo_data.columns]
MAEC_yahoo_data = MAEC_yahoo_data.sort_index(axis=1)
MAEC_yahoo_data.info(verbose=True)
### save ############################################
MAEC_yahoo_data.to_csv('data/data_prep/MAEC_yahoo_data.csv', index=True)
#####################################################
# Out:
# [*********************100%***********************]  1213 of 1213 completed
#
# 249 Failed downloads:
# ['SIVB', 'AIR', 'GGP', 'HCN', 'ENDP', 'CBG', 'GOV', 'ACXM', 'QSII', 'PDCE', 'BOBE']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2015-01-01 -> 2018-12-31)')
# ['KRA', 'MTSC', 'CLI', 'COG', 'WIRE', 'DSPG', 'VRTV', 'SPN', 'QEP', 'WTR', 'MCF', 'MGLN', 'WWE', 'ACC', 'MDP', 'UIHC', 'PLT', 'FB', 'SFLY', 'TIVO', 'VSI', 'DPLO', 'UTX', 'CMO', 'BBBY', 'CRZO', 'TSS', 'RCII', 'HT', 'IVC', 'ERA', 'BRS', 'CTL', 'DRE', 'MBFI', 'MANT', 'AKRX', 'MON', 'MNK', 'RTN', 'RUTH', 'DF', 'TMST', 'HRC', 'OFC', 'NAVG', 'SAFM', 'UNT', 'ITG', 'XLNX', 'DNKN', 'EBIX', 'ESL', 'CXO', 'CY', 'QHC', 'GHL', 'FLIR', 'LPT', 'ATVI', 'FRAN', 'ARRS', 'ESV', 'POL', 'CBB', 'IIVI', 'EXTN', 'STMP', 'MNTA', 'MDSO', 'DISCA', 'CDR', 'AKS', 'INT', 'PBCT', 'CRY', 'RECN', 'DSW', 'CPE', 'TIF', 'BCOR', 'PSB', 'BID', 'CLD', 'CHFC', 'TYPE', 'TECD', 'CTB', 'AEGN', 'CHS', 'WDR', 'VIAB', 'AAWW', 'HMSY', 'AEL', 'SJI', 'DNR', 'WCG', 'FRED', 'CTRL', 'LCI', 'SIX', 'WAGE', 'CORE', 'BKS', 'CTXS', 'WRI', 'CCMP', 'TLRD', 'FTD', 'MDR', 'ANTM', 'ASNA', 'PKI', 'WPG', 'BLL', 'BPFH', 'MYL', 'PES', 'FMBI', 'SPPI', 'SWM', 'MDC', 'NLSN', 'FII', 'ISCA', 'PEI', 'ELY', 'HFC', 'HSKA', 'PGNX', 'BEL', 'CLGX', 'PJC', 'HRS', 'RDC', 'BGG', 'CRAY', 'NLS', 'FBHS', 'RHT', 'RTEC', 'NUVA', 'NP', 'XL', 'KAMN', 'LHCG', 'MINI', 'CBM', 'SLCA', 'NBL', 'VAR', 'APC', 'VG', 'GWB', 'AXE', 'GWR', 'CONE', 'RAVN', 'PRSC', 'CATM', 'NTRI', 'LMNX', 'VRTU', 'WYND', 'WRK', 'ULTI', 'NCR', 'AGN', 'ECHO', 'JCOM', 'CELG', 'KSU', 'ALXN', 'LOGM', 'WLH', 'SNH', 'LABL', 'MDCO', 'DISH', 'CRR', 'WPX', 'RE', 'CREE', 'UFS', 'ETFC', 'UMPQ', 'BBT', 'NEWM', 'CIR', 'HSC', 'EXPR', 'NATI', 'CHSP', 'EFII', 'EGOV', 'CAMP', 'HIBB', 'WLTW', 'JCP', 'TCO', 'AAXN', 'CPSI', 'LLL', 'LM', 'ACOR', 'OPB', 'MIK', 'RRD', 'ABMD', 'ABC', 'ADS', 'ECOL', 'TPRE', 'FRGI']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['CHK', 'DBD', 'EV', 'KEM', 'ETH', 'AAN', 'GPOR', 'HF', 'EDR', 'DO', 'CUB', 'CA', 'CBL', 'SBNY', 'FLOW', 'LB', 'PAY', 'FISV', 'NCI', 'PX', 'INTL', 'EE', 'STI']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2015-01-01 -> 2018-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1420088400, endDate = 1546232400")')
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1005 entries, 2015-01-02 to 2018-12-28
# Data columns (total 7278 columns):
#  #     Column           Dtype
# ---    ------           -----
#  0     AAN_Adj Close    float64
#  1     AAN_Close        float64
#  2     AAN_High         float64
#  3     AAN_Low          float64
#  4     AAN_Open         float64
#  5     AAN_Volume       float64
#  6     AAOI_Adj Close   float64
#  7     AAOI_Close       float64
#  8     AAOI_High        float64
#  9     AAOI_Low         float64
#  10    AAOI_Open        float64
#  11    AAOI_Volume      int64
#  12    AAON_Adj Close   float64
#  13    AAON_Close       float64
#  14    AAON_High        float64
#  15    AAON_Low         float64
#  16    AAON_Open        float64
#  17    AAON_Volume      int64
#  18    AAPL_Adj Close   float64
#  19    AAPL_Close       float64
#  20    AAPL_High        float64
#  21    AAPL_Low         float64
#  22    AAPL_Open        float64
#  23    AAPL_Volume      int64
#  24    AAP_Adj Close    float64
#  25    AAP_Close        float64
#  26    AAP_High         float64
#  27    AAP_Low          float64
#  28    AAP_Open         float64
#  29    AAP_Volume       int64
#  30    AAWW_Adj Close   float64
#  31    AAWW_Close       float64
#  32    AAWW_High        float64
#  33    AAWW_Low         float64
#  34    AAWW_Open        float64
#  35    AAWW_Volume      float64
#  36    AAXN_Adj Close   float64
#  37    AAXN_Close       float64
#  38    AAXN_High        float64
#  39    AAXN_Low         float64
#  40    AAXN_Open        float64
#  41    AAXN_Volume      float64
#  42    ABAX_Adj Close   float64
#  43    ABAX_Close       float64
#  44    ABAX_High        float64
#  45    ABAX_Low         float64
#  46    ABAX_Open        float64
#  47    ABAX_Volume      float64
#  48    ABBV_Adj Close   float64
#  49    ABBV_Close       float64
#  50    ABBV_High        float64
#  51    ABBV_Low         float64
#  52    ABBV_Open        float64
#  53    ABBV_Volume      int64
#  54    ABCB_Adj Close   float64
#  55    ABCB_Close       float64
#  56    ABCB_High        float64
#  57    ABCB_Low         float64
#  58    ABCB_Open        float64
#  59    ABCB_Volume      int64
#  60    ABC_Adj Close    float64
#  61    ABC_Close        float64
#  62    ABC_High         float64
#  63    ABC_Low          float64
#  64    ABC_Open         float64
#  65    ABC_Volume       float64
#  66    ABG_Adj Close    float64
#  67    ABG_Close        float64
#  68    ABG_High         float64
#  69    ABG_Low          float64
#  70    ABG_Open         float64
#  71    ABG_Volume       int64
#  72    ABMD_Adj Close   float64
#  73    ABMD_Close       float64
#  74    ABMD_High        float64
#  75    ABMD_Low         float64
#  76    ABMD_Open        float64
#  77    ABMD_Volume      float64
#  78    ABM_Adj Close    float64
#  79    ABM_Close        float64
#  80    ABM_High         float64
#  81    ABM_Low          float64
#  82    ABM_Open         float64
#  83    ABM_Volume       int64
#  84    ABT_Adj Close    float64
#  85    ABT_Close        float64
#  86    ABT_High         float64
#  87    ABT_Low          float64
#  88    ABT_Open         float64
#  89    ABT_Volume       int64
#  90    ACC_Adj Close    float64
#  91    ACC_Close        float64
#  92    ACC_High         float64
#  93    ACC_Low          float64
#  94    ACC_Open         float64
#  95    ACC_Volume       float64
#  96    ACET_Adj Close   float64
#  97    ACET_Close       float64
#  98    ACET_High        float64
#  99    ACET_Low         float64
#  100   ACET_Open        float64
#  101   ACET_Volume      float64
#  102   ACHC_Adj Close   float64
#  103   ACHC_Close       float64
#  104   ACHC_High        float64
#  105   ACHC_Low         float64
#  106   ACHC_Open        float64
#  107   ACHC_Volume      int64
#  108   ACIW_Adj Close   float64
#  109   ACIW_Close       float64
#  110   ACIW_High        float64
#  111   ACIW_Low         float64
#  112   ACIW_Open        float64
#  113   ACIW_Volume      int64
#  114   ACLS_Adj Close   float64
#  115   ACLS_Close       float64
#  116   ACLS_High        float64
#  117   ACLS_Low         float64
#  118   ACLS_Open        float64
#  119   ACLS_Volume      int64
#  120   ACM_Adj Close    float64
#  121   ACM_Close        float64
#  122   ACM_High         float64
#  123   ACM_Low          float64
#  124   ACM_Open         float64
#  125   ACM_Volume       int64
#  126   ACN_Adj Close    float64
#  127   ACN_Close        float64
#  128   ACN_High         float64
#  129   ACN_Low          float64
#  130   ACN_Open         float64
#  131   ACN_Volume       int64
#  132   ACOR_Adj Close   float64
#  133   ACOR_Close       float64
#  134   ACOR_High        float64
#  135   ACOR_Low         float64
#  136   ACOR_Open        float64
#  137   ACOR_Volume      float64
#  138   ACXM_Adj Close   float64
#  139   ACXM_Close       float64
#  140   ACXM_High        float64
#  141   ACXM_Low         float64
#  142   ACXM_Open        float64
#  143   ACXM_Volume      float64
#  144   ADBE_Adj Close   float64
#  145   ADBE_Close       float64
#  146   ADBE_High        float64
#  147   ADBE_Low         float64
#  148   ADBE_Open        float64
#  149   ADBE_Volume      int64
#  150   ADC_Adj Close    float64
#  151   ADC_Close        float64
#  152   ADC_High         float64
#  153   ADC_Low          float64
#  154   ADC_Open         float64
#  155   ADC_Volume       int64
#  156   ADI_Adj Close    float64
#  157   ADI_Close        float64
#  158   ADI_High         float64
#  159   ADI_Low          float64
#  160   ADI_Open         float64
#  161   ADI_Volume       int64
#  162   ADM_Adj Close    float64
#  163   ADM_Close        float64
#  164   ADM_High         float64
#  165   ADM_Low          float64
#  166   ADM_Open         float64
#  167   ADM_Volume       int64
#  168   ADP_Adj Close    float64
#  169   ADP_Close        float64
#  170   ADP_High         float64
#  171   ADP_Low          float64
#  172   ADP_Open         float64
#  173   ADP_Volume       int64
#  174   ADSK_Adj Close   float64
#  175   ADSK_Close       float64
#  176   ADSK_High        float64
#  177   ADSK_Low         float64
#  178   ADSK_Open        float64
#  179   ADSK_Volume      int64
#  180   ADS_Adj Close    float64
#  181   ADS_Close        float64
#  182   ADS_High         float64
#  183   ADS_Low          float64
#  184   ADS_Open         float64
#  185   ADS_Volume       float64
#  186   AEE_Adj Close    float64
#  187   AEE_Close        float64
#  188   AEE_High         float64
#  189   AEE_Low          float64
#  190   AEE_Open         float64
#  191   AEE_Volume       int64
#  192   AEGN_Adj Close   float64
#  193   AEGN_Close       float64
#  194   AEGN_High        float64
#  195   AEGN_Low         float64
#  196   AEGN_Open        float64
#  197   AEGN_Volume      float64
#  198   AEIS_Adj Close   float64
#  199   AEIS_Close       float64
#  200   AEIS_High        float64
#  201   AEIS_Low         float64
#  202   AEIS_Open        float64
#  203   AEIS_Volume      int64
#  204   AEL_Adj Close    float64
#  205   AEL_Close        float64
#  206   AEL_High         float64
#  207   AEL_Low          float64
#  208   AEL_Open         float64
#  209   AEL_Volume       float64
#  210   AEO_Adj Close    float64
#  211   AEO_Close        float64
#  212   AEO_High         float64
#  213   AEO_Low          float64
#  214   AEO_Open         float64
#  215   AEO_Volume       int64
#  216   AEP_Adj Close    float64
#  217   AEP_Close        float64
#  218   AEP_High         float64
#  219   AEP_Low          float64
#  220   AEP_Open         float64
#  221   AEP_Volume       int64
#  222   AES_Adj Close    float64
#  223   AES_Close        float64
#  224   AES_High         float64
#  225   AES_Low          float64
#  226   AES_Open         float64
#  227   AES_Volume       int64
#  228   AET_Adj Close    float64
#  229   AET_Close        float64
#  230   AET_High         float64
#  231   AET_Low          float64
#  232   AET_Open         float64
#  233   AET_Volume       float64
#  234   AFG_Adj Close    float64
#  235   AFG_Close        float64
#  236   AFG_High         float64
#  237   AFG_Low          float64
#  238   AFG_Open         float64
#  239   AFG_Volume       int64
#  240   AGCO_Adj Close   float64
#  241   AGCO_Close       float64
#  242   AGCO_High        float64
#  243   AGCO_Low         float64
#  244   AGCO_Open        float64
#  245   AGCO_Volume      int64
#  246   AGN_Adj Close    float64
#  247   AGN_Close        float64
#  248   AGN_High         float64
#  249   AGN_Low          float64
#  250   AGN_Open         float64
#  251   AGN_Volume       float64
#  252   AGYS_Adj Close   float64
#  253   AGYS_Close       float64
#  254   AGYS_High        float64
#  255   AGYS_Low         float64
#  256   AGYS_Open        float64
#  257   AGYS_Volume      int64
#  258   AHH_Adj Close    float64
#  259   AHH_Close        float64
#  260   AHH_High         float64
#  261   AHH_Low          float64
#  262   AHH_Open         float64
#  263   AHH_Volume       int64
#  264   AHL_Adj Close    float64
#  265   AHL_Close        float64
#  266   AHL_High         float64
#  267   AHL_Low          float64
#  268   AHL_Open         float64
#  269   AHL_Volume       int64
#  270   AIN_Adj Close    float64
#  271   AIN_Close        float64
#  272   AIN_High         float64
#  273   AIN_Low          float64
#  274   AIN_Open         float64
#  275   AIN_Volume       int64
#  276   AIR_Adj Close    float64
#  277   AIR_Close        float64
#  278   AIR_High         float64
#  279   AIR_Low          float64
#  280   AIR_Open         float64
#  281   AIR_Volume       float64
#  282   AIT_Adj Close    float64
#  283   AIT_Close        float64
#  284   AIT_High         float64
#  285   AIT_Low          float64
#  286   AIT_Open         float64
#  287   AIT_Volume       int64
#  288   AIV_Adj Close    float64
#  289   AIV_Close        float64
#  290   AIV_High         float64
#  291   AIV_Low          float64
#  292   AIV_Open         float64
#  293   AIV_Volume       int64
#  294   AJG_Adj Close    float64
#  295   AJG_Close        float64
#  296   AJG_High         float64
#  297   AJG_Low          float64
#  298   AJG_Open         float64
#  299   AJG_Volume       int64
#  300   AKAM_Adj Close   float64
#  301   AKAM_Close       float64
#  302   AKAM_High        float64
#  303   AKAM_Low         float64
#  304   AKAM_Open        float64
#  305   AKAM_Volume      int64
#  306   AKRX_Adj Close   float64
#  307   AKRX_Close       float64
#  308   AKRX_High        float64
#  309   AKRX_Low         float64
#  310   AKRX_Open        float64
#  311   AKRX_Volume      float64
#  312   AKR_Adj Close    float64
#  313   AKR_Close        float64
#  314   AKR_High         float64
#  315   AKR_Low          float64
#  316   AKR_Open         float64
#  317   AKR_Volume       int64
#  318   AKS_Adj Close    float64
#  319   AKS_Close        float64
#  320   AKS_High         float64
#  321   AKS_Low          float64
#  322   AKS_Open         float64
#  323   AKS_Volume       float64
#  324   ALB_Adj Close    float64
#  325   ALB_Close        float64
#  326   ALB_High         float64
#  327   ALB_Low          float64
#  328   ALB_Open         float64
#  329   ALB_Volume       int64
#  330   ALEX_Adj Close   float64
#  331   ALEX_Close       float64
#  332   ALEX_High        float64
#  333   ALEX_Low         float64
#  334   ALEX_Open        float64
#  335   ALEX_Volume      int64
#  336   ALE_Adj Close    float64
#  337   ALE_Close        float64
#  338   ALE_High         float64
#  339   ALE_Low          float64
#  340   ALE_Open         float64
#  341   ALE_Volume       int64
#  342   ALGN_Adj Close   float64
#  343   ALGN_Close       float64
#  344   ALGN_High        float64
#  345   ALGN_Low         float64
#  346   ALGN_Open        float64
#  347   ALGN_Volume      int64
#  348   ALGT_Adj Close   float64
#  349   ALGT_Close       float64
#  350   ALGT_High        float64
#  351   ALGT_Low         float64
#  352   ALGT_Open        float64
#  353   ALGT_Volume      int64
#  354   ALG_Adj Close    float64
#  355   ALG_Close        float64
#  356   ALG_High         float64
#  357   ALG_Low          float64
#  358   ALG_Open         float64
#  359   ALG_Volume       int64
#  360   ALK_Adj Close    float64
#  361   ALK_Close        float64
#  362   ALK_High         float64
#  363   ALK_Low          float64
#  364   ALK_Open         float64
#  365   ALK_Volume       int64
#  366   ALLE_Adj Close   float64
#  367   ALLE_Close       float64
#  368   ALLE_High        float64
#  369   ALLE_Low         float64
#  370   ALLE_Open        float64
#  371   ALLE_Volume      int64
#  372   ALOG_Adj Close   float64
#  373   ALOG_Close       float64
#  374   ALOG_High        float64
#  375   ALOG_Low         float64
#  376   ALOG_Open        float64
#  377   ALOG_Volume      float64
#  378   ALXN_Adj Close   float64
#  379   ALXN_Close       float64
#  380   ALXN_High        float64
#  381   ALXN_Low         float64
#  382   ALXN_Open        float64
#  383   ALXN_Volume      float64
#  384   AMCX_Adj Close   float64
#  385   AMCX_Close       float64
#  386   AMCX_High        float64
#  387   AMCX_Low         float64
#  388   AMCX_Open        float64
#  389   AMCX_Volume      int64
#  390   AMD_Adj Close    float64
#  391   AMD_Close        float64
#  392   AMD_High         float64
#  393   AMD_Low          float64
#  394   AMD_Open         float64
#  395   AMD_Volume       int64
#  396   AMED_Adj Close   float64
#  397   AMED_Close       float64
#  398   AMED_High        float64
#  399   AMED_Low         float64
#  400   AMED_Open        float64
#  401   AMED_Volume      int64
#  402   AME_Adj Close    float64
#  403   AME_Close        float64
#  404   AME_High         float64
#  405   AME_Low          float64
#  406   AME_Open         float64
#  407   AME_Volume       int64
#  408   AMGN_Adj Close   float64
#  409   AMGN_Close       float64
#  410   AMGN_High        float64
#  411   AMGN_Low         float64
#  412   AMGN_Open        float64
#  413   AMGN_Volume      int64
#  414   AMG_Adj Close    float64
#  415   AMG_Close        float64
#  416   AMG_High         float64
#  417   AMG_Low          float64
#  418   AMG_Open         float64
#  419   AMG_Volume       int64
#  420   AMPH_Adj Close   float64
#  421   AMPH_Close       float64
#  422   AMPH_High        float64
#  423   AMPH_Low         float64
#  424   AMPH_Open        float64
#  425   AMPH_Volume      int64
#  426   AMSF_Adj Close   float64
#  427   AMSF_Close       float64
#  428   AMSF_High        float64
#  429   AMSF_Low         float64
#  430   AMSF_Open        float64
#  431   AMSF_Volume      int64
#  432   AMT_Adj Close    float64
#  433   AMT_Close        float64
#  434   AMT_High         float64
#  435   AMT_Low          float64
#  436   AMT_Open         float64
#  437   AMT_Volume       int64
#  438   AMWD_Adj Close   float64
#  439   AMWD_Close       float64
#  440   AMWD_High        float64
#  441   AMWD_Low         float64
#  442   AMWD_Open        float64
#  443   AMWD_Volume      int64
#  444   AMZN_Adj Close   float64
#  445   AMZN_Close       float64
#  446   AMZN_High        float64
#  447   AMZN_Low         float64
#  448   AMZN_Open        float64
#  449   AMZN_Volume      int64
#  450   ANDE_Adj Close   float64
#  451   ANDE_Close       float64
#  452   ANDE_High        float64
#  453   ANDE_Low         float64
#  454   ANDE_Open        float64
#  455   ANDE_Volume      int64
#  456   ANDV_Adj Close   float64
#  457   ANDV_Close       float64
#  458   ANDV_High        float64
#  459   ANDV_Low         float64
#  460   ANDV_Open        float64
#  461   ANDV_Volume      float64
#  462   ANF_Adj Close    float64
#  463   ANF_Close        float64
#  464   ANF_High         float64
#  465   ANF_Low          float64
#  466   ANF_Open         float64
#  467   ANF_Volume       int64
#  468   ANGO_Adj Close   float64
#  469   ANGO_Close       float64
#  470   ANGO_High        float64
#  471   ANGO_Low         float64
#  472   ANGO_Open        float64
#  473   ANGO_Volume      int64
#  474   ANIK_Adj Close   float64
#  475   ANIK_Close       float64
#  476   ANIK_High        float64
#  477   ANIK_Low         float64
#  478   ANIK_Open        float64
#  479   ANIK_Volume      int64
#  480   ANIP_Adj Close   float64
#  481   ANIP_Close       float64
#  482   ANIP_High        float64
#  483   ANIP_Low         float64
#  484   ANIP_Open        float64
#  485   ANIP_Volume      int64
#  486   ANSS_Adj Close   float64
#  487   ANSS_Close       float64
#  488   ANSS_High        float64
#  489   ANSS_Low         float64
#  490   ANSS_Open        float64
#  491   ANSS_Volume      int64
#  492   ANTM_Adj Close   float64
#  493   ANTM_Close       float64
#  494   ANTM_High        float64
#  495   ANTM_Low         float64
#  496   ANTM_Open        float64
#  497   ANTM_Volume      float64
#  498   AN_Adj Close     float64
#  499   AN_Close         float64
#  500   AN_High          float64
#  501   AN_Low           float64
#  502   AN_Open          float64
#  503   AN_Volume        int64
#  504   AON_Adj Close    float64
#  505   AON_Close        float64
#  506   AON_High         float64
#  507   AON_Low          float64
#  508   AON_Open         float64
#  509   AON_Volume       int64
#  510   AOS_Adj Close    float64
#  511   AOS_Close        float64
#  512   AOS_High         float64
#  513   AOS_Low          float64
#  514   AOS_Open         float64
#  515   AOS_Volume       int64
#  516   APA_Adj Close    float64
#  517   APA_Close        float64
#  518   APA_High         float64
#  519   APA_Low          float64
#  520   APA_Open         float64
#  521   APA_Volume       int64
#  522   APC_Adj Close    float64
#  523   APC_Close        float64
#  524   APC_High         float64
#  525   APC_Low          float64
#  526   APC_Open         float64
#  527   APC_Volume       float64
#  528   APD_Adj Close    float64
#  529   APD_Close        float64
#  530   APD_High         float64
#  531   APD_Low          float64
#  532   APD_Open         float64
#  533   APD_Volume       int64
#  534   APEI_Adj Close   float64
#  535   APEI_Close       float64
#  536   APEI_High        float64
#  537   APEI_Low         float64
#  538   APEI_Open        float64
#  539   APEI_Volume      int64
#  540   APH_Adj Close    float64
#  541   APH_Close        float64
#  542   APH_High         float64
#  543   APH_Low          float64
#  544   APH_Open         float64
#  545   APH_Volume       int64
#  546   APOG_Adj Close   float64
#  547   APOG_Close       float64
#  548   APOG_High        float64
#  549   APOG_Low         float64
#  550   APOG_Open        float64
#  551   APOG_Volume      int64
#  552   ARE_Adj Close    float64
#  553   ARE_Close        float64
#  554   ARE_High         float64
#  555   ARE_Low          float64
#  556   ARE_Open         float64
#  557   ARE_Volume       int64
#  558   ARI_Adj Close    float64
#  559   ARI_Close        float64
#  560   ARI_High         float64
#  561   ARI_Low          float64
#  562   ARI_Open         float64
#  563   ARI_Volume       int64
#  564   AROC_Adj Close   float64
#  565   AROC_Close       float64
#  566   AROC_High        float64
#  567   AROC_Low         float64
#  568   AROC_Open        float64
#  569   AROC_Volume      int64
#  570   ARRS_Adj Close   float64
#  571   ARRS_Close       float64
#  572   ARRS_High        float64
#  573   ARRS_Low         float64
#  574   ARRS_Open        float64
#  575   ARRS_Volume      float64
#  576   ARR_Adj Close    float64
#  577   ARR_Close        float64
#  578   ARR_High         float64
#  579   ARR_Low          float64
#  580   ARR_Open         float64
#  581   ARR_Volume       int64
#  582   ARW_Adj Close    float64
#  583   ARW_Close        float64
#  584   ARW_High         float64
#  585   ARW_Low          float64
#  586   ARW_Open         float64
#  587   ARW_Volume       int64
#  588   ASB_Adj Close    float64
#  589   ASB_Close        float64
#  590   ASB_High         float64
#  591   ASB_Low          float64
#  592   ASB_Open         float64
#  593   ASB_Volume       int64
#  594   ASGN_Adj Close   float64
#  595   ASGN_Close       float64
#  596   ASGN_High        float64
#  597   ASGN_Low         float64
#  598   ASGN_Open        float64
#  599   ASGN_Volume      int64
#  600   ASH_Adj Close    float64
#  601   ASH_Close        float64
#  602   ASH_High         float64
#  603   ASH_Low          float64
#  604   ASH_Open         float64
#  605   ASH_Volume       int64
#  606   ASIX_Adj Close   float64
#  607   ASIX_Close       float64
#  608   ASIX_High        float64
#  609   ASIX_Low         float64
#  610   ASIX_Open        float64
#  611   ASIX_Volume      float64
#  612   ASNA_Adj Close   float64
#  613   ASNA_Close       float64
#  614   ASNA_High        float64
#  615   ASNA_Low         float64
#  616   ASNA_Open        float64
#  617   ASNA_Volume      float64
#  618   ASTE_Adj Close   float64
#  619   ASTE_Close       float64
#  620   ASTE_High        float64
#  621   ASTE_Low         float64
#  622   ASTE_Open        float64
#  623   ASTE_Volume      int64
#  624   ATGE_Adj Close   float64
#  625   ATGE_Close       float64
#  626   ATGE_High        float64
#  627   ATGE_Low         float64
#  628   ATGE_Open        float64
#  629   ATGE_Volume      int64
#  630   ATI_Adj Close    float64
#  631   ATI_Close        float64
#  632   ATI_High         float64
#  633   ATI_Low          float64
#  634   ATI_Open         float64
#  635   ATI_Volume       int64
#  636   ATNI_Adj Close   float64
#  637   ATNI_Close       float64
#  638   ATNI_High        float64
#  639   ATNI_Low         float64
#  640   ATNI_Open        float64
#  641   ATNI_Volume      int64
#  642   ATO_Adj Close    float64
#  643   ATO_Close        float64
#  644   ATO_High         float64
#  645   ATO_Low          float64
#  646   ATO_Open         float64
#  647   ATO_Volume       int64
#  648   ATR_Adj Close    float64
#  649   ATR_Close        float64
#  650   ATR_High         float64
#  651   ATR_Low          float64
#  652   ATR_Open         float64
#  653   ATR_Volume       int64
#  654   ATVI_Adj Close   float64
#  655   ATVI_Close       float64
#  656   ATVI_High        float64
#  657   ATVI_Low         float64
#  658   ATVI_Open        float64
#  659   ATVI_Volume      float64
#  660   AVA_Adj Close    float64
#  661   AVA_Close        float64
#  662   AVA_High         float64
#  663   AVA_Low          float64
#  664   AVA_Open         float64
#  665   AVA_Volume       int64
#  666   AVB_Adj Close    float64
#  667   AVB_Close        float64
#  668   AVB_High         float64
#  669   AVB_Low          float64
#  670   AVB_Open         float64
#  671   AVB_Volume       int64
#  672   AVGO_Adj Close   float64
#  673   AVGO_Close       float64
#  674   AVGO_High        float64
#  675   AVGO_Low         float64
#  676   AVGO_Open        float64
#  677   AVGO_Volume      int64
#  678   AVT_Adj Close    float64
#  679   AVT_Close        float64
#  680   AVT_High         float64
#  681   AVT_Low          float64
#  682   AVT_Open         float64
#  683   AVT_Volume       int64
#  684   AVY_Adj Close    float64
#  685   AVY_Close        float64
#  686   AVY_High         float64
#  687   AVY_Low          float64
#  688   AVY_Open         float64
#  689   AVY_Volume       int64
#  690   AWK_Adj Close    float64
#  691   AWK_Close        float64
#  692   AWK_High         float64
#  693   AWK_Low          float64
#  694   AWK_Open         float64
#  695   AWK_Volume       int64
#  696   AWR_Adj Close    float64
#  697   AWR_Close        float64
#  698   AWR_High         float64
#  699   AWR_Low          float64
#  700   AWR_Open         float64
#  701   AWR_Volume       int64
#  702   AXE_Adj Close    float64
#  703   AXE_Close        float64
#  704   AXE_High         float64
#  705   AXE_Low          float64
#  706   AXE_Open         float64
#  707   AXE_Volume       float64
#  708   AXL_Adj Close    float64
#  709   AXL_Close        float64
#  710   AXL_High         float64
#  711   AXL_Low          float64
#  712   AXL_Open         float64
#  713   AXL_Volume       int64
#  714   AXP_Adj Close    float64
#  715   AXP_Close        float64
#  716   AXP_High         float64
#  717   AXP_Low          float64
#  718   AXP_Open         float64
#  719   AXP_Volume       int64
#  720   AYI_Adj Close    float64
#  721   AYI_Close        float64
#  722   AYI_High         float64
#  723   AYI_Low          float64
#  724   AYI_Open         float64
#  725   AYI_Volume       int64
#  726   AZO_Adj Close    float64
#  727   AZO_Close        float64
#  728   AZO_High         float64
#  729   AZO_Low          float64
#  730   AZO_Open         float64
#  731   AZO_Volume       int64
#  732   AZZ_Adj Close    float64
#  733   AZZ_Close        float64
#  734   AZZ_High         float64
#  735   AZZ_Low          float64
#  736   AZZ_Open         float64
#  737   AZZ_Volume       int64
#  738   A_Adj Close      float64
#  739   A_Close          float64
#  740   A_High           float64
#  741   A_Low            float64
#  742   A_Open           float64
#  743   A_Volume         int64
#  744   BAC_Adj Close    float64
#  745   BAC_Close        float64
#  746   BAC_High         float64
#  747   BAC_Low          float64
#  748   BAC_Open         float64
#  749   BAC_Volume       int64
#  750   BANC_Adj Close   float64
#  751   BANC_Close       float64
#  752   BANC_High        float64
#  753   BANC_Low         float64
#  754   BANC_Open        float64
#  755   BANC_Volume      int64
#  756   BANR_Adj Close   float64
#  757   BANR_Close       float64
#  758   BANR_High        float64
#  759   BANR_Low         float64
#  760   BANR_Open        float64
#  761   BANR_Volume      int64
#  762   BAX_Adj Close    float64
#  763   BAX_Close        float64
#  764   BAX_High         float64
#  765   BAX_Low          float64
#  766   BAX_Open         float64
#  767   BAX_Volume       int64
#  768   BA_Adj Close     float64
#  769   BA_Close         float64
#  770   BA_High          float64
#  771   BA_Low           float64
#  772   BA_Open          float64
#  773   BA_Volume        int64
#  774   BBBY_Adj Close   float64
#  775   BBBY_Close       float64
#  776   BBBY_High        float64
#  777   BBBY_Low         float64
#  778   BBBY_Open        float64
#  779   BBBY_Volume      float64
#  780   BBT_Adj Close    float64
#  781   BBT_Close        float64
#  782   BBT_High         float64
#  783   BBT_Low          float64
#  784   BBT_Open         float64
#  785   BBT_Volume       float64
#  786   BBY_Adj Close    float64
#  787   BBY_Close        float64
#  788   BBY_High         float64
#  789   BBY_Low          float64
#  790   BBY_Open         float64
#  791   BBY_Volume       int64
#  792   BCC_Adj Close    float64
#  793   BCC_Close        float64
#  794   BCC_High         float64
#  795   BCC_Low          float64
#  796   BCC_Open         float64
#  797   BCC_Volume       int64
#  798   BCOR_Adj Close   float64
#  799   BCOR_Close       float64
#  800   BCOR_High        float64
#  801   BCOR_Low         float64
#  802   BCOR_Open        float64
#  803   BCOR_Volume      float64
#  804   BCO_Adj Close    float64
#  805   BCO_Close        float64
#  806   BCO_High         float64
#  807   BCO_Low          float64
#  808   BCO_Open         float64
#  809   BCO_Volume       int64
#  810   BCPC_Adj Close   float64
#  811   BCPC_Close       float64
#  812   BCPC_High        float64
#  813   BCPC_Low         float64
#  814   BCPC_Open        float64
#  815   BCPC_Volume      int64
#  816   BC_Adj Close     float64
#  817   BC_Close         float64
#  818   BC_High          float64
#  819   BC_Low           float64
#  820   BC_Open          float64
#  821   BC_Volume        int64
#  822   BDX_Adj Close    float64
#  823   BDX_Close        float64
#  824   BDX_High         float64
#  825   BDX_Low          float64
#  826   BDX_Open         float64
#  827   BDX_Volume       int64
#  828   BELFB_Adj Close  float64
#  829   BELFB_Close      float64
#  830   BELFB_High       float64
#  831   BELFB_Low        float64
#  832   BELFB_Open       float64
#  833   BELFB_Volume     int64
#  834   BEL_Adj Close    float64
#  835   BEL_Close        float64
#  836   BEL_High         float64
#  837   BEL_Low          float64
#  838   BEL_Open         float64
#  839   BEL_Volume       float64
#  840   BEN_Adj Close    float64
#  841   BEN_Close        float64
#  842   BEN_High         float64
#  843   BEN_Low          float64
#  844   BEN_Open         float64
#  845   BEN_Volume       int64
#  846   BGC_Adj Close    float64
#  847   BGC_Close        float64
#  848   BGC_High         float64
#  849   BGC_Low          float64
#  850   BGC_Open         float64
#  851   BGC_Volume       int64
#  852   BGFV_Adj Close   float64
#  853   BGFV_Close       float64
#  854   BGFV_High        float64
#  855   BGFV_Low         float64
#  856   BGFV_Open        float64
#  857   BGFV_Volume      int64
#  858   BGG_Adj Close    float64
#  859   BGG_Close        float64
#  860   BGG_High         float64
#  861   BGG_Low          float64
#  862   BGG_Open         float64
#  863   BGG_Volume       float64
#  864   BGS_Adj Close    float64
#  865   BGS_Close        float64
#  866   BGS_High         float64
#  867   BGS_Low          float64
#  868   BGS_Open         float64
#  869   BGS_Volume       int64
#  870   BHE_Adj Close    float64
#  871   BHE_Close        float64
#  872   BHE_High         float64
#  873   BHE_Low          float64
#  874   BHE_Open         float64
#  875   BHE_Volume       int64
#  876   BID_Adj Close    float64
#  877   BID_Close        float64
#  878   BID_High         float64
#  879   BID_Low          float64
#  880   BID_Open         float64
#  881   BID_Volume       float64
#  882   BIG_Adj Close    float64
#  883   BIG_Close        float64
#  884   BIG_High         float64
#  885   BIG_Low          float64
#  886   BIG_Open         float64
#  887   BIG_Volume       int64
#  888   BIO_Adj Close    float64
#  889   BIO_Close        float64
#  890   BIO_High         float64
#  891   BIO_Low          float64
#  892   BIO_Open         float64
#  893   BIO_Volume       int64
#  894   BJRI_Adj Close   float64
#  895   BJRI_Close       float64
#  896   BJRI_High        float64
#  897   BJRI_Low         float64
#  898   BJRI_Open        float64
#  899   BJRI_Volume      int64
#  900   BKE_Adj Close    float64
#  901   BKE_Close        float64
#  902   BKE_High         float64
#  903   BKE_Low          float64
#  904   BKE_Open         float64
#  905   BKE_Volume       int64
#  906   BKH_Adj Close    float64
#  907   BKH_Close        float64
#  908   BKH_High         float64
#  909   BKH_Low          float64
#  910   BKH_Open         float64
#  911   BKH_Volume       int64
#  912   BKNG_Adj Close   float64
#  913   BKNG_Close       float64
#  914   BKNG_High        float64
#  915   BKNG_Low         float64
#  916   BKNG_Open        float64
#  917   BKNG_Volume      int64
#  918   BKS_Adj Close    float64
#  919   BKS_Close        float64
#  920   BKS_High         float64
#  921   BKS_Low          float64
#  922   BKS_Open         float64
#  923   BKS_Volume       float64
#  924   BLD_Adj Close    float64
#  925   BLD_Close        float64
#  926   BLD_High         float64
#  927   BLD_Low          float64
#  928   BLD_Open         float64
#  929   BLD_Volume       float64
#  930   BLL_Adj Close    float64
#  931   BLL_Close        float64
#  932   BLL_High         float64
#  933   BLL_Low          float64
#  934   BLL_Open         float64
#  935   BLL_Volume       float64
#  936   BMI_Adj Close    float64
#  937   BMI_Close        float64
#  938   BMI_High         float64
#  939   BMI_Low          float64
#  940   BMI_Open         float64
#  941   BMI_Volume       int64
#  942   BMS_Adj Close    float64
#  943   BMS_Close        float64
#  944   BMS_High         float64
#  945   BMS_Low          float64
#  946   BMS_Open         float64
#  947   BMS_Volume       int64
#  948   BMY_Adj Close    float64
#  949   BMY_Close        float64
#  950   BMY_High         float64
#  951   BMY_Low          float64
#  952   BMY_Open         float64
#  953   BMY_Volume       int64
#  954   BNED_Adj Close   float64
#  955   BNED_Close       float64
#  956   BNED_High        float64
#  957   BNED_Low         float64
#  958   BNED_Open        float64
#  959   BNED_Volume      float64
#  960   BOBE_Adj Close   float64
#  961   BOBE_Close       float64
#  962   BOBE_High        float64
#  963   BOBE_Low         float64
#  964   BOBE_Open        float64
#  965   BOBE_Volume      float64
#  966   BOH_Adj Close    float64
#  967   BOH_Close        float64
#  968   BOH_High         float64
#  969   BOH_Low          float64
#  970   BOH_Open         float64
#  971   BOH_Volume       int64
#  972   BPFH_Adj Close   float64
#  973   BPFH_Close       float64
#  974   BPFH_High        float64
#  975   BPFH_Low         float64
#  976   BPFH_Open        float64
#  977   BPFH_Volume      float64
#  978   BRC_Adj Close    float64
#  979   BRC_Close        float64
#  980   BRC_High         float64
#  981   BRC_Low          float64
#  982   BRC_Open         float64
#  983   BRC_Volume       int64
#  984   BRO_Adj Close    float64
#  985   BRO_Close        float64
#  986   BRO_High         float64
#  987   BRO_Low          float64
#  988   BRO_Open         float64
#  989   BRO_Volume       int64
#  990   BRS_Adj Close    float64
#  991   BRS_Close        float64
#  992   BRS_High         float64
#  993   BRS_Low          float64
#  994   BRS_Open         float64
#  995   BRS_Volume       float64
#  996   BWA_Adj Close    float64
#  997   BWA_Close        float64
#  998   BWA_High         float64
#  999   BWA_Low          float64
#  1000  BWA_Open         float64
#  1001  BWA_Volume       int64
#  1002  BXP_Adj Close    float64
#  1003  BXP_Close        float64
#  1004  BXP_High         float64
#  1005  BXP_Low          float64
#  1006  BXP_Open         float64
#  1007  BXP_Volume       int64
#  1008  BYD_Adj Close    float64
#  1009  BYD_Close        float64
#  1010  BYD_High         float64
#  1011  BYD_Low          float64
#  1012  BYD_Open         float64
#  1013  BYD_Volume       int64
#  1014  B_Adj Close      float64
#  1015  B_Close          float64
#  1016  B_High           float64
#  1017  B_Low            float64
#  1018  B_Open           float64
#  1019  B_Volume         int64
#  1020  CABO_Adj Close   float64
#  1021  CABO_Close       float64
#  1022  CABO_High        float64
#  1023  CABO_Low         float64
#  1024  CABO_Open        float64
#  1025  CABO_Volume      float64
#  1026  CACI_Adj Close   float64
#  1027  CACI_Close       float64
#  1028  CACI_High        float64
#  1029  CACI_Low         float64
#  1030  CACI_Open        float64
#  1031  CACI_Volume      int64
#  1032  CAG_Adj Close    float64
#  1033  CAG_Close        float64
#  1034  CAG_High         float64
#  1035  CAG_Low          float64
#  1036  CAG_Open         float64
#  1037  CAG_Volume       int64
#  1038  CAH_Adj Close    float64
#  1039  CAH_Close        float64
#  1040  CAH_High         float64
#  1041  CAH_Low          float64
#  1042  CAH_Open         float64
#  1043  CAH_Volume       int64
#  1044  CAKE_Adj Close   float64
#  1045  CAKE_Close       float64
#  1046  CAKE_High        float64
#  1047  CAKE_Low         float64
#  1048  CAKE_Open        float64
#  1049  CAKE_Volume      int64
#  1050  CAL_Adj Close    float64
#  1051  CAL_Close        float64
#  1052  CAL_High         float64
#  1053  CAL_Low          float64
#  1054  CAL_Open         float64
#  1055  CAL_Volume       int64
#  1056  CAMP_Adj Close   float64
#  1057  CAMP_Close       float64
#  1058  CAMP_High        float64
#  1059  CAMP_Low         float64
#  1060  CAMP_Open        float64
#  1061  CAMP_Volume      float64
#  1062  CASH_Adj Close   float64
#  1063  CASH_Close       float64
#  1064  CASH_High        float64
#  1065  CASH_Low         float64
#  1066  CASH_Open        float64
#  1067  CASH_Volume      int64
#  1068  CASY_Adj Close   float64
#  1069  CASY_Close       float64
#  1070  CASY_High        float64
#  1071  CASY_Low         float64
#  1072  CASY_Open        float64
#  1073  CASY_Volume      int64
#  1074  CATM_Adj Close   float64
#  1075  CATM_Close       float64
#  1076  CATM_High        float64
#  1077  CATM_Low         float64
#  1078  CATM_Open        float64
#  1079  CATM_Volume      float64
#  1080  CATY_Adj Close   float64
#  1081  CATY_Close       float64
#  1082  CATY_High        float64
#  1083  CATY_Low         float64
#  1084  CATY_Open        float64
#  1085  CATY_Volume      int64
#  1086  CAT_Adj Close    float64
#  1087  CAT_Close        float64
#  1088  CAT_High         float64
#  1089  CAT_Low          float64
#  1090  CAT_Open         float64
#  1091  CAT_Volume       int64
#  1092  CA_Adj Close     float64
#  1093  CA_Close         float64
#  1094  CA_High          float64
#  1095  CA_Low           float64
#  1096  CA_Open          float64
#  1097  CA_Volume        float64
#  1098  CBB_Adj Close    float64
#  1099  CBB_Close        float64
#  1100  CBB_High         float64
#  1101  CBB_Low          float64
#  1102  CBB_Open         float64
#  1103  CBB_Volume       float64
#  1104  CBG_Adj Close    float64
#  1105  CBG_Close        float64
#  1106  CBG_High         float64
#  1107  CBG_Low          float64
#  1108  CBG_Open         float64
#  1109  CBG_Volume       float64
#  1110  CBL_Adj Close    float64
#  1111  CBL_Close        float64
#  1112  CBL_High         float64
#  1113  CBL_Low          float64
#  1114  CBL_Open         float64
#  1115  CBL_Volume       float64
#  1116  CBM_Adj Close    float64
#  1117  CBM_Close        float64
#  1118  CBM_High         float64
#  1119  CBM_Low          float64
#  1120  CBM_Open         float64
#  1121  CBM_Volume       float64
#  1122  CBOE_Adj Close   float64
#  1123  CBOE_Close       float64
#  1124  CBOE_High        float64
#  1125  CBOE_Low         float64
#  1126  CBOE_Open        float64
#  1127  CBOE_Volume      int64
#  1128  CBRL_Adj Close   float64
#  1129  CBRL_Close       float64
#  1130  CBRL_High        float64
#  1131  CBRL_Low         float64
#  1132  CBRL_Open        float64
#  1133  CBRL_Volume      int64
#  1134  CBT_Adj Close    float64
#  1135  CBT_Close        float64
#  1136  CBT_High         float64
#  1137  CBT_Low          float64
#  1138  CBT_Open         float64
#  1139  CBT_Volume       int64
#  1140  CBU_Adj Close    float64
#  1141  CBU_Close        float64
#  1142  CBU_High         float64
#  1143  CBU_Low          float64
#  1144  CBU_Open         float64
#  1145  CBU_Volume       int64
#  1146  CB_Adj Close     float64
#  1147  CB_Close         float64
#  1148  CB_High          float64
#  1149  CB_Low           float64
#  1150  CB_Open          float64
#  1151  CB_Volume        int64
#  1152  CCI_Adj Close    float64
#  1153  CCI_Close        float64
#  1154  CCI_High         float64
#  1155  CCI_Low          float64
#  1156  CCI_Open         float64
#  1157  CCI_Volume       int64
#  1158  CCL_Adj Close    float64
#  1159  CCL_Close        float64
#  1160  CCL_High         float64
#  1161  CCL_Low          float64
#  1162  CCL_Open         float64
#  1163  CCL_Volume       int64
#  1164  CCMP_Adj Close   float64
#  1165  CCMP_Close       float64
#  1166  CCMP_High        float64
#  1167  CCMP_Low         float64
#  1168  CCMP_Open        float64
#  1169  CCMP_Volume      float64
#  1170  CCRN_Adj Close   float64
#  1171  CCRN_Close       float64
#  1172  CCRN_High        float64
#  1173  CCRN_Low         float64
#  1174  CCRN_Open        float64
#  1175  CCRN_Volume      int64
#  1176  CC_Adj Close     float64
#  1177  CC_Close         float64
#  1178  CC_High          float64
#  1179  CC_Low           float64
#  1180  CC_Open          float64
#  1181  CC_Volume        float64
#  1182  CDNS_Adj Close   float64
#  1183  CDNS_Close       float64
#  1184  CDNS_High        float64
#  1185  CDNS_Low         float64
#  1186  CDNS_Open        float64
#  1187  CDNS_Volume      int64
#  1188  CDR_Adj Close    float64
#  1189  CDR_Close        float64
#  1190  CDR_High         float64
#  1191  CDR_Low          float64
#  1192  CDR_Open         float64
#  1193  CDR_Volume       float64
#  1194  CECO_Adj Close   float64
#  1195  CECO_Close       float64
#  1196  CECO_High        float64
#  1197  CECO_Low         float64
#  1198  CECO_Open        float64
#  1199  CECO_Volume      int64
#  1200  CELG_Adj Close   float64
#  1201  CELG_Close       float64
#  1202  CELG_High        float64
#  1203  CELG_Low         float64
#  1204  CELG_Open        float64
#  1205  CELG_Volume      float64
#  1206  CENTA_Adj Close  float64
#  1207  CENTA_Close      float64
#  1208  CENTA_High       float64
#  1209  CENTA_Low        float64
#  1210  CENTA_Open       float64
#  1211  CENTA_Volume     int64
#  1212  CENX_Adj Close   float64
#  1213  CENX_Close       float64
#  1214  CENX_High        float64
#  1215  CENX_Low         float64
#  1216  CENX_Open        float64
#  1217  CENX_Volume      int64
#  1218  CEVA_Adj Close   float64
#  1219  CEVA_Close       float64
#  1220  CEVA_High        float64
#  1221  CEVA_Low         float64
#  1222  CEVA_Open        float64
#  1223  CEVA_Volume      int64
#  1224  CFR_Adj Close    float64
#  1225  CFR_Close        float64
#  1226  CFR_High         float64
#  1227  CFR_Low          float64
#  1228  CFR_Open         float64
#  1229  CFR_Volume       int64
#  1230  CF_Adj Close     float64
#  1231  CF_Close         float64
#  1232  CF_High          float64
#  1233  CF_Low           float64
#  1234  CF_Open          float64
#  1235  CF_Volume        int64
#  1236  CGNX_Adj Close   float64
#  1237  CGNX_Close       float64
#  1238  CGNX_High        float64
#  1239  CGNX_Low         float64
#  1240  CGNX_Open        float64
#  1241  CGNX_Volume      int64
#  1242  CHCT_Adj Close   float64
#  1243  CHCT_Close       float64
#  1244  CHCT_High        float64
#  1245  CHCT_Low         float64
#  1246  CHCT_Open        float64
#  1247  CHCT_Volume      float64
#  1248  CHD_Adj Close    float64
#  1249  CHD_Close        float64
#  1250  CHD_High         float64
#  1251  CHD_Low          float64
#  1252  CHD_Open         float64
#  1253  CHD_Volume       int64
#  1254  CHE_Adj Close    float64
#  1255  CHE_Close        float64
#  1256  CHE_High         float64
#  1257  CHE_Low          float64
#  1258  CHE_Open         float64
#  1259  CHE_Volume       int64
#  1260  CHFC_Adj Close   float64
#  1261  CHFC_Close       float64
#  1262  CHFC_High        float64
#  1263  CHFC_Low         float64
#  1264  CHFC_Open        float64
#  1265  CHFC_Volume      float64
#  1266  CHK_Adj Close    float64
#  1267  CHK_Close        float64
#  1268  CHK_High         float64
#  1269  CHK_Low          float64
#  1270  CHK_Open         float64
#  1271  CHK_Volume       float64
#  1272  CHSP_Adj Close   float64
#  1273  CHSP_Close       float64
#  1274  CHSP_High        float64
#  1275  CHSP_Low         float64
#  1276  CHSP_Open        float64
#  1277  CHSP_Volume      float64
#  1278  CHS_Adj Close    float64
#  1279  CHS_Close        float64
#  1280  CHS_High         float64
#  1281  CHS_Low          float64
#  1282  CHS_Open         float64
#  1283  CHS_Volume       float64
#  1284  CHTR_Adj Close   float64
#  1285  CHTR_Close       float64
#  1286  CHTR_High        float64
#  1287  CHTR_Low         float64
#  1288  CHTR_Open        float64
#  1289  CHTR_Volume      int64
#  1290  CHUY_Adj Close   float64
#  1291  CHUY_Close       float64
#  1292  CHUY_High        float64
#  1293  CHUY_Low         float64
#  1294  CHUY_Open        float64
#  1295  CHUY_Volume      int64
#  1296  CIEN_Adj Close   float64
#  1297  CIEN_Close       float64
#  1298  CIEN_High        float64
#  1299  CIEN_Low         float64
#  1300  CIEN_Open        float64
#  1301  CIEN_Volume      int64
#  1302  CINF_Adj Close   float64
#  1303  CINF_Close       float64
#  1304  CINF_High        float64
#  1305  CINF_Low         float64
#  1306  CINF_Open        float64
#  1307  CINF_Volume      int64
#  1308  CIR_Adj Close    float64
#  1309  CIR_Close        float64
#  1310  CIR_High         float64
#  1311  CIR_Low          float64
#  1312  CIR_Open         float64
#  1313  CIR_Volume       float64
#  1314  CI_Adj Close     float64
#  1315  CI_Close         float64
#  1316  CI_High          float64
#  1317  CI_Low           float64
#  1318  CI_Open          float64
#  1319  CI_Volume        int64
#  1320  CLB_Adj Close    float64
#  1321  CLB_Close        float64
#  1322  CLB_High         float64
#  1323  CLB_Low          float64
#  1324  CLB_Open         float64
#  1325  CLB_Volume       int64
#  1326  CLDT_Adj Close   float64
#  1327  CLDT_Close       float64
#  1328  CLDT_High        float64
#  1329  CLDT_Low         float64
#  1330  CLDT_Open        float64
#  1331  CLDT_Volume      int64
#  1332  CLD_Adj Close    float64
#  1333  CLD_Close        float64
#  1334  CLD_High         float64
#  1335  CLD_Low          float64
#  1336  CLD_Open         float64
#  1337  CLD_Volume       float64
#  1338  CLGX_Adj Close   float64
#  1339  CLGX_Close       float64
#  1340  CLGX_High        float64
#  1341  CLGX_Low         float64
#  1342  CLGX_Open        float64
#  1343  CLGX_Volume      float64
#  1344  CLH_Adj Close    float64
#  1345  CLH_Close        float64
#  1346  CLH_High         float64
#  1347  CLH_Low          float64
#  1348  CLH_Open         float64
#  1349  CLH_Volume       int64
#  1350  CLI_Adj Close    float64
#  1351  CLI_Close        float64
#  1352  CLI_High         float64
#  1353  CLI_Low          float64
#  1354  CLI_Open         float64
#  1355  CLI_Volume       float64
#  1356  CLW_Adj Close    float64
#  1357  CLW_Close        float64
#  1358  CLW_High         float64
#  1359  CLW_Low          float64
#  1360  CLW_Open         float64
#  1361  CLW_Volume       int64
#  1362  CLX_Adj Close    float64
#  1363  CLX_Close        float64
#  1364  CLX_High         float64
#  1365  CLX_Low          float64
#  1366  CLX_Open         float64
#  1367  CLX_Volume       int64
#  1368  CL_Adj Close     float64
#  1369  CL_Close         float64
#  1370  CL_High          float64
#  1371  CL_Low           float64
#  1372  CL_Open          float64
#  1373  CL_Volume        int64
#  1374  CMA_Adj Close    float64
#  1375  CMA_Close        float64
#  1376  CMA_High         float64
#  1377  CMA_Low          float64
#  1378  CMA_Open         float64
#  1379  CMA_Volume       int64
#  1380  CMCSA_Adj Close  float64
#  1381  CMCSA_Close      float64
#  1382  CMCSA_High       float64
#  1383  CMCSA_Low        float64
#  1384  CMCSA_Open       float64
#  1385  CMCSA_Volume     int64
#  1386  CMC_Adj Close    float64
#  1387  CMC_Close        float64
#  1388  CMC_High         float64
#  1389  CMC_Low          float64
#  1390  CMC_Open         float64
#  1391  CMC_Volume       int64
#  1392  CME_Adj Close    float64
#  1393  CME_Close        float64
#  1394  CME_High         float64
#  1395  CME_Low          float64
#  1396  CME_Open         float64
#  1397  CME_Volume       int64
#  1398  CMG_Adj Close    float64
#  1399  CMG_Close        float64
#  1400  CMG_High         float64
#  1401  CMG_Low          float64
#  1402  CMG_Open         float64
#  1403  CMG_Volume       int64
#  1404  CMI_Adj Close    float64
#  1405  CMI_Close        float64
#  1406  CMI_High         float64
#  1407  CMI_Low          float64
#  1408  CMI_Open         float64
#  1409  CMI_Volume       int64
#  1410  CMO_Adj Close    float64
#  1411  CMO_Close        float64
#  1412  CMO_High         float64
#  1413  CMO_Low          float64
#  1414  CMO_Open         float64
#  1415  CMO_Volume       float64
#  1416  CMP_Adj Close    float64
#  1417  CMP_Close        float64
#  1418  CMP_High         float64
#  1419  CMP_Low          float64
#  1420  CMP_Open         float64
# ...
#  6780  VIAB_Adj Close   float64
#  6781  VIAB_Close       float64
#  6782  VIAB_High        float64
#  6783  VIAB_Low         float64
#  6784  VIAB_Open        float64
#  6785  VIAB_Volume      float64
#  6786  VIAV_Adj Close   float64
#  6787  VIAV_Close       float64
#  6788  VIAV_High        float64
#  6789  VIAV_Low         float64
#  6790  VIAV_Open        float64
#  6791  VIAV_Volume      int64
#  6792  VICR_Adj Close   float64
#  6793  VICR_Close       float64
#  6794  VICR_High        float64
#  6795  VICR_Low         float64
#  6796  VICR_Open        float64
#  6797  VICR_Volume      int64
#  6798  VLO_Adj Close    float64
#  6799  VLO_Close        float64
#  6800  VLO_High         float64
#  6801  VLO_Low          float64
#  6802  VLO_Open         float64
#  6803  VLO_Volume       int64
#  6804  VLY_Adj Close    float64
#  6805  VLY_Close        float64
#  6806  VLY_High         float64
#  6807  VLY_Low          float64
#  6808  VLY_Open         float64
#  6809  VLY_Volume       int64
#  6810  VMC_Adj Close    float64
#  6811  VMC_Close        float64
#  6812  VMC_High         float64
#  6813  VMC_Low          float64
#  6814  VMC_Open         float64
#  6815  VMC_Volume       int64
#  6816  VMI_Adj Close    float64
#  6817  VMI_Close        float64
#  6818  VMI_High         float64
#  6819  VMI_Low          float64
#  6820  VMI_Open         float64
#  6821  VMI_Volume       int64
#  6822  VRA_Adj Close    float64
#  6823  VRA_Close        float64
#  6824  VRA_High         float64
#  6825  VRA_Low          float64
#  6826  VRA_Open         float64
#  6827  VRA_Volume       int64
#  6828  VRSK_Adj Close   float64
#  6829  VRSK_Close       float64
#  6830  VRSK_High        float64
#  6831  VRSK_Low         float64
#  6832  VRSK_Open        float64
#  6833  VRSK_Volume      int64
#  6834  VRSN_Adj Close   float64
#  6835  VRSN_Close       float64
#  6836  VRSN_High        float64
#  6837  VRSN_Low         float64
#  6838  VRSN_Open        float64
#  6839  VRSN_Volume      int64
#  6840  VRTS_Adj Close   float64
#  6841  VRTS_Close       float64
#  6842  VRTS_High        float64
#  6843  VRTS_Low         float64
#  6844  VRTS_Open        float64
#  6845  VRTS_Volume      int64
#  6846  VRTU_Adj Close   float64
#  6847  VRTU_Close       float64
#  6848  VRTU_High        float64
#  6849  VRTU_Low         float64
#  6850  VRTU_Open        float64
#  6851  VRTU_Volume      float64
#  6852  VRTV_Adj Close   float64
#  6853  VRTV_Close       float64
#  6854  VRTV_High        float64
#  6855  VRTV_Low         float64
#  6856  VRTV_Open        float64
#  6857  VRTV_Volume      float64
#  6858  VRTX_Adj Close   float64
#  6859  VRTX_Close       float64
#  6860  VRTX_High        float64
#  6861  VRTX_Low         float64
#  6862  VRTX_Open        float64
#  6863  VRTX_Volume      int64
#  6864  VSAT_Adj Close   float64
#  6865  VSAT_Close       float64
#  6866  VSAT_High        float64
#  6867  VSAT_Low         float64
#  6868  VSAT_Open        float64
#  6869  VSAT_Volume      int64
#  6870  VSH_Adj Close    float64
#  6871  VSH_Close        float64
#  6872  VSH_High         float64
#  6873  VSH_Low          float64
#  6874  VSH_Open         float64
#  6875  VSH_Volume       int64
#  6876  VSI_Adj Close    float64
#  6877  VSI_Close        float64
#  6878  VSI_High         float64
#  6879  VSI_Low          float64
#  6880  VSI_Open         float64
#  6881  VSI_Volume       float64
#  6882  VSTO_Adj Close   float64
#  6883  VSTO_Close       float64
#  6884  VSTO_High        float64
#  6885  VSTO_Low         float64
#  6886  VSTO_Open        float64
#  6887  VSTO_Volume      float64
#  6888  VTR_Adj Close    float64
#  6889  VTR_Close        float64
#  6890  VTR_High         float64
#  6891  VTR_Low          float64
#  6892  VTR_Open         float64
#  6893  VTR_Volume       int64
#  6894  VVC_Adj Close    float64
#  6895  VVC_Close        float64
#  6896  VVC_High         float64
#  6897  VVC_Low          float64
#  6898  VVC_Open         float64
#  6899  VVC_Volume       float64
#  6900  VVI_Adj Close    float64
#  6901  VVI_Close        float64
#  6902  VVI_High         float64
#  6903  VVI_Low          float64
#  6904  VVI_Open         float64
#  6905  VVI_Volume       int64
#  6906  VZ_Adj Close     float64
#  6907  VZ_Close         float64
#  6908  VZ_High          float64
#  6909  VZ_Low           float64
#  6910  VZ_Open          float64
#  6911  VZ_Volume        int64
#  6912  V_Adj Close      float64
#  6913  V_Close          float64
#  6914  V_High           float64
#  6915  V_Low            float64
#  6916  V_Open           float64
#  6917  V_Volume         int64
#  6918  WAB_Adj Close    float64
#  6919  WAB_Close        float64
#  6920  WAB_High         float64
#  6921  WAB_Low          float64
#  6922  WAB_Open         float64
#  6923  WAB_Volume       int64
#  6924  WAGE_Adj Close   float64
#  6925  WAGE_Close       float64
#  6926  WAGE_High        float64
#  6927  WAGE_Low         float64
#  6928  WAGE_Open        float64
#  6929  WAGE_Volume      float64
#  6930  WAT_Adj Close    float64
#  6931  WAT_Close        float64
#  6932  WAT_High         float64
#  6933  WAT_Low          float64
#  6934  WAT_Open         float64
#  6935  WAT_Volume       int64
#  6936  WBA_Adj Close    float64
#  6937  WBA_Close        float64
#  6938  WBA_High         float64
#  6939  WBA_Low          float64
#  6940  WBA_Open         float64
#  6941  WBA_Volume       int64
#  6942  WBS_Adj Close    float64
#  6943  WBS_Close        float64
#  6944  WBS_High         float64
#  6945  WBS_Low          float64
#  6946  WBS_Open         float64
#  6947  WBS_Volume       int64
#  6948  WCG_Adj Close    float64
#  6949  WCG_Close        float64
#  6950  WCG_High         float64
#  6951  WCG_Low          float64
#  6952  WCG_Open         float64
#  6953  WCG_Volume       float64
#  6954  WDC_Adj Close    float64
#  6955  WDC_Close        float64
#  6956  WDC_High         float64
#  6957  WDC_Low          float64
#  6958  WDC_Open         float64
#  6959  WDC_Volume       int64
#  6960  WDR_Adj Close    float64
#  6961  WDR_Close        float64
#  6962  WDR_High         float64
#  6963  WDR_Low          float64
#  6964  WDR_Open         float64
#  6965  WDR_Volume       float64
#  6966  WD_Adj Close     float64
#  6967  WD_Close         float64
#  6968  WD_High          float64
#  6969  WD_Low           float64
#  6970  WD_Open          float64
#  6971  WD_Volume        int64
#  6972  WEC_Adj Close    float64
#  6973  WEC_Close        float64
#  6974  WEC_High         float64
#  6975  WEC_Low          float64
#  6976  WEC_Open         float64
#  6977  WEC_Volume       int64
#  6978  WELL_Adj Close   float64
#  6979  WELL_Close       float64
#  6980  WELL_High        float64
#  6981  WELL_Low         float64
#  6982  WELL_Open        float64
#  6983  WELL_Volume      int64
#  6984  WEN_Adj Close    float64
#  6985  WEN_Close        float64
#  6986  WEN_High         float64
#  6987  WEN_Low          float64
#  6988  WEN_Open         float64
#  6989  WEN_Volume       int64
#  6990  WEX_Adj Close    float64
#  6991  WEX_Close        float64
#  6992  WEX_High         float64
#  6993  WEX_Low          float64
#  6994  WEX_Open         float64
#  6995  WEX_Volume       int64
#  6996  WFC_Adj Close    float64
#  6997  WFC_Close        float64
#  6998  WFC_High         float64
#  6999  WFC_Low          float64
#  7000  WFC_Open         float64
#  7001  WFC_Volume       int64
#  7002  WGL_Adj Close    float64
#  7003  WGL_Close        float64
#  7004  WGL_High         float64
#  7005  WGL_Low          float64
#  7006  WGL_Open         float64
#  7007  WGL_Volume       float64
#  7008  WING_Adj Close   float64
#  7009  WING_Close       float64
#  7010  WING_High        float64
#  7011  WING_Low         float64
#  7012  WING_Open        float64
#  7013  WING_Volume      float64
#  7014  WIRE_Adj Close   float64
#  7015  WIRE_Close       float64
#  7016  WIRE_High        float64
#  7017  WIRE_Low         float64
#  7018  WIRE_Open        float64
#  7019  WIRE_Volume      float64
#  7020  WLH_Adj Close    float64
#  7021  WLH_Close        float64
#  7022  WLH_High         float64
#  7023  WLH_Low          float64
#  7024  WLH_Open         float64
#  7025  WLH_Volume       float64
#  7026  WLTW_Adj Close   float64
#  7027  WLTW_Close       float64
#  7028  WLTW_High        float64
#  7029  WLTW_Low         float64
#  7030  WLTW_Open        float64
#  7031  WLTW_Volume      float64
#  7032  WMB_Adj Close    float64
#  7033  WMB_Close        float64
#  7034  WMB_High         float64
#  7035  WMB_Low          float64
#  7036  WMB_Open         float64
#  7037  WMB_Volume       int64
#  7038  WMT_Adj Close    float64
#  7039  WMT_Close        float64
#  7040  WMT_High         float64
#  7041  WMT_Low          float64
#  7042  WMT_Open         float64
#  7043  WMT_Volume       int64
#  7044  WM_Adj Close     float64
#  7045  WM_Close         float64
#  7046  WM_High          float64
#  7047  WM_Low           float64
#  7048  WM_Open          float64
#  7049  WM_Volume        int64
#  7050  WNC_Adj Close    float64
#  7051  WNC_Close        float64
#  7052  WNC_High         float64
#  7053  WNC_Low          float64
#  7054  WNC_Open         float64
#  7055  WNC_Volume       int64
#  7056  WOR_Adj Close    float64
#  7057  WOR_Close        float64
#  7058  WOR_High         float64
#  7059  WOR_Low          float64
#  7060  WOR_Open         float64
#  7061  WOR_Volume       int64
#  7062  WPG_Adj Close    float64
#  7063  WPG_Close        float64
#  7064  WPG_High         float64
#  7065  WPG_Low          float64
#  7066  WPG_Open         float64
#  7067  WPG_Volume       float64
#  7068  WPX_Adj Close    float64
#  7069  WPX_Close        float64
#  7070  WPX_High         float64
#  7071  WPX_Low          float64
#  7072  WPX_Open         float64
#  7073  WPX_Volume       float64
#  7074  WRB_Adj Close    float64
#  7075  WRB_Close        float64
#  7076  WRB_High         float64
#  7077  WRB_Low          float64
#  7078  WRB_Open         float64
#  7079  WRB_Volume       int64
#  7080  WRI_Adj Close    float64
#  7081  WRI_Close        float64
#  7082  WRI_High         float64
#  7083  WRI_Low          float64
#  7084  WRI_Open         float64
#  7085  WRI_Volume       float64
#  7086  WRK_Adj Close    float64
#  7087  WRK_Close        float64
#  7088  WRK_High         float64
#  7089  WRK_Low          float64
#  7090  WRK_Open         float64
#  7091  WRK_Volume       float64
#  7092  WRLD_Adj Close   float64
#  7093  WRLD_Close       float64
#  7094  WRLD_High        float64
#  7095  WRLD_Low         float64
#  7096  WRLD_Open        float64
#  7097  WRLD_Volume      int64
#  7098  WSM_Adj Close    float64
#  7099  WSM_Close        float64
#  7100  WSM_High         float64
#  7101  WSM_Low          float64
#  7102  WSM_Open         float64
#  7103  WSM_Volume       int64
#  7104  WSO_Adj Close    float64
#  7105  WSO_Close        float64
#  7106  WSO_High         float64
#  7107  WSO_Low          float64
#  7108  WSO_Open         float64
#  7109  WSO_Volume       int64
#  7110  WSR_Adj Close    float64
#  7111  WSR_Close        float64
#  7112  WSR_High         float64
#  7113  WSR_Low          float64
#  7114  WSR_Open         float64
#  7115  WSR_Volume       int64
#  7116  WST_Adj Close    float64
#  7117  WST_Close        float64
#  7118  WST_High         float64
#  7119  WST_Low          float64
#  7120  WST_Open         float64
#  7121  WST_Volume       int64
#  7122  WTFC_Adj Close   float64
#  7123  WTFC_Close       float64
#  7124  WTFC_High        float64
#  7125  WTFC_Low         float64
#  7126  WTFC_Open        float64
#  7127  WTFC_Volume      int64
#  7128  WTR_Adj Close    float64
#  7129  WTR_Close        float64
#  7130  WTR_High         float64
#  7131  WTR_Low          float64
#  7132  WTR_Open         float64
#  7133  WTR_Volume       float64
#  7134  WTS_Adj Close    float64
#  7135  WTS_Close        float64
#  7136  WTS_High         float64
#  7137  WTS_Low          float64
#  7138  WTS_Open         float64
#  7139  WTS_Volume       int64
#  7140  WU_Adj Close     float64
#  7141  WU_Close         float64
#  7142  WU_High          float64
#  7143  WU_Low           float64
#  7144  WU_Open          float64
#  7145  WU_Volume        int64
#  7146  WWD_Adj Close    float64
#  7147  WWD_Close        float64
#  7148  WWD_High         float64
#  7149  WWD_Low          float64
#  7150  WWD_Open         float64
#  7151  WWD_Volume       int64
#  7152  WWE_Adj Close    float64
#  7153  WWE_Close        float64
#  7154  WWE_High         float64
#  7155  WWE_Low          float64
#  7156  WWE_Open         float64
#  7157  WWE_Volume       float64
#  7158  WWW_Adj Close    float64
#  7159  WWW_Close        float64
#  7160  WWW_High         float64
#  7161  WWW_Low          float64
#  7162  WWW_Open         float64
#  7163  WWW_Volume       int64
#  7164  WYND_Adj Close   float64
#  7165  WYND_Close       float64
#  7166  WYND_High        float64
#  7167  WYND_Low         float64
#  7168  WYND_Open        float64
#  7169  WYND_Volume      float64
#  7170  WYNN_Adj Close   float64
#  7171  WYNN_Close       float64
#  7172  WYNN_High        float64
#  7173  WYNN_Low         float64
#  7174  WYNN_Open        float64
#  7175  WYNN_Volume      int64
#  7176  WY_Adj Close     float64
#  7177  WY_Close         float64
#  7178  WY_High          float64
#  7179  WY_Low           float64
#  7180  WY_Open          float64
#  7181  WY_Volume        int64
#  7182  XEL_Adj Close    float64
#  7183  XEL_Close        float64
#  7184  XEL_High         float64
#  7185  XEL_Low          float64
#  7186  XEL_Open         float64
#  7187  XEL_Volume       int64
#  7188  XLNX_Adj Close   float64
#  7189  XLNX_Close       float64
#  7190  XLNX_High        float64
#  7191  XLNX_Low         float64
#  7192  XLNX_Open        float64
#  7193  XLNX_Volume      float64
#  7194  XL_Adj Close     float64
#  7195  XL_Close         float64
#  7196  XL_High          float64
#  7197  XL_Low           float64
#  7198  XL_Open          float64
#  7199  XL_Volume        float64
#  7200  XOM_Adj Close    float64
#  7201  XOM_Close        float64
#  7202  XOM_High         float64
#  7203  XOM_Low          float64
#  7204  XOM_Open         float64
#  7205  XOM_Volume       int64
#  7206  XOXO_Adj Close   float64
#  7207  XOXO_Close       float64
#  7208  XOXO_High        float64
#  7209  XOXO_Low         float64
#  7210  XOXO_Open        float64
#  7211  XOXO_Volume      float64
#  7212  XRAY_Adj Close   float64
#  7213  XRAY_Close       float64
#  7214  XRAY_High        float64
#  7215  XRAY_Low         float64
#  7216  XRAY_Open        float64
#  7217  XRAY_Volume      int64
#  7218  XRX_Adj Close    float64
#  7219  XRX_Close        float64
#  7220  XRX_High         float64
#  7221  XRX_Low          float64
#  7222  XRX_Open         float64
#  7223  XRX_Volume       int64
#  7224  XYL_Adj Close    float64
#  7225  XYL_Close        float64
#  7226  XYL_High         float64
#  7227  XYL_Low          float64
#  7228  XYL_Open         float64
#  7229  XYL_Volume       int64
#  7230  X_Adj Close      float64
#  7231  X_Close          float64
#  7232  X_High           float64
#  7233  X_Low            float64
#  7234  X_Open           float64
#  7235  X_Volume         int64
#  7236  YUM_Adj Close    float64
#  7237  YUM_Close        float64
#  7238  YUM_High         float64
#  7239  YUM_Low          float64
#  7240  YUM_Open         float64
#  7241  YUM_Volume       int64
#  7242  ZBH_Adj Close    float64
#  7243  ZBH_Close        float64
#  7244  ZBH_High         float64
#  7245  ZBH_Low          float64
#  7246  ZBH_Open         float64
#  7247  ZBH_Volume       int64
#  7248  ZBRA_Adj Close   float64
#  7249  ZBRA_Close       float64
#  7250  ZBRA_High        float64
#  7251  ZBRA_Low         float64
#  7252  ZBRA_Open        float64
#  7253  ZBRA_Volume      int64
#  7254  ZEUS_Adj Close   float64
#  7255  ZEUS_Close       float64
#  7256  ZEUS_High        float64
#  7257  ZEUS_Low         float64
#  7258  ZEUS_Open        float64
#  7259  ZEUS_Volume      int64
#  7260  ZION_Adj Close   float64
#  7261  ZION_Close       float64
#  7262  ZION_High        float64
#  7263  ZION_Low         float64
#  7264  ZION_Open        float64
#  7265  ZION_Volume      int64
#  7266  ZTS_Adj Close    float64
#  7267  ZTS_Close        float64
#  7268  ZTS_High         float64
#  7269  ZTS_Low          float64
#  7270  ZTS_Open         float64
#  7271  ZTS_Volume       int64
#  7272  ZUMZ_Adj Close   float64
#  7273  ZUMZ_Close       float64
#  7274  ZUMZ_High        float64
#  7275  ZUMZ_Low         float64
#  7276  ZUMZ_Open        float64
#  7277  ZUMZ_Volume      int64
# dtypes: float64(6365), int64(913)
# memory usage: 55.8 MB

# %%
print(len(MAEC_tickers))
print(len(pd.unique(successful_tickers)))
# Out:
# 1213
# 1213

# %%
MAEC_alpha_data = pd.DataFrame()
bad_tickers = []
tickers = MAEC_filename_data.Ticker.unique().tolist()
for ticker in tqdm(tickers):
    try:
        response = requests.get(alpha_url.format(ticker,API_KEY)).json()
        ticker_df = pd.DataFrame(response['Time Series (Daily)']).T
        ticker_df.columns = [f"{ticker}_{col}" for col in alpha_columns]
        ticker_df.index = pd.to_datetime(ticker_df.index)
        ticker_df = ticker_df.apply(pd.to_numeric, errors='coerce')
        ### save ############################################
        ticker_df.to_csv(alpha_dir.format(ticker), index=True)
        #####################################################
        ticker_df_2017 = ticker_df[(ticker_df.index.year >= 2015) & (ticker_df.index.year <= 2018)]
        ticker_df_2017 = ticker_df_2017.rename(columns={f"{ticker}_Adj Close": ticker})
        ticker_df_2017 = ticker_df_2017[[ticker]].copy()
        if MAEC_alpha_data.empty:
            MAEC_alpha_data = ticker_df_2017
        else:
            MAEC_alpha_data = pd.concat([MAEC_alpha_data, ticker_df_2017], axis=1)
        # this API has a limit per minute
        time.sleep(0.8)
    except KeyboardInterrupt: break
    except Exception as e: 
        bad_tickers.append([ticker, e])

MAEC_alpha_data.info(verbose=True)
### save ############################################
MAEC_alpha_data.to_csv('data/data_prep/MAEC_alpha_data.csv', index=True)
#####################################################
# Out:
# 100%|██████████| 1213/1213 [28:50<00:00,  1.43s/it]
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2015-01-02 to 2018-12-31
# Data columns (total 1155 columns):
#  #     Column  Dtype
# ---    ------  -----
#  0     LMAT    float64
#  1     ACIW    float64
#  2     ADSK    float64
#  3     AMWD    float64
#  4     ANSS    float64
#  5     CRI     float64
#  6     ECPG    float64
#  7     IRDM    float64
#  8     LYV     float64
#  9     ORN     float64
#  10    NWN     float64
#  11    RDC     float64
#  12    SJI     float64
#  13    BID     float64
#  14    MDR     float64
#  15    TG      float64
#  16    AZO     float64
#  17    NX      float64
#  18    AMED    float64
#  19    ANF     float64
#  20    ESL     float64
#  21    FL      float64
#  22    KOPN    float64
#  23    RAVN    float64
#  24    PLCE    float64
#  25    ULTA    float64
#  26    BKE     float64
#  27    RGEN    float64
#  28    DSW     float64
#  29    FDS     float64
#  30    GIII    float64
#  31    PAYX    float64
#  32    REX     float64
#  33    SCHL    float64
#  34    CCL     float64
#  35    MOV     float64
#  36    MU      float64
#  37    PERY    float64
#  38    WFC     float64
#  39    WSO     float64
#  40    CBU     float64
#  41    LII     float64
#  42    LRCX    float64
#  43    RMBS    float64
#  44    SANM    float64
#  45    ABG     float64
#  46    AMGN    float64
#  47    BMI     float64
#  48    CMG     float64
#  49    IBKR    float64
#  50    KMB     float64
#  51    MAN     float64
#  52    NTRS    float64
#  53    OMC     float64
#  54    RF      float64
#  55    SBNY    float64
#  56    STBA    float64
#  57    SYK     float64
#  58    AN      float64
#  59    AZZ     float64
#  60    BA      float64
#  61    CATY    float64
#  62    CLW     float64
#  63    EXPO    float64
#  64    LAD     float64
#  65    MPWR    float64
#  66    PCH     float64
#  67    R       float64
#  68    SEIC    float64
#  69    SNBR    float64
#  70    TMO     float64
#  71    XLNX    float64
#  72    ATGE    float64
#  73    AVT     float64
#  74    CMS     float64
#  75    COL     float64
#  76    DAN     float64
#  77    EFII    float64
#  78    FAF     float64
#  79    GHL     float64
#  80    HAFC    float64
#  81    HSY     float64
#  82    HZO     float64
#  83    JNPR    float64
#  84    LSTR    float64
#  85    MSFT    float64
#  86    MTH     float64
#  87    NTGR    float64
#  88    NUE     float64
#  89    PII     float64
#  90    POOL    float64
#  91    PTEN    float64
#  92    RMD     float64
#  93    SFNC    float64
#  94    SRCL    float64
#  95    TBI     float64
#  96    UAL     float64
#  97    UFI     float64
#  98    PFS     float64
#  99    SPG     float64
#  100   XRX     float64
#  101   OSIS    float64
#  102   ROP     float64
#  103   WRB     float64
#  104   AET     float64
#  105   AKAM    float64
#  106   BGFV    float64
#  107   CIR     float64
#  108   CNC     float64
#  109   CRUS    float64
#  110   EPR     float64
#  111   HELE    float64
#  112   HLIT    float64
#  113   IDXX    float64
#  114   IIVI    float64
#  115   LOGM    float64
#  116   MAS     float64
#  117   MRCY    float64
#  118   MSTR    float64
#  119   NATI    float64
#  120   NOV     float64
#  121   OMI     float64
#  122   WDC     float64
#  123   WWW     float64
#  124   WYND    float64
#  125   ASGN    float64
#  126   BEN     float64
#  127   CFR     float64
#  128   EQIX    float64
#  129   GPRE    float64
#  130   HF      float64
#  131   NOC     float64
#  132   PKE     float64
#  133   PX      float64
#  134   APD     float64
#  135   ARW     float64
#  136   CHSP    float64
#  137   COP     float64
#  138   CRR     float64
#  139   CYTK    float64
#  140   FSS     float64
#  141   GEO     float64
#  142   HST     float64
#  143   INCY    float64
#  144   LLL     float64
#  145   NI      float64
#  146   NTRI    float64
#  147   ODFL    float64
#  148   OIS     float64
#  149   PBI     float64
#  150   RGS     float64
#  151   SKYW    float64
#  152   SWKS    float64
#  153   TFX     float64
#  154   WRLD    float64
#  155   WU      float64
#  156   XOM     float64
#  157   XYL     float64
#  158   AXL     float64
#  159   CBOE    float64
#  160   CTB     float64
#  161   FE      float64
#  162   GWR     float64
#  163   LM      float64
#  164   LPNT    float64
#  165   MCO     float64
#  166   NSP     float64
#  167   PEG     float64
#  168   TDS     float64
#  169   VFC     float64
#  170   CEVA    float64
#  171   CHUY    float64
#  172   CMCSA   float64
#  173   DO      float64
#  174   FN      float64
#  175   L       float64
#  176   NUVA    float64
#  177   TXRH    float64
#  178   ABMD    float64
#  179   ACLS    float64
#  180   CRAY    float64
#  181   CTL     float64
#  182   CVLT    float64
#  183   DIS     float64
#  184   ESE     float64
#  185   HCA     float64
#  186   ICUI    float64
#  187   K       float64
#  188   KLIC    float64
#  189   KMT     float64
#  190   MDC     float64
#  191   MDCO    float64
#  192   MYGN    float64
#  193   SMG     float64
#  194   ANDE    float64
#  195   CLH     float64
#  196   CRZO    float64
#  197   DDD     float64
#  198   LAMR    float64
#  199   MSI     float64
#  200   NSIT    float64
#  201   SNH     float64
#  202   VECO    float64
#  203   VSI     float64
#  204   WD      float64
#  205   ALEX    float64
#  206   BKNG    float64
#  207   CNK     float64
#  208   CNSL    float64
#  209   CUTR    float64
#  210   EBS     float64
#  211   GDOT    float64
#  212   MTD     float64
#  213   NVDA    float64
#  214   ROCK    float64
#  215   SPPI    float64
#  216   TAP     float64
#  217   CROX    float64
#  218   SSP     float64
#  219   TREX    float64
#  220   WELL    float64
#  221   GTY     float64
#  222   RBC     float64
#  223   IFF     float64
#  224   MCK     float64
#  225   JACK    float64
#  226   JWN     float64
#  227   HD      float64
#  228   RRGB    float64
#  229   VSAT    float64
#  230   HPQ     float64
#  231   MNRO    float64
#  232   ROST    float64
#  233   TTC     float64
#  234   CHS     float64
#  235   CBRL    float64
#  236   CRVL    float64
#  237   DAKT    float64
#  238   GES     float64
#  239   MDT     float64
#  240   COO     float64
#  241   LABL    float64
#  242   HRB     float64
#  243   UNFI    float64
#  244   KMX     float64
#  245   SONC    float64
#  246   BBBY    float64
#  247   MON     float64
#  248   BKS     float64
#  249   AYI     float64
#  250   GIS     float64
#  251   STZ     float64
#  252   MSM     float64
#  253   AIR     float64
#  254   FAST    float64
#  255   PNC     float64
#  256   AMD     float64
#  257   ANGO    float64
#  258   GS      float64
#  259   IIIN    float64
#  260   PM      float64
#  261   SHW     float64
#  262   UFPI    float64
#  263   WBS     float64
#  264   GWW     float64
#  265   KSU     float64
#  266   AAPL    float64
#  267   ASTE    float64
#  268   ATI     float64
#  269   MANH    float64
#  270   SNV     float64
#  271   TRV     float64
#  272   VZ      float64
#  273   AXP     float64
#  274   CAKE    float64
#  275   EGHT    float64
#  276   FTNT    float64
#  277   TSCO    float64
#  278   ALK     float64
#  279   AMZN    float64
#  280   AOS     float64
#  281   COF     float64
#  282   CSL     float64
#  283   DGII    float64
#  284   DGX     float64
#  285   DHR     float64
#  286   FIS     float64
#  287   FNB     float64
#  288   MMM     float64
#  289   MSCC    float64
#  290   NDAQ    float64
#  291   ORI     float64
#  292   PHM     float64
#  293   RSG     float64
#  294   TYL     float64
#  295   B       float64
#  296   CPF     float64
#  297   FLIR    float64
#  298   OFG     float64
#  299   RGA     float64
#  300   HAE     float64
#  301   POL     float64
#  302   AGCO    float64
#  303   CTXS    float64
#  304   GILD    float64
#  305   HSII    float64
#  306   OSPN    float64
#  307   PCAR    float64
#  308   VICR    float64
#  309   ALGT    float64
#  310   FCF     float64
#  311   SLAB    float64
#  312   TGI     float64
#  313   ADP     float64
#  314   CRL     float64
#  315   CRS     float64
#  316   FLR     float64
#  317   IART    float64
#  318   IT      float64
#  319   MD      float64
#  320   MDLZ    float64
#  321   PRFT    float64
#  322   SAM     float64
#  323   SWK     float64
#  324   SYNA    float64
#  325   TPX     float64
#  326   VG      float64
#  327   WST     float64
#  328   XRAY    float64
#  329   VRTS    float64
#  330   WY      float64
#  331   MCY     float64
#  332   QNST    float64
#  333   ALE     float64
#  334   CBT     float64
#  335   CHD     float64
#  336   UFCS    float64
#  337   ACXM    float64
#  338   CTSH    float64
#  339   ECHO    float64
#  340   EE      float64
#  341   ITRI    float64
#  342   MED     float64
#  343   PLUS    float64
#  344   WCG     float64
#  345   AGN     float64
#  346   ANDV    float64
#  347   CUB     float64
#  348   PGNX    float64
#  349   STMP    float64
#  350   VIAB    float64
#  351   TTI     float64
#  352   PRAA    float64
#  353   TTWO    float64
#  354   ZBRA    float64
#  355   KSS     float64
#  356   ADI     float64
#  357   LZB     float64
#  358   NTAP    float64
#  359   TGT     float64
#  360   WSM     float64
#  361   GME     float64
#  362   SCVL    float64
#  363   KFY     float64
#  364   BRC     float64
#  365   RHT     float64
#  366   ACN     float64
#  367   PRGS    float64
#  368   CSX     float64
#  369   KEY     float64
#  370   LNN     float64
#  371   PPG     float64
#  372   USB     float64
#  373   WYNN    float64
#  374   DOV     float64
#  375   FITB    float64
#  376   PNR     float64
#  377   RLI     float64
#  378   UTX     float64
#  379   CA      float64
#  380   SVU     float64
#  381   BJRI    float64
#  382   BMS     float64
#  383   CY      float64
#  384   HBAN    float64
#  385   LLY     float64
#  386   MHO     float64
#  387   PRLB    float64
#  388   QSII    float64
#  389   SKX     float64
#  390   SPSC    float64
#  391   SXT     float64
#  392   UMPQ    float64
#  393   UNP     float64
#  394   VRSN    float64
#  395   RCL     float64
#  396   SSD     float64
#  397   STT     float64
#  398   BOH     float64
#  399   ABAX    float64
#  400   FELE    float64
#  401   FISV    float64
#  402   MDSO    float64
#  403   TPR     float64
#  404   ULTI    float64
#  405   AIT     float64
#  406   APC     float64
#  407   CMC     float64
#  408   DHX     float64
#  409   DSPG    float64
#  410   GRMN    float64
#  411   SAH     float64
#  412   VAR     float64
#  413   VLO     float64
#  414   VRTX    float64
#  415   ALXN    float64
#  416   AVY     float64
#  417   BC      float64
#  418   CENX    float64
#  419   COLB    float64
#  420   DIN     float64
#  421   DLR     float64
#  422   EHTH    float64
#  423   GT      float64
#  424   GTLS    float64
#  425   LANC    float64
#  426   LKQ     float64
#  427   MGM     float64
#  428   MOH     float64
#  429   OMCL    float64
#  430   PDFS    float64
#  431   PES     float64
#  432   SCSC    float64
#  433   UVE     float64
#  434   WMB     float64
#  435   AON     float64
#  436   BCO     float64
#  437   BGG     float64
#  438   CL      float64
#  439   EXC     float64
#  440   IDCC    float64
#  441   IRM     float64
#  442   NWL     float64
#  443   SBSI    float64
#  444   STX     float64
#  445   UFS     float64
#  446   EDR     float64
#  447   ETR     float64
#  448   EVR     float64
#  449   DISCA   float64
#  450   OCLR    float64
#  451   SRE     float64
#  452   VMC     float64
#  453   VSH     float64
#  454   AGYS    float64
#  455   AVA     float64
#  456   DVN     float64
#  457   OSUR    float64
#  458   PZZA    float64
#  459   AAWW    float64
#  460   AES     float64
#  461   CLDT    float64
#  462   CNP     float64
#  463   CORT    float64
#  464   HE      float64
#  465   HII     float64
#  466   HRC     float64
#  467   IPCC    float64
#  468   MASI    float64
#  469   OGE     float64
#  470   SSTK    float64
#  471   TRIP    float64
#  472   UEIC    float64
#  473   ZEUS    float64
#  474   LXU     float64
#  475   MHK     float64
#  476   AMG     float64
#  477   APEI    float64
#  478   DISH    float64
#  479   LGND    float64
#  480   SRDX    float64
#  481   LOW     float64
#  482   KIRK    float64
#  483   HIBB    float64
#  484   TSN     float64
#  485   CPB     float64
#  486   DLTR    float64
#  487   TECD    float64
#  488   TIF     float64
#  489   DCI     float64
#  490   DE      float64
#  491   EXPR    float64
#  492   ALOG    float64
#  493   TOL     float64
#  494   VRA     float64
#  495   ADBE    float64
#  496   JBL     float64
#  497   ORCL    float64
#  498   APOG    float64
#  499   RECN    float64
#  500   FINL    float64
#  501   SNX     float64
#  502   INTC    float64
#  503   FHN     float64
#  504   MS      float64
#  505   WWD     float64
#  506   EAT     float64
#  507   KMI     float64
#  508   TEL     float64
#  509   ETFC    float64
#  510   ISRG    float64
#  511   SIVB    float64
#  512   SLM     float64
#  513   ABCB    float64
#  514   STI     float64
#  515   DHI     float64
#  516   AKS     float64
#  517   ISCA    float64
#  518   PG      float64
#  519   TSS     float64
#  520   CNMD    float64
#  521   DFS     float64
#  522   GD      float64
#  523   HOLX    float64
#  524   PYPL    float64
#  525   TXN     float64
#  526   TXT     float64
#  527   VLY     float64
#  528   EA      float64
#  529   FICO    float64
#  530   GNTX    float64
#  531   IVZ     float64
#  532   KEM     float64
#  533   NEE     float64
#  534   CVX     float64
#  535   HON     float64
#  536   MAT     float64
#  537   ONB     float64
#  538   PFE     float64
#  539   RHI     float64
#  540   SXI     float64
#  541   ENR     float64
#  542   ETN     float64
#  543   JLL     float64
#  544   POWL    float64
#  545   LQDT    float64
#  546   PJC     float64
#  547   POWI    float64
#  548   RL      float64
#  549   TDC     float64
#  550   CME     float64
#  551   HAS     float64
#  552   BHE     float64
#  553   CVS     float64
#  554   GLT     float64
#  555   MPAA    float64
#  556   STE     float64
#  557   TDG     float64
#  558   DTE     float64
#  559   INTL    float64
#  560   LPSN    float64
#  561   AAP     float64
#  562   ATVI    float64
#  563   BWA     float64
#  564   FLO     float64
#  565   LPX     float64
#  566   NNN     float64
#  567   NUS     float64
#  568   SON     float64
#  569   TYPE    float64
#  570   WWE     float64
#  571   IPG     float64
#  572   BYD     float64
#  573   EIG     float64
#  574   MANT    float64
#  575   SNPS    float64
#  576   AAN     float64
#  577   LH      float64
#  578   PCG     float64
#  579   PNW     float64
#  580   DRH     float64
#  581   FSLR    float64
#  582   LXP     float64
#  583   M       float64
#  584   SF      float64
#  585   CHK     float64
#  586   CRM     float64
#  587   EV      float64
#  588   FARO    float64
#  589   AWK     float64
#  590   BGS     float64
#  591   DPZ     float64
#  592   EME     float64
#  593   FCN     float64
#  594   GVA     float64
#  595   NPO     float64
#  596   PWR     float64
#  597   TWI     float64
#  598   UTHR    float64
#  599   HMSY    float64
#  600   MGLN    float64
#  601   OFIX    float64
#  602   NKTR    float64
#  603   AEO     float64
#  604   CIEN    float64
#  605   SUP     float64
#  606   DKS     float64
#  607   ABM     float64
#  608   KBH     float64
#  609   OXM     float64
#  610   GBX     float64
#  611   GPN     float64
#  612   HCSG    float64
#  613   JPM     float64
#  614   BAC     float64
#  615   CUBI    float64
#  616   SFBS    float64
#  617   BRO     float64
#  618   GPC     float64
#  619   MBFI    float64
#  620   ABT     float64
#  621   FMBI    float64
#  622   ITW     float64
#  623   KO      float64
#  624   NWE     float64
#  625   PPBI    float64
#  626   BANC    float64
#  627   BPFH    float64
#  628   GM      float64
#  629   HBI     float64
#  630   KALU    float64
#  631   NEM     float64
#  632   PBCT    float64
#  633   PKG     float64
#  634   PLXS    float64
#  635   RJF     float64
#  636   SBUX    float64
#  637   AHL     float64
#  638   FFBC    float64
#  639   HNI     float64
#  640   INDB    float64
#  641   NBHC    float64
#  642   SYF     float64
#  643   TRST    float64
#  644   ETH     float64
#  645   KN      float64
#  646   OPB     float64
#  647   ADC     float64
#  648   BAX     float64
#  649   CMP     float64
#  650   CPLA    float64
#  651   ESRX    float64
#  652   HMST    float64
#  653   MKSI    float64
#  654   NBR     float64
#  655   WAB     float64
#  656   CINF    float64
#  657   GPI     float64
#  658   HIW     float64
#  659   HLT     float64
#  660   IP      float64
#  661   LDOS    float64
#  662   O       float64
#  663   PSA     float64
#  664   SIX     float64
#  665   SLCA    float64
#  666   SXC     float64
#  667   TEX     float64
#  668   TKR     float64
#  669   WEX     float64
#  670   X       float64
#  671   ABBV    float64
#  672   ATNI    float64
#  673   ENVA    float64
#  674   INGR    float64
#  675   INVA    float64
#  676   KS      float64
#  677   MO      float64
#  678   ORLY    float64
#  679   RTN     float64
#  680   SPOK    float64
#  681   ZBH     float64
#  682   ACHC    float64
#  683   AJG     float64
#  684   CHE     float64
#  685   ECOL    float64
#  686   FII     float64
#  687   FLS     float64
#  688   HIG     float64
#  689   LEG     float64
#  690   MATW    float64
#  691   NFG     float64
#  692   NR      float64
#  693   PFG     float64
#  694   VTR     float64
#  695   WRK     float64
#  696   EGOV    float64
#  697   LMNX    float64
#  698   QLYS    float64
#  699   RTEC    float64
#  700   AEIS    float64
#  701   AIN     float64
#  702   ARE     float64
#  703   AROC    float64
#  704   CC      float64
#  705   COTY    float64
#  706   CYH     float64
#  707   DUK     float64
#  708   FMC     float64
#  709   GMED    float64
#  710   HCI     float64
#  711   ILMN    float64
#  712   LNTH    float64
#  713   LTC     float64
#  714   MNTA    float64
#  715   OGS     float64
#  716   OLN     float64
#  717   TCO     float64
#  718   ARRS    float64
#  719   CSGS    float64
#  720   CTLT    float64
#  721   D       float64
#  722   FTK     float64
#  723   ICE     float64
#  724   INN     float64
#  725   IOSP    float64
#  726   JKHY    float64
#  727   LITE    float64
#  728   MATX    float64
#  729   MDU     float64
#  730   MPW     float64
#  731   MTDR    float64
#  732   REG     float64
#  733   STRA    float64
#  734   SUPN    float64
#  735   VRSK    float64
#  736   WTR     float64
#  737   XOXO    float64
#  738   ZTS     float64
#  739   AWR     float64
#  740   BDX     float64
#  741   BEL     float64
#  742   CB      float64
#  743   CONE    float64
#  744   CTRL    float64
#  745   CUZ     float64
#  746   CXO     float64
#  747   EGL     float64
#  748   ES      float64
#  749   GPOR    float64
#  750   LFUS    float64
#  751   LHCG    float64
#  752   LNC     float64
#  753   MHLD    float64
#  754   MMS     float64
#  755   MRO     float64
#  756   MTRX    float64
#  757   NRG     float64
#  758   OA      float64
#  759   OHI     float64
#  760   OXY     float64
#  761   PRI     float64
#  762   RIG     float64
#  763   SBH     float64
#  764   SFM     float64
#  765   SPXC    float64
#  766   THG     float64
#  767   UNT     float64
#  768   WAGE    float64
#  769   WGL     float64
#  770   WING    float64
#  771   WPX     float64
#  772   EOG     float64
#  773   NAVG    float64
#  774   PGR     float64
#  775   POST    float64
#  776   PRSC    float64
#  777   SEM     float64
#  778   TPRE    float64
#  779   AMPH    float64
#  780   DEA     float64
#  781   DPLO    float64
#  782   EGRX    float64
#  783   ENTA    float64
#  784   FCPT    float64
#  785   MXL     float64
#  786   SEDG    float64
#  787   ACM     float64
#  788   CORE    float64
#  789   CVG     float64
#  790   EZPW    float64
#  791   IVR     float64
#  792   LGIH    float64
#  793   NCLH    float64
#  794   NSA     float64
#  795   PAHC    float64
#  796   VRTV    float64
#  797   AEE     float64
#  798   ALB     float64
#  799   BLD     float64
#  800   IPAR    float64
#  801   KELYA   float64
#  802   MCF     float64
#  803   MTSC    float64
#  804   CTRE    float64
#  805   A       float64
#  806   TJX     float64
#  807   PLAB    float64
#  808   EXP     float64
#  809   KEYS    float64
#  810   WMT     float64
#  811   BBY     float64
#  812   HPE     float64
#  813   DY      float64
#  814   CAL     float64
#  815   COST    float64
#  816   CPRT    float64
#  817   DECK    float64
#  818   PDCO    float64
#  819   PVH     float64
#  820   SAFM    float64
#  821   SPTN    float64
#  822   OLLI    float64
#  823   AVGO    float64
#  824   FIVE    float64
#  825   ZUMZ    float64
#  826   CASY    float64
#  827   HQY     float64
#  828   MIK     float64
#  829   PLAY    float64
#  830   VMI     float64
#  831   FWRD    float64
#  832   SLB     float64
#  833   AVB     float64
#  834   AXE     float64
#  835   CAT     float64
#  836   CLGX    float64
#  837   HSTM    float64
#  838   MDXG    float64
#  839   ZION    float64
#  840   BANR    float64
#  841   BXP     float64
#  842   PSB     float64
#  843   RNR     float64
#  844   AEP     float64
#  845   AMT     float64
#  846   ANIK    float64
#  847   BCC     float64
#  848   CATM    float64
#  849   CCMP    float64
#  850   CELG    float64
#  851   CMO     float64
#  852   CWT     float64
#  853   DBD     float64
#  854   DRE     float64
#  855   EXPE    float64
#  856   EXR     float64
#  857   GOV     float64
#  858   HOG     float64
#  859   IDA     float64
#  860   ITGR    float64
#  861   KRA     float64
#  862   MA      float64
#  863   MAR     float64
#  864   MMC     float64
#  865   NEU     float64
#  866   SBAC    float64
#  867   SPGI    float64
#  868   THRM    float64
#  869   TILE    float64
#  870   UNM     float64
#  871   AMSF    float64
#  872   ATR     float64
#  873   CBL     float64
#  874   CI      float64
#  875   CTS     float64
#  876   FR      float64
#  877   JCI     float64
#  878   KBR     float64
#  879   KRG     float64
#  880   LYB     float64
#  881   PBF     float64
#  882   PSX     float64
#  883   RUTH    float64
#  884   WRI     float64
#  885   ADM     float64
#  886   AEGN    float64
#  887   AHH     float64
#  888   CENTA   float64
#  889   CMI     float64
#  890   HVT     float64
#  891   NJR     float64
#  892   RYAM    float64
#  893   SABR    float64
#  894   SHOO    float64
#  895   ARR     float64
#  896   DEI     float64
#  897   DNOW    float64
#  898   FLOW    float64
#  899   LIVN    float64
#  900   NBL     float64
#  901   SM      float64
#  902   AAOI    float64
#  903   AEL     float64
#  904   AME     float64
#  905   ATO     float64
#  906   BGC     float64
#  907   CABO    float64
#  908   CCRN    float64
#  909   CDR     float64
#  910   CF      float64
#  911   HI      float64
#  912   HR      float64
#  913   HSIC    float64
#  914   INGN    float64
#  915   ITT     float64
#  916   KOP     float64
#  917   LOCO    float64
#  918   MDRX    float64
#  919   MET     float64
#  920   MNST    float64
#  921   MUSA    float64
#  922   NGVT    float64
#  923   NP      float64
#  924   PBH     float64
#  925   PRU     float64
#  926   TDY     float64
#  927   BRS     float64
#  928   KND     float64
#  929   MTX     float64
#  930   RMAX    float64
#  931   WTS     float64
#  932   CPE     float64
#  933   DIOD    float64
#  934   MYL     float64
#  935   VRTU    float64
#  936   CVCO    float64
#  937   WEN     float64
#  938   RGLD    float64
#  939   VIAV    float64
#  940   VSTO    float64
#  941   CHCT    float64
#  942   SYY     float64
#  943   CREE    float64
#  944   CSCO    float64
#  945   CACI    float64
#  946   HRL     float64
#  947   LB      float64
#  948   KLXI    float64
#  949   GEF     float64
#  950   BNED    float64
#  951   SAIC    float64
#  952   KR      float64
#  953   NEOG    float64
#  954   NKE     float64
#  955   WOR     float64
#  956   DAL     float64
#  957   VAC     float64
#  958   IEX     float64
#  959   JNJ     float64
#  960   WTFC    float64
#  961   APH     float64
#  962   EBAY    float64
#  963   FULT    float64
#  964   HOPE    float64
#  965   HWC     float64
#  966   ASB     float64
#  967   CLB     float64
#  968   HLX     float64
#  969   KLAC    float64
#  970   STC     float64
#  971   STLD    float64
#  972   WBA     float64
#  973   GBCI    float64
#  974   GE      float64
#  975   CDNS    float64
#  976   ACC     float64
#  977   HUBB    float64
#  978   JBLU    float64
#  979   MINI    float64
#  980   NCI     float64
#  981   WAT     float64
#  982   WDR     float64
#  983   WNC     float64
#  984   AKR     float64
#  985   EQR     float64
#  986   FSP     float64
#  987   HT      float64
#  988   HUBG    float64
#  989   IR      float64
#  990   IRBT    float64
#  991   LUV     float64
#  992   MMSI    float64
#  993   PTC     float64
#  994   RRC     float64
#  995   SFLY    float64
#  996   SLGN    float64
#  997   UCBI    float64
#  998   UDR     float64
#  999   WEC     float64
#  1000  WM      float64
#  1001  ALLE    float64
#  1002  KWR     float64
#  1003  NTCT    float64
#  1004  QEP     float64
#  1005  TER     float64
#  1006  TRN     float64
#  1007  XEL     float64
#  1008  THS     float64
#  1009  CMA     float64
#  1010  C       float64
#  1011  GLW     float64
#  1012  LMT     float64
#  1013  HES     float64
#  1014  ALGN    float64
#  1015  AFG     float64
#  1016  EQT     float64
#  1017  MAA     float64
#  1018  PH      float64
#  1019  V       float64
#  1020  AIV     float64
#  1021  CBM     float64
#  1022  CLX     float64
#  1023  KIM     float64
#  1024  CAH     float64
#  1025  COHR    float64
#  1026  MNK     float64
#  1027  COR     float64
#  1028  DNKN    float64
#  1029  EFX     float64
#  1030  ENS     float64
#  1031  ENSG    float64
#  1032  NWSA    float64
#  1033  RYN     float64
#  1034  SEE     float64
#  1035  YUM     float64
#  1036  EGN     float64
#  1037  LECO    float64
#  1038  MLM     float64
#  1039  KHC     float64
#  1040  NMIH    float64
#  1041  PEP     float64
#  1042  CHTR    float64
#  1043  DVA     float64
#  1044  RS      float64
#  1045  ECL     float64
#  1046  NDSN    float64
#  1047  ROG     float64
#  1048  AMCX    float64
#  1049  BIO     float64
#  1050  CECO    float64
#  1051  INTU    float64
#  1052  PRA     float64
#  1053  RGR     float64
#  1054  ROIC    float64
#  1055  TNC     float64
#  1056  TREE    float64
#  1057  SWN     float64
#  1058  PRGO    float64
#  1059  TGNA    float64
#  1060  RRD     float64
#  1061  KAMN    float64
#  1062  SHAK    float64
#  1063  SWX     float64
#  1064  UHS     float64
#  1065  BOBE    float64
#  1066  CMTL    float64
#  1067  PAY     float64
#  1068  SIG     float64
#  1069  TTEC    float64
#  1070  LEN     float64
#  1071  CTAS    float64
#  1072  CAG     float64
#  1073  QHC     float64
#  1074  HOMB    float64
#  1075  FCX     float64
#  1076  MKTX    float64
#  1077  NSC     float64
#  1078  ROK     float64
#  1079  PATK    float64
#  1080  CGNX    float64
#  1081  GGP     float64
#  1082  MRK     float64
#  1083  ARI     float64
#  1084  EL      float64
#  1085  HUM     float64
#  1086  SMP     float64
#  1087  AAON    float64
#  1088  ANIP    float64
#  1089  DNR     float64
#  1090  GFF     float64
#  1091  MSCI    float64
#  1092  MUR     float64
#  1093  PPL     float64
#  1094  REGN    float64
#  1095  GEOS    float64
#  1096  HCN     float64
#  1097  PDCE    float64
#  1098  WLH     float64
#  1099  TISI    float64
#  1100  PLD     float64
#  1101  CCI     float64
#  1102  GATX    float64
#  1103  SNA     float64
#  1104  HAL     float64
#  1105  LPT     float64
#  1106  EGP     float64
#  1107  PB      float64
#  1108  TRMK    float64
#  1109  BMY     float64
#  1110  CW      float64
#  1111  KEX     float64
#  1112  KRC     float64
#  1113  NLSN    float64
#  1114  HSKA    float64
#  1115  HRS     float64
#  1116  SCG     float64
#  1117  UNH     float64
#  1118  MCD     float64
#  1119  XL      float64
#  1120  MOS     float64
#  1121  APA     float64
#  1122  TIVO    float64
#  1123  ACET    float64
#  1124  BELFB   float64
#  1125  CBG     float64
#  1126  FRGI    float64
#  1127  BCPC    float64
#  1128  DRI     float64
#  1129  PETS    float64
#  1130  ASH     float64
#  1131  CASH    float64
#  1132  VVC     float64
#  1133  WIRE    float64
#  1134  LNT     float64
#  1135  EXTN    float64
#  1136  ALG     float64
#  1137  PARR    float64
#  1138  OI      float64
#  1139  IRT     float64
#  1140  ROL     float64
#  1141  UMBF    float64
#  1142  DLX     float64
#  1143  GWB     float64
#  1144  VVI     float64
#  1145  SAIA    float64
#  1146  UAA     float64
#  1147  ITG     float64
#  1148  SKT     float64
#  1149  ASIX    float64
#  1150  BKH     float64
#  1151  MYE     float64
#  1152  WSR     float64
#  1153  ODP     float64
#  1154  GCO     float64
# dtypes: float64(1155)
# memory usage: 8.9 MB

# %%
errors = [str(pair[1]) for pair in bad_tickers]
bad_tickers = [pair[0] for pair in bad_tickers]
print(len(bad_tickers))
print(np.unique(errors))
# Out:
# 58
# ["'Time Series (Daily)'" 'Expecting value: line 1 column 1 (char 0)']

# %%
print(bad_tickers)
# Out:
# ['GPS', 'JCP', 'TUP', 'BBT', 'MDP', 'LL', 'ABC', 'PKI', 'HFC', 'HSC', 'CBB', 'ILG', 'JCOM', 'EBIX', 'ENDP', 'BIG', 'ASNA', 'IVC', 'BCOR', 'INT', 'FRED', 'CAMP', 'ELY', 'COG', 'CLD', 'CRY', 'PLT', 'FRAN', 'ADS', 'CPSI', 'FBHS', 'CHFC', 'UIHC', 'OFC', 'TMST', 'FTD', 'SWM', 'WPG', 'WLTW', 'AKRX', 'BLL', 'DF', 'TLRD', 'SPN', 'CLI', 'ESV', 'RCII', 'ANTM', 'RE', 'NCR', 'NEWM', 'PEI', 'LCI', 'ERA', 'ACOR', 'FB', 'AAXN', 'NLS']
