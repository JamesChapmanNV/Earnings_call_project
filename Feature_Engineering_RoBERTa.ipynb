# %% [markdown]
# # Earnings Call Project: RoBERTa
# <br>
# CIS 831 Deep Learning – Term Project<br>
# Kansas State University
# <br><br>
# James Chapman<br>
# John Woods<br>
# Nathan Diehl<br>
# <br>

# %% [markdown]
# This notebook featurizes the text and audio data from the earnings calls. Each earnings calls data comes pre-processed such that each sentence of the call corresponds to 1 line-of-text and 1 MP3 audio file. The transcript text is processed with the Glove–300 pre-trained word embedding, and the audio files are processed with Praat using parselmouth.
# - Text (Glove–300) [Glove Download](https://nlp.stanford.edu/projects/glove/)
# - Audio (Praat) [Parselmouth](https://parselmouth.readthedocs.io/en/stable/)
#
# The data from this notebook is stored in the "data/data_prep" directory as the following CSVs.
# - glove_features
# - MAEC_glove_features
# - praat_features
# - MAEC_praat_features

# %%
import sys
IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    # !pip install transformers
    from google.colab import drive
    drive.mount('/content/gdrive')
    # %cd gdrive/My Drive/831

# %%
import pandas as pd
import numpy as np
import time
import json
import csv
import re
import os
from datetime import datetime
from tqdm import tqdm
from transformers import RobertaModel, RobertaTokenizer
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
MAEC_dir = 'data/MAEC/MAEC_Dataset' # https://github.com/Earnings-Call-Dataset/MAEC-A-Multimodal-Aligned-Earnings-Conference-Call-Dataset-for-Financial-Risk-Prediction

############# too big for GitHub ########################
############# stored on local disk ######################
original_data_dir = r"D:\original_dataset" # https://github.com/GeminiLn/EarningsCall_Dataset 
MAEC_audio_dir = r"D:\MAEC_audio" 
# there is a link for the audio data in the MAEC GitHub, but it does not work
# I emailed the authors, and they send another link.
# There is like a half-million files, but only 19 GB
# https://drive.google.com/file/d/1m1GRCHgKn9Vz9IFMC_SpCog6uP3-gFgY/view?usp=drive_link

# %%
# Loop through the directory, each folder represents an earnings conference call; the folders are named as "CompanyName_Date".
filename_data = []
for filename in os.listdir(original_data_dir):
    company_name, date_str = filename.rsplit('_', 1)
    date_str = date_str.split('.')[0] 
    date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    filename_data.append([company_name, date])
filename_data = pd.DataFrame(filename_data, columns=["Company", "Date"])
company_ticker = pd.read_csv('data/data_prep/company_ticker.csv')
filename_data = filename_data.merge(company_ticker, on="Company", how="left")

# Loop through the directory, each folder represents an earnings conference call; the folders are named as "Date_CompanyName".
MAEC_filename_data = []
for filename in os.listdir(MAEC_dir):
    date_str, ticker = filename.rsplit('_', 1)
    date_str = date_str.split('.')[0] 
    date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    MAEC_filename_data.append([ticker, date])
MAEC_filename_data = pd.DataFrame(MAEC_filename_data, columns=["Ticker", "Date"])

# %% [markdown]
# # RoBERTa features from meeting transcript text files
#
# RoBERTa documentation can be found at https://huggingface.co/FacebookAI/roberta-large
#
# ### Following code is adapted FROM
# [GitHub HTML Encoder](https://github.com/YangLinyi/HTML-Hierarchical-Transformer-based-Multi-task-Learning-for-Volatility-Prediction/blob/master/Model/Token-Level%20Encoder/HuggingFace-Roberta-Token-Encoder.py)

# %%
# This is adapted from
# https://github.com/YangLinyi/HTML-Hierarchical-Transformer-based-Multi-task-Learning-for-Volatility-Prediction/blob/master/Model/Token-Level%20Encoder/HuggingFace-Roberta-Token-Encoder.py
model = RobertaModel.from_pretrained('roberta-large').to(device)
tokenizer = RobertaTokenizer.from_pretrained('roberta-large')

def get_RoBERTa(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)
    with torch.no_grad():
        outputs = model(**inputs)
        # [CLS] embedding for sentence-level representation
        cls_embedding = outputs.last_hidden_state[:, 0, :].cpu().numpy()
    #print(cls_embedding.shape)
    # 1024 features 
    return cls_embedding
####################################################
####################################################
# # How to implement average pooling instead of CLS
#         # average pooling over token embeddings
#         token_embeddings = outputs.last_hidden_state
#         sentence_embedding = torch.mean(token_embeddings, dim=1).cpu().numpy()  
#     return sentence_embedding
# Out:
# C:\Users\James\anaconda3\lib\site-packages\huggingface_hub\file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
RoBERTa_features = pd.DataFrame()
RoBERTa_error = []
for Company, Date in tqdm(filename_data[['Company', 'Date']].values):
    Date = Date.replace('-', '')
    text_path = f"D:/original_dataset/{Company}_{Date}/TextSequence.txt"
    try:
        with open(text_path, 'r', encoding='utf-8', errors='replace') as file:
            for i, line in enumerate(file, start=1):
                sentence_embedding = get_RoBERTa(line.strip())
                # 1024 features 
                features_df = pd.DataFrame(sentence_embedding, columns=[f'RoBERTa_{j}' for j in range(1024)])
                features_df['Company'] = Company
                features_df['Date'] = Date
                features_df['Sentence_num'] = i
                RoBERTa_features = pd.concat([RoBERTa_features, features_df], ignore_index=True)
    except KeyboardInterrupt: break
    except Exception as e:
        RoBERTa_error.append((Company, Date, str(e)))

print(len(RoBERTa_error))
print(RoBERTa_error)
# Out:
# 100%|██████████| 572/572 [1:38:39<00:00, 10.35s/it]
# 0
# []

# %%
RoBERTa_features.info(verbose=True)
###############################################
RoBERTa_features.to_csv('data/data_prep/RoBERTa_features.csv', index=False)
###############################################
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89722 entries, 0 to 89721
# Data columns (total 1027 columns):
#  #     Column        Dtype
# ---    ------        -----
#  0     RoBERTa_0     float32
#  1     RoBERTa_1     float32
#  2     RoBERTa_2     float32
#  3     RoBERTa_3     float32
#  4     RoBERTa_4     float32
#  5     RoBERTa_5     float32
#  6     RoBERTa_6     float32
#  7     RoBERTa_7     float32
#  8     RoBERTa_8     float32
#  9     RoBERTa_9     float32
#  10    RoBERTa_10    float32
#  11    RoBERTa_11    float32
#  12    RoBERTa_12    float32
#  13    RoBERTa_13    float32
#  14    RoBERTa_14    float32
#  15    RoBERTa_15    float32
#  16    RoBERTa_16    float32
#  17    RoBERTa_17    float32
#  18    RoBERTa_18    float32
#  19    RoBERTa_19    float32
#  20    RoBERTa_20    float32
#  21    RoBERTa_21    float32
#  22    RoBERTa_22    float32
#  23    RoBERTa_23    float32
#  24    RoBERTa_24    float32
#  25    RoBERTa_25    float32
#  26    RoBERTa_26    float32
#  27    RoBERTa_27    float32
#  28    RoBERTa_28    float32
#  29    RoBERTa_29    float32
#  30    RoBERTa_30    float32
#  31    RoBERTa_31    float32
#  32    RoBERTa_32    float32
#  33    RoBERTa_33    float32
#  34    RoBERTa_34    float32
#  35    RoBERTa_35    float32
#  36    RoBERTa_36    float32
#  37    RoBERTa_37    float32
#  38    RoBERTa_38    float32
#  39    RoBERTa_39    float32
#  40    RoBERTa_40    float32
#  41    RoBERTa_41    float32
#  42    RoBERTa_42    float32
#  43    RoBERTa_43    float32
#  44    RoBERTa_44    float32
#  45    RoBERTa_45    float32
#  46    RoBERTa_46    float32
#  47    RoBERTa_47    float32
#  48    RoBERTa_48    float32
#  49    RoBERTa_49    float32
#  50    RoBERTa_50    float32
#  51    RoBERTa_51    float32
#  52    RoBERTa_52    float32
#  53    RoBERTa_53    float32
#  54    RoBERTa_54    float32
#  55    RoBERTa_55    float32
#  56    RoBERTa_56    float32
#  57    RoBERTa_57    float32
#  58    RoBERTa_58    float32
#  59    RoBERTa_59    float32
#  60    RoBERTa_60    float32
#  61    RoBERTa_61    float32
#  62    RoBERTa_62    float32
#  63    RoBERTa_63    float32
#  64    RoBERTa_64    float32
#  65    RoBERTa_65    float32
#  66    RoBERTa_66    float32
#  67    RoBERTa_67    float32
#  68    RoBERTa_68    float32
#  69    RoBERTa_69    float32
#  70    RoBERTa_70    float32
#  71    RoBERTa_71    float32
#  72    RoBERTa_72    float32
#  73    RoBERTa_73    float32
#  74    RoBERTa_74    float32
#  75    RoBERTa_75    float32
#  76    RoBERTa_76    float32
#  77    RoBERTa_77    float32
#  78    RoBERTa_78    float32
#  79    RoBERTa_79    float32
#  80    RoBERTa_80    float32
#  81    RoBERTa_81    float32
#  82    RoBERTa_82    float32
#  83    RoBERTa_83    float32
#  84    RoBERTa_84    float32
#  85    RoBERTa_85    float32
#  86    RoBERTa_86    float32
#  87    RoBERTa_87    float32
#  88    RoBERTa_88    float32
#  89    RoBERTa_89    float32
#  90    RoBERTa_90    float32
#  91    RoBERTa_91    float32
#  92    RoBERTa_92    float32
#  93    RoBERTa_93    float32
#  94    RoBERTa_94    float32
#  95    RoBERTa_95    float32
#  96    RoBERTa_96    float32
#  97    RoBERTa_97    float32
#  98    RoBERTa_98    float32
#  99    RoBERTa_99    float32
#  100   RoBERTa_100   float32
#  101   RoBERTa_101   float32
#  102   RoBERTa_102   float32
#  103   RoBERTa_103   float32
#  104   RoBERTa_104   float32
#  105   RoBERTa_105   float32
#  106   RoBERTa_106   float32
#  107   RoBERTa_107   float32
#  108   RoBERTa_108   float32
#  109   RoBERTa_109   float32
#  110   RoBERTa_110   float32
#  111   RoBERTa_111   float32
#  112   RoBERTa_112   float32
#  113   RoBERTa_113   float32
#  114   RoBERTa_114   float32
#  115   RoBERTa_115   float32
#  116   RoBERTa_116   float32
#  117   RoBERTa_117   float32
#  118   RoBERTa_118   float32
#  119   RoBERTa_119   float32
#  120   RoBERTa_120   float32
#  121   RoBERTa_121   float32
#  122   RoBERTa_122   float32
#  123   RoBERTa_123   float32
#  124   RoBERTa_124   float32
#  125   RoBERTa_125   float32
#  126   RoBERTa_126   float32
#  127   RoBERTa_127   float32
#  128   RoBERTa_128   float32
#  129   RoBERTa_129   float32
#  130   RoBERTa_130   float32
#  131   RoBERTa_131   float32
#  132   RoBERTa_132   float32
#  133   RoBERTa_133   float32
#  134   RoBERTa_134   float32
#  135   RoBERTa_135   float32
#  136   RoBERTa_136   float32
#  137   RoBERTa_137   float32
#  138   RoBERTa_138   float32
#  139   RoBERTa_139   float32
#  140   RoBERTa_140   float32
#  141   RoBERTa_141   float32
#  142   RoBERTa_142   float32
#  143   RoBERTa_143   float32
#  144   RoBERTa_144   float32
#  145   RoBERTa_145   float32
#  146   RoBERTa_146   float32
#  147   RoBERTa_147   float32
#  148   RoBERTa_148   float32
#  149   RoBERTa_149   float32
#  150   RoBERTa_150   float32
#  151   RoBERTa_151   float32
#  152   RoBERTa_152   float32
#  153   RoBERTa_153   float32
#  154   RoBERTa_154   float32
#  155   RoBERTa_155   float32
#  156   RoBERTa_156   float32
#  157   RoBERTa_157   float32
#  158   RoBERTa_158   float32
#  159   RoBERTa_159   float32
#  160   RoBERTa_160   float32
#  161   RoBERTa_161   float32
#  162   RoBERTa_162   float32
#  163   RoBERTa_163   float32
#  164   RoBERTa_164   float32
#  165   RoBERTa_165   float32
#  166   RoBERTa_166   float32
#  167   RoBERTa_167   float32
#  168   RoBERTa_168   float32
#  169   RoBERTa_169   float32
#  170   RoBERTa_170   float32
#  171   RoBERTa_171   float32
#  172   RoBERTa_172   float32
#  173   RoBERTa_173   float32
#  174   RoBERTa_174   float32
#  175   RoBERTa_175   float32
#  176   RoBERTa_176   float32
#  177   RoBERTa_177   float32
#  178   RoBERTa_178   float32
#  179   RoBERTa_179   float32
#  180   RoBERTa_180   float32
#  181   RoBERTa_181   float32
#  182   RoBERTa_182   float32
#  183   RoBERTa_183   float32
#  184   RoBERTa_184   float32
#  185   RoBERTa_185   float32
#  186   RoBERTa_186   float32
#  187   RoBERTa_187   float32
#  188   RoBERTa_188   float32
#  189   RoBERTa_189   float32
#  190   RoBERTa_190   float32
#  191   RoBERTa_191   float32
#  192   RoBERTa_192   float32
#  193   RoBERTa_193   float32
#  194   RoBERTa_194   float32
#  195   RoBERTa_195   float32
#  196   RoBERTa_196   float32
#  197   RoBERTa_197   float32
#  198   RoBERTa_198   float32
#  199   RoBERTa_199   float32
#  200   RoBERTa_200   float32
#  201   RoBERTa_201   float32
#  202   RoBERTa_202   float32
#  203   RoBERTa_203   float32
#  204   RoBERTa_204   float32
#  205   RoBERTa_205   float32
#  206   RoBERTa_206   float32
#  207   RoBERTa_207   float32
#  208   RoBERTa_208   float32
#  209   RoBERTa_209   float32
#  210   RoBERTa_210   float32
#  211   RoBERTa_211   float32
#  212   RoBERTa_212   float32
#  213   RoBERTa_213   float32
#  214   RoBERTa_214   float32
#  215   RoBERTa_215   float32
#  216   RoBERTa_216   float32
#  217   RoBERTa_217   float32
#  218   RoBERTa_218   float32
#  219   RoBERTa_219   float32
#  220   RoBERTa_220   float32
#  221   RoBERTa_221   float32
#  222   RoBERTa_222   float32
#  223   RoBERTa_223   float32
#  224   RoBERTa_224   float32
#  225   RoBERTa_225   float32
#  226   RoBERTa_226   float32
#  227   RoBERTa_227   float32
#  228   RoBERTa_228   float32
#  229   RoBERTa_229   float32
#  230   RoBERTa_230   float32
#  231   RoBERTa_231   float32
#  232   RoBERTa_232   float32
#  233   RoBERTa_233   float32
#  234   RoBERTa_234   float32
#  235   RoBERTa_235   float32
#  236   RoBERTa_236   float32
#  237   RoBERTa_237   float32
#  238   RoBERTa_238   float32
#  239   RoBERTa_239   float32
#  240   RoBERTa_240   float32
#  241   RoBERTa_241   float32
#  242   RoBERTa_242   float32
#  243   RoBERTa_243   float32
#  244   RoBERTa_244   float32
#  245   RoBERTa_245   float32
#  246   RoBERTa_246   float32
#  247   RoBERTa_247   float32
#  248   RoBERTa_248   float32
#  249   RoBERTa_249   float32
#  250   RoBERTa_250   float32
#  251   RoBERTa_251   float32
#  252   RoBERTa_252   float32
#  253   RoBERTa_253   float32
#  254   RoBERTa_254   float32
#  255   RoBERTa_255   float32
#  256   RoBERTa_256   float32
#  257   RoBERTa_257   float32
#  258   RoBERTa_258   float32
#  259   RoBERTa_259   float32
#  260   RoBERTa_260   float32
#  261   RoBERTa_261   float32
#  262   RoBERTa_262   float32
#  263   RoBERTa_263   float32
#  264   RoBERTa_264   float32
#  265   RoBERTa_265   float32
#  266   RoBERTa_266   float32
#  267   RoBERTa_267   float32
#  268   RoBERTa_268   float32
#  269   RoBERTa_269   float32
#  270   RoBERTa_270   float32
#  271   RoBERTa_271   float32
#  272   RoBERTa_272   float32
#  273   RoBERTa_273   float32
#  274   RoBERTa_274   float32
#  275   RoBERTa_275   float32
#  276   RoBERTa_276   float32
#  277   RoBERTa_277   float32
#  278   RoBERTa_278   float32
#  279   RoBERTa_279   float32
#  280   RoBERTa_280   float32
#  281   RoBERTa_281   float32
#  282   RoBERTa_282   float32
#  283   RoBERTa_283   float32
#  284   RoBERTa_284   float32
#  285   RoBERTa_285   float32
#  286   RoBERTa_286   float32
#  287   RoBERTa_287   float32
#  288   RoBERTa_288   float32
#  289   RoBERTa_289   float32
#  290   RoBERTa_290   float32
#  291   RoBERTa_291   float32
#  292   RoBERTa_292   float32
#  293   RoBERTa_293   float32
#  294   RoBERTa_294   float32
#  295   RoBERTa_295   float32
#  296   RoBERTa_296   float32
#  297   RoBERTa_297   float32
#  298   RoBERTa_298   float32
#  299   RoBERTa_299   float32
#  300   RoBERTa_300   float32
#  301   RoBERTa_301   float32
#  302   RoBERTa_302   float32
#  303   RoBERTa_303   float32
#  304   RoBERTa_304   float32
#  305   RoBERTa_305   float32
#  306   RoBERTa_306   float32
#  307   RoBERTa_307   float32
#  308   RoBERTa_308   float32
#  309   RoBERTa_309   float32
#  310   RoBERTa_310   float32
#  311   RoBERTa_311   float32
#  312   RoBERTa_312   float32
#  313   RoBERTa_313   float32
#  314   RoBERTa_314   float32
#  315   RoBERTa_315   float32
#  316   RoBERTa_316   float32
#  317   RoBERTa_317   float32
#  318   RoBERTa_318   float32
#  319   RoBERTa_319   float32
#  320   RoBERTa_320   float32
#  321   RoBERTa_321   float32
#  322   RoBERTa_322   float32
#  323   RoBERTa_323   float32
#  324   RoBERTa_324   float32
#  325   RoBERTa_325   float32
#  326   RoBERTa_326   float32
#  327   RoBERTa_327   float32
#  328   RoBERTa_328   float32
#  329   RoBERTa_329   float32
#  330   RoBERTa_330   float32
#  331   RoBERTa_331   float32
#  332   RoBERTa_332   float32
#  333   RoBERTa_333   float32
#  334   RoBERTa_334   float32
#  335   RoBERTa_335   float32
#  336   RoBERTa_336   float32
#  337   RoBERTa_337   float32
#  338   RoBERTa_338   float32
#  339   RoBERTa_339   float32
#  340   RoBERTa_340   float32
#  341   RoBERTa_341   float32
#  342   RoBERTa_342   float32
#  343   RoBERTa_343   float32
#  344   RoBERTa_344   float32
#  345   RoBERTa_345   float32
#  346   RoBERTa_346   float32
#  347   RoBERTa_347   float32
#  348   RoBERTa_348   float32
#  349   RoBERTa_349   float32
#  350   RoBERTa_350   float32
#  351   RoBERTa_351   float32
#  352   RoBERTa_352   float32
#  353   RoBERTa_353   float32
#  354   RoBERTa_354   float32
#  355   RoBERTa_355   float32
#  356   RoBERTa_356   float32
#  357   RoBERTa_357   float32
#  358   RoBERTa_358   float32
#  359   RoBERTa_359   float32
#  360   RoBERTa_360   float32
#  361   RoBERTa_361   float32
#  362   RoBERTa_362   float32
#  363   RoBERTa_363   float32
#  364   RoBERTa_364   float32
#  365   RoBERTa_365   float32
#  366   RoBERTa_366   float32
#  367   RoBERTa_367   float32
#  368   RoBERTa_368   float32
#  369   RoBERTa_369   float32
#  370   RoBERTa_370   float32
#  371   RoBERTa_371   float32
#  372   RoBERTa_372   float32
#  373   RoBERTa_373   float32
#  374   RoBERTa_374   float32
#  375   RoBERTa_375   float32
#  376   RoBERTa_376   float32
#  377   RoBERTa_377   float32
#  378   RoBERTa_378   float32
#  379   RoBERTa_379   float32
#  380   RoBERTa_380   float32
#  381   RoBERTa_381   float32
#  382   RoBERTa_382   float32
#  383   RoBERTa_383   float32
#  384   RoBERTa_384   float32
#  385   RoBERTa_385   float32
#  386   RoBERTa_386   float32
#  387   RoBERTa_387   float32
#  388   RoBERTa_388   float32
#  389   RoBERTa_389   float32
#  390   RoBERTa_390   float32
#  391   RoBERTa_391   float32
#  392   RoBERTa_392   float32
#  393   RoBERTa_393   float32
#  394   RoBERTa_394   float32
#  395   RoBERTa_395   float32
#  396   RoBERTa_396   float32
#  397   RoBERTa_397   float32
#  398   RoBERTa_398   float32
#  399   RoBERTa_399   float32
#  400   RoBERTa_400   float32
#  401   RoBERTa_401   float32
#  402   RoBERTa_402   float32
#  403   RoBERTa_403   float32
#  404   RoBERTa_404   float32
#  405   RoBERTa_405   float32
#  406   RoBERTa_406   float32
#  407   RoBERTa_407   float32
#  408   RoBERTa_408   float32
#  409   RoBERTa_409   float32
#  410   RoBERTa_410   float32
#  411   RoBERTa_411   float32
#  412   RoBERTa_412   float32
#  413   RoBERTa_413   float32
#  414   RoBERTa_414   float32
#  415   RoBERTa_415   float32
#  416   RoBERTa_416   float32
#  417   RoBERTa_417   float32
#  418   RoBERTa_418   float32
#  419   RoBERTa_419   float32
#  420   RoBERTa_420   float32
#  421   RoBERTa_421   float32
#  422   RoBERTa_422   float32
#  423   RoBERTa_423   float32
#  424   RoBERTa_424   float32
#  425   RoBERTa_425   float32
#  426   RoBERTa_426   float32
#  427   RoBERTa_427   float32
#  428   RoBERTa_428   float32
#  429   RoBERTa_429   float32
#  430   RoBERTa_430   float32
#  431   RoBERTa_431   float32
#  432   RoBERTa_432   float32
#  433   RoBERTa_433   float32
#  434   RoBERTa_434   float32
#  435   RoBERTa_435   float32
#  436   RoBERTa_436   float32
#  437   RoBERTa_437   float32
#  438   RoBERTa_438   float32
#  439   RoBERTa_439   float32
#  440   RoBERTa_440   float32
#  441   RoBERTa_441   float32
#  442   RoBERTa_442   float32
#  443   RoBERTa_443   float32
#  444   RoBERTa_444   float32
#  445   RoBERTa_445   float32
#  446   RoBERTa_446   float32
#  447   RoBERTa_447   float32
#  448   RoBERTa_448   float32
#  449   RoBERTa_449   float32
#  450   RoBERTa_450   float32
#  451   RoBERTa_451   float32
#  452   RoBERTa_452   float32
#  453   RoBERTa_453   float32
#  454   RoBERTa_454   float32
#  455   RoBERTa_455   float32
#  456   RoBERTa_456   float32
#  457   RoBERTa_457   float32
#  458   RoBERTa_458   float32
#  459   RoBERTa_459   float32
#  460   RoBERTa_460   float32
#  461   RoBERTa_461   float32
#  462   RoBERTa_462   float32
#  463   RoBERTa_463   float32
#  464   RoBERTa_464   float32
#  465   RoBERTa_465   float32
#  466   RoBERTa_466   float32
#  467   RoBERTa_467   float32
#  468   RoBERTa_468   float32
#  469   RoBERTa_469   float32
#  470   RoBERTa_470   float32
#  471   RoBERTa_471   float32
#  472   RoBERTa_472   float32
#  473   RoBERTa_473   float32
#  474   RoBERTa_474   float32
#  475   RoBERTa_475   float32
#  476   RoBERTa_476   float32
#  477   RoBERTa_477   float32
#  478   RoBERTa_478   float32
#  479   RoBERTa_479   float32
#  480   RoBERTa_480   float32
#  481   RoBERTa_481   float32
#  482   RoBERTa_482   float32
#  483   RoBERTa_483   float32
#  484   RoBERTa_484   float32
#  485   RoBERTa_485   float32
#  486   RoBERTa_486   float32
#  487   RoBERTa_487   float32
#  488   RoBERTa_488   float32
#  489   RoBERTa_489   float32
#  490   RoBERTa_490   float32
#  491   RoBERTa_491   float32
#  492   RoBERTa_492   float32
#  493   RoBERTa_493   float32
#  494   RoBERTa_494   float32
#  495   RoBERTa_495   float32
#  496   RoBERTa_496   float32
#  497   RoBERTa_497   float32
#  498   RoBERTa_498   float32
#  499   RoBERTa_499   float32
#  500   RoBERTa_500   float32
#  501   RoBERTa_501   float32
#  502   RoBERTa_502   float32
#  503   RoBERTa_503   float32
#  504   RoBERTa_504   float32
#  505   RoBERTa_505   float32
#  506   RoBERTa_506   float32
#  507   RoBERTa_507   float32
#  508   RoBERTa_508   float32
#  509   RoBERTa_509   float32
#  510   RoBERTa_510   float32
#  511   RoBERTa_511   float32
#  512   RoBERTa_512   float32
#  513   RoBERTa_513   float32
#  514   RoBERTa_514   float32
#  515   RoBERTa_515   float32
#  516   RoBERTa_516   float32
#  517   RoBERTa_517   float32
#  518   RoBERTa_518   float32
#  519   RoBERTa_519   float32
#  520   RoBERTa_520   float32
#  521   RoBERTa_521   float32
#  522   RoBERTa_522   float32
#  523   RoBERTa_523   float32
#  524   RoBERTa_524   float32
#  525   RoBERTa_525   float32
#  526   RoBERTa_526   float32
#  527   RoBERTa_527   float32
#  528   RoBERTa_528   float32
#  529   RoBERTa_529   float32
#  530   RoBERTa_530   float32
#  531   RoBERTa_531   float32
#  532   RoBERTa_532   float32
#  533   RoBERTa_533   float32
#  534   RoBERTa_534   float32
#  535   RoBERTa_535   float32
#  536   RoBERTa_536   float32
#  537   RoBERTa_537   float32
#  538   RoBERTa_538   float32
#  539   RoBERTa_539   float32
#  540   RoBERTa_540   float32
#  541   RoBERTa_541   float32
#  542   RoBERTa_542   float32
#  543   RoBERTa_543   float32
#  544   RoBERTa_544   float32
#  545   RoBERTa_545   float32
#  546   RoBERTa_546   float32
#  547   RoBERTa_547   float32
#  548   RoBERTa_548   float32
#  549   RoBERTa_549   float32
#  550   RoBERTa_550   float32
#  551   RoBERTa_551   float32
#  552   RoBERTa_552   float32
#  553   RoBERTa_553   float32
#  554   RoBERTa_554   float32
#  555   RoBERTa_555   float32
#  556   RoBERTa_556   float32
#  557   RoBERTa_557   float32
#  558   RoBERTa_558   float32
#  559   RoBERTa_559   float32
#  560   RoBERTa_560   float32
#  561   RoBERTa_561   float32
#  562   RoBERTa_562   float32
#  563   RoBERTa_563   float32
#  564   RoBERTa_564   float32
#  565   RoBERTa_565   float32
#  566   RoBERTa_566   float32
#  567   RoBERTa_567   float32
#  568   RoBERTa_568   float32
#  569   RoBERTa_569   float32
#  570   RoBERTa_570   float32
#  571   RoBERTa_571   float32
#  572   RoBERTa_572   float32
#  573   RoBERTa_573   float32
#  574   RoBERTa_574   float32
#  575   RoBERTa_575   float32
#  576   RoBERTa_576   float32
#  577   RoBERTa_577   float32
#  578   RoBERTa_578   float32
#  579   RoBERTa_579   float32
#  580   RoBERTa_580   float32
#  581   RoBERTa_581   float32
#  582   RoBERTa_582   float32
#  583   RoBERTa_583   float32
#  584   RoBERTa_584   float32
#  585   RoBERTa_585   float32
#  586   RoBERTa_586   float32
#  587   RoBERTa_587   float32
#  588   RoBERTa_588   float32
#  589   RoBERTa_589   float32
#  590   RoBERTa_590   float32
#  591   RoBERTa_591   float32
#  592   RoBERTa_592   float32
#  593   RoBERTa_593   float32
#  594   RoBERTa_594   float32
#  595   RoBERTa_595   float32
#  596   RoBERTa_596   float32
#  597   RoBERTa_597   float32
#  598   RoBERTa_598   float32
#  599   RoBERTa_599   float32
#  600   RoBERTa_600   float32
#  601   RoBERTa_601   float32
#  602   RoBERTa_602   float32
#  603   RoBERTa_603   float32
#  604   RoBERTa_604   float32
#  605   RoBERTa_605   float32
#  606   RoBERTa_606   float32
#  607   RoBERTa_607   float32
#  608   RoBERTa_608   float32
#  609   RoBERTa_609   float32
#  610   RoBERTa_610   float32
#  611   RoBERTa_611   float32
#  612   RoBERTa_612   float32
#  613   RoBERTa_613   float32
#  614   RoBERTa_614   float32
#  615   RoBERTa_615   float32
#  616   RoBERTa_616   float32
#  617   RoBERTa_617   float32
#  618   RoBERTa_618   float32
#  619   RoBERTa_619   float32
#  620   RoBERTa_620   float32
#  621   RoBERTa_621   float32
#  622   RoBERTa_622   float32
#  623   RoBERTa_623   float32
#  624   RoBERTa_624   float32
#  625   RoBERTa_625   float32
#  626   RoBERTa_626   float32
#  627   RoBERTa_627   float32
#  628   RoBERTa_628   float32
#  629   RoBERTa_629   float32
#  630   RoBERTa_630   float32
#  631   RoBERTa_631   float32
#  632   RoBERTa_632   float32
#  633   RoBERTa_633   float32
#  634   RoBERTa_634   float32
#  635   RoBERTa_635   float32
#  636   RoBERTa_636   float32
#  637   RoBERTa_637   float32
#  638   RoBERTa_638   float32
#  639   RoBERTa_639   float32
#  640   RoBERTa_640   float32
#  641   RoBERTa_641   float32
#  642   RoBERTa_642   float32
#  643   RoBERTa_643   float32
#  644   RoBERTa_644   float32
#  645   RoBERTa_645   float32
#  646   RoBERTa_646   float32
#  647   RoBERTa_647   float32
#  648   RoBERTa_648   float32
#  649   RoBERTa_649   float32
#  650   RoBERTa_650   float32
#  651   RoBERTa_651   float32
#  652   RoBERTa_652   float32
#  653   RoBERTa_653   float32
#  654   RoBERTa_654   float32
#  655   RoBERTa_655   float32
#  656   RoBERTa_656   float32
#  657   RoBERTa_657   float32
#  658   RoBERTa_658   float32
#  659   RoBERTa_659   float32
#  660   RoBERTa_660   float32
#  661   RoBERTa_661   float32
#  662   RoBERTa_662   float32
#  663   RoBERTa_663   float32
#  664   RoBERTa_664   float32
#  665   RoBERTa_665   float32
#  666   RoBERTa_666   float32
#  667   RoBERTa_667   float32
#  668   RoBERTa_668   float32
#  669   RoBERTa_669   float32
#  670   RoBERTa_670   float32
#  671   RoBERTa_671   float32
#  672   RoBERTa_672   float32
#  673   RoBERTa_673   float32
#  674   RoBERTa_674   float32
#  675   RoBERTa_675   float32
#  676   RoBERTa_676   float32
#  677   RoBERTa_677   float32
#  678   RoBERTa_678   float32
#  679   RoBERTa_679   float32
#  680   RoBERTa_680   float32
#  681   RoBERTa_681   float32
#  682   RoBERTa_682   float32
#  683   RoBERTa_683   float32
#  684   RoBERTa_684   float32
#  685   RoBERTa_685   float32
#  686   RoBERTa_686   float32
#  687   RoBERTa_687   float32
#  688   RoBERTa_688   float32
#  689   RoBERTa_689   float32
#  690   RoBERTa_690   float32
#  691   RoBERTa_691   float32
#  692   RoBERTa_692   float32
#  693   RoBERTa_693   float32
#  694   RoBERTa_694   float32
#  695   RoBERTa_695   float32
#  696   RoBERTa_696   float32
#  697   RoBERTa_697   float32
#  698   RoBERTa_698   float32
#  699   RoBERTa_699   float32
#  700   RoBERTa_700   float32
#  701   RoBERTa_701   float32
#  702   RoBERTa_702   float32
#  703   RoBERTa_703   float32
#  704   RoBERTa_704   float32
#  705   RoBERTa_705   float32
#  706   RoBERTa_706   float32
#  707   RoBERTa_707   float32
#  708   RoBERTa_708   float32
#  709   RoBERTa_709   float32
#  710   RoBERTa_710   float32
#  711   RoBERTa_711   float32
#  712   RoBERTa_712   float32
#  713   RoBERTa_713   float32
#  714   RoBERTa_714   float32
#  715   RoBERTa_715   float32
#  716   RoBERTa_716   float32
#  717   RoBERTa_717   float32
#  718   RoBERTa_718   float32
#  719   RoBERTa_719   float32
#  720   RoBERTa_720   float32
#  721   RoBERTa_721   float32
#  722   RoBERTa_722   float32
#  723   RoBERTa_723   float32
#  724   RoBERTa_724   float32
#  725   RoBERTa_725   float32
#  726   RoBERTa_726   float32
#  727   RoBERTa_727   float32
#  728   RoBERTa_728   float32
#  729   RoBERTa_729   float32
#  730   RoBERTa_730   float32
#  731   RoBERTa_731   float32
#  732   RoBERTa_732   float32
#  733   RoBERTa_733   float32
#  734   RoBERTa_734   float32
#  735   RoBERTa_735   float32
#  736   RoBERTa_736   float32
#  737   RoBERTa_737   float32
#  738   RoBERTa_738   float32
#  739   RoBERTa_739   float32
#  740   RoBERTa_740   float32
#  741   RoBERTa_741   float32
#  742   RoBERTa_742   float32
#  743   RoBERTa_743   float32
#  744   RoBERTa_744   float32
#  745   RoBERTa_745   float32
#  746   RoBERTa_746   float32
#  747   RoBERTa_747   float32
#  748   RoBERTa_748   float32
#  749   RoBERTa_749   float32
#  750   RoBERTa_750   float32
#  751   RoBERTa_751   float32
#  752   RoBERTa_752   float32
#  753   RoBERTa_753   float32
#  754   RoBERTa_754   float32
#  755   RoBERTa_755   float32
#  756   RoBERTa_756   float32
#  757   RoBERTa_757   float32
#  758   RoBERTa_758   float32
#  759   RoBERTa_759   float32
#  760   RoBERTa_760   float32
#  761   RoBERTa_761   float32
#  762   RoBERTa_762   float32
#  763   RoBERTa_763   float32
#  764   RoBERTa_764   float32
#  765   RoBERTa_765   float32
#  766   RoBERTa_766   float32
#  767   RoBERTa_767   float32
#  768   RoBERTa_768   float32
#  769   RoBERTa_769   float32
#  770   RoBERTa_770   float32
#  771   RoBERTa_771   float32
#  772   RoBERTa_772   float32
#  773   RoBERTa_773   float32
#  774   RoBERTa_774   float32
#  775   RoBERTa_775   float32
#  776   RoBERTa_776   float32
#  777   RoBERTa_777   float32
#  778   RoBERTa_778   float32
#  779   RoBERTa_779   float32
#  780   RoBERTa_780   float32
#  781   RoBERTa_781   float32
#  782   RoBERTa_782   float32
#  783   RoBERTa_783   float32
#  784   RoBERTa_784   float32
#  785   RoBERTa_785   float32
#  786   RoBERTa_786   float32
#  787   RoBERTa_787   float32
#  788   RoBERTa_788   float32
#  789   RoBERTa_789   float32
#  790   RoBERTa_790   float32
#  791   RoBERTa_791   float32
#  792   RoBERTa_792   float32
#  793   RoBERTa_793   float32
#  794   RoBERTa_794   float32
#  795   RoBERTa_795   float32
#  796   RoBERTa_796   float32
#  797   RoBERTa_797   float32
#  798   RoBERTa_798   float32
#  799   RoBERTa_799   float32
#  800   RoBERTa_800   float32
#  801   RoBERTa_801   float32
#  802   RoBERTa_802   float32
#  803   RoBERTa_803   float32
#  804   RoBERTa_804   float32
#  805   RoBERTa_805   float32
#  806   RoBERTa_806   float32
#  807   RoBERTa_807   float32
#  808   RoBERTa_808   float32
#  809   RoBERTa_809   float32
#  810   RoBERTa_810   float32
#  811   RoBERTa_811   float32
#  812   RoBERTa_812   float32
#  813   RoBERTa_813   float32
#  814   RoBERTa_814   float32
#  815   RoBERTa_815   float32
#  816   RoBERTa_816   float32
#  817   RoBERTa_817   float32
#  818   RoBERTa_818   float32
#  819   RoBERTa_819   float32
#  820   RoBERTa_820   float32
#  821   RoBERTa_821   float32
#  822   RoBERTa_822   float32
#  823   RoBERTa_823   float32
#  824   RoBERTa_824   float32
#  825   RoBERTa_825   float32
#  826   RoBERTa_826   float32
#  827   RoBERTa_827   float32
#  828   RoBERTa_828   float32
#  829   RoBERTa_829   float32
#  830   RoBERTa_830   float32
#  831   RoBERTa_831   float32
#  832   RoBERTa_832   float32
#  833   RoBERTa_833   float32
#  834   RoBERTa_834   float32
#  835   RoBERTa_835   float32
#  836   RoBERTa_836   float32
#  837   RoBERTa_837   float32
#  838   RoBERTa_838   float32
#  839   RoBERTa_839   float32
#  840   RoBERTa_840   float32
#  841   RoBERTa_841   float32
#  842   RoBERTa_842   float32
#  843   RoBERTa_843   float32
#  844   RoBERTa_844   float32
#  845   RoBERTa_845   float32
#  846   RoBERTa_846   float32
#  847   RoBERTa_847   float32
#  848   RoBERTa_848   float32
#  849   RoBERTa_849   float32
#  850   RoBERTa_850   float32
#  851   RoBERTa_851   float32
#  852   RoBERTa_852   float32
#  853   RoBERTa_853   float32
#  854   RoBERTa_854   float32
#  855   RoBERTa_855   float32
#  856   RoBERTa_856   float32
#  857   RoBERTa_857   float32
#  858   RoBERTa_858   float32
#  859   RoBERTa_859   float32
#  860   RoBERTa_860   float32
#  861   RoBERTa_861   float32
#  862   RoBERTa_862   float32
#  863   RoBERTa_863   float32
#  864   RoBERTa_864   float32
#  865   RoBERTa_865   float32
#  866   RoBERTa_866   float32
#  867   RoBERTa_867   float32
#  868   RoBERTa_868   float32
#  869   RoBERTa_869   float32
#  870   RoBERTa_870   float32
#  871   RoBERTa_871   float32
#  872   RoBERTa_872   float32
#  873   RoBERTa_873   float32
#  874   RoBERTa_874   float32
#  875   RoBERTa_875   float32
#  876   RoBERTa_876   float32
#  877   RoBERTa_877   float32
#  878   RoBERTa_878   float32
#  879   RoBERTa_879   float32
#  880   RoBERTa_880   float32
#  881   RoBERTa_881   float32
#  882   RoBERTa_882   float32
#  883   RoBERTa_883   float32
#  884   RoBERTa_884   float32
#  885   RoBERTa_885   float32
#  886   RoBERTa_886   float32
#  887   RoBERTa_887   float32
#  888   RoBERTa_888   float32
#  889   RoBERTa_889   float32
#  890   RoBERTa_890   float32
#  891   RoBERTa_891   float32
#  892   RoBERTa_892   float32
#  893   RoBERTa_893   float32
#  894   RoBERTa_894   float32
#  895   RoBERTa_895   float32
#  896   RoBERTa_896   float32
#  897   RoBERTa_897   float32
#  898   RoBERTa_898   float32
#  899   RoBERTa_899   float32
#  900   RoBERTa_900   float32
#  901   RoBERTa_901   float32
#  902   RoBERTa_902   float32
#  903   RoBERTa_903   float32
#  904   RoBERTa_904   float32
#  905   RoBERTa_905   float32
#  906   RoBERTa_906   float32
#  907   RoBERTa_907   float32
#  908   RoBERTa_908   float32
#  909   RoBERTa_909   float32
#  910   RoBERTa_910   float32
#  911   RoBERTa_911   float32
#  912   RoBERTa_912   float32
#  913   RoBERTa_913   float32
#  914   RoBERTa_914   float32
#  915   RoBERTa_915   float32
#  916   RoBERTa_916   float32
#  917   RoBERTa_917   float32
#  918   RoBERTa_918   float32
#  919   RoBERTa_919   float32
#  920   RoBERTa_920   float32
#  921   RoBERTa_921   float32
#  922   RoBERTa_922   float32
#  923   RoBERTa_923   float32
#  924   RoBERTa_924   float32
#  925   RoBERTa_925   float32
#  926   RoBERTa_926   float32
#  927   RoBERTa_927   float32
#  928   RoBERTa_928   float32
#  929   RoBERTa_929   float32
#  930   RoBERTa_930   float32
#  931   RoBERTa_931   float32
#  932   RoBERTa_932   float32
#  933   RoBERTa_933   float32
#  934   RoBERTa_934   float32
#  935   RoBERTa_935   float32
#  936   RoBERTa_936   float32
#  937   RoBERTa_937   float32
#  938   RoBERTa_938   float32
#  939   RoBERTa_939   float32
#  940   RoBERTa_940   float32
#  941   RoBERTa_941   float32
#  942   RoBERTa_942   float32
#  943   RoBERTa_943   float32
#  944   RoBERTa_944   float32
#  945   RoBERTa_945   float32
#  946   RoBERTa_946   float32
#  947   RoBERTa_947   float32
#  948   RoBERTa_948   float32
#  949   RoBERTa_949   float32
#  950   RoBERTa_950   float32
#  951   RoBERTa_951   float32
#  952   RoBERTa_952   float32
#  953   RoBERTa_953   float32
#  954   RoBERTa_954   float32
#  955   RoBERTa_955   float32
#  956   RoBERTa_956   float32
#  957   RoBERTa_957   float32
#  958   RoBERTa_958   float32
#  959   RoBERTa_959   float32
#  960   RoBERTa_960   float32
#  961   RoBERTa_961   float32
#  962   RoBERTa_962   float32
#  963   RoBERTa_963   float32
#  964   RoBERTa_964   float32
#  965   RoBERTa_965   float32
#  966   RoBERTa_966   float32
#  967   RoBERTa_967   float32
#  968   RoBERTa_968   float32
#  969   RoBERTa_969   float32
#  970   RoBERTa_970   float32
#  971   RoBERTa_971   float32
#  972   RoBERTa_972   float32
#  973   RoBERTa_973   float32
#  974   RoBERTa_974   float32
#  975   RoBERTa_975   float32
#  976   RoBERTa_976   float32
#  977   RoBERTa_977   float32
#  978   RoBERTa_978   float32
#  979   RoBERTa_979   float32
#  980   RoBERTa_980   float32
#  981   RoBERTa_981   float32
#  982   RoBERTa_982   float32
#  983   RoBERTa_983   float32
#  984   RoBERTa_984   float32
#  985   RoBERTa_985   float32
#  986   RoBERTa_986   float32
#  987   RoBERTa_987   float32
#  988   RoBERTa_988   float32
#  989   RoBERTa_989   float32
#  990   RoBERTa_990   float32
#  991   RoBERTa_991   float32
#  992   RoBERTa_992   float32
#  993   RoBERTa_993   float32
#  994   RoBERTa_994   float32
#  995   RoBERTa_995   float32
#  996   RoBERTa_996   float32
#  997   RoBERTa_997   float32
#  998   RoBERTa_998   float32
#  999   RoBERTa_999   float32
#  1000  RoBERTa_1000  float32
#  1001  RoBERTa_1001  float32
#  1002  RoBERTa_1002  float32
#  1003  RoBERTa_1003  float32
#  1004  RoBERTa_1004  float32
#  1005  RoBERTa_1005  float32
#  1006  RoBERTa_1006  float32
#  1007  RoBERTa_1007  float32
#  1008  RoBERTa_1008  float32
#  1009  RoBERTa_1009  float32
#  1010  RoBERTa_1010  float32
#  1011  RoBERTa_1011  float32
#  1012  RoBERTa_1012  float32
#  1013  RoBERTa_1013  float32
#  1014  RoBERTa_1014  float32
#  1015  RoBERTa_1015  float32
#  1016  RoBERTa_1016  float32
#  1017  RoBERTa_1017  float32
#  1018  RoBERTa_1018  float32
#  1019  RoBERTa_1019  float32
#  1020  RoBERTa_1020  float32
#  1021  RoBERTa_1021  float32
#  1022  RoBERTa_1022  float32
#  1023  RoBERTa_1023  float32
#  1024  Company       object
#  1025  Date          object
#  1026  Sentence_num  int64
# dtypes: float32(1024), int64(1), object(2)
# memory usage: 352.5+ MB

# %% [markdown]
# # Repeat with MACE

# %%
MACE_RoBERTa_features = pd.DataFrame()
MACE_RoBERTa_error = []
for Ticker, Date in tqdm(MAEC_filename_data[['Ticker', 'Date']].values):
    Date = Date.replace('-', '')
    text_path = f"D:/MAEC_audio/{Date}_{Ticker}/text.txt"
    try:
        with open(text_path, 'r', encoding='utf-8', errors='replace') as file:
            for i, line in enumerate(file, start=1):
                sentence_embedding = get_RoBERTa(line.strip())
                # 1024 features 
                features_df = pd.DataFrame(sentence_embedding, columns=[f'RoBERTa_{j}' for j in range(1024)])
                features_df['Ticker'] = Ticker
                features_df['Date'] = Date
                features_df['Sentence_num'] = i
                MACE_RoBERTa_features = pd.concat([MACE_RoBERTa_features, features_df], ignore_index=True)
    except KeyboardInterrupt: break
    except Exception as e:
        MACE_RoBERTa_error.append((Company, Date, str(e)))

print(len(MACE_RoBERTa_error))
print(MACE_RoBERTa_error)
# Out:
#  28%|██▊       | 977/3443 [1:45:21<5:22:24,  7.84s/it]

# %%
MACE_RoBERTa_features.info(verbose=True)
###############################################
MACE_RoBERTa_features.to_csv('data/data_prep/MACE_RoBERTa_features.csv', index=False)
###############################################
